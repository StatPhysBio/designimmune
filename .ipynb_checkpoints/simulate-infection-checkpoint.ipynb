# %% [markdown]
# # Run infection dynamics with monoclonal killer T cell response

# %%
import numpy as np
from matplotlib.cm import get_cmap
import matplotlib.pyplot as plt
import matplotlib as mpl

import multiprocessing as mp
from tqdm import tqdm
from joblib import Parallel, delayed
from scipy import stats
import os
from stoch_sim_model import *
from optimize_nets import *
import seaborn as sns

plt.style.use('custom.mplstyle')
# %config InlineBackend.figure_format = 'retina'
# %load_ext line_profiler

# %%
avg_sim_time = 1.75/(60*60)

print('full-reg:',(len(psi_2d_nobias)**4)*len(vir_prop_select),
      np.ceil((len(psi_2d_nobias)**4*len(vir_prop_select))/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('prim-Nact-Ediv:',len(psi_2d)*len(psi_2d)*len(vir_prop_select), 
      np.ceil((len(psi_2d)*len(psi_2d)*len(vir_prop_select))/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('auto-sparse-reg:',len(psi_2d_sparse)*4, 
      np.ceil((len(psi_2d_sparse)*4)/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('sparse-reg:', len(psi_2d_sparse)*len(vir_prop_select),
      np.ceil(len(psi_2d_sparse)*len(vir_prop_select)/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')
# Out:
# full-reg: 2367144300 11507.0 2057 jobs per cpu per hour
# prim-Nact-Ediv: 21067500 103.0 2057 jobs per cpu per hour
# auto-sparse-reg: 1250000 7.0 2057 jobs per cpu per hour
# sparse-reg: 93750000 456.0 2057 jobs per cpu per hour

# %% [markdown]
# ### (1) Plot population averaged trajectories

# %%
# Set simulation parameters
N_0 = 300
K_IE = (1)*(10**6)
d_I = 125*d_S
b_I = 2.0*(10**(-7))

infection_type = "prim" #"prim", "sec"
vir_model = 'indep_harm' #'indep_harm
NE_regulation = [psi_max/2, psi_max/2, 0.0*psi_max/2, 0.5*psi_max]
EM_regulation = [-1.0*psi_max/2, -1.0*psi_max/2, 0.0*psi_max/2, -0.5*psi_max]
Na_regulation = [psi_max/2, psi_max/2, 0, 0]
EE_regulation = [psi_max/2, psi_max/2, 0, 0]

# %%
# %lprun -T lprof0 -f lin_stoch_sim lin_stoch_sim(N_0 = 300, b_I = b_I, K_IE = 100*K_IE, d_I = d_I, K_EH = 10*K_EH, \
                                                NE_regulation = NE_regulation, \
                                                EM_regulation = EM_regulation, \
                                                activation_regulation = Na_regulation, \
                                                expansion_regulation = EE_regulation)
# Out:
# *** Profile printout saved to text file 'lprof0'.
# Timer unit: 1e-09 s
#
# Total time: 0.722122 s
# File: /mmfs1/home/oukogu/infoimmune/stoch_sim_model.py
# Function: lin_stoch_sim at line 138
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    138                                           def lin_stoch_sim(S_0 = S_0, I_0 = I_0, b_I = b_I, d_S = d_S, d_I = d_I, d_IE = d_IE, K_IE = K_IE, K_SE = K_SE,
#    139                                                               b_H = b_H, d_H = d_H, K_EH = K_EH,
#    140                                                               N_0 = N_0, max_Na = max_Na, b_myc = b_myc, d_myc = d_myc, myc_thresh = myc_thresh, max_expand = max_expand,
#    141                                                               char_times = [t_bind, t_unbind, t_Na_div, t_E_div, t_M_div, t_E_die, t_act],
#    142                                                               NE_regulation = NE_psis,
#    143                                                               EM_regulation = EM_psis,
#    144                                                               activation_regulation = act_psis,
#    145                                                               expansion_regulation = exp_psis,
#    146                                                               infection = "prim",
#    147                                                               vir_model = "indep_harm",
#    148                                                               duration = sim_duration,
#    149                                                               steps = sim_steps,
#    150                                                               reg_model = "mwc_like",
#    151                                                               out_data = "small"):
#    152
#    153                                               # VARIABLE DEFINITIONS:
#    154                                               # S_0 := S_0, I_0 := I_0, b_S := b_S, b_I := b_I, d_S := d_S, d_I := d_I, d_IE := d_IE, K_IE := K_IE,
#    155                                               # b_H := b_H, d_H := d_H, K_EH := K_EH,
#    156                                               # N_0 := N_0, max_Na := max_Na, b_myc := b_myc, d_myc := d_myc, myc_thresh := myc_thresh,
#    157                                               # char_times := [t_bind, t_unbind, t_Na_div, t_E_div, t_M_div, t_EM_diff, t_E_die, t_Nact],
#    158
#    159                                               #################################
#    160                                               ### SET META-VARIABLES FOR SIMULATION ###
#    161                                               #################################
#    162         1       1261.0   1261.0      0.0      dt =  duration/steps
#    163         1        731.0    731.0      0.0      N_0_var = int(N_0)
#    164         1        201.0    201.0      0.0      b_S = S_0*d_S
#    165
#    166                                               # draw population of reponding cells for agent-based simulations
#    167         1       1092.0   1092.0      0.0      psi_Nact_I, psi_Nact_H, psi_Nact_P, F0_Nact = activation_regulation[0], activation_regulation[1], activation_regulation[2], activation_regulation[3]
#    168         1        951.0    951.0      0.0      psi_NE_I, psi_NE_H, psi_NE_P, F0_NE = NE_regulation[0], NE_regulation[1], NE_regulation[2], NE_regulation[3]
#    169         1        701.0    701.0      0.0      psi_EM_I, psi_EM_H, psi_EM_P, F0_EM = EM_regulation[0], EM_regulation[1], EM_regulation[2], EM_regulation[3]
#    170         1        851.0    851.0      0.0      psi_Ediv_I, psi_Ediv_H, psi_Ediv_P, F0_Ediv = expansion_regulation[0], expansion_regulation[1], expansion_regulation[2], expansion_regulation[3]
#    171
#    172         1        120.0    120.0      0.0      p_tcr = 1.0 #np.ones(N_0_var)
#    173         1        240.0    240.0      0.0      p_cyt = 1.0 #np.ones(N_0_var)
#    174
#    175                                               # define variables for storage
#    176         1      11687.0  11687.0      0.0      I = np.zeros(int(steps)+1)
#    177         1       5618.0   5618.0      0.0      S = np.zeros(int(steps)+1)
#    178         1     301881.0 301881.0      0.0      V = np.zeros(int(steps)+1)
#    179         1       5959.0   5959.0      0.0      H = np.zeros(int(steps)+1)
#    180         1      55053.0  55053.0      0.0      P = np.zeros(int(steps)+1)
#    181         1       3185.0   3185.0      0.0      I_d_I = np.zeros(int(steps)+1)
#    182         1      26980.0  26980.0      0.0      I_d_S = np.zeros(int(steps)+1)
#    183         1       5348.0   5348.0      0.0      I_d_IE = np.zeros(int(steps)+1)
#    184         1      64186.0  64186.0      0.0      I_d_SE = np.zeros(int(steps)+1)
#    185
#    186         1     133980.0 133980.0      0.0      N_m = np.zeros((int(steps)+1, N_0_var), dtype = np.int32)
#    187         1      36454.0  36454.0      0.0      N_m[0,:] +=1
#    188         1      63605.0  63605.0      0.0      T_Ecyt = [[] for i in np.arange(0, N_0_var)]
#    189                                               # T_Ecyt = np.zeros(int(steps)+1, dtype = np.int32)
#    190
#    191         1      15282.0  15282.0      0.0      div_count = np.ones(N_0_var)
#    192         1       3736.0   3736.0      0.0      div_E_count = np.ones(N_0_var)
#    193         1       2664.0   2664.0      0.0      div_M_count = np.ones(N_0_var)
#    194         1       1182.0   1182.0      0.0      diff_EpM_count = np.zeros(N_0_var, dtype = np.int32)
#    195
#    196         1      55172.0  55172.0      0.0      Na_m = np.zeros((int(steps)+1, N_0_var), dtype = np.int32)
#    197         1      62574.0  62574.0      0.0      Ma_m = np.zeros((int(steps)+1, N_0_var), dtype = np.int32)
#    198         1      65618.0  65618.0      0.0      E_m = np.zeros((int(steps)+1, N_0_var), dtype = np.int32) # effector in periphary
#    199         1       1773.0   1773.0      0.0      T_E = np.zeros(N_0_var)
#    200
#    201         1        401.0    401.0      0.0      if out_data == "full":
#    202                                                   mycN_m = np.zeros((int(steps)+1, N_0_var))
#    203                                                   mycMa_m = np.zeros((int(steps)+1, N_0_var))
#    204                                                   mycE_m = np.zeros((int(steps)+1, N_0_var))
#    205
#    206         1       2674.0   2674.0      0.0      bias_t = np.zeros((int(steps)+1, 4))
#    207
#    208                                               # Define event timer variables
#    209         1        772.0    772.0      0.0      bound_N = np.zeros(N_0_var, dtype =np.int32)
#    210         1        521.0    521.0      0.0      bound_N_time = np.zeros(N_0_var)
#    211         1       3936.0   3936.0      0.0      Na_div_flag = np.ones(N_0_var, dtype =np.int32)
#    212         1       2173.0   2173.0      0.0      Na_flag = np.ones(N_0_var, dtype =np.int32)
#    213
#    214         1        561.0    561.0      0.0      mycN = np.zeros(N_0_var)
#    215         1        762.0    762.0      0.0      mycE = np.zeros(N_0_var)
#    216         1        871.0    871.0      0.0      mycMa = np.zeros(N_0_var)
#    217
#    218         1     109034.0 109034.0      0.0      r_NaE = np.zeros((int(steps)+1, N_0_var))
#    219         1     120761.0 120761.0      0.0      r_EM = np.zeros((int(steps)+1, N_0_var))
#    220         1     122553.0 122553.0      0.0      r_Nact = np.zeros((int(steps)+1, N_0_var))
#    221         1     114081.0 114081.0      0.0      r_Ediv = np.zeros((int(steps)+1, N_0_var))
#    222         1       1633.0   1633.0      0.0      cum_r_NaE = np.zeros(N_0_var)
#    223
#    224         1        471.0    471.0      0.0      b_unbind_t = np.zeros(N_0_var)
#    225         1        421.0    421.0      0.0      b_N_bind = np.zeros(N_0_var)
#    226         1      13520.0  13520.0      0.0      b_Na_div = np.ones(N_0_var)/char_times[2]
#    227         1        481.0    481.0      0.0      b_myc_t = np.zeros(N_0_var)
#    228         1       4286.0   4286.0      0.0      b_E_div = np.ones(N_0_var)/char_times[3]
#    229         1       3575.0   3575.0      0.0      b_Ma_div = np.ones(N_0_var)/char_times[4]
#    230         1       3746.0   3746.0      0.0      d_E_die = np.ones(N_0_var)/char_times[5]
#    231
#    232                                               #################################
#    233                                               ### RUN POPULATION SIMULATION ###
#    234                                               #################################
#    235         1        101.0    101.0      0.0      t = 0.0
#    236         1        851.0    851.0      0.0      S[0] = S_0
#    237         1        831.0    831.0      0.0      I[0] = I_0 if vir_model != 'autoimmune' else 0.0
#    238         1        210.0    210.0      0.0      V[0] = 0
#    239         1        360.0    360.0      0.0      H[0] = 0.0
#    240         1        251.0    251.0      0.0      P[0] = 0.0
#    241
#    242      2001     368395.0    184.1      0.1      for i in np.arange(1, int(steps) + 1):
#    243                                                   # select virulence model:
#    244      2000     312393.0    156.2      0.0          if vir_model == "dep_harm": # makes  average virus produced roughly the same independent of infected death rate
#    245                                                       b_I_t = b_I + d_I/S_0
#    246                                                       d_Sauto = 0
#    247                                                       t_Hauto = 1.0
#    248                                                       t_Hcancer = 1.0
#    249      2000     335517.0    167.8      0.0          elif vir_model == "autoimmune":
#    250                                                       b_I_t = 0.0
#    251                                                       d_Sauto = d_I
#    252                                                       K_SE = K_IE
#    253                                                       I_0 = 0.0
#    254                                                       t_Hauto = 1.0 # duration of autoimmune inflammation
#    255                                                       t_Hcancer = 1.0
#    256                                                   else:
#    257      2000     270928.0    135.5      0.0              b_I_t = b_I
#    258      2000     231999.0    116.0      0.0              d_Sauto = 0
#    259      2000     202961.0    101.5      0.0              t_Hauto = 1.0
#    260      2000     199721.0     99.9      0.0              t_Hcancer = 1.0
#    261                                                   # elif vir_model == "cancer":
#    262                                                   #     b_I_t = b_I
#    263                                                   #     d_Sauto = 0
#    264                                                   #     t_Hauto = 1.0
#    265                                                   #     S_0 = S_0 - I_0
#    266                                                   #     t_Hcancer = 1.0 # duration of supplied inflammatory cytokines
#    267
#    268                                                   # Compute total population of cell types
#    269      2000    9138887.0   4569.4      1.3          E_pop = np.sum(E_m[i-1])
#    270
#    271
#    272                                                   #### Run infection dynamics: replication and effector clearance ####
#    273
#    274                                                   # Update state of susceptible, infected and inflammation
#    275                                                   # (a) event variables
#    276
#    277      2000    4041874.0   2020.9      0.6          S_to_I, I_die = dt*S[i-1]*(I[i-1] >= I_0)*b_I_t*I[i-1], dt*I[i-1]*(d_IE*(E_pop)/(K_IE + I[i-1] + E_pop) + d_I)
#    278      2000    2640426.0   1320.2      0.4          I_d_IE[i] += I_d_IE[i-1] + dt*I[i-1]*d_IE*(E_pop)/(K_IE + I[i-1] + E_pop) # cells killed by immune response
#    279      2000    2013506.0   1006.8      0.3          I_d_I[i] += I_d_I[i-1] + dt*I[i-1]*d_I + (I[i] if i == int(steps) else 0) # cells killed by infection
#    280      2000    2417491.0   1208.7      0.3          I_d_SE[i] += I_d_SE[i-1] + dt*S[i-1]*( d_IE*(E_pop)/(K_SE + S[i-1] + E_pop) )
#    281      2000    1477804.0    738.9      0.2          I_d_S[i] += I_d_S[i-1] + dt*S[i-1]*d_S
#    282
#    283                                                   # (b) state variables
#    284      2000    6050770.0   3025.4      0.8          S[i] += S[i-1] - S_to_I + dt*(b_S - (d_S + d_Sauto*np.exp(-(t/t_Hauto)**2))*S[i-1] - S[i-1]*d_IE*(E_pop)/(K_SE + S[i-1] + E_pop))*(S[i-1] >= 1.0)
#    285
#    286      2000    1119344.0    559.7      0.2          I[i] += I[i-1] + S_to_I - I_die
#    287
#    288      2000    3061298.0   1530.6      0.4          harm_detected = I_die + dt*S[i-1]*d_Sauto*np.exp(-(t/t_Hauto)**2) + S_to_I*(vir_model == "cancer")
#    289      2000     786220.0    393.1      0.1          immunopathology = I_d_SE[i] + I_d_IE[i]
#    290      2000     978569.0    489.3      0.1          cells_sensed = (I[i] + S[i]*K_IE/K_SE)
#    291
#    292      2000    4430559.0   2215.3      0.6          H[i] += H[i-1] + b_H*(harm_detected) - dt*d_H*H[i-1]*(H[i-1] >= 0.0) + 0*K_EH*np.exp(-(t/t_Hcancer)**2)*(vir_model == "cancer")
#    293      2000    2204518.0   1102.3      0.3          P[i] += P[i-1] + b_H*(immunopathology) - dt*d_H*P[i-1]*(P[i-1] >= 0.0)
#    294
#    295                                                   ## I. Recruitment/Priming
#    296
#    297                                                   # (a) Phase 1: Naive cells encounter and bind APCs
#    298      2000     359506.0    179.8      0.0          if cells_sensed >= 1:
#    299      2000   64689909.0  32345.0      9.0              bound_N += np.random.binomial(N_m[i-1], b_N_bind*dt) - np.random.binomial(N_m[i-1], b_unbind_t*dt)
#    300                                                   else:
#    301                                                       bound_N = 0*bound_N
#    302
#    303      2000   15029085.0   7514.5      2.1          bound_N_time += bound_N*bound_N*dt - (1-bound_N)*bound_N_time*dt*N_m[i-1] # only reset to zero if the cell is not activated
#    304
#    305                                                   # (b) Phase 2: Activated naive cells are bound to APCs and receive stimulation.
#    306      2000   11404303.0   5702.2      1.6          act_N = (1 - bound_N)*(mycN >= myc_thresh)*(N_m[i-1] > 0)
#    307
#    308                                                   # (c) Phase 3: Unbound activated naive cells divide and then differentiate
#    309      2000   26981313.0  13490.7      3.7          div_Na = np.random.binomial(Na_m[i-1]*Na_div_flag, dt*b_Na_div)
#    310
#    311      2000   38383457.0  19191.7      5.3          diff_NaE = np.random.binomial(Na_m[i-1]*(1 - Na_div_flag), 1 - np.exp(-cum_r_NaE*dt) if np.sum(Na_m[i-1]) > 0 else 0)
#    312
#    313                                                   ## II. Expansion
#    314
#    315                                                   # (a) New central memory cells divide
#    316      2000   27763618.0  13881.8      3.8          div_Ma = np.random.binomial(Ma_m[i-1] - diff_EpM_count, dt*b_Ma_div)
#    317
#    318                                                   # (b) Effector cells divide, differentiate, die
#    319      2000   26369240.0  13184.6      3.7          die_E = np.random.binomial(E_m[i-1], d_E_die*dt)
#    320      2000   27233079.0  13616.5      3.8          div_E = np.random.binomial(E_m[i-1] - die_E, dt*(b_E_div))
#    321      2000   27710819.0  13855.4      3.8          diff_EM = np.random.binomial(E_m[i-1] - die_E, dt*r_EM[i-1])
#    322
#    323                                                   #### Update population dynamics: ####
#    324      2000    3937639.0   1968.8      0.5          N_m[i] += N_m[i-1] - act_N
#    325      2000   14286434.0   7143.2      2.0          Na_m[i] += Na_m[i-1] + div_Na + act_N - (1 - Na_div_flag)*Na_m[i-1]
#    326
#    327      2000   13729756.0   6864.9      1.9          Ma_m[i] += Ma_m[i-1] + div_Ma + (1 - Na_div_flag)*(Na_m[i-1] - diff_NaE) + diff_EM
#    328      2000   11912679.0   5956.3      1.6          E_m[i] += E_m[i-1] + div_E + (1 - Na_div_flag)*(diff_NaE) - (die_E + diff_EM)
#    329
#    330                                                   # Update division flag to allow division to proceed
#    331      2000    6536861.0   3268.4      0.9          Na_div_flag = (Na_m[i] < max_Na)*(Na_m[i] > 0)
#    332      2000    4134251.0   2067.1      0.6          div_count += div_Na + div_E + div_Ma
#    333      2000    2116867.0   1058.4      0.3          div_E_count += div_E
#    334      2000    2036369.0   1018.2      0.3          div_M_count += div_Ma
#    335      2000    3087011.0   1543.5      0.4          diff_EpM_count += diff_EM
#    336
#    337                                                   #### New binding events ####
#    338
#    339      2000   27437569.0  13718.8      3.8          b_N_bind = (N_m[i] > 0)*(1 - bound_N)*f_XtoY(sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i], psi_1 = psi_max/4, psi_2 = psi_max/2, psi_1_2 = 0.0, F_0 = -1.0, K_1 = S_0, K_2 = K_EH, K_3 = K_EH, reg_model = reg_model)/char_times[0] if cells_sensed >= 1 else 0.0
#    340
#    341      2000   34976344.0  17488.2      4.8          b_unbind_t = bound_N*np.fmin(2*(bound_N_time)/(f_XtoY(sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i], psi_1 = psi_max/2, psi_2 = 0.0, psi_1_2 = 0.0, F_0 = -2.0, K_1 = (K_IE*(vir_model != "autoimmune") + K_SE*(vir_model == "autoimmune")), K_2 = K_EH, K_3 = K_EH, reg_model = reg_model)*char_times[1]*2/np.sqrt(np.pi))**2, 1/dt) if np.sum(bound_N) >= 1 else 0.0
#    342
#    343      2000   17144387.0   8572.2      2.4          b_myc_t = b_myc*f_XtoY(sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i], psi_1 = psi_Nact_I, psi_2 = psi_Nact_H, psi_3 = psi_Nact_P, F_0 = F0_Nact, K_1 = (K_IE*(vir_model != "autoimmune") + K_SE*(vir_model == "autoimmune")), K_2 = K_EH, K_3 = K_EH, reg_model = reg_model)*bound_N # Maybe: multiply by np.sqrt(np.pi)/2. Can see argument for leaving as a linear rate
#    344
#    345                                                   #### MYC Dynamics ####
#    346      2000   37098365.0  18549.2      5.1          mycN = (mycN + dt*(b_myc_t - (1 - bound_N)*f_XtoY(sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i], psi_1 = -psi_Ediv_I, psi_2 = -psi_Ediv_H, psi_3 = -psi_Ediv_P, F_0 = -F0_Ediv, K_1 = (K_IE*(vir_model != "autoimmune") + K_SE*(vir_model == "autoimmune")), K_2 = K_EH, K_3 = K_EH, reg_model = reg_model)*mycN*d_myc*(mycN > 0)))*(N_m[i] + Na_m[i] > 0)
#    347
#    348      2000   30850820.0  15425.4      4.3          mycE = (mycE - dt*(f_XtoY(sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i], psi_1 = -psi_Ediv_I, psi_2 = -psi_Ediv_H, psi_3 = -psi_Ediv_P, F_0 = -F0_Ediv, K_1 = (K_IE*(vir_model != "autoimmune") + K_SE*(vir_model == "autoimmune")), K_2 = K_EH, K_3 = K_EH, reg_model = reg_model)*mycE*d_myc))*(E_m[i] >= 1) + mycN*(Na_m[i] > 0)
#    349
#    350      2000   14510575.0   7255.3      2.0          mycMa = (mycMa - dt*(mycMa*d_myc))*(Ma_m[i] > 0) + mycN*(Na_m[i] > 0) # higher decay rate of myc
#    351
#    352                                                   #### Time-dependent rates modulated by antigen and cytokine signals ####
#    353      2000     490341.0    245.2      0.1          b_Na_div = 1/char_times[2]
#    354      2000    7850380.0   3925.2      1.1          b_E_div = (mycE >= myc_thresh)*(div_count < max_expand)/char_times[3]
#    355      2000    7387580.0   3693.8      1.0          b_Ma_div = (mycMa >= myc_thresh)*(div_count < max_expand)/char_times[4]
#    356
#    357                                                   #### Transition probabilities modulated by antigen and cytokine signals ####
#    358      2000    4263691.0   2131.8      0.6          r_Nact[i] += b_myc_t/myc_thresh
#    359
#    360      2000   26340939.0  13170.5      3.6          r_NaE[i] += (r_NaE[i-1] + 2*dt*f_XtoY(sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i], psi_1 = psi_NE_I, psi_2 = psi_NE_H, psi_3 = psi_NE_P,F_0 = F0_NE, K_1 = (K_IE*(vir_model != "autoimmune") + K_SE*(vir_model == "autoimmune")), K_2 = K_EH, K_3 = K_EH, reg_model = reg_model)/(2/np.sqrt(np.pi)*(char_times[6]))**2)*(N_m[i]*bound_N > 0)
#    361
#    362      2000   24320502.0  12160.3      3.4          r_EM[i] += (r_EM[i-1] + 2*dt*f_XtoY(sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i], psi_1 = psi_EM_I, psi_2 = psi_EM_H, psi_3 = psi_EM_P, F_0 = F0_EM, K_1 = (K_IE*(vir_model != "autoimmune") + K_SE*(vir_model == "autoimmune")), K_2 = K_EH, K_3 = K_EH, reg_model = reg_model)/(2/np.sqrt(np.pi)*char_times[1]**2))*(E_m[i] > 0) # Urgent: need to square entire denominator
#    363
#    364      2000    2099507.0   1049.8      0.3          r_Ediv[i] += b_E_div
#    365
#    366      2000    1500051.0    750.0      0.2          cum_r_NaE += r_NaE[i]
#    367
#    368                                                   # store time cells become effector
#    369      2000   11842708.0   5921.4      1.6          T_E += dt*(E_m[i] > 0) if np.sum(E_m[i]) > 0 else 0.0
#    370      2000   11459719.0   5729.9      1.6          d_E_die = 2*(E_m[i] > 0)*T_E/(2/np.sqrt(np.pi)*char_times[5])**2
#    371
#    372                                                   # store time an effector spends in cytotoxic state
#    373      2096   13697332.0   6535.0      1.9          for l in np.where((N_m[i] == 0)*(E_m[i] + b_Ma_div > 0))[0]:
#    374                                                       # T_Ecyt[int(T_E[l]/dt)] += diff_EM[l]
#    375                                                       # T_Ecyt[0] += np.sum(diff_NaE[l] + div_Ma[l])
#    376        96     200743.0   2091.1      0.0              T_Ecyt[l] += (diff_NaE[l] + div_Ma[l])*[0.0] + diff_EM[l]*[T_E[l].item()]
#    377
#    378                                                   # T_Ecyt += np.sum(diff_NaE + div_Ma)*[0.0] + [diff_EM*T_E.tolist()]
#    379
#    380                                                   #### Store myc levels ####
#    381      2000     323739.0    161.9      0.0          if out_data == "full":
#    382                                                       mycN_m[i] += mycN
#    383                                                       mycMa_m[i] += mycMa
#    384                                                       mycE_m[i] += mycE
#    385
#    386                                                   #### Store differentiation biases
#    387      4000   19391020.0   4847.8      2.7          bias_t[i] += np.array([np.mean((r_Nact[i])) if N_0 > 0.0 else 0.0,
#    388      2000   31244535.0  15622.3      4.3                                 np.mean((r_NaE[i])[N_m[i]*bound_N > 0]) if np.sum(N_m[i]*bound_N) > 0.0 else 0.0,
#    389      2000   12126835.0   6063.4      1.7                                 np.mean((r_EM[i])[E_m[i] > 0]) if np.sum(E_m[i]) > 0.0 else 0.0,
#    390      2000   11716253.0   5858.1      1.6                                 np.mean(r_Ediv[i][E_m[i] > 0]) if np.sum(E_m[i]) > 0.0 else 0.0])
#    391
#    392                                                   # Increment time
#    393      2000     459527.0    229.8      0.1          t += dt
#    394
#    395                                               # Collect population dynamics
#    396         1     947689.0 947689.0      0.1      N, Na, Ma, E = np.sum(N_m, axis = 1), np.sum(Na_m, axis = 1), np.sum(Ma_m, axis = 1), np.sum(E_m, axis = 1)
#    397
#    398         1     125358.0 125358.0      0.0      T_pEcytM = np.concatenate(T_Ecyt) if N_0 > 0 else np.array([0.0]) # time that memory spends in effector
#    399                                               # T_pEcytM = T_Ecyt # time that memory spends in effector
#    400                                               # Project out surviving primary memory
#    401         1       1462.0   1462.0      0.0      M_duration = fsolve(memory_duration, 1.0, args = (T_pEcytM, char_times[5], N_0, dt), xtol = 0.001).item() if len(T_pEcytM) > N_0 and N_0 > 0.0 else 0.0
#    402
#    403         2     122033.0  61016.5      0.0      lineage_comp = np.vstack([np.amax(Na_m, axis = 0) ,
#    404         1        120.0    120.0      0.0                                div_M_count,
#    405         1        100.0    100.0      0.0                                div_E_count,
#    406         1      18528.0  18528.0      0.0                                p_tcr*np.ones(N_0_var),
#    407         1       3716.0   3716.0      0.0                                p_cyt*np.ones(N_0_var)])
#    408
#    409         1      15343.0  15343.0      0.0      dyn_data = np.array([S, I, N, Na, E, Ma, H, I_d_I + I_d_IE, I_d_SE]).T
#    410         1        131.0    131.0      0.0      prim_bias = bias_t
#    411
#    412         1      39629.0  39629.0      0.0      ts = np.linspace(0, duration, int(steps) + 1)
#    413
#    414                                               # Compute summary statistics from simulations
#    415                                               ## extract primary/secondary infection dynamics
#    416         1       2794.0   2794.0      0.0      pS, pI, N, Na, pE, pM, pH, pI_d_I, pI_d_SE = dyn_data[:,0], dyn_data[:,1], dyn_data[:,2], dyn_data[:, 3], dyn_data[:,4], dyn_data[:,5], dyn_data[:,6], dyn_data[:,7], dyn_data[:,8]
#    417
#    418         1        651.0    651.0      0.0      dt = ts[1]-ts[0]
#    419
#    420         3       9515.0   3171.7      0.0      parameters = np.concatenate((np.array([S_0, I_0, b_I, d_S, d_I, d_IE, K_IE,
#    421         1        140.0    140.0      0.0                b_H, d_H, K_EH,
#    422         1        190.0    190.0      0.0                N_0, max_Na, b_myc, d_myc, myc_thresh]),
#    423         1        141.0    141.0      0.0                char_times,
#    424         1        120.0    120.0      0.0                activation_regulation, NE_regulation, EM_regulation, expansion_regulation))
#    425
#    426         2      11907.0   5953.5      0.0      sim_summary = np.array([np.sum(pI*dt),
#    427         1      10646.0  10646.0      0.0                         np.argmax(pI)*dt,
#    428         1       6740.0   6740.0      0.0                         np.argmax(pI < I_0)*dt,
#    429         1       6420.0   6420.0      0.0                         np.amax(pI_d_I),
#    430         1       4247.0   4247.0      0.0                         np.amax(pI_d_SE),
#    431         1       4306.0   4306.0      0.0                         np.sum(div_E_count),
#    432         1       3485.0   3485.0      0.0                         np.argmax(pE)*dt,
#    433         1     538506.0 538506.0      0.1                         (np.mean(np.argmax(E_m > 0 , axis = 0)*dt*(np.amax(E_m, axis = 0) > 0 )) + sim_duration*(np.max(pE) < 1.0)) if N_0 > 0 else sim_duration,
#    434         1        401.0    401.0      0.0                         pM[-1],
#    435         1        230.0    230.0      0.0                         M_duration if N_0 > 0 else 0.0,
#    436         1       7040.0   7040.0      0.0                         np.sum(pE*dt),
#    437         1       6039.0   6039.0      0.0                         np.sum(pH*dt),
#    438         1       6490.0   6490.0      0.0                         np.amin(pS)])
#    439
#    440                                               # down-size timeseries
#    441         1        982.0    982.0      0.0      pnts = int(0.1*steps)
#    442         1      36375.0  36375.0      0.0      keep = [i*10 for i in np.arange(0,pnts)]
#    443
#    444         1        301.0    301.0      0.0      if out_data == "full":
#    445                                                   out_dict = {"reg_coeffs": np.concatenate((activation_regulation, NE_regulation, EM_regulation, expansion_regulation)), "cell_time_series": dyn_data, "time": ts, "lineage_diff": lineage_comp, "prim_diff_bias": prim_bias, "eff_by_lin": (E_m), "N_myc_by_lin": mycN_m, "Ma_myc_by_lin": mycMa_m, "E_myc_by_lin": mycE_m, "parameters": parameters, "summary_stats": sim_summary, "pmemory_formed": T_pEcytM if N_0 > 0 else []}
#    446         1        130.0    130.0      0.0      elif out_data == "small":
#    447         1      33480.0  33480.0      0.0          out_dict = {"cell_time_series": dyn_data[keep], "prim_diff_bias": prim_bias[keep],"parameters": parameters, "summary_stats": sim_summary}
#    448
#    449         1        120.0    120.0      0.0      return out_dict

# %%
# Run single simulation
# %timeit -n 2 -r 2
data_dict = lin_stoch_sim(N_0 = N_0, b_I = b_I, 
                          K_IE = K_IE,
                          d_I = d_I,
                          K_EH = K_EH,
                          NE_regulation = NE_regulation,
                          EM_regulation = EM_regulation,
                          activation_regulation = Na_regulation,
                          expansion_regulation = EE_regulation,
                          infection = infection_type,
                          vir_model = vir_model,
                          reg_model = 'mwc_like',
                          out_data = "full")

# %%
regs = data_dict["reg_coeffs"]
dyn = data_dict["cell_time_series"]
ts = data_dict["time"]
lin_comp = data_dict["lineage_diff"]
p_diff = data_dict["prim_diff_bias"]
parameters = data_dict["parameters"]
sim_summary = data_dict["summary_stats"]
mycN = data_dict["N_myc_by_lin"]
mycMa = data_dict["Ma_myc_by_lin"]
mycE = data_dict["E_myc_by_lin"]
Eff = data_dict["eff_by_lin"]
T_pEcytM = data_dict["pmemory_formed"]

S, I, N, Na, E, M, H, I_d_I, I_d_S = dyn[:,-9], dyn[:,-8], dyn[:,-7], dyn[:,-6], dyn[:,-5], dyn[:,-4], dyn[:,-3], dyn[:,-2], dyn[:,-1]

reg_string = '-'.join(np.array(Na_regulation + NE_regulation + EM_regulation + EE_regulation).astype('U4'))

# %%
# Plot simulated immune dynamics
fig, (ax1, ax2, ax3) = plt.subplots(3, dpi = 150, constrained_layout=True, sharex = False, figsize=(5,5))

ax1.plot(ts, S, 'k', label = r'susceptible, $S$')
ax1.plot(ts, I, 'b', label = r'infected, $I$')

ax1.plot(ts, I_d_S, 'r', linestyle = '--', label = r'susceptible killed')
ax1.plot(ts, I_d_I, 'g', linestyle = '--', label = r'infected killed')
ax1.axhline(y = K_EH, color = 'k', linestyle = '--')
ax1.set(ylabel='Cell count')
ax1.set_ylim(1, S_0*2)
ax1.semilogy()
ax1.minorticks_off()
ax1.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

ax2.plot(ts, Na, 'b', label = r'Activated, $N^*$')
ax2.plot(ts, E, 'orange', label = r'Effector, $E$')
ax2.plot(ts, M, 'g', label = r'Memory, $M$')
ax2.plot(ts, S, 'grey', label = r'Susceptible, $S$')
ax2.plot(ts, I, 'r', label = r'infected, $I$')
ax2.set(ylabel='Cell count')
ax2.semilogy()
ax2.minorticks_off()
ax2.set_ylim(1, S_0*2)
ax2.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

ax3.plot(ts, f_XtoY(sig_1 = I, sig_2 = H, psi_1 = psi_max/2, psi_2 = psi_max/2, psi_1_2 = 0, F_0 = 0.0, K_1 = K_IE, K_2 = K_EH),
         'k-', label = r'Regulation, $f(I,H)$')
ax3.set(xlabel=r'Time (days)', ylabel='Regulation')
ax3.minorticks_off()
ax3.set_ylim(0,1.05)

fig.savefig("_figs/"+infection_type+'-'+'virus-effector dynamics-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
plt.plot(ts, N)
plt.ylim(0, 1.1*N_0)
np.mean(np.argmax(Eff >0 , axis = 0)*(ts[1]-ts[0])*(np.amax(Eff, axis = 0) > 0 ))
# Out:
# 9.036533333333333

# %%
plt.plot(ts, np.log((1 + I/K_IE)), 'r')
plt.plot(ts, np.log((1 + H/K_EH)), 'k--')

# %%
plt.plot(ts,d_IE*E/(K_IE + I + E), 'r')
plt.plot(ts, d_IE*E/(K_IE + E), 'k--')

# %%
print(f'Memory fraction = {(np.max(M))/np.max(E)}')
print(f'Number of memory cells = {np.max(M)}')
print(f'1st infection harm = {sim_summary[3]/(d_S*S_0)}')
print(f'1st response toxicity = {sim_summary[4]/(d_S*S_0)}')
print(f'Minimum susceptible = {np.min(S)/S_0}')
# Out:
# Memory fraction = 0.1768612284362119
# Number of memory cells = 187677.0
# 1st infection harm = 35.303107832952875
# 1st response toxicity = 18.305030864239068
# Minimum susceptible = 0.4907331212439424

# %%
# Plot simulated infection dynamics: pretty plots
pnts = 50
keep = [i*int(len(E)/pnts) for i in np.arange(0,pnts)]
sus = S[keep]
naive = Na[keep]
eff = E[keep]
mem = M[keep]
p_load = np.log(1 + I[keep]/K_IE)
inflam = np.log((1 + H[keep]/K_EH))/np.log((1 + S_0/K_EH))
inf_harm = I_d_I[keep]
toxicity = I_d_S[keep]
time = ts[keep]

fig, ax = plt.subplots(figsize=(10.0,5))

ax.plot(time, naive, 'k--')
im = ax.scatter(time, naive, marker ='*', c = p_load, cmap='coolwarm', 
            label = r'Act., $N^*$') #, norm=mpl.colors.LogNorm())

ax.plot(time, eff, 'k--')
ax.scatter(time, eff, marker ='o', c = p_load, cmap='coolwarm', 
            label = r'Eff., $E$') #, norm=mpl.colors.LogNorm())

ax.plot(time, mem, 'k--')
ax.scatter(time, mem, marker ='s', c = p_load, cmap='coolwarm',
            label = r'Mem., $M$') #, norm=mpl.colors.LogNorm())

ax.plot(time, inf_harm, 'r', linewidth = 2.0, label = r'Harm, $\mathcal{H}_I$')

ax.plot(time, toxicity, 'y', linewidth = 2.0,label = r'Toxicity, $\mathcal{H}_S$')

ax.set_box_aspect(1)
cb = fig.colorbar(im, ax=ax, orientation='vertical', shrink = 0.75, pad = 0.05)
cb.set_label('Ag. stimulation', fontsize = 14)
cb.ax.tick_params(labelsize=8)
ax.set_ylabel('Cell count', fontsize = 18)
ax.set_xlabel(r"Time (days)", fontsize = 18)
ax.semilogy()
ax.minorticks_off()
ax.set_ylim(1,)
locmaj = mpl.ticker.LogLocator(numticks=4)
ax.yaxis.set_major_locator(locmaj)

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        ax.axvline(x=time[i], linestyle='-', linewidth=5.5, color='pink', alpha=inflam[i], label =r"Infam. stim.", zorder = 0)
    else:
        ax.axvline(x=time[i], linestyle='-', linewidth=5.5, color='pink', alpha=inflam[i], zorder = 0)

ax.legend(loc='center right', bbox_to_anchor=(1.8, 0.7), fontsize = 12)

plt.savefig('_figs/'+infection_type+'-timeline-of-infection-dynamics-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
# Plot simulated infection dynamics: pretty plots of harm
pnts = 150
keep = [i*int(len(E)/pnts) for i in np.arange(0,pnts)]

eff = E[keep]
p_load = I[keep]/S_0
sus = S[keep]/S_0
inf_harm = I_d_I[keep]/S_0
inflam_harm = I_d_S[keep]/S_0
inflam = np.log((1 + H[keep]/K_EH))/np.log((1 + S_0/K_EH))
time = ts[keep]

plt.scatter(time, p_load, marker ='s', c =eff/K_IE, cmap='coolwarm', 
            label = r'Infected cells, $I$') #, norm=mpl.colors.LogNorm())
plt.plot(time, p_load, 'k--')

# plt.scatter(time, sus, marker ='>', c =eff/K_IE, cmap='coolwarm', 
#             label = r'Susceptible cells, $S$') #, norm=mpl.colors.LogNorm())
# plt.plot(time, sus, 'k--')

plt.scatter(time, inf_harm, marker ='o', c =eff/K_IE, cmap='coolwarm', 
            label = 'Infected cells killed')
plt.plot(time, inf_harm, 'k--')

plt.scatter(time, inflam_harm, marker ='*', c =eff/K_IE, cmap='coolwarm',
            label = 'Susceptible cells killed')
plt.plot(time, inflam_harm, 'k--')

plt.colorbar(label = "Primary effector response")
plt.ylabel('Fraction of susceptible cells', fontsize = 14)
plt.xlabel(r"Time, $t$ (days)", fontsize = 14)

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        plt.axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], label =r"Inflammation, $H$", zorder = 0)
    else:
        plt.axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        
plt.legend(loc='center right', bbox_to_anchor=(1.85, 0.8), fontsize = 10)
plt.savefig('_figs/'+infection_type+'-infection-harm-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
# Plot simulated infection dynamics: pretty plots
pnts = 150
keep = [1 + i*int(len(E)/pnts) for i in np.arange(0,pnts)]
bias_diff = p_diff[keep] if infection_type == "prim" else s_diff[keep]
p_load = I[keep]/S_0
sus = S[keep]
inflam =  np.log((1 + H[keep]/K_EH))/np.log((1 + S_0/K_EH))
time = ts[keep]

fig, axs = plt.subplots(2,2, figsize=(7,7))

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0, label =r"Inflammation, $H$")
    else:
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0, label =r"Inflammation, $H$")

im1 = axs[0,0].scatter(time, bias_diff[:,0], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$N \longrightarrow N^*$')
axs[0,0].plot(time, bias_diff[:,0],'k--')
axs[0,0].title.set_text(r'$N \longrightarrow N^*$')
axs[0,0].set_box_aspect(1)

im2 = axs[0,1].scatter(time, bias_diff[:,1], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$N^* \longrightarrow E$')
axs[0,1].plot(time, bias_diff[:,1],'k--')
axs[0,1].title.set_text(r'$N^* \longrightarrow E$')
axs[0,1].set_box_aspect(1)

im3 = axs[1,0].scatter(time, bias_diff[:,2], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$E \longrightarrow M$')
axs[1,0].plot(time, bias_diff[:,2],'k--')
axs[1,0].title.set_text(r'$E \longrightarrow M$')
axs[1,0].set_box_aspect(1)

im4 = axs[1,1].scatter(time, bias_diff[:,3], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$E \longrightarrow M$')
axs[1,1].plot(time, bias_diff[:,3],'k--')
axs[1,1].title.set_text(r'$E \longrightarrow E + E$')
axs[1,1].set_box_aspect(1)

axs[0,0].set_ylabel('Rate [day$^{-1}$]', fontsize = 14)
axs[1,0].set_ylabel('Rate [day$^{-1}$]', fontsize = 14)
axs[1,0].set_xlabel("Time (days)", fontsize = 14)
axs[1,1].set_xlabel("Time (days)", fontsize = 14)

fig.subplots_adjust(wspace=.4, hspace = 0.1)
cb = fig.colorbar(im1, ax=axs, shrink = 0.5, pad = 0.05, orientation='vertical')
cb.set_label('Fraction infected,'+ r'$\frac{I}{S_0}$')

#cb.set_clim(-0.4,0.4)
    
# plt.colorbar(label =r"pathogen load, $I(t)$")
# plt.ylabel('transition weight', fontsize = 16)
# plt.xlabel("time (days)", fontsize = 16)
# plt.legend() #bbox_to_anchor=(1.05, 1.0), loc='upper left')

plt.savefig('_figs/'+infection_type+'-diff-bias-over-time-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %% [markdown]
# ### (2) Plot lineage-based trajectories

# %%
keys = np.array(['Memory', 'Effector'])
all_counts = lin_comp[1:3].T
effector_ranking = np.argsort(all_counts[:, 1])[::-1]
all_counts = all_counts[effector_ranking]
total_counts = all_counts.sum(axis=1)
norm_counts = all_counts / total_counts[:, None]
norm_counts[~np.isfinite(norm_counts)] = 0
comp_argsort = np.argsort(np.max(all_counts, axis=0))
bar_dict = {k: v for k, v in zip(keys[comp_argsort], norm_counts.T[comp_argsort])}
lineage_idxs = np.arange(all_counts.shape[0])

fig, ax = plt.subplots()
bottom = np.zeros(len(lineage_idxs))
cmap_colors = sns.color_palette('Set2', 10)
cmap_colors = [cmap_colors[i]
               for i in [0, 1, 5]]#[7, 2, 0, 1, 5]]
# cmap_colors = [cmap_colors[i]
#                for i in [6, 1, 2, 5, 0]]
width = 1

for i, (celltype, fraction) in enumerate(bar_dict.items()):
    ax.bar(lineage_idxs, fraction, width,
           edgecolor='k', linewidth=0.01,
           label=celltype, bottom=bottom, color=cmap_colors[i])
    bottom += fraction
    
ax.legend(loc='center right', bbox_to_anchor=(1.4, 0.5), fontsize = 12)
ax.set_xlim(-0.5, len(all_counts) - 0.5)
ax.set_xlabel('sub-clone lineages \n (ranked by effector response)', fontsize = 15)
ax.set_ylabel('fractional cell-fate \ncomposition', fontsize = 15)
#ax.set_yscale('log')

ax.set_xticks(np.arange(0, Eff.shape[1], int(Eff.shape[1]/10)))
ax.set_xticklabels(1 + np.arange(0, Eff.shape[1], int(Eff.shape[1]/10)), fontsize=9)

ax.set_yticks(np.round(np.arange(0, 1.2, 0.2), 1))
ax.set_yticklabels(ax.get_yticks(), fontsize=12)

fig.savefig("_figs/"+infection_type+'-'+'fates-by-lin-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
plt.errorbar(ts, np.mean(Eff, axis = 1), yerr = np.std(Eff, axis = 1), errorevery = 100)
plt.semilogy()
# Out:
# []

# %%
plt.plot(ts, mycN, 'r--')
plt.errorbar(ts, np.mean(mycN, axis = 1), yerr = np.std(mycN, axis = 1), errorevery = 100)
#plt.plot(ts, mycMa, 'k-')
plt.axhline(y = myc_thresh, color = 'k', linestyle = '--')
print(np.sum(np.max(mycE, axis=0) < myc_thresh)/N_0)
# Out:
# 0.043333333333333335

# %%
#plt.hist(np.argmax(mycNa > 0, axis = 0)*sim_duration/sim_steps, bins='auto')
plt.hist(T_pEcytM, bins = 'auto', histtype='step');
# plt.hist(T_sEcytM, bins='auto', histtype='step');

# %%
# Compute max values in the data
r = np.arange(5)
width = 0.5
plt.bar(r, np.amax(np.array([I, Na, E, M, H]).T, axis = 0), width = width)

plt.xlabel("response")
plt.ylabel("value")

plt.xticks(r, ["Infected","Naive","Effector","Memory", "Inflammation"], fontsize = 7)

plt.semilogy()
plt.suptitle(r'Peak response response: $N_0=$ '+str(N_0) +r', $d_I=$'+str(d_I))
# Out:
# Text(0.5, 0.98, 'Peak response response: $N_0=$ 300, $d_I=$1.25')

# %%
bias_1 = f_XtoY(I, H, 
       -2.0, -2.0, 0.0, F_0 = 4*np.log(2), 
       K_I = K_IE, K_H = K_EH)
bias_2 = f_XtoY(I, H, 
       -2.0, 2.0, 0.0, F_0 = -0*np.log(2), 
       K_I = K_IE, K_H = K_EH)

plt.plot(ts, bias_1, 'r')
plt.plot(ts, bias_2, 'k--')
plt.plot(ts, Na/np.amax(Na))
plt.plot(ts, A/(Na + A))
plt.plot(ts, H**l_H/(K_EH**l_H + H**l_H))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 bias_1 = f_XtoY(I, H,
#       2        -2.0, -2.0, 0.0, F_0 = 4*np.log(2),
#       3        K_I = K_IE, K_H = K_EH)
#       4 bias_2 = f_XtoY(I, H,
#       5        -2.0, 2.0, 0.0, F_0 = -0*np.log(2),
#       6        K_I = K_IE, K_H = K_EH)
#       8 plt.plot(ts, bias_1, 'r')
#
# TypeError: f_XtoY() got an unexpected keyword argument 'K_I'

# %%
d="/gscratch/scrubbed/oukogu/infoimmune/sim_output/no_cell_var/raw/"
comment = "auto-sparse-reg"
runs = 1

run(batch = [0.0], outdir=d, comment=comment, runs = runs, num_cpu = 75, run_time = 12.0)

# %%
d_file = '/gscratch/scrubbed/oukogu/infoimmune/sim_output/no_cell_var/raw/sim_batch_0.0-'+str(runs)+'-prim-'+comment+'.pkl'
with open(d_file, 'rb') as f:   
    out = pickle.load(f)
