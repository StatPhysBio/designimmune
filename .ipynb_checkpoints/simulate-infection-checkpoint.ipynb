# %% [markdown]
# # Run infection dynamics with monoclonal killer T cell response

# %%
import numpy as np
from matplotlib.cm import get_cmap
import matplotlib.pyplot as plt
import matplotlib as mpl

import multiprocessing as mp
from tqdm import tqdm
from joblib import Parallel, delayed
from scipy import stats
import os
import seaborn as sns
from stoch_sim_model import *
from optimize_nets import *

plt.style.use('custom.mplstyle')
# %config InlineBackend.figure_format = 'retina'
# %load_ext line_profiler

# %%
avg_sim_time = 2.5/(60*60) # 1.6/(60*60)

print('full-reg:',(len(psi_2d_nobias)**4)*len(infection_sample_select),
      np.ceil((len(psi_2d_nobias)**4*len(infection_sample_select))/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('prim-Nact-Ediv:',len(psi_2d)*len(psi_2d)*len(infection_sample_select), 
      np.ceil((len(psi_2d)*len(psi_2d)*len(infection_sample_select))/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('auto-sparse-reg:',len(psi_2d_sparse)*len(auto_sample), 
      np.ceil((len(psi_2d_sparse)*len(auto_sample))/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('cancer-sparse-reg:',len(psi_2d_sparse)*len(cancer_sample), 
      np.ceil((len(psi_2d_sparse)*len(cancer_sample))/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('sparse-reg:', len(psi_2d_sparse)*len(infection_sample_select),
      np.ceil(len(psi_2d_sparse)*len(infection_sample_select)/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')
# Out:
# full-reg: 6581250 46.0 1440 jobs per cpu per hour
# prim-Nact-Ediv: 731250 6.0 1440 jobs per cpu per hour
# auto-sparse-reg: 1562500 11.0 1440 jobs per cpu per hour
# cancer-sparse-reg: 7812500 55.0 1440 jobs per cpu per hour
# sparse-reg: 40625000 283.0 1440 jobs per cpu per hour

# %% [markdown]
# ### (1) Plot population averaged trajectories

# %%
# Set simulation parameters
N_0 = 1000
K_IE = (1)*(10**6)
d_I = 50*d_S # d_S #
b_I = 1.5*(10**(-7)) # 1.50*(10**(-7)) # b_C
I_0 = 1*I_0  # 0.1*S_0 # I_0

infection_model = 'acute' #'acute', 'autoimmune', 'cancer'
Na_regulation = [psi_max, psi_max, -psi_max, 1.0*L0_max]
NE_regulation = [psi_max, psi_max, -psi_max, 1.0*L0_max]
EM_regulation = [-psi_max, -psi_max, 0*psi_max, -1.0*L0_max]
EE_regulation = [psi_max, psi_max, -psi_max, -0.0*L0_max]

# %%
# %lprun -T lprof0 -f lin_stoch_sim lin_stoch_sim(N_0 = 1000, b_I = b_I, K_IE = K_IE, d_I = d_I, K_EH = K_EH, \
                                                NE_regulation = NE_regulation, \
                                                EM_regulation = EM_regulation, \
                                                activation_regulation = Na_regulation, \
                                                expansion_regulation = EE_regulation, \
                                                memory_death = False)
# Out:
# *** Profile printout saved to text file 'lprof0'.
# Timer unit: 1e-09 s
#
# Total time: 1.24403 s
# File: /mmfs1/home/oukogu/infoimmune/stoch_sim_model.py
# Function: lin_stoch_sim at line 193
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    193                                           def lin_stoch_sim(S_0 = S_0, I_0 = I_0, b_I = b_I, d_S = d_S, d_I = d_I, d_IE = d_IE, K_IE = K_IE, K_SE = K_SE,
#    194                                                             b_H = b_H, d_H = d_H, K_EH = K_EH,
#    195                                                             N_0 = N_0, max_Na = max_Na, b_myc = b_myc, d_myc = d_myc, myc_thresh = myc_thresh, max_expand = max_expand,
#    196                                                             char_times = [t_bind, t_unbind, t_Na_div, t_E_div, t_M_div, t_E_die, t_act],
#    197                                                             NE_regulation = NE_psis,
#    198                                                             EM_regulation = EM_psis,
#    199                                                             activation_regulation = act_psis,
#    200                                                             expansion_regulation = exp_psis,
#    201                                                             infection_model = "acute",
#    202                                                             duration = sim_duration,
#    203                                                             steps = sim_steps,
#    204                                                             reg_model = "mwc_like",
#    205                                                             out_data = "small",
#    206                                                             memory_death = False,
#    207                                                             seed = None):
#    208         1     166439.0 166439.0      0.0      rng = np.random.default_rng(seed)
#    209
#    210         1        271.0    271.0      0.0      if reg_model == 'mwc_like':
#    211         1        621.0    621.0      0.0          f_XtoY = f_XtoY_mwc_like
#    212                                               elif reg_model == 'competition_model':
#    213                                                   f_XtoY = f_XtoY_competition
#    214                                               else:
#    215                                                   f_XtoY = f_XtoY_ret0
#    216                                               # VARIABLE DEFINITIONS:
#    217                                               # S_0 := S_0, I_0 := I_0, b_S := b_S, b_I := b_I, d_S := d_S, d_I := d_I, d_IE := d_IE, K_IE := K_IE,
#    218                                               # b_H := b_H, d_H := d_H, K_EH := K_EH,
#    219                                               # N_0 := N_0, max_Na := max_Na, b_myc := b_myc, d_myc := d_myc, myc_thresh := myc_thresh,
#    220                                               # char_times := [t_bind, t_unbind, t_Na_div, t_E_div, t_M_div, t_EM_diff, t_E_die, t_Na],
#    221
#    222                                               #################################
#    223                                               ### SET META-VARIABLES FOR SIMULATION ###
#    224                                               #################################
#    225         1        711.0    711.0      0.0      dt =  duration/steps
#    226         1        551.0    551.0      0.0      N_0_var = int(N_0)
#    227         1        711.0    711.0      0.0      b_S = S_0*d_S
#    228
#    229                                               # draw population of reponding cells for agent-based simulations
#    230         1        971.0    971.0      0.0      psi_Na_I, psi_Na_HI, psi_Na_HE, L0_Na = activation_regulation[0], activation_regulation[1], activation_regulation[2], activation_regulation[3]
#    231         1        641.0    641.0      0.0      psi_NE_I, psi_NE_HI, psi_NE_HE, L0_NE = NE_regulation[0], NE_regulation[1], NE_regulation[2], NE_regulation[3]
#    232         1        551.0    551.0      0.0      psi_EM_I, psi_EM_HI, psi_EM_HE, L0_EM = EM_regulation[0], EM_regulation[1], EM_regulation[2], EM_regulation[3]
#    233         1        310.0    310.0      0.0      psi_EE_I, psi_EE_HI, psi_EE_HE, L0_EE = expansion_regulation[0], expansion_regulation[1], expansion_regulation[2], expansion_regulation[3]
#    234
#    235         1        260.0    260.0      0.0      p_tcr = 1.0 #np.ones(N_0_var)
#    236         1        340.0    340.0      0.0      p_cyt = 1.0 #np.ones(N_0_var)
#    237
#    238         1        250.0    250.0      0.0      int_steps = int(steps)
#    239
#    240                                               # define variables for storage
#    241         1       1923.0   1923.0      0.0      I = np.zeros(int_steps+1)
#    242         1       1582.0   1582.0      0.0      S = np.zeros(int_steps+1)
#    243         1       1382.0   1382.0      0.0      HI = np.zeros(int_steps+1)
#    244         1       1552.0   1552.0      0.0      HE = np.zeros(int_steps+1)
#    245         1       1452.0   1452.0      0.0      I_d_I = np.zeros(int_steps+1)
#    246         1       1532.0   1532.0      0.0      I_d_IE = np.zeros(int_steps+1)
#    247         1       1622.0   1622.0      0.0      S_d_SE = np.zeros(int_steps+1)
#    248
#    249         1      21552.0  21552.0      0.0      N_m = np.zeros((int_steps+1, N_0_var), dtype = np.int32)
#    250         1      23836.0  23836.0      0.0      N_m[0,:] +=1
#    251         1     166940.0 166940.0      0.0      T_Ecyt = [[] for i in np.arange(0, N_0_var)]
#    252         1     185477.0 185477.0      0.0      survive_M = [[] for i in np.arange(0, N_0_var)]
#    253                                               # T_Ecyt = np.zeros(int_steps+1, dtype = np.int32)
#    254
#    255         1       3996.0   3996.0      0.0      div_count = np.zeros(N_0_var)
#    256         1      32779.0  32779.0      0.0      div_E_count = np.log2(max_Na)*np.ones(N_0_var)
#    257         1       9644.0   9644.0      0.0      div_M_count = np.log2(max_Na)*np.ones(N_0_var)
#    258         1       1762.0   1762.0      0.0      diff_EpM_count = np.zeros(N_0_var, dtype = np.int32)
#    259         1       4146.0   4146.0      0.0      die_M = np.zeros(N_0_var, dtype = np.int32)
#    260
#    261         1       9935.0   9935.0      0.0      Na_m = np.zeros((int_steps+1, N_0_var), dtype = np.int32)
#    262         1       4887.0   4887.0      0.0      Ma_m = np.zeros((int_steps+1, N_0_var), dtype = np.int32)
#    263         1       4878.0   4878.0      0.0      E_m = np.zeros((int_steps+1, N_0_var), dtype = np.int32) # effector in periphary
#    264         1       1242.0   1242.0      0.0      T_E = np.zeros(N_0_var)
#    265
#    266         1        772.0    772.0      0.0      if out_data == "full":
#    267                                                   mycN_m = np.zeros((int_steps+1, N_0_var))
#    268                                                   mycMa_m = np.zeros((int_steps+1, N_0_var))
#    269                                                   mycE_m = np.zeros((int_steps+1, N_0_var))
#    270
#    271         1       3545.0   3545.0      0.0      bias_t = np.zeros((int_steps+1, 4))
#    272
#    273                                               # Define event timer variables
#    274         1        841.0    841.0      0.0      bound_N = np.zeros(N_0_var, dtype =np.int32)
#    275         1       1122.0   1122.0      0.0      bound_N_time = np.zeros(N_0_var)
#    276         1       4176.0   4176.0      0.0      Na_div_flag = np.ones(N_0_var, dtype =np.int32)
#    277         1       3115.0   3115.0      0.0      Na_flag = np.ones(N_0_var, dtype =np.int32)
#    278
#    279         1       1052.0   1052.0      0.0      mycN = np.zeros(N_0_var)
#    280         1        911.0    911.0      0.0      mycE = np.zeros(N_0_var)
#    281         1       2303.0   2303.0      0.0      mycMa = np.zeros(N_0_var)
#    282
#    283         1       7381.0   7381.0      0.0      r_NaE = np.zeros((int_steps+1, N_0_var))
#    284         1       6550.0   6550.0      0.0      r_EM = np.zeros((int_steps+1, N_0_var))
#    285         1       4817.0   4817.0      0.0      r_Na = np.zeros((int_steps+1, N_0_var))
#    286         1       4697.0   4697.0      0.0      r_EE = np.zeros((int_steps+1, N_0_var))
#    287         1       1262.0   1262.0      0.0      cum_r_NaE = np.zeros(N_0_var)
#    288
#    289         1       1191.0   1191.0      0.0      b_unbind_t = np.zeros(N_0_var)
#    290         1        942.0    942.0      0.0      b_N_bind = np.zeros(N_0_var)
#    291         1       8322.0   8322.0      0.0      b_Na_div = np.ones(N_0_var)/char_times[2]
#    292         1        511.0    511.0      0.0      b_myc_t = np.zeros(N_0_var)
#    293         1       5127.0   5127.0      0.0      b_E_div = np.ones(N_0_var)/char_times[3]
#    294         1       4217.0   4217.0      0.0      b_Ma_div = np.ones(N_0_var)/char_times[4]
#    295         1       5518.0   5518.0      0.0      d_E_die = np.ones(N_0_var)/char_times[5]
#    296
#    297                                               #################################
#    298                                               ### RUN POPULATION SIMULATION ###
#    299                                               #################################
#    300         1        160.0    160.0      0.0      t = 0.0
#    301         1        771.0    771.0      0.0      S[0] = S_0
#    302         1        241.0    241.0      0.0      I[0] = I_0
#    303         1        221.0    221.0      0.0      HI[0] = 0.0
#    304         1        170.0    170.0      0.0      HE[0] = 0.0
#    305
#    306         1        130.0    130.0      0.0      sum_e_m = 0
#    307
#    308      2501     468150.0    187.2      0.0      for i in np.arange(1, int_steps + 1):
#    309                                                   # select virulence model:
#    310      2500    1106679.0    442.7      0.1          if (b_I > 0 and I_0 <= S_0/1000) or infection_model == 'acute': # "acute"
#    311      2500     346416.0    138.6      0.0              b_I_t = b_I
#    312      2500     377259.0    150.9      0.0              d_Sauto = 0.0
#    313      2500     409556.0    163.8      0.0              infection_model = 'acute'
#    314                                                   elif (b_I > 0 and I_0 > S_0/1000) or infection_model == 'cancer': # "cancer"
#    315                                                       b_I_t = b_I/S_0
#    316                                                       d_Sauto = 0.0
#    317                                                       infection_model = 'cancer'
#    318                                                   elif b_I == 0 or infection_model == 'autoimmune': # "autoimmune"
#    319                                                       b_I_t = 0.0
#    320                                                       d_Sauto = d_I
#    321                                                       K_SE = K_IE
#    322                                                       I_0 = 0.0
#    323                                                       infection_model = 'autoimmune'
#    324                                                   else:
#    325                                                       b_I_t = b_I
#    326                                                       d_Sauto = 0
#    327
#    328                                                   # Compute total population of cell types
#    329                                                   # Use sum computed in previous iteration.
#    330      2500     341877.0    136.8      0.0          E_pop = sum_e_m
#    331
#    332                                                   #### Run infection dynamics: replication and effector clearance ####
#    333
#    334                                                   # Update state of susceptible, infected and inflammation
#    335                                                   # (a) event variables
#    336      2500    3303373.0   1321.3      0.3          S_to_I = dt * S[i - 1] * (I[i - 1] >= I_0) * b_I_t * I[i - 1] * (S[i - 1] >= 1.0)
#    337      2500    3441723.0   1376.7      0.3          I_d_IE[i] += I_d_IE[i - 1] + dt * I[i - 1] * d_IE * E_pop / (K_IE + I[i - 1] + E_pop) # infected/cancer cells killed by immune response
#    338      2500    2181324.0    872.5      0.2          I_d_I[i] += I_d_I[i - 1] + dt * I[i - 1]*d_I*(infection_model == "acute") # cells killed by infection
#    339      2500    3195457.0   1278.2      0.3          S_d_SE[i] += S_d_SE[i - 1] + dt * S[i - 1] * (d_IE * E_pop / (K_SE + S[i - 1] + E_pop)) # susceptible cells killed by immune response
#    340
#    341                                                   # (b) state variables
#    342      7500    2579216.0    343.9      0.2          S[i] += S[i - 1] - S_to_I + dt * (
#    343      5000    4558150.0    911.6      0.4              b_S - (d_S + (d_Sauto / t_Hauto) * np.exp(-(t / t_Hauto)**2 / 2)) * S[i - 1]
#    344      2500     985222.0    394.1      0.1              - (S_d_SE[i] - S_d_SE[i - 1])
#    345      2500     759041.0    303.6      0.1          ) * (S[i - 1] >= 1.0)
#    346
#    347      2500    2909274.0   1163.7      0.2          I[i] += I[i - 1] + S_to_I - (I_d_IE[i] + I_d_I[i] - I_d_IE[i - 1] - I_d_I[i - 1])
#    348
#    349      2500    4542721.0   1817.1      0.4          harm_detected = (I_d_I[i] - I_d_I[i - 1]) + dt * S[i - 1] * (d_Sauto / t_Hauto) * np.exp(-(t / t_Hauto)**2 / 2) + S_to_I * (infection_model == "cancer")
#    350      2500    1809285.0    723.7      0.1          immunopathology = (S_d_SE[i] - S_d_SE[i - 1]) + (I_d_IE[i] - I_d_IE[i - 1])
#    351      2500    1628030.0    651.2      0.1          cells_sensed = I[i - 1] + (S[i - 1] * K_IE / K_SE)
#    352
#    353      2500    2984031.0   1193.6      0.2          HI[i] += HI[i - 1] + b_H * harm_detected - dt * d_H * HI[i - 1] * (HI[i - 1] >= 0.0)
#    354
#    355      2500    2629298.0   1051.7      0.2          HE[i] += HE[i - 1] + b_H * immunopathology - dt * d_H * HE[i - 1] * (HE[i - 1] >= 0.0)
#    356
#    357                                                   ## I. Recruitment/Priming
#    358
#    359                                                   # (a) Phase 1: Naive cells encounter and bind APCs
#    360      2500     511507.0    204.6      0.0          if cells_sensed >= 1:
#    361      2500  109554262.0  43821.7      8.8              bound_N += rng.binomial(N_m[i - 1], b_N_bind * dt) - rng.binomial(N_m[i - 1], b_unbind_t * dt)
#    362                                                   else:
#    363                                                       bound_N = 0
#    364
#    365      2500   18990879.0   7596.4      1.5          bound_N_time += dt * (bound_N - (1 - bound_N) * bound_N_time * N_m[i - 1]) # only reset to zero if the cell is not activated
#    366
#    367                                                   # (b) Phase 2: Activated naive cells are bound to APCs and receive stimulation.
#    368      2500   15953479.0   6381.4      1.3          act_N = (1 - bound_N) * (mycN >= myc_thresh) * (N_m[i - 1] > 0)
#    369
#    370                                                   # (c) Phase 3: Unbound activated naive cells divide and then differentiate
#    371      2500   42101196.0  16840.5      3.4          div_Na = rng.binomial(Na_m[i - 1] * Na_div_flag, dt * b_Na_div)
#    372
#    373      5000   35447542.0   7089.5      2.8          diff_NaE = rng.binomial(
#    374      2500    8112955.0   3245.2      0.7              Na_m[i - 1] * (1 - Na_div_flag),
#    375      2500   17843472.0   7137.4      1.4              1 - np.exp(-cum_r_NaE*dt) if np.sum(Na_m[i - 1]) > 0 else 0
#    376                                                   )
#    377
#    378                                                   ## II. Expansion
#    379
#    380                                                   # (a) New central memory cells divide
#    381      2500   45937424.0  18375.0      3.7          div_Ma = rng.binomial(Ma_m[i - 1] - diff_EpM_count, dt * b_Ma_div)
#    382
#    383                                                   # (b) Effector cells divide, differentiate, die
#    384      2500   79372559.0  31749.0      6.4          die_E = rng.binomial(E_m[i - 1], d_E_die * dt)
#    385      2500   69296573.0  27718.6      5.6          diff_EM = rng.binomial(E_m[i - 1] - die_E, dt * r_EM[i - 1])
#    386      2500   56127917.0  22451.2      4.5          div_E = rng.binomial(E_m[i - 1] - die_E - diff_EM, dt * b_E_div)
#    387      2500    8849646.0   3539.9      0.7          diff_EpM_count += diff_EM - die_M
#    388
#    389                                                   #### Update population dynamics: ####
#    390      2500   13493698.0   5397.5      1.1          N_m[i] += N_m[i - 1] - act_N
#    391      2500   27398731.0  10959.5      2.2          Na_m[i] += Na_m[i - 1] + div_Na + act_N - (1 - Na_div_flag) * Na_m[i - 1]
#    392
#    393      2500   29603791.0  11841.5      2.4          Ma_m[i] += Ma_m[i - 1] + div_Ma + (1 - Na_div_flag)*(Na_m[i - 1] - diff_NaE) + diff_EM - die_M
#    394      2500   24625584.0   9850.2      2.0          E_m[i] += E_m[i - 1] + div_E + (1 - Na_div_flag) * diff_NaE - (die_E + diff_EM)
#    395
#    396                                                   # Evaluate sums and create masks
#    397      2500   13536197.0   5414.5      1.1          sum_n_m = np.sum(N_m[i])
#    398      2500   11677730.0   4671.1      0.9          sum_e_m = np.sum(E_m[i])
#    399      2500    4619351.0   1847.7      0.4          e_m_nonzero_mask = E_m[i] > 0
#    400      2500    3586903.0   1434.8      0.3          n_m_nonzero_mask = N_m[i] > 0
#    401      2500    3472579.0   1389.0      0.3          na_m_nonzero_mask = Na_m[i] > 0
#    402      2500    6157502.0   2463.0      0.5          ma_m_nonzero_mask = Ma_m[i] + Ma_m[i-1]> 0
#    403      2500    1921386.0    768.6      0.2          n_na_sum_nonzero_mask = n_m_nonzero_mask | na_m_nonzero_mask
#    404
#    405                                                   # store time cells spend in effector effector
#    406      2500    6043669.0   2417.5      0.5          T_E += dt * e_m_nonzero_mask if sum_e_m > 0 else 0.0
#    407      2500   13111508.0   5244.6      1.1          d_E_die = 0.5 * np.sqrt(np.pi) * e_m_nonzero_mask * T_E / char_times[5]**2
#    408      2500    4225696.0   1690.3      0.3          die_M = 0*die_M
#    409
#    410                                                   # store time an effector spends in cytotoxic state
#    411      2500   22608649.0   9043.5      1.8          for_where = ((1 - Na_div_flag)*(Na_m[i-1] - diff_NaE) + div_Ma + diff_EM + ma_m_nonzero_mask*memory_death > 0)
#    412      2500    5626064.0   2250.4      0.5          where_output = np.where(for_where)[0]
#    413     13844    5665235.0    409.2      0.5          for l in where_output:
#    414
#    415     11344    1570720.0    138.5      0.1              if memory_death:
#    416                                                           if Ma_m[i,l] > 0:
#    417                                                               T_Ecyt[l] = list(itertools.compress(T_Ecyt[l], survive_M[l])) + ((1 - Na_div_flag[l])*(Na_m[i-1,l] - diff_NaE[l]) + div_Ma[l]) * [0.0] + diff_EM[l] * [T_E[l].item()]
#    418                                                               arr = np.array(T_Ecyt[l])
#    419                                                               survive_M[l] = (rng.random(size = Ma_m[i,l]) > (arr > 0)*dt/memory_lifespan(arr, min_time = dt))
#    420                                                               die_M[l] = Ma_m[i,l] - np.sum(survive_M[l])
#    421                                                           else:
#    422                                                               T_Ecyt[l] += ((1 - Na_div_flag[l])*(Na_m[i-1,l] - diff_NaE[l]) + div_Ma[l]) * [0.0] + diff_EM[l] * [T_E[l].item()]
#    423                                                               arr = np.array([])
#    424                                                               survive_M[l] = []
#    425                                                               die_M[l] = 0
#    426                                                       else:
#    427     11344   33509624.0   2954.0      2.7                  T_Ecyt[l] += ((1 - Na_div_flag[l])*(Na_m[i-1,l] - diff_NaE[l]) + div_Ma[l]) * [0.0] + diff_EM[l] * [T_E[l].item()]
#    428
#    429                                                   # Update division flag to allow division to proceed
#    430      2500    7628545.0   3051.4      0.6          div_count += div_Na + div_E + div_Ma
#    431      2500    3637937.0   1455.2      0.3          div_E_count += div_E
#    432      2500    3426312.0   1370.5      0.3          div_M_count += div_Ma
#    433      2500    5566937.0   2226.8      0.4          Na_div_flag = (Na_m[i] < max_Na)*(na_m_nonzero_mask)
#    434
#    435                                                   #### New binding events ####
#    436      7500   25593283.0   3412.4      2.1          b_N_bind = (n_m_nonzero_mask) * (1 - bound_N) * f_XtoY(
#    437      2500    1449509.0    579.8      0.1              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    438      2500    3646728.0   1458.7      0.3              psi_1 = 0.0, psi_2 = psi_max, psi_3 = 0.0, L_0 = -psi_max*np.log(2), K_1 = S_0, K_2 = K_EH, K_3 = K_EH
#    439      5000    1283482.0    256.7      0.1          ) / (char_times[0] if infection_model != "autoimmune" else t_bind_eM) if cells_sensed >= 1 else 0.0
#    440
#    441      4534    6722628.0   1482.7      0.5          b_unbind_t = bound_N * np.fmin(
#    442      4068    6729487.0   1654.2      0.5              2 * bound_N_time / (
#    443     10170    9495668.0    933.7      0.8                  f_XtoY(
#    444      2034    1055329.0    518.8      0.1                      sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    445      2034    2556815.0   1257.0      0.2                      psi_1 = psi_max, psi_2 = 0.0,psi_3 = 0.0, L_0 = -psi_max*np.log(2),
#    446      2034     598130.0    294.1      0.0                      K_1 = (K_IE*(infection_model != "autoimmune") + K_SE*(infection_model == "autoimmune")),
#    447      2034     239177.0    117.6      0.0                      K_2 = K_EH, K_3 = K_EH
#    448      6102    2302004.0    377.3      0.2                  ) * char_times[1] * 2 / np.sqrt(np.pi)
#    449      4068     663646.0    163.1      0.1              )**2, 1 / dt
#    450      2500   13154254.0   5261.7      1.1          ) if np.sum(bound_N) >= 1 else 0.0
#    451
#    452      7500   14560785.0   1941.4      1.2          b_myc_t = b_myc * f_XtoY(
#    453      2500    1231056.0    492.4      0.1              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    454      2500     354531.0    141.8      0.0              psi_1 = psi_Na_I, psi_2 = psi_Na_HI, psi_3 = psi_Na_HE, L_0 = L0_Na,
#    455      2500     626401.0    250.6      0.1              K_1 = (K_IE*(infection_model != "autoimmune") + K_SE*(infection_model == "autoimmune")),
#    456      2500     275025.0    110.0      0.0              K_2 = K_EH, K_3 = K_EH
#    457      2500     254567.0    101.8      0.0          ) * bound_N
#    458
#    459                                                   #### MYC Dynamics ####
#    460     15000   36991692.0   2466.1      3.0          mycN = (mycN + dt * (b_myc_t - (1 - bound_N) * f_XtoY(
#    461      2500    1198912.0    479.6      0.1              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    462      2500     658109.0    263.2      0.1              psi_1 = -psi_EE_I, psi_2 = -psi_EE_HI, psi_3 = -psi_EE_HE, L_0 = -L0_EE,
#    463      2500     586836.0    234.7      0.0              K_1 = (K_IE*(infection_model != "autoimmune") + K_SE*(infection_model == "autoimmune")),
#    464      2500     260735.0    104.3      0.0              K_2 = K_EH, K_3 = K_EH
#    465     10000    4658659.0    465.9      0.4          ) * mycN * d_myc * (mycN > 0))) * n_na_sum_nonzero_mask # (1 - bound_N)*
#    466
#    467     15000   27077198.0   1805.1      2.2          mycE = (mycE - dt * (f_XtoY(
#    468      2500    1231168.0    492.5      0.1              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    469      2500     654954.0    262.0      0.1              psi_1 = -psi_EE_I, psi_2 = -psi_EE_HI, psi_3 = -psi_EE_HE, L_0 = -L0_EE,
#    470      2500     623308.0    249.3      0.1              K_1 = (K_IE*(infection_model != "autoimmune") + K_SE*(infection_model == "autoimmune")),
#    471      7500     892688.0    119.0      0.1              K_2 = K_EH, K_3 = K_EH)*mycE*d_myc)
#    472      5000    7482170.0   1496.4      0.6          ) * (E_m[i] >= 1) + mycN * (na_m_nonzero_mask)
#    473
#    474      2500   18976142.0   7590.5      1.5          mycMa = (mycMa - dt * mycMa * d_myc) * (Ma_m[i] > 0) + mycN * na_m_nonzero_mask # higher decay rate of myc
#    475
#    476                                                   #### Time-dependent rates modulated by antigen and cytokine signals ####
#    477      2500     709763.0    283.9      0.1          b_Na_div = 1 / char_times[2]
#    478      2500   11694933.0   4678.0      0.9          b_E_div = (mycE >= myc_thresh) * (div_count < max_expand) / char_times[3]
#    479      2500   10577562.0   4231.0      0.9          b_Ma_div = (mycMa >= myc_thresh) * (div_count < max_expand) / char_times[4]
#    480
#    481                                                   #### Transition probabilities modulated by antigen and cytokine signals ####
#    482      2500   17957544.0   7183.0      1.4          r_Na[i] += b_myc_t / myc_thresh
#    483
#    484     10000   46369285.0   4636.9      3.7          r_NaE[i] += (r_NaE[i - 1] + 2 * (mycN >= myc_thresh) * dt * f_XtoY(
#    485      2500    1275482.0    510.2      0.1              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    486      2500     405168.0    162.1      0.0              psi_1 = psi_NE_I, psi_2 = psi_NE_HI, psi_3 = psi_NE_HE,L_0 = L0_NE,
#    487      2500     603979.0    241.6      0.0              K_1 = (K_IE*(infection_model != "autoimmune") + K_SE*(infection_model == "autoimmune")),
#    488      2500     276919.0    110.8      0.0              K_2 = K_EH, K_3 = K_EH
#    489      5000    3431900.0    686.4      0.3          ) / (2 / np.sqrt(np.pi) * (char_times[1] - char_times[6]))**2) * n_na_sum_nonzero_mask
#    490
#    491     10000   30645009.0   3064.5      2.5          r_EM[i] += (r_EM[i - 1] + 2 * dt * f_XtoY(
#    492      2500    1128534.0    451.4      0.1              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    493      2500     352801.0    141.1      0.0              psi_1 = psi_EM_I, psi_2 = psi_EM_HI, psi_3 = psi_EM_HE, L_0 = L0_EM,
#    494      2500     561615.0    224.6      0.0              K_1 = (K_IE*(infection_model != "autoimmune") + K_SE*(infection_model == "autoimmune")),
#    495      2500     284601.0    113.8      0.0              K_2 = K_EH, K_3 = K_EH
#    496      5000    3147646.0    629.5      0.3          ) / (2 / np.sqrt(np.pi) * (char_times[1] + char_times[6]))**2) * e_m_nonzero_mask # char_times[6] + char_times[6] to reverse priming and differentiation
#    497
#    498      2500   12625927.0   5050.4      1.0          r_EE[i] += b_E_div
#    499
#    500      2500    2443132.0    977.3      0.2          cum_r_NaE += r_NaE[i]
#    501
#    502                                                   #### Store myc levels ####
#    503      2500     530238.0    212.1      0.0          if out_data == "full":
#    504                                                       mycN_m[i] += mycN
#    505                                                       mycMa_m[i] += mycMa
#    506                                                       mycE_m[i] += mycE
#    507
#    508                                                   #### Store differentiation biases
#    509      2500    1571444.0    628.6      0.1          to_add_to_bias = np.zeros(4)
#    510      2500    3603664.0   1441.5      0.3          if sum_n_m > 0.:
#    511      2500   28888603.0  11555.4      2.3              to_add_to_bias[0] = np.mean(r_Na[i][n_m_nonzero_mask])
#    512      2500   20407032.0   8162.8      1.6              to_add_to_bias[1] = np.mean(r_NaE[i][n_m_nonzero_mask])
#    513      2500    3286236.0   1314.5      0.3          if sum_e_m > 0.:
#    514      2143   18418173.0   8594.6      1.5              to_add_to_bias[2] = np.mean(r_EM[i][e_m_nonzero_mask])
#    515      2143   17427462.0   8132.3      1.4              to_add_to_bias[3] = np.mean(r_EE[i][e_m_nonzero_mask])
#    516      2500    2587538.0   1035.0      0.2          bias_t[i] += to_add_to_bias
#    517
#    518                                                   # Increment time
#    519      2500     654318.0    261.7      0.1          t += dt
#    520
#    521                                               # Collect population dynamics
#    522         1    4140232.0    4e+06      0.3      N, Na, Ma, E = np.sum(N_m, axis = 1), np.sum(Na_m, axis = 1), np.sum(Ma_m, axis = 1), np.sum(E_m, axis = 1)
#    523
#    524         1     914981.0 914981.0      0.1      T_pEcytM = np.concatenate(T_Ecyt) if N_0 > 0 else np.array([0.0]) # time that memory spends in effector
#    525         1      18839.0  18839.0      0.0      count_cM = np.sum(T_pEcytM == 0
#    526         1      60020.0  60020.0      0.0                       ) if len(T_pEcytM[T_pEcytM == 0]) > 0 and N_0 > 0.0 else 0.0
#    527         1      34141.0  34141.0      0.0      count_eM = np.sum(memory_lifespan(T_pEcytM) > char_times[5]
#    528         1      44456.0  44456.0      0.0                       ) if len(T_pEcytM[memory_lifespan(T_pEcytM) > char_times[5]]) > 0 and N_0 > 0.0 else 0.0
#    529
#    530                                               # Project out surviving primary memory
#    531         2      36304.0  18152.0      0.0      cM_duration = np.mean(memory_lifespan(T_pEcytM[T_pEcytM == 0])
#    532         2      18097.0   9048.5      0.0                           )/365.25 if len(T_pEcytM[T_pEcytM == 0]) > 0 and N_0 > 0.0 else 0.0
#    533         2      69103.0  34551.5      0.0      eM_duration = np.mean(memory_lifespan(T_pEcytM[memory_lifespan(T_pEcytM) > char_times[5]])
#    534         2      35183.0  17591.5      0.0                           )/365.25 if len(T_pEcytM[memory_lifespan(T_pEcytM) > char_times[5]]) > 0 and N_0 > 0.0 else 0.0
#    535
#    536         1       1452.0   1452.0      0.0      zeros_n_0_var = np.zeros(N_0_var)
#    537
#    538         2      37546.0  18773.0      0.0      lineage_comp = np.vstack([
#    539         1     299108.0 299108.0      0.0          np.amax(Na_m, axis = 0), div_M_count, div_E_count,
#    540         1       4577.0   4577.0      0.0          p_tcr + zeros_n_0_var, p_cyt + zeros_n_0_var
#    541                                               ])
#    542
#    543         1      20651.0  20651.0      0.0      dyn_data = np.array([S, I, N, Na, E, Ma, HI, I_d_I + I_d_IE, S_d_SE, HE]).T # add I_d_IE as a separate variable
#    544         1        150.0    150.0      0.0      prim_bias = bias_t
#    545
#    546         1      51257.0  51257.0      0.0      ts = np.linspace(0, duration, int_steps + 1)
#    547
#    548                                               # Compute summary statistics from simulations
#    549                                               ## extract primary/secondary infection dynamics
#    550         1       3245.0   3245.0      0.0      pS, pI, N, Na, pE, pM, pHI, pI_d_I, pI_d_SE, pHE = dyn_data[:,0], dyn_data[:,1], dyn_data[:,2], dyn_data[:, 3], dyn_data[:,4], dyn_data[:,5], dyn_data[:,6], dyn_data[:,7], dyn_data[:,8], dyn_data[:,9]
#    551
#    552         1        591.0    591.0      0.0      dt = ts[1]-ts[0]
#    553
#    554         3       8783.0   2927.7      0.0      parameters = np.concatenate((np.array([S_0, I_0, b_I, d_S, d_I, d_IE, K_IE,
#    555         1        160.0    160.0      0.0                b_H, d_H, K_EH,
#    556         1        140.0    140.0      0.0                N_0, max_Na, b_myc, d_myc, myc_thresh]),
#    557         1        171.0    171.0      0.0                char_times,
#    558         1        110.0    110.0      0.0                activation_regulation, NE_regulation, EM_regulation, expansion_regulation))
#    559
#    560         2      20150.0  10075.0      0.0      sim_summary = np.array([np.sum(pI*dt) + np.sum(pS*dt)*(infection_model == "autoimmune"),
#    561         1      14872.0  14872.0      0.0                         np.argmax(pI)*dt,
#    562         1       6690.0   6690.0      0.0                         np.argmax(pI < I_0)*dt,
#    563         1       7221.0   7221.0      0.0                         np.amax(pI_d_I) + I[-1],
#    564         1       4587.0   4587.0      0.0                         np.amax(pI_d_SE),
#    565         1       4888.0   4888.0      0.0                         np.sum(div_E_count),
#    566         1      10566.0  10566.0      0.0                         np.argmax(pE)*dt + sim_duration*(np.max(pE) < 1.0),
#    567         1      11917.0  11917.0      0.0                         (np.argmax(pE >= N_0 , axis = 0)*dt + sim_duration*(np.max(pE) < N_0)) if N_0 > 0 else sim_duration,
#    568         1        230.0    230.0      0.0                         count_eM,
#    569         1        341.0    341.0      0.0                         eM_duration,
#    570         1        110.0    110.0      0.0                         count_cM,
#    571         1        331.0    331.0      0.0                         cM_duration,
#    572         1       6510.0   6510.0      0.0                         np.sum(pHE*dt),
#    573         1       6230.0   6230.0      0.0                         np.sum(pHI*dt),
#    574         1       9054.0   9054.0      0.0                         np.amin(pS)])
#    575
#    576                                               # down-size timeseries
#    577         1       1072.0   1072.0      0.0      pnts = int(0.1*steps)
#    578         1      42513.0  42513.0      0.0      keep = [i*10 for i in np.arange(0,pnts)]
#    579
#    580         1        421.0    421.0      0.0      if out_data == "full":
#    581                                                   out_dict = {"reg_coeffs": np.concatenate((activation_regulation, NE_regulation, EM_regulation, expansion_regulation)), "cell_time_series": dyn_data, "time": ts, "lineage_diff": lineage_comp, "prim_diff_bias": prim_bias, "eff_by_lin": (E_m), "N_myc_by_lin": mycN_m, "Ma_myc_by_lin": mycMa_m, "E_myc_by_lin": mycE_m, "parameters": parameters, "summary_stats": sim_summary, "pmemory_formed": T_pEcytM if N_0 > 0 else []}
#    582         1        170.0    170.0      0.0      elif out_data == "small":
#    583         1      37917.0  37917.0      0.0          out_dict = {"cell_time_series": dyn_data[keep], "prim_diff_bias": prim_bias[keep],"parameters": parameters, "summary_stats": sim_summary}
#    584
#    585         1        110.0    110.0      0.0      return out_dict

# %%
# Run single simulation
# %timeit -n 2 -r 2
data_dict = lin_stoch_sim(N_0 = N_0,
                          I_0 = I_0,
                          b_I = b_I, 
                          K_IE = K_IE,
                          d_I = d_I,
                          K_EH = K_EH,
                          NE_regulation = NE_regulation,
                          EM_regulation = EM_regulation,
                          activation_regulation = Na_regulation,
                          expansion_regulation = EE_regulation,
                          infection_model = infection_model,
                          reg_model = 'mwc_like',
                          out_data = "full",
                          memory_death = False)

# %%
regs = data_dict["reg_coeffs"]
dyn = data_dict["cell_time_series"]
ts = data_dict["time"]
lin_comp = data_dict["lineage_diff"]
p_diff = data_dict["prim_diff_bias"]
parameters = data_dict["parameters"]
sim_summary = data_dict["summary_stats"]
mycN = data_dict["N_myc_by_lin"]
mycMa = data_dict["Ma_myc_by_lin"]
mycE = data_dict["E_myc_by_lin"]
Eff = data_dict["eff_by_lin"]
T_pEcytM = data_dict["pmemory_formed"]

S, I, N, Na, E, M, HI, I_d_I, I_d_S, HE = dyn[:,0], dyn[:,1], dyn[:,2], dyn[:, 3], dyn[:,4], dyn[:,5], dyn[:,6], dyn[:,7], dyn[:,8], dyn[:,9]

reg_string = '-'.join(np.array(Na_regulation + NE_regulation + EM_regulation + EE_regulation).astype('U4'))

# %%
# Plot simulated immune dynamics
fig, (ax1, ax2, ax3) = plt.subplots(3, dpi = 150, constrained_layout=True, sharex = False, figsize=(5,5))

ax1.plot(ts, S, 'k', label = r'susceptible, $S$')
ax1.plot(ts, I, 'b', label = r'infected, $I$')

ax1.plot(ts, I_d_S, 'r', linestyle = '--', label = r'susceptible killed')
ax1.plot(ts, I_d_I, 'g', linestyle = '--', label = r'infected killed')
ax1.set(ylabel='Cell count')
ax1.set_ylim(1, S_0*2)
ax1.semilogy()
ax1.minorticks_off()
ax1.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

ax2.plot(ts, Na, 'b', label = r'Activated, $N^*$')
ax2.plot(ts, E, 'orange', label = r'Effector, $E$')
ax2.plot(ts, M, 'g', label = r'Memory, $M$')
ax2.plot(ts, S, 'grey', label = r'Susceptible, $S$')
ax2.plot(ts, I, 'r', label = r'infected, $I$')
ax2.set(ylabel='Cell count')
ax2.semilogy()
ax2.minorticks_off()
ax2.set_ylim(1, S_0*2)
ax2.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

ax3.plot(ts, f_XtoY_mwc_like(sig_1 = I, sig_2 = HI, sig_3 = HE, 
                             psi_1 = EM_regulation[0], psi_2 = EM_regulation[1], psi_3 = EM_regulation[2], L_0 = EM_regulation[3], 
                             K_1 = K_IE, K_2 = K_EH, K_3 = K_EH),
         'k-', label = r'Regulation, $f(I,H)$')
ax3.set(xlabel=r'Time [days]', ylabel='Regulation')
ax3.minorticks_off()
ax3.set_ylim(0,1.05)

fig.savefig("_figs/"+infection_model+'-'+'virus-effector dynamics-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
plt.plot(ts, N)
plt.ylim(0, 1.05*N_0)
np.mean(np.argmax(Eff >0 , axis = 0)*(ts[1]-ts[0])*(np.amax(Eff, axis = 0) > 0 ))
# Out:
# 4.646552000000001

# %%
plt.plot(ts, np.log((1 + I/K_IE)), 'r', label = "Ag.")
plt.plot(ts, np.log((1 + HE/K_EH)), 'b--', label = "Anti-inflam.")
plt.plot(ts, np.log((1 + HI/K_EH)), 'k--', label = "Pro-inflam.")
plt.legend()

# %%
plt.plot(ts,d_IE*E/(K_IE + I + E), 'r')
plt.plot(ts, d_IE*E/(K_IE + E), 'k--')

# %%
print(f'Memory fraction = {(sim_summary[8]+sim_summary[10])/sim_summary[5]}')
print(f'Number of memory cells = {np.max(M)}')
print(f'1st infection harm = {sim_summary[3]/(d_S*S_0)}')
print(f'1st response toxicity = {sim_summary[4]/(d_S*S_0)}')
print(f'Minimum susceptible = {np.min(S)/S_0}')
# Out:
# Memory fraction = 0.11204069707489774
# Number of memory cells = 27968.0
# 1st infection harm = 22.26919844881242
# 1st response toxicity = 11.9283580931463
# Minimum susceptible = 0.7829943723391039

# %%
# Plot simulated infection dynamics: pretty plots
pnts = 50
keep = [i*int(len(E)/pnts) for i in np.arange(0,pnts)]
sus = S[keep]
naive = Na[keep]
eff = E[keep]
mem = M[keep]
p_load = np.log(1 + I[keep]/K_IE)/np.log(1 + np.max(I[keep])/K_IE) if np.max(I[keep]) > 0 else I[keep]
inflam = np.log((1 + HI[keep]/K_EH))/np.log((1 + np.max(HI[keep])/K_EH))
anti_inflam = np.log((1 + HE[keep]/K_EH))/np.log((1 + np.max(HE[keep])/K_EH)) if np.max(HE[keep]) > 0 else HE[keep]
inf_harm = I_d_I[keep]
toxicity = I_d_S[keep]
time = ts[keep]

fig, ax = plt.subplots(figsize=(7.5,5))

ax.plot(ts, I, 'r', label = r'Infected, $I$', linewidth=2.5)
# ax.plot(ts, S, 'grey', label = r'Susceptible, $S$', linewidth=2.5)

ax.plot(ts, E + M, 'orange', zorder = 1, linewidth=2.5, label = r'T cells, $E + M$')
im = ax.scatter(time, eff+mem, marker ='o', c = p_load, cmap='coolwarm') #, norm=mpl.colors.LogNorm())

ax.plot(ts, I_d_I, 'black', zorder = 1, linewidth=2.5, label = r'Infection harm')
ax.plot(ts, I_d_S, 'green', zorder = 1, linewidth=2.5, label = r'Toxicity harm')
# ax.plot(time, mem, 'k--')
# ax.scatter(time, mem, marker ='s', c = p_load, cmap='coolwarm',
#             label = r'Mem., $M$') #, norm=mpl.colors.LogNorm())

# ax.plot(time, inf_harm, 'r', linewidth = 2.0, label = r'Harm, $\mathcal{H}_I$')

# ax.plot(time, toxicity, 'y', linewidth = 2.0,label = r'Toxicity, $\mathcal{H}_S$')

ax.set_box_aspect(1)
cb = fig.colorbar(im, ax=ax, orientation='vertical', shrink = 0.75, pad = 0.05)
cb.set_label('Ag. stimulation', fontsize = 14)
cb.ax.tick_params(labelsize=8)
ax.set_ylabel('Cell count', fontsize = 18)
ax.set_xlabel(r"Time [days]", fontsize = 18)
ax.semilogy()
ax.minorticks_off()
ax.set_ylim(1,)
# locmaj = mpl.ticker.LogLocator(numticks=4)
# ax.yaxis.set_major_locator(locmaj)

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        ax.axvline(x=time[i], linestyle='-', linewidth=6.5, color='pink', alpha=inflam[i], label =r"Harm. stim.", zorder = 0)
        ax.axvline(x=time[i], linestyle='-', linewidth=6.5, color='grey', alpha=anti_inflam[i]/2, label =r"Tox. stim.", zorder = 0)
    else:
        ax.axvline(x=time[i], linestyle='-', linewidth=6.5, color='pink', alpha=inflam[i], zorder = 0)
        ax.axvline(x=time[i], linestyle='-', linewidth=6.5, color='grey', alpha=anti_inflam[i]/2, zorder = 0)

ax.legend(loc='lower right', fontsize = 10)

plt.savefig('_figs/'+infection_model+'-timeline-of-infection-dynamics-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
# Plot simulated infection dynamics: pretty plots of harm
pnts = 50
keep = [i*int(len(E)/pnts) for i in np.arange(0,pnts)]

eff = E[keep]
p_load = I[keep]/S_0
sus = S[keep]/S_0
inf_harm = I_d_I[keep]/S_0
inflam_harm = I_d_S[keep]/S_0
inflam = np.log((1 + HI[keep]/K_EH))/np.log((1 + S_0/K_EH))
time = ts[keep]

plt.scatter(time, p_load, marker ='s', c =eff/K_IE, cmap='coolwarm', 
            label = r'Infected cells, $I$') #, norm=mpl.colors.LogNorm())
plt.plot(time, p_load, 'k--')

# plt.scatter(time, sus, marker ='>', c =eff/K_IE, cmap='coolwarm', 
#             label = r'Susceptible cells, $S$') #, norm=mpl.colors.LogNorm())
# plt.plot(time, sus, 'k--')

plt.scatter(time, inf_harm, marker ='o', c =eff/K_IE, cmap='coolwarm', 
            label = 'Infected cells killed')
plt.plot(time, inf_harm, 'k--')

plt.scatter(time, inflam_harm, marker ='*', c =eff/K_IE, cmap='coolwarm',
            label = 'Susceptible cells killed')
plt.plot(time, inflam_harm, 'k--')

plt.colorbar(label = "Primary effector response")
plt.ylabel('Fraction of susceptible cells', fontsize = 14)
plt.xlabel(r"Time, $t$ [days]", fontsize = 14)

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        plt.axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], label =r"Inflammation, $H$", zorder = 0)
    else:
        plt.axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        
plt.legend(loc='center right', bbox_to_anchor=(1.85, 0.8), fontsize = 10)
plt.savefig('_figs/'+infection_model+'-infection-harm-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
# Plot simulated infection dynamics: pretty plots
pnts = 150
keep = [1 + i*int(len(E)/pnts) for i in np.arange(0,pnts)]
bias_diff = p_diff[keep]
sus = S[keep]
p_load = np.log(1 + I[keep]/K_IE)/np.log(1 + np.max(I[keep])/K_IE) if np.max(I[keep]) > 0 else I[keep]
inflam = np.log((1 + HI[keep]/K_EH))/np.log((1 + np.max(HI[keep])/K_EH))
anti_inflam = np.log((1 + HE[keep]/K_EH))/np.log((1 + np.max(HE[keep])/K_EH)) if np.max(HE[keep]) > 0 else HE[keep]
time = ts[keep]

fig, axs = plt.subplots(2,2, figsize=(7,7))

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0, label =r"Inflammation, $H$")
        
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0, label =r"Anti-inflammation, $P$")
    else:
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0, label =r"Inflammation, $H$")
        
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0, label =r"Anti-inflammation, $P$")


im1 = axs[0,0].scatter(time, bias_diff[:,0], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$N \longrightarrow N^*$')
axs[0,0].plot(time, bias_diff[:,0],'k--')
axs[0,0].title.set_text(r'$N \longrightarrow N^*$')
axs[0,0].set_box_aspect(1)

im2 = axs[0,1].scatter(time, bias_diff[:,1], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$N^* \longrightarrow E$')
axs[0,1].plot(time, bias_diff[:,1],'k--')
axs[0,1].title.set_text(r'$N^* \longrightarrow E$')
axs[0,1].set_box_aspect(1)

im3 = axs[1,0].scatter(time, bias_diff[:,2], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$E \longrightarrow M$')
axs[1,0].plot(time, bias_diff[:,2],'k--')
axs[1,0].title.set_text(r'$E \longrightarrow M$')
axs[1,0].set_box_aspect(1)

im4 = axs[1,1].scatter(time, bias_diff[:,3], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$E \longrightarrow M$')
axs[1,1].plot(time, bias_diff[:,3],'k--')
axs[1,1].title.set_text(r'$E \longrightarrow E + E$')
axs[1,1].set_box_aspect(1)

axs[0,0].set_ylabel('Rate [day$^{-1}$]', fontsize = 14)
axs[1,0].set_ylabel('Rate [day$^{-1}$]', fontsize = 14)
axs[1,0].set_xlabel("Time [days]", fontsize = 14)
axs[1,1].set_xlabel("Time [days]", fontsize = 14)

fig.subplots_adjust(wspace=.3, hspace = 0.1)
cb = fig.colorbar(im1, ax=axs, shrink = 0.5, pad = 0.05, orientation='vertical')
cb.set_label('Ag. stimulation')

#cb.set_clim(-0.4,0.4)
    
# plt.colorbar(label =r"pathogen load, $I(t)$")
# plt.ylabel('transition weight', fontsize = 16)
# plt.xlabel("time (days)", fontsize = 16)
# plt.legend() #bbox_to_anchor=(1.05, 1.0), loc='upper left')

plt.savefig('_figs/'+infection_model+'-diff-bias-over-time-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %% [markdown]
# ### (2) Plot lineage-based trajectories

# %%
keys = np.array(['Memory', 'Effector'])
all_counts = lin_comp[1:3].T
effector_ranking = np.argsort(all_counts[:, 1])[::-1]
all_counts = all_counts[effector_ranking]
total_counts = all_counts.sum(axis=1)
norm_counts = all_counts / total_counts[:, None]
norm_counts[~np.isfinite(norm_counts)] = 0
comp_argsort = np.argsort(np.max(all_counts, axis=0))
bar_dict = {k: v for k, v in zip(keys[comp_argsort], norm_counts.T[comp_argsort])}
lineage_idxs = np.arange(all_counts.shape[0])

fig, ax = plt.subplots()
bottom = np.zeros(len(lineage_idxs))
cmap_colors = sns.color_palette('Set2', 10)
cmap_colors = [cmap_colors[i]
               for i in [0, 1, 5]]#[7, 2, 0, 1, 5]]
# cmap_colors = [cmap_colors[i]
#                for i in [6, 1, 2, 5, 0]]
width = 1

for i, (celltype, fraction) in enumerate(bar_dict.items()):
    ax.bar(lineage_idxs, fraction, width,
           edgecolor='k', linewidth=0.01,
           label=celltype, bottom=bottom, color=cmap_colors[i])
    bottom += fraction
    
ax.legend(loc='center right', bbox_to_anchor=(1.4, 0.5), fontsize = 12)
ax.set_xlim(-0.5, len(all_counts) - 0.5)
ax.set_xlabel('sub-clone lineages \n (ranked by effector response)', fontsize = 15)
ax.set_ylabel('fractional cell-fate \ncomposition', fontsize = 15)
#ax.set_yscale('log')

ax.set_xticks(np.arange(0, Eff.shape[1], int(Eff.shape[1]/10)))
ax.set_xticklabels(1 + np.arange(0, Eff.shape[1], int(Eff.shape[1]/10)), fontsize=9)

ax.set_yticks(np.round(np.arange(0, 1.2, 0.2), 1))
ax.set_yticklabels(ax.get_yticks(), fontsize=12)

fig.savefig("_figs/"+infection_model+'-'+'fates-by-lin-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
plt.errorbar(ts, np.mean(Eff, axis = 1), yerr = np.std(Eff, axis = 1), errorevery = 100)
plt.semilogy()
# Out:
# []

# %%
plt.plot(ts, mycE, 'r--')
plt.errorbar(ts, np.mean(mycE, axis = 1), yerr = np.std(mycE, axis = 1), errorevery = 100)
#plt.plot(ts, mycMa, 'k-')
plt.axhline(y = myc_thresh, color = 'k', linestyle = '--')
print(np.sum(np.max(mycE, axis=0) > myc_thresh)/N_0)
# Out:
# 0.7198

# %%
plt.hist(T_pEcytM, bins = 'auto', histtype='step');
plt.xlabel("Time in effector state")
plt.ylabel("Counts")
# Out:
# Text(0, 0.5, 'Counts')

# %%
plt.hist(memory_lifespan(T_pEcytM[memory_lifespan(T_pEcytM) > t_E_die])/365.25, bins = 'auto', histtype='step');
plt.xlabel("Memory lifespan")
plt.ylabel("Counts")
print(sim_summary[9], sim_summary[11])
# Out:
# 3.8263717279234863 5.0

# %%
# Compute max values in the data
r = np.arange(6)
width = 0.5
plt.bar(r, np.amax(np.array([I, Na, E, M, HI, HE]).T, axis = 0), width = width)

plt.xlabel("response")
plt.ylabel("value")

plt.xticks(r, ["Infected","Naive","Effector","Memory", "Inflammation", "Anti-inflammation"], fontsize = 7)

plt.semilogy()
plt.suptitle(r'Peak response response: $N_0=$ '+str(N_0) +r', $d_I=$'+str(d_I))
# Out:
# Text(0.5, 0.98, 'Peak response response: $N_0=$ 10000, $d_I=$0.5')

# %%
bias_1 = f_XtoY(I, HI, 
       -2.0, -2.0, 0.0, L_0 = 4*np.log(2), 
       K_I = K_IE, K_H = K_EH)
bias_2 = f_XtoY(I, HI, 
       -2.0, 2.0, 0.0, L_0 = -0*np.log(2), 
       K_I = K_IE, K_H = K_EH)

plt.plot(ts, bias_1, 'r')
plt.plot(ts, bias_2, 'k--')
plt.plot(ts, Na/np.amax(Na))
plt.plot(ts, A/(Na + A))
plt.plot(ts, H**l_H/(K_EH**l_H + H**l_H))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 bias_1 = f_XtoY(I, HI,
#       2        -2.0, -2.0, 0.0, L_0 = 4*np.log(2),
#       3        K_I = K_IE, K_H = K_EH)
#       4 bias_2 = f_XtoY(I, HI,
#       5        -2.0, 2.0, 0.0, L_0 = -0*np.log(2),
#       6        K_I = K_IE, K_H = K_EH)
#       8 plt.plot(ts, bias_1, 'r')
#
# NameError: name 'f_XtoY' is not defined

# %%
d="/gscratch/scrubbed/oukogu/infoimmune/sim_output/no_cell_var/raw/"
comment = "sparse-reg"
infection_model = "acute" # "cancer", "acute"
runs = 5

run(batch = [196.0], outdir=d, comment=comment, infection_model = infection_model, runs = runs, num_cpu = 136, run_time = 4.0)

# %%
d_file = '/gscratch/scrubbed/oukogu/infoimmune/sim_output/no_cell_var/raw/sim_batch_0.0-'+str(runs)+'-'+infection_model+'-'+comment+'.pkl'
with open(d_file, 'rb') as f:   
    out = pickle.load(f)
