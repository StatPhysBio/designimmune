# %% [markdown]
# # Run infection dynamics with monoclonal killer T cell response

# %%
import numpy as np
from matplotlib.cm import get_cmap
import matplotlib.pyplot as plt
import matplotlib as mpl

import multiprocessing as mp
from tqdm import tqdm
from joblib import Parallel, delayed
from scipy import stats
import os
import seaborn as sns
from stoch_sim_model import *
from optimize_nets import *

plt.style.use('custom.mplstyle')
# %config InlineBackend.figure_format = 'retina'
# %load_ext line_profiler

# %%
avg_sim_time = 1.5/(60*60) # 1.6/(60*60)

print('full-reg:',(len(psi_4d)**4)*len(infection_sample_select),
      np.ceil((len(psi_4d)**4*len(infection_sample_select))/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('auto-sparse-reg:',len(psi_sparse)*len(auto_sample), 
      np.ceil((len(psi_sparse)*len(auto_sample))/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('cancer-sparse-reg:',len(psi_sparse)*len(cancer_sample), 
      np.ceil((len(psi_sparse)*len(cancer_sample))/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('sparse-reg:', len(psi_sparse)*len(infection_sample_select),
      np.ceil(len(psi_sparse)*len(infection_sample_select)/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')
# Out:
# full-reg: 19836425781250 82651775.0 2400 jobs per cpu per hour
# auto-sparse-reg: 4687500 20.0 2400 jobs per cpu per hour
# cancer-sparse-reg: 2812500 12.0 2400 jobs per cpu per hour
# sparse-reg: 40625000 170.0 2400 jobs per cpu per hour

# %% [markdown]
# ### (1) Plot population averaged trajectories

# %%
# Set simulation parameters
N_0 = 1000
K_I = (1)*(10**6)
d_I = 50*d_S # d_S #
b_I = 1.5*(10**(-7)) # 1.50*(10**(-7)) # b_C
I_0 = 1*I_0  # 0.1*S_0 # I_0

infection_model = 'acute' #'acute', 'autoimmune', 'cancer'
Na_regulation = [2, 2, -0, -0.5*L0_max]
NE_regulation = [2, 2, -0, 1.0*L0_max]
EM_regulation = [-2, -2, 0, -0.5*L0_max]
Edie_regulation = [2, 2, -1.0, 0.25*L0_max]

# %%
# %lprun -T lprof0 -f lin_stoch_sim lin_stoch_sim(N_0 = 1000, b_I = b_I, K_I = K_I, d_I = d_I, K_H = K_H, \
                                                NE_regulation = NE_regulation, \
                                                EM_regulation = EM_regulation, \
                                                activation_regulation = Na_regulation, \
                                                contraction_regulation = Edie_regulation, \
                                                memory_death = False)
# Out:
# *** Profile printout saved to text file 'lprof0'.
# Timer unit: 1e-09 s
#
# Total time: 1.04038 s
# File: /mmfs1/home/oukogu/infoimmune/stoch_sim_model.py
# Function: lin_stoch_sim at line 151
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    151                                           def lin_stoch_sim(S_0 = S_0, I_0 = I_0, b_I = b_I, d_S = d_S, d_I = d_I, d_IE = d_IE, K_I = K_I, K_S = K_S,
#    152                                                             b_H = b_H, d_H = d_H, K_H = K_H,
#    153                                                             N_0 = N_0, max_Na = max_Na, b_myc = b_myc, d_myc = d_myc, myc_thresh = myc_thresh, max_expand = max_expand,
#    154                                                             char_times = [t_bind, t_unbind, t_Na_div, t_E_div, t_M_div, t_E_die, t_cycle],
#    155                                                             NE_regulation = NE_psis,
#    156                                                             EM_regulation = EM_psis,
#    157                                                             activation_regulation = act_psis,
#    158                                                             contraction_regulation = contract_psis,
#    159                                                             infection_model = "acute",
#    160                                                             duration = sim_duration,
#    161                                                             steps = sim_steps,
#    162                                                             reg_model = "mwc_like",
#    163                                                             out_data = "small",
#    164                                                             memory_death = False,
#    165                                                             seed = None):
#    166         1     230747.0 230747.0      0.0      rng = np.random.default_rng(seed)
#    167
#    168         1        340.0    340.0      0.0      if reg_model == 'mwc_like':
#    169         1        771.0    771.0      0.0          f_XtoY = f_XtoY_mwc_like
#    170                                               else:
#    171                                                   f_XtoY = f_XtoY_ret0
#    172
#    173                                               # VARIABLE DEFINITIONS:
#    174                                               # S_0 := S_0, I_0 := I_0, b_S := b_S, b_I := b_I, d_S := d_S, d_I := d_I, d_IE := d_IE, K_I := K_I,
#    175                                               # b_H := b_H, d_H := d_H, K_H := K_H,
#    176                                               # N_0 := N_0, max_Na := max_Na, b_myc := b_myc, d_myc := d_myc, myc_thresh := myc_thresh,
#    177                                               # char_times := [t_bind, t_unbind, t_Na_div, t_E_div, t_M_div, t_EM_diff, t_E_die, t_Na],
#    178
#    179                                               #################################
#    180                                               ### SET META-VARIABLES FOR SIMULATION ###
#    181                                               #################################
#    182         1        571.0    571.0      0.0      dt =  duration/steps
#    183         1        621.0    621.0      0.0      N_0_var = int(N_0)
#    184         1        621.0    621.0      0.0      b_S = S_0*d_S
#    185
#    186                                               # draw population of reponding cells for agent-based simulations
#    187         1       1472.0   1472.0      0.0      psi_myc_I, psi_myc_HI, psi_myc_HE, L0_Na = activation_regulation[0], activation_regulation[1], activation_regulation[2], activation_regulation[3]
#    188         1        421.0    421.0      0.0      psi_NE_I, psi_NE_HI, psi_NE_HE, L0_NE = NE_regulation[0], NE_regulation[1], NE_regulation[2], NE_regulation[3]
#    189         1        320.0    320.0      0.0      psi_EM_I, psi_EM_HI, psi_EM_HE, L0_EM = EM_regulation[0], EM_regulation[1], EM_regulation[2], EM_regulation[3]
#    190         1        520.0    520.0      0.0      psi_Edie_I, psi_Edie_HI, psi_Edie_HE, L0_Edie = contraction_regulation[0], contraction_regulation[1], contraction_regulation[2], contraction_regulation[3]
#    191
#    192         1        110.0    110.0      0.0      p_tcr = 1.0 #np.ones(N_0_var)
#    193         1        110.0    110.0      0.0      p_cyt = 1.0 #np.ones(N_0_var)
#    194
#    195         1        210.0    210.0      0.0      int_steps = int(steps)
#    196
#    197                                               # define variables for storage
#    198         1       4116.0   4116.0      0.0      I = np.zeros(int_steps+1)
#    199         1       2504.0   2504.0      0.0      S = np.zeros(int_steps+1)
#    200         1       1602.0   1602.0      0.0      HI = np.zeros(int_steps+1)
#    201         1       2143.0   2143.0      0.0      HE = np.zeros(int_steps+1)
#    202         1       1863.0   1863.0      0.0      I_d_I = np.zeros(int_steps+1)
#    203         1       2634.0   2634.0      0.0      I_d_IE = np.zeros(int_steps+1)
#    204         1       1722.0   1722.0      0.0      S_d_SE = np.zeros(int_steps+1)
#    205
#    206         1    1355247.0    1e+06      0.1      N_m = np.zeros((int_steps+1, N_0_var), dtype = np.int32)
#    207         1      31747.0  31747.0      0.0      N_m[0,:] += 1
#    208         1     230647.0 230647.0      0.0      T_Ecyt = [[] for i in np.arange(0, N_0_var)]
#    209         1     290747.0 290747.0      0.0      survive_M = [[] for i in np.arange(0, N_0_var)]
#    210
#    211         1       1873.0   1873.0      0.0      div_count = np.zeros(N_0_var)
#    212         1      36475.0  36475.0      0.0      div_E_count = np.log2(max_Na)*np.ones(N_0_var)
#    213         1       8553.0   8553.0      0.0      div_M_count = np.log2(max_Na)*np.ones(N_0_var)
#    214         1       1312.0   1312.0      0.0      diff_EpM_count = np.zeros(N_0_var, dtype = np.int32)
#    215         1       1252.0   1252.0      0.0      die_M = np.zeros(N_0_var, dtype = np.int32)
#    216
#    217         1     219690.0 219690.0      0.0      Na_m = np.zeros((int_steps+1, N_0_var), dtype = np.int32)
#    218         1      53931.0  53931.0      0.0      Ma_m = np.zeros((int_steps+1, N_0_var), dtype = np.int32)
#    219         1      52579.0  52579.0      0.0      E_m = np.zeros((int_steps+1, N_0_var), dtype = np.int32) # effector in periphary
#    220         1       4687.0   4687.0      0.0      T_E = np.zeros(N_0_var)
#    221
#    222         1        611.0    611.0      0.0      if out_data == "full":
#    223                                                   mycN_m = np.zeros((int_steps+1, N_0_var))
#    224                                                   mycMa_m = np.zeros((int_steps+1, N_0_var))
#    225                                                   mycE_m = np.zeros((int_steps+1, N_0_var))
#    226
#    227         1       4838.0   4838.0      0.0      bias_t = np.zeros((int_steps+1, 4))
#    228
#    229                                               # Define event timer variables
#    230         1       1171.0   1171.0      0.0      bound_N = np.zeros(N_0_var, dtype =np.int32)
#    231         1       1693.0   1693.0      0.0      bound_N_time = np.zeros(N_0_var)
#    232         1       5118.0   5118.0      0.0      Na_div_flag = np.ones(N_0_var, dtype =np.int32)
#    233         1       2895.0   2895.0      0.0      Na_flag = np.ones(N_0_var, dtype =np.int32)
#    234
#    235         1       1463.0   1463.0      0.0      mycN = np.zeros(N_0_var)
#    236         1       1462.0   1462.0      0.0      mycE = np.zeros(N_0_var)
#    237         1       1492.0   1492.0      0.0      mycMa = np.zeros(N_0_var)
#    238
#    239         1      14432.0  14432.0      0.0      r_NaE = np.zeros((int_steps+1, N_0_var))
#    240         1       5158.0   5158.0      0.0      r_EM = np.zeros((int_steps+1, N_0_var))
#    241         1       6880.0   6880.0      0.0      r_Na = np.zeros((int_steps+1, N_0_var))
#    242         1       4837.0   4837.0      0.0      r_Edie = np.zeros((int_steps+1, N_0_var))
#    243         1       4206.0   4206.0      0.0      cum_r_NaE = np.zeros(N_0_var)
#    244
#    245         1       1272.0   1272.0      0.0      r_unbind_t = np.zeros(N_0_var)
#    246         1       1352.0   1352.0      0.0      r_N_bind = np.zeros(N_0_var)
#    247         1      11787.0  11787.0      0.0      r_Na_div = np.ones(N_0_var)/char_times[2]
#    248         1        561.0    561.0      0.0      r_myc_t = np.zeros(N_0_var)
#    249         1       6139.0   6139.0      0.0      r_E_div = np.ones(N_0_var)/char_times[3]
#    250         1       4878.0   4878.0      0.0      r_Ma_div = np.ones(N_0_var)/char_times[4]
#    251
#    252                                               #################################
#    253                                               ### RUN POPULATION SIMULATION ###
#    254                                               #################################
#    255         1        170.0    170.0      0.0      t = 0.0
#    256         1        892.0    892.0      0.0      S[0] = S_0
#    257         1        300.0    300.0      0.0      I[0] = I_0
#    258         1        260.0    260.0      0.0      HI[0] = 0.0
#    259         1        380.0    380.0      0.0      HE[0] = 0.0
#    260
#    261         1        350.0    350.0      0.0      sum_e_m = 0
#    262
#    263      2001     388077.0    193.9      0.0      for i in np.arange(1, int_steps + 1):
#    264                                                   # select virulence model:
#    265      2000     924500.0    462.2      0.1          if (b_I > 0 and I_0 <= S_0/1000) or infection_model == 'acute': # "acute"
#    266      2000     278022.0    139.0      0.0              b_I_t = b_I
#    267      2000     238665.0    119.3      0.0              d_Sauto = 0.0
#    268      2000     289627.0    144.8      0.0              infection_model = 'acute'
#    269
#    270                                                   elif (b_I > 0 and I_0 > 0.01*S_0) or infection_model == 'cancer': # "cancer"
#    271                                                       b_I_t = b_I/S_0
#    272                                                       d_Sauto = 0.0
#    273                                                       infection_model = 'cancer'
#    274
#    275                                                   elif b_I == 0 or infection_model == 'autoimmune': # "autoimmune"
#    276                                                       b_I_t = 0.0
#    277                                                       d_Sauto = d_I
#    278                                                       K_S = K_I
#    279                                                       I_0 = 0.0
#    280                                                       infection_model = 'autoimmune'
#    281
#    282                                                   else:
#    283                                                       b_I_t = b_I
#    284                                                       d_Sauto = 0
#    285
#    286                                                   # Compute total population of cell types
#    287                                                   # Use sum computed in previous iteration.
#    288      2000     243870.0    121.9      0.0          E_pop = sum_e_m
#    289
#    290                                                   #### Run infection dynamics: replication and effector clearance ####
#    291
#    292                                                   # Update state of susceptible, infected and inflammation
#    293                                                   # (a) event variables
#    294      2000    2606817.0   1303.4      0.3          S_to_I = dt * S[i - 1] * b_I_t * I[i - 1] * (S[i - 1] >= 1.0) * (I[i - 1] >= I_0)
#    295      2000    2767080.0   1383.5      0.3          I_d_IE[i] += I_d_IE[i - 1] + dt * I[i - 1] * d_IE * E_pop / (K_I + I[i - 1] + E_pop) # infected/cancer cells killed by immune response
#    296      2000    1798622.0    899.3      0.2          I_d_I[i] += I_d_I[i - 1] + dt * I[i - 1]*d_I*(infection_model == "acute") # cells killed by infection
#    297      2000    2612100.0   1306.0      0.3          S_d_SE[i] += S_d_SE[i - 1] + dt * S[i - 1] * (d_IE * E_pop / (K_S + S[i - 1] + E_pop)) # susceptible cells killed by immune response
#    298
#    299                                                   # (b) state variables
#    300      6000    1953514.0    325.6      0.2          S[i] += S[i - 1] - S_to_I + dt * (
#    301      4000    3600931.0    900.2      0.3              b_S - (d_S + (d_Sauto / t_Hauto) * np.exp(-(t / t_Hauto)**2 / 2)) * S[i - 1]
#    302      2000     900885.0    450.4      0.1              - (S_d_SE[i] - S_d_SE[i - 1])/dt
#    303      2000     575070.0    287.5      0.1          ) * (S[i - 1] >= 1.0)
#    304
#    305      2000    2324905.0   1162.5      0.2          I[i] += I[i - 1] + S_to_I - (I_d_IE[i] + I_d_I[i] - I_d_IE[i - 1] - I_d_I[i - 1])
#    306
#    307      2000    3568873.0   1784.4      0.3          harm_detected = (I_d_I[i] - I_d_I[i - 1]) + dt * S[i - 1] * (d_Sauto / t_Hauto) * np.exp(-(t / t_Hauto)**2 / 2) + S_to_I * (infection_model == "cancer")
#    308      2000    1431960.0    716.0      0.1          immunopathology = (S_d_SE[i] - S_d_SE[i - 1]) + (I_d_IE[i] - I_d_IE[i - 1])
#    309      2000    1269637.0    634.8      0.1          cells_sensed = I[i - 1] + (S[i - 1] * K_I / K_S)
#    310
#    311      2000    2390701.0   1195.4      0.2          HI[i] += HI[i - 1] + b_H * harm_detected - dt * d_H * HI[i - 1] * (HI[i - 1] >= 0.0)
#    312
#    313      2000    2121916.0   1061.0      0.2          HE[i] += HE[i - 1] + b_H * immunopathology - dt * d_H * HE[i - 1] * (HE[i - 1] >= 0.0)
#    314
#    315                                                   ## I. Recruitment/Priming
#    316
#    317                                                   # (a) Phase 1: Naive cells encounter and bind APCs
#    318      2000     388399.0    194.2      0.0          if cells_sensed >= 1:
#    319      2000   74566284.0  37283.1      7.2              bound_N += rng.binomial(N_m[i - 1], r_N_bind * dt) - rng.binomial(N_m[i - 1], r_unbind_t * dt)
#    320                                                   else:
#    321                                                       bound_N = 0
#    322
#    323      2000   14718745.0   7359.4      1.4          bound_N_time += dt * bound_N - (1 - bound_N) * bound_N_time * N_m[i - 1] # only reset to zero if the cell is not activated
#    324
#    325                                                   # (b) Phase 2: Activated naive cells are bound to APCs and receive stimulation.
#    326      2000   12623941.0   6312.0      1.2          act_N = (1 - bound_N) * (mycN >= myc_thresh) * (N_m[i - 1] > 0)
#    327
#    328                                                   ## II. Early differentiation
#    329
#    330                                                   # (a) Unbound activated naive cells divide and then differentiate
#    331      2000   32240127.0  16120.1      3.1          div_Na = rng.binomial(Na_m[i - 1] * Na_div_flag, dt * r_Na_div)
#    332
#    333      4000   27145334.0   6786.3      2.6          diff_NaE = rng.binomial(
#    334      2000    6279165.0   3139.6      0.6              Na_m[i - 1] * (1 - Na_div_flag),
#    335      2000   11575981.0   5788.0      1.1              1 - np.exp(-cum_r_NaE * dt) if np.sum(Na_m[i - 1]) > 0 else 0
#    336                                                   )
#    337
#    338                                                   ## III. Expansion and contraction
#    339
#    340                                                   # (a) New central memory cells divide
#    341      2000   34130102.0  17065.1      3.3          div_Ma = rng.binomial(Ma_m[i - 1] - diff_EpM_count, dt * r_Ma_div)
#    342
#    343                                                   # (b) Effector cells divide, differentiate, die
#    344      2000   57616286.0  28808.1      5.5          die_E = rng.binomial(E_m[i - 1], r_Edie[i - 1] * dt)
#    345      2000   47414356.0  23707.2      4.6          diff_EM = rng.binomial(E_m[i - 1] - die_E, dt * r_EM[i - 1])
#    346      2000   55625668.0  27812.8      5.3          div_E = rng.binomial(E_m[i - 1] - die_E - diff_EM, dt * r_E_div)
#    347      2000    6992627.0   3496.3      0.7          diff_EpM_count += diff_EM - die_M
#    348
#    349                                                   #### Update population dynamics: ####
#    350      2000    4636455.0   2318.2      0.4          N_m[i] += N_m[i - 1] - act_N
#    351      2000   22877516.0  11438.8      2.2          Na_m[i] += Na_m[i - 1] + div_Na + act_N - (1 - Na_div_flag) * Na_m[i - 1]
#    352
#    353      2000   23846627.0  11923.3      2.3          Ma_m[i] += Ma_m[i - 1] + div_Ma + (1 - Na_div_flag)*(Na_m[i - 1] - diff_NaE) + diff_EM - die_M
#    354      2000   19506394.0   9753.2      1.9          E_m[i] += E_m[i - 1] + div_E + (1 - Na_div_flag) * diff_NaE - (die_E + diff_EM)
#    355
#    356                                                   # Evaluate sums and create masks
#    357      2000   11791729.0   5895.9      1.1          sum_n_m = np.sum(N_m[i]*bound_N)
#    358      2000    9379266.0   4689.6      0.9          sum_na_m = np.sum(Na_m[i])
#    359      2000    9172919.0   4586.5      0.9          sum_e_m = np.sum(E_m[i])
#    360      2000    3425856.0   1712.9      0.3          e_m_nonzero_mask = E_m[i] > 0
#    361      2000    2960539.0   1480.3      0.3          n_m_nonzero_mask = N_m[i] > 0
#    362      2000    2769660.0   1384.8      0.3          na_m_nonzero_mask = Na_m[i] > 0
#    363      2000    5881814.0   2940.9      0.6          bound_na_sum_nonzero_mask = Na_m[i] > 0 | bound_N
#    364      2000    4656408.0   2328.2      0.4          ma_m_nonzero_mask = Ma_m[i] + Ma_m[i-1] > 0
#    365      2000    1433003.0    716.5      0.1          n_na_sum_nonzero_mask = n_m_nonzero_mask | na_m_nonzero_mask
#    366
#    367                                                   # store time cells spend in effector effector
#    368      2000    4318616.0   2159.3      0.4          T_E += dt * e_m_nonzero_mask if sum_e_m > 0 else 0.0
#    369      2000    3059711.0   1529.9      0.3          die_M = 0*die_M
#    370
#    371                                                   # store time an effector spends in cytotoxic state
#    372      2000   17685196.0   8842.6      1.7          for_where = ((1 - Na_div_flag)*(Na_m[i-1] - diff_NaE) + div_Ma + diff_EM + ma_m_nonzero_mask*memory_death > 0)
#    373      2000    4352400.0   2176.2      0.4          where_output = np.where(for_where)[0]
#    374     57225   10579200.0    184.9      1.0          for l in where_output:
#    375
#    376     55225    6410295.0    116.1      0.6              if memory_death:
#    377                                                           if Ma_m[i,l] > 0:
#    378                                                               T_Ecyt[l] = list(itertools.compress(T_Ecyt[l], survive_M[l])) + ((1 - Na_div_flag[l])*(Na_m[i-1,l] - diff_NaE[l]) + div_Ma[l]) * [0.0] + diff_EM[l] * [T_E[l].item()]
#    379                                                               arr = np.array(T_Ecyt[l])
#    380                                                               survive_M[l] = (rng.random(size = Ma_m[i,l]) > (arr > 0)*dt/memory_lifespan(arr, min_time = dt))
#    381                                                               die_M[l] = Ma_m[i,l] - np.sum(survive_M[l])
#    382                                                           else:
#    383                                                               T_Ecyt[l] += ((1 - Na_div_flag[l])*(Na_m[i-1,l] - diff_NaE[l]) + div_Ma[l]) * [0.0] + diff_EM[l] * [T_E[l].item()]
#    384                                                               arr = np.array([])
#    385                                                               survive_M[l] = []
#    386                                                               die_M[l] = 0
#    387                                                       else:
#    388     55225  146368668.0   2650.4     14.1                  T_Ecyt[l] += ((1 - Na_div_flag[l])*(Na_m[i-1,l] - diff_NaE[l]) + div_Ma[l]) * [0.0] + diff_EM[l] * [T_E[l].item()]
#    389
#    390                                                   # Update division flag to allow division to proceed
#    391      2000    5888508.0   2944.3      0.6          div_count += div_Na + div_E + div_Ma
#    392      2000    2802295.0   1401.1      0.3          div_E_count += div_E
#    393      2000    2698083.0   1349.0      0.3          div_M_count += div_Ma
#    394      2000    4338905.0   2169.5      0.4          Na_div_flag = (Na_m[i] < max_Na)*(na_m_nonzero_mask)
#    395
#    396                                                   #### New binding events ####
#    397      6000   20376310.0   3396.1      2.0          r_N_bind = (n_m_nonzero_mask) * (1 - bound_N) * f_XtoY(
#    398      2000    1196132.0    598.1      0.1              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    399      2000    2834824.0   1417.4      0.3              psi_1 = 0.0, psi_2 = psi_max, psi_3 = 0.0, L_0 = -psi_max*np.log(2), K_1 = S_0, K_2 = K_H, K_3 = K_H
#    400      4000     832793.0    208.2      0.1          ) / (char_times[0]) if cells_sensed >= 1 else 0.0
#    401
#    402      2356    1375480.0    583.8      0.1          r_unbind_t = bound_N * np.fmin(
#    403       712    1123685.0   1578.2      0.1              2 * bound_N_time / (
#    404      1780    1586329.0    891.2      0.2                  f_XtoY(
#    405       356     172630.0    484.9      0.0                      sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    406       356     415885.0   1168.2      0.0                      psi_1 = psi_max, psi_2 = 0.0,psi_3 = 0.0, L_0 = -psi_max*np.log(2),
#    407       356      85806.0    241.0      0.0                      K_1 = (K_I*(infection_model != "autoimmune") + K_S*(infection_model == "autoimmune")),
#    408       356      39165.0    110.0      0.0                      K_2 = K_H, K_3 = K_H
#    409      1068     394516.0    369.4      0.0                  ) * char_times[1] * 2 / np.sqrt(np.pi)
#    410       712     111218.0    156.2      0.0              )**2, 1 / dt
#    411      2000   10253640.0   5126.8      1.0          ) if np.sum(bound_N) >= 1 else 0.0
#    412
#    413      4000    8411943.0   2103.0      0.8          r_myc_t = b_myc * f_XtoY(
#    414      2000     972864.0    486.4      0.1              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    415      2000     287234.0    143.6      0.0              psi_1 = psi_myc_I, psi_2 = psi_myc_HI, psi_3 = psi_myc_HE, L_0 = L0_Na,
#    416      2000     518448.0    259.2      0.0              K_1 = (K_I*(infection_model != "autoimmune") + K_S*(infection_model == "autoimmune")),
#    417      2000     206914.0    103.5      0.0              K_2 = K_H, K_3 = K_H
#    418                                                   )
#    419
#    420                                                   #### MYC Dynamics ####
#    421      2000   15951208.0   7975.6      1.5          mycN = (mycN + dt * (r_myc_t - d_myc * mycN * (mycN > 0)) ) * n_na_sum_nonzero_mask
#    422
#    423      2000   18367553.0   9183.8      1.8          mycE = (mycE + dt * (r_myc_t - d_myc * mycE * (mycE > 0)) ) * e_m_nonzero_mask + mycN * (na_m_nonzero_mask)
#    424
#    425     10000   21085088.0   2108.5      2.0          mycMa = 0*(mycMa + dt * (b_myc * f_XtoY(
#    426      2000     951731.0    475.9      0.1              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    427      2000     310467.0    155.2      0.0              psi_1 = psi_myc_I, psi_2 = 0.0, psi_3 = 0.0, L_0 = L0_Na,
#    428      2000     403984.0    202.0      0.0              K_1 = (K_I*(infection_model != "autoimmune") + K_S*(infection_model == "autoimmune")),
#    429      2000     200735.0    100.4      0.0              K_2 = K_H, K_3 = K_H
#    430      6000    9828091.0   1638.0      0.9          ) - d_myc * mycMa * (mycMa > 0)) ) * ma_m_nonzero_mask + mycN * na_m_nonzero_mask # Unclear division dynamics for central memory
#    431
#    432                                                   #### Time-dependent rates modulated by antigen and cytokine signals ####
#    433      2000     483794.0    241.9      0.0          r_Na_div = 1 / char_times[2]
#    434      2000    8955039.0   4477.5      0.9          r_E_div = (mycE >= myc_thresh) * (div_count < max_expand) / char_times[3]
#    435      2000    8262155.0   4131.1      0.8          r_Ma_div = (mycMa >= myc_thresh) * (div_count < max_expand) / char_times[4]
#    436
#    437                                                   #### Transition probabilities modulated by antigen and cytokine signals ####
#    438      2000   11912478.0   5956.2      1.1          r_Na[i] += r_E_div
#    439
#    440      6000   27244895.0   4540.8      2.6          r_NaE[i] += (mycN >= myc_thresh) * bound_na_sum_nonzero_mask * f_XtoY(
#    441      2000    1006205.0    503.1      0.1              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    442      2000     275293.0    137.6      0.0              psi_1 = psi_NE_I, psi_2 = psi_NE_HI, psi_3 = psi_NE_HE,L_0 = L0_NE,
#    443      2000     473390.0    236.7      0.0              K_1 = (K_I*(infection_model != "autoimmune") + K_S*(infection_model == "autoimmune")),
#    444      4000     551196.0    137.8      0.1              K_2 = K_H, K_3 = K_H)/char_times[6]
#    445
#    446      8000   21711140.0   2713.9      2.1          r_EM[i] += f_XtoY(
#    447      2000     894213.0    447.1      0.1              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    448      2000     289369.0    144.7      0.0              psi_1 = psi_EM_I, psi_2 = psi_EM_HI, psi_3 = psi_EM_HE, L_0 = L0_EM,
#    449      2000     459852.0    229.9      0.0              K_1 = (K_I*(infection_model != "autoimmune") + K_S*(infection_model == "autoimmune")),
#    450      6000     669625.0    111.6      0.1              K_2 = K_H, K_3 = K_H)/char_times[6] * e_m_nonzero_mask
#    451
#    452      8000   21202781.0   2650.3      2.0          r_Edie[i] += f_XtoY(
#    453      2000     906215.0    453.1      0.1              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    454      2000     468032.0    234.0      0.0              psi_1 = -psi_Edie_I, psi_2 = -psi_Edie_HI, psi_3 = -psi_Edie_HE, L_0 = -L0_Edie,
#    455      2000     507458.0    253.7      0.0              K_1 = (K_I*(infection_model != "autoimmune") + K_S*(infection_model == "autoimmune")),
#    456      6000     715198.0    119.2      0.1              K_2 = K_H, K_3 = K_H)/char_times[6] * e_m_nonzero_mask
#    457
#    458      2000    1885583.0    942.8      0.2          cum_r_NaE += r_NaE[i]
#    459
#    460                                                   #### Store myc levels ####
#    461      2000     376279.0    188.1      0.0          if out_data == "full":
#    462                                                       mycN_m[i] += mycN
#    463                                                       mycMa_m[i] += mycMa
#    464                                                       mycE_m[i] += mycE
#    465
#    466                                                   #### Store differentiation biases
#    467      2000    1019813.0    509.9      0.1          to_add_to_bias = np.zeros(4)
#    468      2000   12562388.0   6281.2      1.2          if np.sum(bound_na_sum_nonzero_mask) > 0.:
#    469       287    3506945.0  12219.3      0.3              to_add_to_bias[1] = np.mean(r_NaE[i][bound_na_sum_nonzero_mask])
#    470
#    471      2000    2267074.0   1133.5      0.2          if sum_e_m > 0.:
#    472      1382   13976201.0  10113.0      1.3              to_add_to_bias[0] = np.mean(r_Na[i][e_m_nonzero_mask])
#    473      1382   10767611.0   7791.3      1.0              to_add_to_bias[2] = np.mean(r_EM[i][e_m_nonzero_mask])
#    474      1382   10292230.0   7447.3      1.0              to_add_to_bias[3] = np.mean(r_Edie[i][e_m_nonzero_mask])
#    475
#    476      2000    2008666.0   1004.3      0.2          bias_t[i] += to_add_to_bias
#    477
#    478                                                   # Increment time
#    479      2000     512121.0    256.1      0.0          t += dt
#    480
#    481                                               # Collect population dynamics
#    482         1    3353802.0    3e+06      0.3      N, Na, Ma, E = np.sum(N_m, axis = 1), np.sum(Na_m, axis = 1), np.sum(Ma_m, axis = 1), np.sum(E_m, axis = 1)
#    483
#    484         1    4041415.0    4e+06      0.4      T_pEcytM = np.concatenate(T_Ecyt) if N_0 > 0 else np.array([0.0]) # time that memory spends in effector
#    485         1      47661.0  47661.0      0.0      count_cM = np.sum(T_pEcytM == 0
#    486         1      42875.0  42875.0      0.0                       ) if len(T_pEcytM[T_pEcytM == 0]) > 0 and N_0 > 0.0 else 0.0
#    487         1      33310.0  33310.0      0.0      count_eM = np.sum(T_pEcytM > 0
#    488         1      29043.0  29043.0      0.0                       ) if len(T_pEcytM[T_pEcytM == 0]) > 0 and N_0 > 0.0 else 0.0
#    489
#    490                                               # Project out surviving primary memory
#    491         1     397457.0 397457.0      0.0      mean_frac_cM = count_cM/np.sum(np.amax(Na_m, axis = 0)) if np.sum(np.amax(Na_m, axis = 0)) > 0.0 else 0.0
#    492         1     426841.0 426841.0      0.0      mean_T_pEcyteM = np.mean(T_pEcytM[T_pEcytM > 0]) if len(T_pEcytM[T_pEcytM > 0]) > 0 and N_0 > 0.0 else 0.0
#    493
#    494         1       1562.0   1562.0      0.0      zeros_n_0_var = np.zeros(N_0_var)
#    495
#    496         2      46119.0  23059.5      0.0      lineage_comp = np.vstack([
#    497         1     154101.0 154101.0      0.0          np.amax(Na_m, axis = 0), div_M_count, div_E_count,
#    498         1       4987.0   4987.0      0.0          p_tcr + zeros_n_0_var, p_cyt + zeros_n_0_var
#    499                                               ])
#    500
#    501         1      21973.0  21973.0      0.0      dyn_data = np.array([S, I, N, Na, E, Ma, HI, I_d_I + I_d_IE, S_d_SE, HE]).T # add I_d_IE as a separate variable
#    502         1        331.0    331.0      0.0      prim_bias = bias_t
#    503
#    504         1      66750.0  66750.0      0.0      ts = np.linspace(0, duration, int_steps + 1)
#    505
#    506                                               # Compute summary statistics from simulations
#    507                                               ## extract primary/secondary infection dynamics
#    508         1       3655.0   3655.0      0.0      pS, pI, N, Na, pE, pM, pHI, pI_d_I, pI_d_SE, pHE = dyn_data[:,0], dyn_data[:,1], dyn_data[:,2], dyn_data[:, 3], dyn_data[:,4], dyn_data[:,5], dyn_data[:,6], dyn_data[:,7], dyn_data[:,8], dyn_data[:,9]
#    509
#    510         1        821.0    821.0      0.0      dt = ts[1] - ts[0]
#    511
#    512         3       8583.0   2861.0      0.0      parameters = np.concatenate((np.array([S_0, I_0, b_I, d_S, d_I, d_IE, K_I,
#    513         1       1022.0   1022.0      0.0                b_H, d_H, K_H,
#    514         1        151.0    151.0      0.0                N_0, max_Na, b_myc, d_myc, myc_thresh]),
#    515         1        101.0    101.0      0.0                char_times,
#    516         1        130.0    130.0      0.0                activation_regulation, NE_regulation, EM_regulation, contraction_regulation))
#    517
#    518         2      16175.0   8087.5      0.0      sim_summary = np.array([np.amax(pI) + np.amax(pS)*(infection_model == "autoimmune"),
#    519         1      18748.0  18748.0      0.0                         np.argmax(pI)*dt,
#    520         1       7561.0   7561.0      0.0                         np.argmax(pI < I_0)*dt,
#    521         1       5388.0   5388.0      0.0                         np.amax(pI_d_I) + I[-1],
#    522         1       5879.0   5879.0      0.0                         np.amax(pI_d_SE),
#    523         1       5779.0   5779.0      0.0                         np.sum(div_E_count),
#    524         1      14873.0  14873.0      0.0                         np.argmax(pE)*dt + sim_duration*(np.max(pE) < 1.0),
#    525         1      12128.0  12128.0      0.0                         (np.argmax(pE >= N_0 , axis = 0)*dt + sim_duration*(np.max(pE) < N_0)) if N_0 > 0 else sim_duration,
#    526         1        110.0    110.0      0.0                         count_eM,
#    527         1        100.0    100.0      0.0                         mean_T_pEcyteM,
#    528         1        140.0    140.0      0.0                         count_cM,
#    529         1        130.0    130.0      0.0                         mean_frac_cM,
#    530         1       4106.0   4106.0      0.0                         np.amax(pHE),
#    531         1       4006.0   4006.0      0.0                         np.amax(pHI),
#    532         1      10485.0  10485.0      0.0                         np.amin(pS)])
#    533
#    534                                               # down-size timeseries
#    535         1        961.0    961.0      0.0      pnts = int(0.1*steps)
#    536         1      35343.0  35343.0      0.0      keep = [i*10 for i in np.arange(0,pnts)]
#    537
#    538         1        260.0    260.0      0.0      if out_data == "full":
#    539                                                   out_dict = {"reg_coeffs": np.concatenate((activation_regulation, NE_regulation, EM_regulation, contraction_regulation)), "cell_time_series": dyn_data, "time": ts, "lineage_diff": lineage_comp, "prim_diff_bias": prim_bias, "eff_by_lin": (E_m), "N_myc_by_lin": mycN_m, "Ma_myc_by_lin": mycMa_m, "E_myc_by_lin": mycE_m, "parameters": parameters, "summary_stats": sim_summary, "pmemory_formed": T_pEcytM if N_0 > 0 else []}
#    540         1        221.0    221.0      0.0      elif out_data == "small":
#    541         1      27942.0  27942.0      0.0          out_dict = {"cell_time_series": dyn_data[keep], "prim_diff_bias": prim_bias[keep],"parameters": parameters, "summary_stats": sim_summary}
#    542
#    543         1        111.0    111.0      0.0      return out_dict

# %%
# Run single simulation
# %timeit -n 2 -r 2
data_dict = lin_stoch_sim(N_0 = N_0,
                          I_0 = I_0,
                          b_I = b_I, 
                          K_I = K_I,
                          d_I = d_I,
                          K_H = K_H,
                          NE_regulation = NE_regulation,
                          EM_regulation = EM_regulation,
                          activation_regulation = Na_regulation,
                          contraction_regulation = Edie_regulation,
                          infection_model = infection_model,
                          reg_model = 'mwc_like',
                          out_data = "full",
                          memory_death = False)

# %%
np.amax(Eff, axis = 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 np.amax(Eff, axis = 0)
#
# NameError: name 'Eff' is not defined

# %%
regs = data_dict["reg_coeffs"]
dyn = data_dict["cell_time_series"]
ts = data_dict["time"]
lin_comp = data_dict["lineage_diff"]
p_diff = data_dict["prim_diff_bias"]
parameters = data_dict["parameters"]
sim_summary = data_dict["summary_stats"]
mycN = data_dict["N_myc_by_lin"]
mycMa = data_dict["Ma_myc_by_lin"]
mycE = data_dict["E_myc_by_lin"]
Eff = data_dict["eff_by_lin"]
T_pEcytM = data_dict["pmemory_formed"]

S, I, N, Na, E, M, HI, I_d_I, I_d_S, HE = dyn[:,0], dyn[:,1], dyn[:,2], dyn[:, 3], dyn[:,4], dyn[:,5], dyn[:,6], dyn[:,7], dyn[:,8], dyn[:,9]

reg_string = '-'.join(np.array(Na_regulation + NE_regulation + EM_regulation + Edie_regulation).astype('U4'))

# %%
# Plot simulated immune dynamics
fig, (ax1, ax2, ax3) = plt.subplots(3, dpi = 150, constrained_layout=True, sharex = False, figsize=(5,5))

ax1.plot(ts, S, 'k', label = r'susceptible, $S$')
ax1.plot(ts, I, 'b', label = r'infected, $I$')

ax1.plot(ts, I_d_S, 'r', linestyle = '--', label = r'susceptible killed')
ax1.plot(ts, I_d_I, 'g', linestyle = '--', label = r'infected killed')
ax1.set(ylabel='Cell count')
ax1.set_ylim(1, S_0*2)
ax1.semilogy()
ax1.minorticks_off()
ax1.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

ax2.plot(ts, Na, 'b', label = r'Activated, $N^*$')
ax2.plot(ts, E, 'orange', label = r'Effector, $E$')
ax2.plot(ts, M, 'g', label = r'Memory, $M$')
ax2.plot(ts, S, 'grey', label = r'Susceptible, $S$')
ax2.plot(ts, I, 'r', label = r'infected, $I$')
ax2.set(ylabel='Cell count')
ax2.semilogy()
ax2.minorticks_off()
ax2.set_ylim(1, S_0*2)
ax2.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

ax3.plot(ts, f_XtoY_mwc_like(sig_1 = I, sig_2 = HI, sig_3 = HE, 
                             psi_1 = EM_regulation[0], psi_2 = EM_regulation[1], psi_3 = EM_regulation[2], L_0 = EM_regulation[3], 
                             K_1 = K_I, K_2 = K_H, K_3 = K_H),
         'k-', label = r'Regulation, $f(I,H)$')
ax3.set(xlabel=r'Time [days]', ylabel='Regulation')
ax3.minorticks_off()
ax3.set_ylim(0,1.05)

fig.savefig("_figs/"+infection_model+'-'+'virus-effector dynamics-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
plt.plot(ts, N)
plt.ylim(0, 1.05*N_0)
np.mean(np.argmax(Eff >0 , axis = 0)*(ts[1]-ts[0])*(np.amax(Eff, axis = 0) > 0 ))

# %%
plt.plot(ts, np.log((1 + I/K_I)), 'r', label = "Ag.")
plt.plot(ts, np.log((1 + HE/K_H)), 'b--', label = "Anti-inflam.")
plt.plot(ts, np.log((1 + HI/K_H)), 'k--', label = "Pro-inflam.")
plt.legend()

# %%
plt.plot(ts,d_IE*E/(K_I + I + E), 'r')
plt.plot(ts, d_IE*E/(K_I + E), 'k--')

# %%
print(f'Memory fraction = {(sim_summary[8]+sim_summary[10])/(sim_summary[5] + sim_summary[8]+sim_summary[10])}')
print(f'Number of memory cells = {np.max(M)}')
print(f'1st infection harm = {sim_summary[3]/(d_S*S_0)}')
print(f'1st response toxicity = {sim_summary[4]/(d_S*S_0)}')
print(f'Minimum susceptible = {np.min(S)/S_0}')

# %%
# Plot simulated infection dynamics: pretty plots
pnts = 50
keep = [i*int(len(E)/pnts) for i in np.arange(0,pnts)]
sus = S[keep]
naive = Na[keep]
eff = E[keep]
mem = M[keep]
p_load = np.log(1 + I[keep]/K_I)/np.log(1 + np.max(I[keep])/K_I) if np.max(I[keep]) > 0 else I[keep]
inflam = np.log((1 + HI[keep]/K_H))/np.log((1 + np.max(HI[keep])/K_H))
anti_inflam = np.log((1 + HE[keep]/K_H))/np.log((1 + np.max(HE[keep])/K_H)) if np.max(HE[keep]) > 0 else HE[keep]
inf_harm = I_d_I[keep]
toxicity = I_d_S[keep]
time = ts[keep]

fig, ax = plt.subplots(figsize=(7.5,5))

ax.plot(ts, I, 'r', label = r'Infected, $I$', linewidth=2.5)
# ax.plot(ts, S, 'grey', label = r'Susceptible, $S$', linewidth=2.5)

ax.plot(ts, E + M, 'orange', zorder = 1, linewidth=2.5, label = r'T cells, $E + M$')
im = ax.scatter(time, eff+mem, marker ='o', c = p_load, cmap='coolwarm') #, norm=mpl.colors.LogNorm())

ax.plot(ts, I_d_I, 'black', zorder = 1, linewidth=2.5, label = r'Infection harm')
ax.plot(ts, I_d_S, 'green', zorder = 1, linewidth=2.5, label = r'Toxicity harm')
# ax.plot(time, mem, 'k--')
# ax.scatter(time, mem, marker ='s', c = p_load, cmap='coolwarm',
#             label = r'Mem., $M$') #, norm=mpl.colors.LogNorm())

# ax.plot(time, inf_harm, 'r', linewidth = 2.0, label = r'Harm, $\mathcal{H}_I$')

# ax.plot(time, toxicity, 'y', linewidth = 2.0,label = r'Toxicity, $\mathcal{H}_S$')

ax.set_box_aspect(1)
cb = fig.colorbar(im, ax=ax, orientation='vertical', shrink = 0.75, pad = 0.05)
cb.set_label('Ag. stimulation', fontsize = 14)
cb.ax.tick_params(labelsize=8)
ax.set_ylabel('Cell count', fontsize = 18)
ax.set_xlabel(r"Time [days]", fontsize = 18)
ax.semilogy()
ax.minorticks_off()
ax.set_ylim(1,)
# locmaj = mpl.ticker.LogLocator(numticks=4)
# ax.yaxis.set_major_locator(locmaj)

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        ax.axvline(x=time[i], linestyle='-', linewidth=6.5, color='pink', alpha=inflam[i], label =r"Harm. stim.", zorder = 0)
        ax.axvline(x=time[i], linestyle='-', linewidth=6.5, color='grey', alpha=anti_inflam[i]/2, label =r"Tox. stim.", zorder = 0)
    else:
        ax.axvline(x=time[i], linestyle='-', linewidth=6.5, color='pink', alpha=inflam[i], zorder = 0)
        ax.axvline(x=time[i], linestyle='-', linewidth=6.5, color='grey', alpha=anti_inflam[i]/2, zorder = 0)

ax.legend(loc='lower right', fontsize = 10)

plt.savefig('_figs/'+infection_model+'-timeline-of-infection-dynamics-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
# Plot simulated infection dynamics: pretty plots of harm
pnts = 50
keep = [i*int(len(E)/pnts) for i in np.arange(0,pnts)]

eff = E[keep]
p_load = I[keep]/S_0
sus = S[keep]/S_0
inf_harm = I_d_I[keep]/S_0
inflam_harm = I_d_S[keep]/S_0
inflam = np.log((1 + HI[keep]/K_H))/np.log((1 + S_0/K_H))
time = ts[keep]

plt.scatter(time, p_load, marker ='s', c =eff/K_I, cmap='coolwarm', 
            label = r'Infected cells, $I$') #, norm=mpl.colors.LogNorm())
plt.plot(time, p_load, 'k--')

# plt.scatter(time, sus, marker ='>', c =eff/K_I, cmap='coolwarm', 
#             label = r'Susceptible cells, $S$') #, norm=mpl.colors.LogNorm())
# plt.plot(time, sus, 'k--')

plt.scatter(time, inf_harm, marker ='o', c =eff/K_I, cmap='coolwarm', 
            label = 'Infected cells killed')
plt.plot(time, inf_harm, 'k--')

plt.scatter(time, inflam_harm, marker ='*', c =eff/K_I, cmap='coolwarm',
            label = 'Susceptible cells killed')
plt.plot(time, inflam_harm, 'k--')

plt.colorbar(label = "Primary effector response")
plt.ylabel('Fraction of susceptible cells', fontsize = 14)
plt.xlabel(r"Time, $t$ [days]", fontsize = 14)

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        plt.axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], label =r"Inflammation, $H$", zorder = 0)
    else:
        plt.axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        
plt.legend(loc='center right', bbox_to_anchor=(1.85, 0.8), fontsize = 10)
plt.savefig('_figs/'+infection_model+'-infection-harm-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
# Plot simulated infection dynamics: pretty plots
pnts = 150
keep = [1 + i*int(len(E)/pnts) for i in np.arange(0,pnts)]
bias_diff = p_diff[keep]
sus = S[keep]
p_load = np.log(1 + I[keep]/K_I)/np.log(1 + np.max(I[keep])/K_I) if np.max(I[keep]) > 0 else I[keep]
inflam = np.log((1 + HI[keep]/K_H))/np.log((1 + np.max(HI[keep])/K_H))
anti_inflam = np.log((1 + HE[keep]/K_H))/np.log((1 + np.max(HE[keep])/K_H)) if np.max(HE[keep]) > 0 else HE[keep]
time = ts[keep]

fig, axs = plt.subplots(2,2, figsize=(7,7))

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0, label =r"Inflammation, $H$")
        
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0, label =r"Anti-inflammation, $P$")
    else:
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0, label =r"Inflammation, $H$")
        
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0, label =r"Anti-inflammation, $P$")


im1 = axs[0,0].scatter(time, bias_diff[:,0], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$E \longrightarrow 2E$')
axs[0,0].plot(time, bias_diff[:,0],'k--')
axs[0,0].title.set_text(r'$E \longrightarrow 2E$')
axs[0,0].set_box_aspect(1)

im2 = axs[0,1].scatter(time, bias_diff[:,1], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$N^* \longrightarrow E$')
axs[0,1].plot(time, bias_diff[:,1],'k--')
axs[0,1].title.set_text(r'$N^* \longrightarrow E$')
axs[0,1].set_box_aspect(1)

im3 = axs[1,0].scatter(time, bias_diff[:,2], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$E \longrightarrow M$')
axs[1,0].plot(time, bias_diff[:,2],'k--')
axs[1,0].title.set_text(r'$E \longrightarrow M$')
axs[1,0].set_box_aspect(1)

im4 = axs[1,1].scatter(time, bias_diff[:,3], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$E \longrightarrow \emptyset$')
axs[1,1].plot(time, bias_diff[:,3],'k--')
axs[1,1].title.set_text(r'$E \longrightarrow \emptyset$')
axs[1,1].set_box_aspect(1)

axs[0,0].set_ylabel('Rate [day$^{-1}$]', fontsize = 14)
axs[1,0].set_ylabel('Rate [day$^{-1}$]', fontsize = 14)
axs[1,0].set_xlabel("Time [days]", fontsize = 14)
axs[1,1].set_xlabel("Time [days]", fontsize = 14)

fig.subplots_adjust(wspace=.3, hspace = 0.1)
cb = fig.colorbar(im1, ax=axs, shrink = 0.5, pad = 0.05, orientation='vertical')
cb.set_label('Ag. stimulation')

#cb.set_clim(-0.4,0.4)
    
# plt.colorbar(label =r"pathogen load, $I(t)$")
# plt.ylabel('transition weight', fontsize = 16)
# plt.xlabel("time (days)", fontsize = 16)
# plt.legend() #bbox_to_anchor=(1.05, 1.0), loc='upper left')

plt.savefig('_figs/'+infection_model+'-diff-bias-over-time-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %% [markdown]
# ### (2) Plot lineage-based trajectories

# %%
keys = np.array(['Memory', 'Effector'])
all_counts = lin_comp[1:3].T
effector_ranking = np.argsort(all_counts[:, 1])[::-1]
all_counts = all_counts[effector_ranking]
total_counts = all_counts.sum(axis=1)
norm_counts = all_counts / total_counts[:, None]
norm_counts[~np.isfinite(norm_counts)] = 0
comp_argsort = np.argsort(np.max(all_counts, axis=0))
bar_dict = {k: v for k, v in zip(keys[comp_argsort], norm_counts.T[comp_argsort])}
lineage_idxs = np.arange(all_counts.shape[0])

fig, ax = plt.subplots()
bottom = np.zeros(len(lineage_idxs))
cmap_colors = sns.color_palette('Set2', 10)
cmap_colors = [cmap_colors[i]
               for i in [0, 1, 5]]#[7, 2, 0, 1, 5]]
# cmap_colors = [cmap_colors[i]
#                for i in [6, 1, 2, 5, 0]]
width = 1

for i, (celltype, fraction) in enumerate(bar_dict.items()):
    ax.bar(lineage_idxs, fraction, width,
           edgecolor='k', linewidth=0.01,
           label=celltype, bottom=bottom, color=cmap_colors[i])
    bottom += fraction
    
ax.legend(loc='center right', bbox_to_anchor=(1.4, 0.5), fontsize = 12)
ax.set_xlim(-0.5, len(all_counts) - 0.5)
ax.set_xlabel('sub-clone lineages \n (ranked by effector response)', fontsize = 15)
ax.set_ylabel('fractional cell-fate \ncomposition', fontsize = 15)
#ax.set_yscale('log')

ax.set_xticks(np.arange(0, Eff.shape[1], int(Eff.shape[1]/10)))
ax.set_xticklabels(1 + np.arange(0, Eff.shape[1], int(Eff.shape[1]/10)), fontsize=9)

ax.set_yticks(np.round(np.arange(0, 1.2, 0.2), 1))
ax.set_yticklabels(ax.get_yticks(), fontsize=12)

fig.savefig("_figs/"+infection_model+'-'+'fates-by-lin-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
plt.errorbar(ts, np.mean(Eff, axis = 1), yerr = np.std(Eff, axis = 1), errorevery = 100)
plt.semilogy()

# %%
plt.plot(ts, mycMa, 'r--')
plt.errorbar(ts, np.mean(mycMa, axis = 1), yerr = np.std(mycMa, axis = 1), errorevery = 100)
#plt.plot(ts, mycMa, 'k-')
plt.axhline(y = myc_thresh, color = 'k', linestyle = '--')
print(np.sum(np.max(mycMa, axis=0) > myc_thresh)/N_0)

# %%
plt.hist(T_pEcytM, bins = 'auto', histtype='step');
plt.xlabel("Time in effector state")
plt.ylabel("Counts")

# %%
plt.hist(memory_lifespan(T_pEcytM[memory_lifespan(T_pEcytM) > t_E_die])/365.25, bins = 'auto', histtype='step');
plt.xlabel("Memory lifespan")
plt.ylabel("Counts")
print(sim_summary[9], sim_summary[11])

# %%
# Compute max values in the data
r = np.arange(6)
width = 0.5
plt.bar(r, np.amax(np.array([I, Na, E, M, HI, HE]).T, axis = 0), width = width)

plt.xlabel("response")
plt.ylabel("value")

plt.xticks(r, ["Infected","Naive","Effector","Memory", "Inflammation", "Anti-inflammation"], fontsize = 7)

plt.semilogy()
plt.suptitle(r'Peak response response: $N_0=$ '+str(N_0) +r', $d_I=$'+str(d_I))

# %%
bias_1 = f_XtoY(I, HI, 
       -2.0, -2.0, 0.0, L_0 = 4*np.log(2), 
       K_I = K_I, K_H = K_H)
bias_2 = f_XtoY(I, HI, 
       -2.0, 2.0, 0.0, L_0 = -0*np.log(2), 
       K_I = K_I, K_H = K_H)

plt.plot(ts, bias_1, 'r')
plt.plot(ts, bias_2, 'k--')
plt.plot(ts, Na/np.amax(Na))
plt.plot(ts, A/(Na + A))
plt.plot(ts, H**l_H/(K_H**l_H + H**l_H))

# %%
d="/gscratch/scrubbed/oukogu/infoimmune/sim_output/no_cell_var/raw/"
comment = "sparse-reg"
infection_model = "acute" # "cancer", "acute"
runs = 5

run(batch = [196.0], outdir=d, comment=comment, infection_model = infection_model, runs = runs, num_cpu = 136, run_time = 4.0)

# %%
d_file = '/gscratch/scrubbed/oukogu/infoimmune/sim_output/no_cell_var/raw/sim_batch_0.0-'+str(runs)+'-'+infection_model+'-'+comment+'.pkl'
with open(d_file, 'rb') as f:   
    out = pickle.load(f)
