# %% [markdown]
# # Run infection dynamics with monoclonal killer T cell response

# %%
import numpy as np
from matplotlib.cm import get_cmap
import matplotlib.pyplot as plt
import matplotlib as mpl

import multiprocessing as mp
from tqdm import tqdm
from joblib import Parallel, delayed
from scipy import stats
import os
import seaborn as sns
from stoch_sim_model import *
from optimize_nets import *

plt.style.use('custom.mplstyle')
# %config InlineBackend.figure_format = 'retina'
# %load_ext line_profiler

# %%
avg_sim_time = 1.25/(60*60) # 1.6/(60*60)

print('full-reg:',(len(psi_4d)**4)*len(infection_sample_select),
      np.ceil((len(psi_4d)**4*len(infection_sample_select))/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('auto-sparse-reg:',len(psi_sparse)*len(auto_sample), 
      np.ceil((len(psi_sparse)*len(auto_sample))/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('cancer-sparse-reg:',len(psi_sparse)*len(cancer_sample), 
      np.ceil((len(psi_sparse)*len(cancer_sample))/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('sparse-reg:', len(psi_sparse)*len(infection_sample_select),
      np.ceil(len(psi_sparse)*len(infection_sample_select)/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')
# Out:
# full-reg: 185302018885184100 1029455660474.0 1800 jobs per cpu per hour
# auto-sparse-reg: 14554485 81.0 1800 jobs per cpu per hour
# cancer-sparse-reg: 8732691 49.0 1800 jobs per cpu per hour
# sparse-reg: 97029900 540.0 1800 jobs per cpu per hour

# %% [markdown]
# ### (1) Plot population averaged trajectories

# %%
# Set simulation parameters
N_0 = 100
K_I = 1.0*S_0
d_I = 20*d_S #50*d_S # d_S
b_I = 1.0*(10**(-7)) # 1.50*(10**(-7)) # b_C
I_0 = I_min #0.1*S_0 #I_min #0.05*S_0 # I_0

infection_model = 'acute_all' #'acute', 'autoimmune', 'cancer'
Na_regulation = [2.0, 2.0, -0.25, -0.5*L0_max]
NE_regulation = [2, 2, -0.25, 0.5*L0_max]
EM_regulation = [-0, -0, 0, -L0_max**3]
Edie_regulation = [-2, -2, 0.25, -0.35*L0_max]

# %%
# %lprun -T lprof0 -f lin_stoch_sim lin_stoch_sim(N_0 = 100, b_I = b_I, K_I = K_I, d_I = d_I, K_H = K_H, \
                                                NE_regulation = NE_regulation, \
                                                EM_regulation = EM_regulation, \
                                                activation_regulation = Na_regulation, \
                                                contraction_regulation = Edie_regulation, \
                                                memory_death = False)
# Out:
# *** Profile printout saved to text file 'lprof0'.
# Timer unit: 1e-09 s
#
# Total time: 0.886453 s
# File: /mmfs1/home/oukogu/infoimmune/stoch_sim_model.py
# Function: lin_stoch_sim at line 176
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    176                                           def lin_stoch_sim(S_0 = S_0, I_0 = I_min, b_I = b_I, d_S = d_S, d_I = d_I, d_IE = d_IE, K_I = K_I, K_S = K_S,
#    177                                                             d_H = d_H, K_H = K_H,
#    178                                                             N_0 = N_0, max_Na = max_Na, max_expand = max_expand,
#    179                                                             char_times = [t_bind, t_unbind, t_Na_div, t_E_div, t_M_div, t_E_die, t_cycle],
#    180                                                             NE_regulation = NE_psis,
#    181                                                             EM_regulation = EM_psis,
#    182                                                             activation_regulation = act_psis,
#    183                                                             contraction_regulation = contract_psis,
#    184                                                             infection_model = "acute",
#    185                                                             duration = sim_duration,
#    186                                                             steps = sim_steps,
#    187                                                             reg_model = "mwc_like",
#    188                                                             out_data = "small",
#    189                                                             memory_death = False,
#    190                                                             seed = None):
#    191         1     481692.0 481692.0      0.1      rng = np.random.default_rng(seed)
#    192
#    193         1        320.0    320.0      0.0      if reg_model == 'mwc_like':
#    194         1        420.0    420.0      0.0          f_XtoY = f_XtoY_mwc_like
#    195                                               else:
#    196                                                   f_XtoY = f_XtoY_ret0
#    197
#    198                                               # VARIABLE DEFINITIONS:
#    199                                               # S_0 := S_0, I_0 := I_0, b_S := b_S, b_I := b_I, d_S := d_S, d_I := d_I, d_IE := d_IE, K_I := K_I,
#    200                                               # d_H := d_H, K_H := K_H,
#    201                                               # N_0 := N_0, max_Na := max_Na,
#    202                                               # char_times := [t_bind, t_unbind, t_Na_div, t_E_div, t_M_div, t_EM_diff, t_E_die, t_Na],
#    203
#    204                                               #################################
#    205                                               ### SET META-VARIABLES FOR SIMULATION ###
#    206                                               #################################
#    207         1        981.0    981.0      0.0      dt =  duration/steps
#    208         1        881.0    881.0      0.0      N_0_var = int(N_0)
#    209         1        360.0    360.0      0.0      b_S = S_0*d_S
#    210
#    211                                               # draw population of reponding cells for agent-based simulations
#    212         1       1352.0   1352.0      0.0      psi_myc_I, psi_myc_HI, psi_myc_HE, L0_Na = activation_regulation[0], activation_regulation[1], activation_regulation[2], activation_regulation[3]
#    213         1        852.0    852.0      0.0      psi_NE_I, psi_NE_HI, psi_NE_HE, L0_NE = NE_regulation[0], NE_regulation[1], NE_regulation[2], NE_regulation[3]
#    214         1        771.0    771.0      0.0      psi_EM_I, psi_EM_HI, psi_EM_HE, L0_EM = EM_regulation[0], EM_regulation[1], EM_regulation[2], EM_regulation[3]
#    215         1        741.0    741.0      0.0      psi_Edie_I, psi_Edie_HI, psi_Edie_HE, L0_Edie = contraction_regulation[0], contraction_regulation[1], contraction_regulation[2], contraction_regulation[3]
#    216
#    217         1        130.0    130.0      0.0      p_tcr = 1.0 #np.linspace(1/10, 1, N_0_var)
#    218         1        130.0    130.0      0.0      p_cyt = 1.0 #np.ones(N_0_var)
#    219
#    220         1        240.0    240.0      0.0      int_steps = int(steps)
#    221
#    222                                               # define variables for storage
#    223         1       3826.0   3826.0      0.0      I = np.zeros(int_steps+1)
#    224         1      79449.0  79449.0      0.0      S = np.zeros(int_steps+1)
#    225         1       4707.0   4707.0      0.0      HI = np.zeros(int_steps+1)
#    226         1      10336.0  10336.0      0.0      HE = np.zeros(int_steps+1)
#    227         1      18187.0  18187.0      0.0      I_d_I = np.zeros(int_steps+1)
#    228         1       3245.0   3245.0      0.0      I_d_IE = np.zeros(int_steps+1)
#    229         1      11247.0  11247.0      0.0      S_d_SE = np.zeros(int_steps+1)
#    230
#    231         1     142003.0 142003.0      0.0      N_m = np.zeros((int_steps+1, N_0_var), dtype = np.int32)
#    232         1      19389.0  19389.0      0.0      N_m[0,:] += 1
#    233         1      31778.0  31778.0      0.0      T_Ecyt = [[] for i in np.arange(0, N_0_var)]
#    234         1      20571.0  20571.0      0.0      survive_M = [[] for i in np.arange(0, N_0_var)]
#    235
#    236         1        692.0    692.0      0.0      div_count = np.zeros(N_0_var)
#    237         1      26920.0  26920.0      0.0      div_E_count = np.log2(max_Na)*np.ones(N_0_var)
#    238         1       7471.0   7471.0      0.0      div_M_count = np.log2(max_Na)*np.ones(N_0_var)
#    239         1       1222.0   1222.0      0.0      diff_EpM_count = np.zeros(N_0_var, dtype = np.int32)
#    240         1        771.0    771.0      0.0      die_M = np.zeros(N_0_var, dtype = np.int32)
#    241
#    242         1      29444.0  29444.0      0.0      Na_m = np.zeros((int_steps+1, N_0_var), dtype = np.int32)
#    243         1     120731.0 120731.0      0.0      Ma_m = np.zeros((int_steps+1, N_0_var), dtype = np.int32)
#    244         1      29043.0  29043.0      0.0      E_m = np.zeros((int_steps+1, N_0_var), dtype = np.int32) # effector in periphary
#    245         1       1973.0   1973.0      0.0      T_E = np.zeros(N_0_var)
#    246
#    247         1       3345.0   3345.0      0.0      bias_t = np.zeros((int_steps+1, 4))
#    248
#    249                                               # Define event timer variables
#    250         1        661.0    661.0      0.0      bound_N = np.zeros(N_0_var, dtype =np.int32)
#    251         1        801.0    801.0      0.0      bound_N_time = np.zeros(N_0_var)
#    252         1       5147.0   5147.0      0.0      Na_div_flag = np.ones(N_0_var, dtype =np.int32)
#    253         1       2544.0   2544.0      0.0      Na_flag = np.ones(N_0_var, dtype =np.int32)
#    254
#    255         1      60190.0  60190.0      0.0      r_NaE = np.zeros((int_steps+1, N_0_var))
#    256         1      64166.0  64166.0      0.0      r_EM = np.zeros((int_steps+1, N_0_var))
#    257         1      59309.0  59309.0      0.0      r_Na = np.zeros((int_steps+1, N_0_var))
#    258         1      56625.0  56625.0      0.0      r_E_div = np.zeros((int_steps+1, N_0_var))
#    259         1     241302.0 241302.0      0.0      r_Edie = np.zeros((int_steps+1, N_0_var))
#    260         1       1182.0   1182.0      0.0      cum_r_NaE = np.zeros(N_0_var)
#    261
#    262         1        601.0    601.0      0.0      r_unbind_t = np.zeros(N_0_var)
#    263         1        301.0    301.0      0.0      r_N_bind = np.zeros(N_0_var)
#    264         1      12178.0  12178.0      0.0      r_Na_div = np.ones(N_0_var)/char_times[2]
#    265         1       4077.0   4077.0      0.0      r_Ma_div = np.ones(N_0_var)/char_times[4]
#    266
#    267                                               #################################
#    268                                               ### RUN POPULATION SIMULATION ###
#    269                                               #################################
#    270         1        220.0    220.0      0.0      t = 0.0
#    271         1        601.0    601.0      0.0      S[0] = S_0
#    272         1        190.0    190.0      0.0      I[0] = I_0
#    273         1        250.0    250.0      0.0      HI[0] = 0.0
#    274         1        210.0    210.0      0.0      HE[0] = 0.0
#    275
#    276         1        110.0    110.0      0.0      sum_e_m = 0
#    277
#    278      3001     487780.0    162.5      0.1      for i in np.arange(1, int_steps + 1):
#    279                                                   # select virulence model:
#    280      3000    1010338.0    336.8      0.1          if (b_I > 0 and I_0 <= 0.001*S_0) or infection_model == 'acute': # "acute"
#    281      3000     373256.0    124.4      0.0              b_I_t = b_I
#    282      3000     316664.0    105.6      0.0              d_Sauto = 0.0
#    283      3000     386491.0    128.8      0.0              infection_model = 'acute'
#    284
#    285                                                   elif (b_I > 0 and I_0 >= 0.01*S_0) or 'cancer' in infection_model: # "cancer"
#    286                                                       b_I_t = b_I*(1 - I[i - 1]/S_0)/S[i - 1]
#    287                                                       d_Sauto = 0.0
#    288                                                       infection_model = 'cancer'
#    289
#    290                                                   elif b_I == 0 or 'autoimmune' in infection_model: # "autoimmune"
#    291                                                       b_I_t = 0.0
#    292                                                       d_Sauto = d_I
#    293                                                       K_S = K_I
#    294                                                       I_0 = 0.0
#    295                                                       infection_model = 'autoimmune'
#    296
#    297                                                   else:
#    298                                                       b_I_t = b_I
#    299                                                       d_Sauto = 0
#    300
#    301                                                   # Compute total population of cell types
#    302                                                   # Use sum computed in previous iteration.
#    303      3000     346355.0    115.5      0.0          E_pop = sum_e_m
#    304
#    305                                                   #### Run infection dynamics: replication and effector clearance ####
#    306
#    307                                                   # Update state of susceptible, infected and inflammation
#    308                                                   # (a) Record new cell infections and cell killing events
#    309      3000    4264725.0   1421.6      0.5          S_to_I = dt * S[i - 1] * b_I_t * I[i - 1] * (S[i - 1] >= 1.0) * (I[i - 1] >= I_min) * (I[i - 1] <= S_0)
#    310      3000    3905676.0   1301.9      0.4          I_d_IE[i] += I_d_IE[i - 1] + dt * I[i - 1] * d_IE * E_pop / (K_I + I[i - 1] + E_pop) # infected/cancer cells killed by immune response
#    311      3000    2956904.0    985.6      0.3          I_d_I[i] += I_d_I[i - 1] + dt * I[i - 1]*d_I*(infection_model == "acute") + S_to_I * (infection_model == "cancer") # cells killed by infection or cancer
#    312      3000    3701089.0   1233.7      0.4          S_d_SE[i] += S_d_SE[i - 1] + dt * S[i - 1] * (d_IE * E_pop / (K_S + S[i - 1] + E_pop)) # susceptible cells killed by immune response
#    313
#    314                                                   # (b) Evolve susceptible and infected populations
#    315      9000    2887817.0    320.9      0.3          S[i] += S[i - 1] - S_to_I + dt * (
#    316      6000    5148580.0    858.1      0.6              b_S - (d_S + (d_Sauto / t_Hauto) * np.exp(-(t / t_Hauto)**2 / 2)) * S[i - 1]
#    317      3000    1330122.0    443.4      0.2              - (S_d_SE[i] - S_d_SE[i - 1])/dt
#    318      3000     859071.0    286.4      0.1          ) * (S[i - 1] >= 1.0)
#    319
#    320      3000    3791319.0   1263.8      0.4          I[i] += I[i - 1] + S_to_I - (I_d_IE[i] + I_d_I[i] - I_d_IE[i - 1] - I_d_I[i - 1]) + S_to_I * (infection_model == "cancer")
#    321
#    322                                                   # (C) Evolve inflammatory responses
#    323      3000    4808829.0   1602.9      0.5          harm_detected = (I_d_I[i] - I_d_I[i - 1]) + dt * S[i - 1] * (d_Sauto / t_Hauto) * np.exp(-(t / t_Hauto)**2 / 2)
#    324      3000    2086123.0    695.4      0.2          immunopathology = (S_d_SE[i] - S_d_SE[i - 1]) + (I_d_IE[i] - I_d_IE[i - 1])
#    325      3000     783084.0    261.0      0.1          cells_sensed = I[i - 1] # + (S[i - 1] * K_I / K_S)
#    326
#    327      3000    3087209.0   1029.1      0.3          HI[i] += HI[i - 1] + harm_detected - dt * d_H * HI[i - 1] * (HI[i - 1] >= 0.0)
#    328
#    329      3000    2817438.0    939.1      0.3          HE[i] += HE[i - 1] + immunopathology - dt * d_H * HE[i - 1] * (HE[i - 1] >= 0.0)
#    330
#    331                                                   ## I. Recruitment/Priming
#    332
#    333                                                   # (a) Phase 1: Naive cells encounter and bind APCs
#    334      3000     518070.0    172.7      0.1          if cells_sensed >= 1:
#    335      3000   72408811.0  24136.3      8.2              bound_N += rng.binomial(N_m[i - 1], r_N_bind * dt) - rng.binomial(N_m[i - 1], r_unbind_t * dt)
#    336                                                   else:
#    337                                                       bound_N = 0
#    338
#    339      3000   15398260.0   5132.8      1.7          bound_N_time += dt * bound_N - (1 - bound_N) * bound_N_time * N_m[i - 1] # only reset to zero if the cell is not activated
#    340
#    341                                                   # (b) Phase 2: Activated naive cells are bound to APCs and receive stimulation.
#    342      3000   30276602.0  10092.2      3.4          act_N = rng.binomial(N_m[i - 1], dt * r_Na[i - 1])
#    343
#    344                                                   ## II. Early differentiation
#    345
#    346                                                   # (a) Unbound activated naive cells divide and then differentiate
#    347      3000   29700285.0   9900.1      3.4          div_Na = rng.binomial(Na_m[i - 1] * Na_div_flag, dt * r_Na_div)
#    348
#    349      6000   25739329.0   4289.9      2.9          diff_NaE = rng.binomial(
#    350      3000    6944709.0   2314.9      0.8              Na_m[i - 1] * (1 - Na_div_flag),
#    351      3000   18408722.0   6136.2      2.1              1 - np.exp(-cum_r_NaE * dt) if np.sum(Na_m[i - 1]) > 0 else 0
#    352                                                   )
#    353
#    354                                                   ## III. Expansion and contraction
#    355
#    356                                                   # (a) New central memory cells divide
#    357      3000   32191982.0  10730.7      3.6          div_Ma = rng.binomial(Ma_m[i - 1] - diff_EpM_count, dt * r_Ma_div)
#    358
#    359                                                   # (b) Effector cells divide, differentiate, die
#    360      3000   37974320.0  12658.1      4.3          die_E = rng.binomial(E_m[i - 1], dt * r_Edie[i - 1])
#    361      3000   33839742.0  11279.9      3.8          diff_EM = rng.binomial(E_m[i - 1] - die_E, dt * r_EM[i - 1])
#    362      3000   36406119.0  12135.4      4.1          div_E = rng.binomial(E_m[i - 1] - die_E - diff_EM, dt * r_E_div[i - 1])
#    363      3000    7322942.0   2441.0      0.8          diff_EpM_count += diff_EM - die_M
#    364
#    365                                                   #### Update population dynamics: ####
#    366      3000    8449254.0   2816.4      1.0          N_m[i] += N_m[i - 1] - act_N
#    367      3000   16492104.0   5497.4      1.9          Na_m[i] += Na_m[i - 1] + div_Na + act_N - (1 - Na_div_flag) * Na_m[i - 1]
#    368
#    369      3000   19075454.0   6358.5      2.2          Ma_m[i] += Ma_m[i - 1] + div_Ma + (1 - Na_div_flag)*(Na_m[i - 1] - diff_NaE) + diff_EM - die_M
#    370      3000   14973742.0   4991.2      1.7          E_m[i] += E_m[i - 1] + div_E + (1 - Na_div_flag) * diff_NaE - (die_E + diff_EM)
#    371
#    372                                                   # Evaluate sums and create masks
#    373      3000   13736653.0   4578.9      1.5          sum_e_m = np.sum(E_m[i])
#    374      3000    5170938.0   1723.6      0.6          e_m_nonzero_mask = E_m[i] > 0
#    375      3000    4094246.0   1364.7      0.5          n_m_nonzero_mask = N_m[i] > 0
#    376      3000    3975527.0   1325.2      0.4          na_m_nonzero_mask = Na_m[i] > 0
#    377      3000    7292414.0   2430.8      0.8          bound_na_sum_nonzero_mask = Na_m[i] > 0 | bound_N
#    378      3000    6199788.0   2066.6      0.7          ma_m_nonzero_mask = Ma_m[i] + Ma_m[i-1] > 0
#    379      3000    1814214.0    604.7      0.2          n_na_sum_nonzero_mask = n_m_nonzero_mask | na_m_nonzero_mask
#    380
#    381                                                   # store time cells spend in effector effector
#    382      3000    5113831.0   1704.6      0.6          T_E += dt * e_m_nonzero_mask if sum_e_m > 0 else 0.0
#    383      3000    3794877.0   1265.0      0.4          die_M = 0*die_M
#    384
#    385                                                   # store time an effector spends in cytotoxic state
#    386      3000   17510282.0   5836.8      2.0          for_where = ((1 - Na_div_flag)*(Na_m[i-1] - diff_NaE) + div_Ma + diff_EM + ma_m_nonzero_mask*memory_death > 0)
#    387      3000    5134784.0   1711.6      0.6          where_output = np.where(for_where)[0]
#    388      3054    3379857.0   1106.7      0.4          for l in where_output:
#    389
#    390        54       8896.0    164.7      0.0              if memory_death:
#    391                                                           if Ma_m[i,l] > 0:
#    392                                                               T_Ecyt[l] = list(itertools.compress(T_Ecyt[l], survive_M[l])) + ((1 - Na_div_flag[l])*(Na_m[i-1,l] - diff_NaE[l]) + div_Ma[l]) * [0.0] + diff_EM[l] * [T_E[l].item()]
#    393                                                               arr = np.array(T_Ecyt[l])
#    394                                                               survive_M[l] = (rng.random(size = Ma_m[i,l]) > (arr > 0)*dt/memory_lifespan(arr, min_time = dt))
#    395                                                               die_M[l] = Ma_m[i,l] - np.sum(survive_M[l])
#    396                                                           else:
#    397                                                               T_Ecyt[l].extend(((1 - Na_div_flag[l])*(Na_m[i-1,l] - diff_NaE[l]) + div_Ma[l]) * [0.0] + diff_EM[l] * [T_E[l].item()])
#    398                                                               arr = np.array([])
#    399                                                               survive_M[l] = []
#    400                                                               die_M[l] = 0
#    401                                                       else:
#    402        54     287890.0   5331.3      0.0                  T_Ecyt[l].extend(((1 - Na_div_flag[l])*(Na_m[i-1,l] - diff_NaE[l]) + div_Ma[l]) * [0.0] + diff_EM[l] * [T_E[l].item()])
#    403
#    404                                                   # Update division flag to allow division to proceed
#    405      3000    5574758.0   1858.3      0.6          div_count += div_Na + div_E + div_Ma
#    406      3000    2638444.0    879.5      0.3          div_E_count += div_E
#    407      3000    2562607.0    854.2      0.3          div_M_count += div_Ma
#    408      3000    5800496.0   1933.5      0.7          Na_div_flag = (Na_m[i] < max_Na)*(na_m_nonzero_mask)
#    409
#    410                                                   #### New binding events ####
#    411      9000   25437716.0   2826.4      2.9          r_N_bind = (n_m_nonzero_mask) * (1 - bound_N) * f_XtoY(
#    412      3000    1795646.0    598.5      0.2              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    413      3000    4022391.0   1340.8      0.5              psi_1 = 0.0, psi_2 = 1/np.log(2), psi_3 = 0.0, L_0 = -1, K_1 = S_0, K_2 = K_H, K_3 = K_HE # The rate of non-specific binding is important
#    414      6000    1095086.0    182.5      0.1          ) / (char_times[0]) if cells_sensed >= 1 else 0.0
#    415
#    416      5998    6307317.0   1051.6      0.7          r_unbind_t = bound_N * np.fmin(
#    417      5996    7484599.0   1248.3      0.8              2 * bound_N_time / (
#    418     14990   13792194.0    920.1      1.6                  f_XtoY(
#    419      2998    1475968.0    492.3      0.2                      sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    420      2998    3631720.0   1211.4      0.4                      psi_1 = L0_max/np.log(2), psi_2 = 0.0, psi_3 = 0.0, L_0 = -L0_max,
#    421      2998     797401.0    266.0      0.1                      K_1 = (K_I*(infection_model != "autoimmune") + K_S*(infection_model == "autoimmune")),
#    422      2998     377383.0    125.9      0.0                      K_2 = K_H, K_3 = K_HE
#    423      8994    3350769.0    372.6      0.4                  ) * char_times[1] * 2 / np.sqrt(np.pi)
#    424      5996     824195.0    137.5      0.1              )**2, 1 / dt
#    425      3000   13790103.0   4596.7      1.6          ) if np.sum(bound_N) >= 1 else 0.0
#    426
#    427                                                   #### Transition rates modulated by antigen and cytokine signals ####
#    428      3000     638970.0    213.0      0.1          r_Na_div = 1 / char_times[2]
#    429
#    430      3000   10293806.0   3431.3      1.2          r_Ma_div = 0 * (div_count < max_expand) / char_times[4]
#    431
#    432     12000   24182878.0   2015.2      2.7          r_Na[i] += bound_N*f_XtoY(
#    433      3000    1317381.0    439.1      0.1              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    434      3000     464709.0    154.9      0.1              psi_1 = psi_myc_I, psi_2 = psi_myc_HI, psi_3 = psi_myc_HE, L_0 = L0_Na,
#    435      3000     718087.0    239.4      0.1              K_1 = (K_I*(infection_model != "autoimmune") + K_S*(infection_model == "autoimmune")),
#    436      3000     384231.0    128.1      0.0              K_2 = K_H, K_3 = K_HE
#    437      6000     754376.0    125.7      0.1          )/char_times[6] * n_m_nonzero_mask
#    438
#    439     12000   18818742.0   1568.2      2.1          r_NaE[i] += f_XtoY(
#    440      3000    1289944.0    430.0      0.1              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    441      3000     418058.0    139.4      0.0              psi_1 = psi_NE_I, psi_2 = psi_NE_HI, psi_3 = psi_NE_HE,L_0 = L0_NE,
#    442      3000     702636.0    234.2      0.1              K_1 = (K_I*(infection_model != "autoimmune") + K_S*(infection_model == "autoimmune")),
#    443      9000    1172741.0    130.3      0.1              K_2 = K_H, K_3 = K_HE)/char_times[6] * bound_na_sum_nonzero_mask
#    444
#    445     12000   27086667.0   2257.2      3.1          r_E_div[i] += (div_count < max_expand) * f_XtoY(
#    446      3000    1369658.0    456.6      0.2              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    447      3000     439766.0    146.6      0.0              psi_1 = psi_myc_I, psi_2 = psi_myc_HI, psi_3 = psi_myc_HE, L_0 = L0_Na,
#    448      3000     712003.0    237.3      0.1              K_1 = (K_I*(infection_model != "autoimmune") + K_S*(infection_model == "autoimmune")),
#    449      3000     388318.0    129.4      0.0              K_2 = K_H, K_3 = K_HE
#    450      6000     708398.0    118.1      0.1          )/char_times[6] * e_m_nonzero_mask
#    451
#    452     12000   18647320.0   1553.9      2.1          r_EM[i] += f_XtoY(
#    453      3000    1279597.0    426.5      0.1              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    454      3000     427390.0    142.5      0.0              psi_1 = psi_EM_I, psi_2 = psi_EM_HI, psi_3 = psi_EM_HE, L_0 = L0_EM,
#    455      3000     696359.0    232.1      0.1              K_1 = (K_I*(infection_model != "autoimmune") + K_S*(infection_model == "autoimmune")),
#    456      9000    1166889.0    129.7      0.1              K_2 = K_H, K_3 = K_HE)/char_times[6] * e_m_nonzero_mask
#    457
#    458     12000   18512451.0   1542.7      2.1          r_Edie[i] += f_XtoY(
#    459      3000    1290940.0    430.3      0.1              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    460      3000     440873.0    147.0      0.0              psi_1 = psi_Edie_I, psi_2 = psi_Edie_HI, psi_3 = psi_Edie_HE, L_0 = L0_Edie,
#    461      3000     745224.0    248.4      0.1              K_1 = (K_I*(infection_model != "autoimmune") + K_S*(infection_model == "autoimmune")),
#    462      9000    1101251.0    122.4      0.1              K_2 = K_H, K_3 = K_HE)/char_times[6] * e_m_nonzero_mask
#    463
#    464      3000    2097417.0    699.1      0.2          cum_r_NaE += r_NaE[i]
#    465
#    466                                                   #### Store differentiation biases
#    467      3000    1406755.0    468.9      0.2          to_add_to_bias = np.zeros(4)
#    468
#    469      3000   17444957.0   5815.0      2.0          if np.sum(n_m_nonzero_mask) > 0.:
#    470      3000   25293532.0   8431.2      2.9              to_add_to_bias[0] = np.mean(r_Na[i][n_m_nonzero_mask])
#    471
#    472      3000   16173549.0   5391.2      1.8          if np.sum(bound_na_sum_nonzero_mask) > 0.:
#    473      1119    7852093.0   7017.1      0.9              to_add_to_bias[1] = np.mean(r_NaE[i][bound_na_sum_nonzero_mask])
#    474
#    475      3000    3494841.0   1164.9      0.4          if sum_e_m > 0.:
#    476      2907   20563173.0   7073.7      2.3              to_add_to_bias[2] = np.mean(r_E_div[i][e_m_nonzero_mask])
#    477      2907   19851064.0   6828.7      2.2              to_add_to_bias[3] = np.mean(r_Edie[i][e_m_nonzero_mask])
#    478
#    479      3000    2961174.0    987.1      0.3          bias_t[i] += to_add_to_bias
#    480
#    481                                                   # Increment time
#    482      3000     585104.0    195.0      0.1          t += dt
#    483
#    484                                               # Collect population dynamics
#    485         1     574762.0 574762.0      0.1      N, Na, Ma, E = np.sum(N_m, axis = 1), np.sum(Na_m, axis = 1), np.sum(Ma_m, axis = 1), np.sum(E_m, axis = 1)
#    486
#    487         1      69164.0  69164.0      0.0      T_pEcytM = np.concatenate(T_Ecyt) if N_0 > 0 else np.array([0.0]) # time that memory spends in effector
#    488         1       8853.0   8853.0      0.0      count_cM = np.sum(T_pEcytM == 0
#    489         1       6700.0   6700.0      0.0                       ) if len(T_pEcytM[T_pEcytM == 0]) > 0 and N_0 > 0.0 else 0.0
#    490         1       6770.0   6770.0      0.0      count_eM = np.sum(T_pEcytM > 0
#    491         1       2374.0   2374.0      0.0                       ) if len(T_pEcytM[T_pEcytM == 0]) > 0 and N_0 > 0.0 else 0.0
#    492
#    493                                               # Project out surviving primary memory
#    494         1     159479.0 159479.0      0.0      mean_frac_cM = count_cM/np.sum(np.amax(Na_m, axis = 0)) if np.sum(np.amax(Na_m, axis = 0)) > 0.0 else 0.0
#    495         1       2504.0   2504.0      0.0      mean_T_pEcyteM = np.mean(T_pEcytM[T_pEcytM > 0]) if len(T_pEcytM[T_pEcytM > 0]) > 0 and N_0 > 0.0 else 0.0
#    496
#    497         1        731.0    731.0      0.0      zeros_n_0_var = np.zeros(N_0_var)
#    498
#    499         1      14652.0  14652.0      0.0      selection_ratio = np.sum(div_E_count*p_tcr)/np.sum(div_E_count) if np.sum(div_E_count) > 0 else 0.0
#    500
#    501         2      37064.0  18532.0      0.0      lineage_comp = np.vstack([
#    502         1      65408.0  65408.0      0.0          np.amax(Na_m, axis = 0), div_M_count, div_E_count,
#    503         1       3004.0   3004.0      0.0          p_tcr + zeros_n_0_var, p_cyt + zeros_n_0_var
#    504                                               ])
#    505
#    506         1      21983.0  21983.0      0.0      dyn_data = np.array([S, I, N, Na, E, Ma, HI, I_d_I + I_d_IE, S_d_SE, HE]).T # add I_d_IE as a separate variable
#    507         1        120.0    120.0      0.0      prim_bias = bias_t
#    508
#    509         1      52198.0  52198.0      0.0      ts = np.linspace(0, duration, int_steps + 1)
#    510
#    511                                               # Compute summary statistics from simulations
#    512                                               ## extract primary/secondary infection dynamics
#    513         1       2904.0   2904.0      0.0      pS, pI, N, Na, pE, pM, pHI, pI_d_I, pI_d_SE, pHE = dyn_data[:,0], dyn_data[:,1], dyn_data[:,2], dyn_data[:,3], dyn_data[:,4], dyn_data[:,5], dyn_data[:,6], dyn_data[:,7], dyn_data[:,8], dyn_data[:,9]
#    514
#    515         1        631.0    631.0      0.0      dt = ts[1] - ts[0]
#    516
#    517         3       9383.0   3127.7      0.0      parameters = np.concatenate((np.array([S_0, I_0, b_I, d_S, d_I, d_IE, K_I,
#    518         1        210.0    210.0      0.0                d_H, K_H,
#    519         1         70.0     70.0      0.0                N_0, max_Na]),
#    520         1        101.0    101.0      0.0                char_times,
#    521         1        230.0    230.0      0.0                activation_regulation, NE_regulation, EM_regulation, contraction_regulation))
#    522
#    523         2       3115.0   1557.5      0.0      sim_summary = np.array([I[-1]/I_0,
#    524         1      14031.0  14031.0      0.0                         np.argmax(pI)*dt,
#    525         1       6219.0   6219.0      0.0                         np.argmax(pI < I_min)*dt,
#    526         1       8232.0   8232.0      0.0                         np.amax(pI_d_I) + I[-1],
#    527         1       4617.0   4617.0      0.0                         np.amax(pI_d_SE),
#    528         1       4907.0   4907.0      0.0                         np.sum(div_E_count),
#    529         1      10826.0  10826.0      0.0                         np.argmax(pE)*dt*(np.max(pE + pM) >= max_Na) if N_0 > 0 else duration,
#    530         1      16014.0  16014.0      0.0                         (np.argmax((pE + pM) >= max_Na, axis = 0)*dt + duration*(np.amax(pE + pM) < max_Na)) if N_0 > 0 else duration,
#    531         1        110.0    110.0      0.0                         count_eM,
#    532         1        100.0    100.0      0.0                         mean_T_pEcyteM,
#    533         1      12649.0  12649.0      0.0                         (duration - (np.argmax(pE[::-1] >= 10*N_0 , axis = 0)*dt))*(np.max(pE) >= 10*N_0) if N_0 > 0 else 0.0,
#    534         1        100.0    100.0      0.0                         mean_frac_cM,
#    535         1       4467.0   4467.0      0.0                         np.amax(pHE),
#    536         1       4176.0   4176.0      0.0                         np.amax(pHI),
#    537         1        111.0    111.0      0.0                         selection_ratio])
#    538
#    539                                               # down-size timeseries
#    540         1        821.0    821.0      0.0      pnts = int(0.1*steps)
#    541         1      58678.0  58678.0      0.0      keep = [i*10 for i in np.arange(0,pnts)]
#    542
#    543         1        561.0    561.0      0.0      if out_data == "full":
#    544                                                   out_dict = {"reg_coeffs": np.concatenate((activation_regulation, NE_regulation, EM_regulation, contraction_regulation)),
#    545                                                               "cell_time_series": dyn_data,
#    546                                                               "time": ts,
#    547                                                               "lineage_diff": lineage_comp,
#    548                                                               "prim_diff_bias": prim_bias,
#    549                                                               "eff_by_lin": (E_m),
#    550                                                               "parameters": parameters,
#    551                                                               "summary_stats": sim_summary,
#    552                                                               "pmemory_formed": T_pEcytM if N_0 > 0 else []}
#    553         1        160.0    160.0      0.0      elif out_data == "small":
#    554         2      39479.0  19739.5      0.0          out_dict = {"cell_time_series": dyn_data[keep],
#    555         1      22884.0  22884.0      0.0                      "prim_diff_bias": prim_bias[keep],
#    556         1        120.0    120.0      0.0                      "parameters": parameters,
#    557         1        130.0    130.0      0.0                      "summary_stats": sim_summary}
#    558
#    559         1        120.0    120.0      0.0      return out_dict

# %%
# Run single simulation
# %timeit -n 2 -r 2
data_dict = lin_stoch_sim(N_0 = N_0,
                          I_0 = I_0,
                          b_I = b_I, 
                          K_I = K_I,
                          d_I = d_I,
                          K_H = K_H,
                          NE_regulation = NE_regulation,
                          EM_regulation = EM_regulation,
                          activation_regulation = Na_regulation,
                          contraction_regulation = Edie_regulation,
                          infection_model = infection_model,
                          reg_model = 'mwc_like',
                          out_data = "full",
                          memory_death = False)

# %%
regs = data_dict["reg_coeffs"]
dyn = data_dict["cell_time_series"]
ts = data_dict["time"]
lin_comp = data_dict["lineage_diff"]
p_diff = data_dict["prim_diff_bias"]
parameters = data_dict["parameters"]
sim_summary = data_dict["summary_stats"]
Eff = data_dict["eff_by_lin"]
T_pEcytM = data_dict["pmemory_formed"]

S, I, N, Na, E, M, HI, I_d_I, I_d_S, HE = dyn[:,0], dyn[:,1], dyn[:,2], dyn[:, 3], dyn[:,4], dyn[:,5], dyn[:,6], dyn[:,7], dyn[:,8], dyn[:,9]

reg_string = '-'.join(np.array(Na_regulation + NE_regulation + EM_regulation + Edie_regulation).astype('U4'))

# %%
# Plot simulated immune dynamics
fig, (ax1, ax2, ax3) = plt.subplots(3, dpi = 150, constrained_layout=True, sharex = True, figsize=(5,5))

ax1.plot(ts, S, 'k', linewidth = 1.5, label = r'susceptible, $S$')
ax1.plot(ts, I, 'b', linewidth = 1.5, label = r'infected, $I$')

ax1.plot(ts, I_d_S, 'r', linewidth = 1.5, linestyle = '--', label = r'susceptible killed')
ax1.plot(ts, I_d_I, 'g', linewidth = 1.5, linestyle = '--', label = r'infected killed')
ax1.set(ylabel='Cell count')
ax1.set_ylim(1, S_0*2)
ax1.semilogy()
ax1.minorticks_off()
ax1.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

ax2.plot(ts, Na, 'b', linewidth = 1.5, label = r'Activated, $N^*$')
ax2.plot(ts, E, 'orange', linewidth = 1.5, label = r'Effector, $E$')
ax2.plot(ts, M, 'g', linewidth = 1.5, label = r'Memory, $M$')
ax2.plot(ts, S, 'grey', linewidth = 1.5, label = r'Susceptible, $S$')
ax2.plot(ts, I, 'r', linewidth = 1.5, label = r'infected, $I$')
ax2.set(ylabel='Cell count')
ax2.semilogy()
ax2.minorticks_off()
ax2.set_ylim(1, S_0*2)
ax2.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

ax3.plot(ts, f_XtoY_mwc_like(sig_1 = I, sig_2 = HI, sig_3 = HE, 
                             psi_1 = EM_regulation[0], psi_2 = EM_regulation[1], psi_3 = EM_regulation[2], L_0 = EM_regulation[3], 
                             K_1 = K_I, K_2 = K_H, K_3 = K_H),
         'k-', label = r'Regulation, $f(I,H)$')
ax3.set(xlabel=r'Time [days]', ylabel='Regulation')
ax3.minorticks_off()
ax3.set_ylim(0,1.05)

fig.savefig("_figs/"+infection_model+'-'+'virus-effector dynamics.png', dpi=300, bbox_inches="tight")

# %%
plt.plot(ts, N)
plt.ylim(0, 1.05*N_0)
np.mean(np.argmax(Eff >0 , axis = 0)*(ts[1]-ts[0])*(np.amax(Eff, axis = 0) > 0 ))
# Out:
# 7.9113999999999995

# %%
plt.plot(ts, np.log((1 + I/K_I)), 'r', label = "Ag.")
plt.plot(ts, np.log((1 + HE/K_HE)), 'b--', label = "Anti-inflam.")
plt.plot(ts, np.log((1 + HI/K_H)), 'k--', label = "Pro-inflam.")
plt.legend()

# %%
plt.plot(ts,d_IE*E/(K_I + I + E), 'r')
plt.plot(ts, d_IE*E/(K_I + E), 'k--')

# %%
print(f'Memory fraction = {(sim_summary[8])/(sim_summary[5] + sim_summary[8])}')
print(f'Number of memory cells = {np.max(M)}')
print(f'1st infection harm = {sim_summary[3]/S_0}')
print(f'1st response toxicity = {sim_summary[4]/S_0}')
print(f'Minimum susceptible = {np.min(S)/S_0}')
# Out:
# Memory fraction = 0.0
# Number of memory cells = 101.0
# 1st infection harm = 0.2720208854182442
# 1st response toxicity = 0.7704374837269848
# Minimum susceptible = 0.012683425033979526

# %%
# Plot simulated infection dynamics: pretty plots
pnts = 50
keep = [i*int(len(E)/pnts) for i in np.arange(0,pnts)]
sus = S[keep]
naive = Na[keep]
eff = E[keep]
mem = M[keep]
p_load = np.log(1 + I[keep]/K_I)/np.log(1 + np.max(I[keep])/K_I) if np.max(I[keep]) > 0 else I[keep]
inflam = np.log((1 + HI[keep]/K_H))/np.log((1 + np.max(HI[keep])/K_H))
anti_inflam = np.log((1 + HE[keep]/K_H))/np.log((1 + np.max(HE[keep])/K_H)) if np.max(HE[keep]) > 0 else HE[keep]
inf_harm = I_d_I[keep]
toxicity = I_d_S[keep]
time = ts[keep]

fig, ax = plt.subplots(figsize=(7.5,5))

ax.plot(ts, I, 'r', label = r'Infected, $I$', linewidth=2.5)
# ax.plot(ts, S, 'grey', label = r'Susceptible, $S$', linewidth=2.5)

ax.plot(ts, E + M, 'orange', zorder = 1, linewidth=2.5, label = r'T cells, $E + M$')
im = ax.scatter(time, eff+mem, marker ='o', c = p_load, cmap='coolwarm') #, norm=mpl.colors.LogNorm())

ax.plot(ts, I_d_I, 'black', zorder = 1, linewidth=2.5, label = r'Infection harm')
ax.plot(ts, I_d_S, 'green', zorder = 1, linewidth=2.5, label = r'Toxicity harm')
# ax.plot(time, mem, 'k--')
# ax.scatter(time, mem, marker ='s', c = p_load, cmap='coolwarm',
#             label = r'Mem., $M$') #, norm=mpl.colors.LogNorm())

# ax.plot(time, inf_harm, 'r', linewidth = 2.0, label = r'Harm, $\mathcal{H}_I$')

# ax.plot(time, toxicity, 'y', linewidth = 2.0,label = r'Toxicity, $\mathcal{H}_S$')

ax.set_box_aspect(1)
cb = fig.colorbar(im, ax=ax, orientation='vertical', shrink = 0.75, pad = 0.05)
cb.set_label('Ag. stimulation', fontsize = 14)
cb.ax.tick_params(labelsize=8)
ax.set_ylabel('Cell count', fontsize = 18)
ax.set_xlabel(r"Time [days]", fontsize = 18)
ax.semilogy()
ax.minorticks_off()
ax.set_ylim(1,)
# locmaj = mpl.ticker.LogLocator(numticks=4)
# ax.yaxis.set_major_locator(locmaj)

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        ax.axvline(x=time[i], linestyle='-', linewidth=6.5, color='pink', alpha=inflam[i], label =r"Harm. stim.", zorder = 0)
        ax.axvline(x=time[i], linestyle='-', linewidth=6.5, color='grey', alpha=anti_inflam[i]/2, label =r"Tox. stim.", zorder = 0)
    else:
        ax.axvline(x=time[i], linestyle='-', linewidth=6.5, color='pink', alpha=inflam[i], zorder = 0)
        ax.axvline(x=time[i], linestyle='-', linewidth=6.5, color='grey', alpha=anti_inflam[i]/2, zorder = 0)

ax.legend(loc='lower right', fontsize = 10)

plt.savefig('_figs/'+infection_model+'-timeline-of-infection-dynamics-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
# Plot simulated infection dynamics: pretty plots of harm
pnts = 50
keep = [i*int(len(E)/pnts) for i in np.arange(0,pnts)]

eff = E[keep]
p_load = I[keep]/S_0
sus = S[keep]/S_0
inf_harm = I_d_I[keep]/S_0
inflam_harm = I_d_S[keep]/S_0
inflam = np.log((1 + HI[keep]/K_H))/np.log((1 + S_0/K_H))
time = ts[keep]

plt.scatter(time, p_load, marker ='s', c =eff/K_I, cmap='coolwarm', 
            label = r'Infected cells, $I$') #, norm=mpl.colors.LogNorm())
plt.plot(time, p_load, 'k--')

# plt.scatter(time, sus, marker ='>', c =eff/K_I, cmap='coolwarm', 
#             label = r'Susceptible cells, $S$') #, norm=mpl.colors.LogNorm())
# plt.plot(time, sus, 'k--')

plt.scatter(time, inf_harm, marker ='o', c =eff/K_I, cmap='coolwarm', 
            label = 'Infected cells killed')
plt.plot(time, inf_harm, 'k--')

plt.scatter(time, inflam_harm, marker ='*', c =eff/K_I, cmap='coolwarm',
            label = 'Susceptible cells killed')
plt.plot(time, inflam_harm, 'k--')

plt.colorbar(label = "Primary effector response")
plt.ylabel('Fraction of susceptible cells', fontsize = 14)
plt.xlabel(r"Time, $t$ [days]", fontsize = 14)

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        plt.axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], label =r"Inflammation, $H$", zorder = 0)
    else:
        plt.axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        
plt.legend(loc='center right', bbox_to_anchor=(1.85, 0.8), fontsize = 10)
plt.savefig('_figs/'+infection_model+'-infection-harm-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
# Plot simulated infection dynamics: pretty plots
pnts = 150
keep = [1 + i*int(len(E)/pnts) for i in np.arange(0,pnts)]
bias_diff = p_diff[keep]
sus = S[keep]
p_load = np.log(1 + I[keep]/K_I)/np.log(1 + np.max(I[keep])/K_I) if np.max(I[keep]) > 0 else I[keep]
inflam = np.log((1 + HI[keep]/K_H))/np.log((1 + np.max(HI[keep])/K_H))
anti_inflam = np.log((1 + HE[keep]/K_H))/np.log((1 + np.max(HE[keep])/K_H)) if np.max(HE[keep]) > 0 else HE[keep]
time = ts[keep]

fig, axs = plt.subplots(2,2, figsize=(7,7))

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0, label =r"Inflammation, $H$")
        
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0, label =r"Anti-inflammation, $P$")
    else:
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0, label =r"Inflammation, $H$")
        
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0, label =r"Anti-inflammation, $P$")


im1 = axs[0,0].scatter(time, bias_diff[:,0], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$N \longrightarrow N^*$')
axs[0,0].plot(time, bias_diff[:,0],'k--')
axs[0,0].title.set_text(r'$N \longrightarrow N^*$')
axs[0,0].set_box_aspect(1)

im2 = axs[0,1].scatter(time, bias_diff[:,1], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$N^* \longrightarrow E$')
axs[0,1].plot(time, bias_diff[:,1],'k--')
axs[0,1].title.set_text(r'$N^* \longrightarrow E$')
axs[0,1].set_box_aspect(1)

im3 = axs[1,0].scatter(time, bias_diff[:,2], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$E \longrightarrow 2E$')
axs[1,0].plot(time, bias_diff[:,2],'k--')
axs[1,0].title.set_text(r'$E \longrightarrow 2E$')
axs[1,0].set_box_aspect(1)

im4 = axs[1,1].scatter(time, bias_diff[:,3], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$E \longrightarrow \emptyset$')
axs[1,1].plot(time, bias_diff[:,3],'k--')
axs[1,1].title.set_text(r'$E \longrightarrow \emptyset$')
axs[1,1].set_box_aspect(1)

axs[0,0].set_ylabel('Rate [day$^{-1}$]', fontsize = 14)
axs[1,0].set_ylabel('Rate [day$^{-1}$]', fontsize = 14)
axs[1,0].set_xlabel("Time [days]", fontsize = 14)
axs[1,1].set_xlabel("Time [days]", fontsize = 14)

fig.subplots_adjust(wspace=.3, hspace = 0.1)
cb = fig.colorbar(im1, ax=axs, shrink = 0.5, pad = 0.05, orientation='vertical')
cb.set_label('Ag. stimulation')

#cb.set_clim(-0.4,0.4)
    
# plt.colorbar(label =r"pathogen load, $I(t)$")
# plt.ylabel('transition weight', fontsize = 16)
# plt.xlabel("time (days)", fontsize = 16)
# plt.legend() #bbox_to_anchor=(1.05, 1.0), loc='upper left')

plt.savefig('_figs/'+infection_model+'-diff-bias-over-time-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %% [markdown]
# ### (2) Plot lineage-based trajectories

# %%
keys = np.array(['Memory', 'Effector'])
all_counts = lin_comp[1:3].T
effector_ranking = np.argsort(all_counts[:, 1])[::-1]
all_counts = all_counts[effector_ranking]
total_counts = all_counts.sum(axis=1)
norm_counts = all_counts / total_counts[:, None]
norm_counts[~np.isfinite(norm_counts)] = 0
comp_argsort = np.argsort(np.max(all_counts, axis=0))
bar_dict = {k: v for k, v in zip(keys[comp_argsort], norm_counts.T[comp_argsort])}
lineage_idxs = np.arange(all_counts.shape[0])

fig, ax = plt.subplots()
bottom = np.zeros(len(lineage_idxs))
cmap_colors = sns.color_palette('Set2', 10)
cmap_colors = [cmap_colors[i]
               for i in [0, 1, 5]]#[7, 2, 0, 1, 5]]
# cmap_colors = [cmap_colors[i]
#                for i in [6, 1, 2, 5, 0]]
width = 1

for i, (celltype, fraction) in enumerate(bar_dict.items()):
    ax.bar(lineage_idxs, fraction, width,
           edgecolor='k', linewidth=0.01,
           label=celltype, bottom=bottom, color=cmap_colors[i])
    bottom += fraction
    
ax.legend(loc='center right', bbox_to_anchor=(1.4, 0.5), fontsize = 12)
ax.set_xlim(-0.5, len(all_counts) - 0.5)
ax.set_xlabel('sub-clone lineages \n (ranked by effector response)', fontsize = 15)
ax.set_ylabel('fractional cell-fate \ncomposition', fontsize = 15)
#ax.set_yscale('log')

ax.set_xticks(np.arange(0, Eff.shape[1], int(Eff.shape[1]/10)))
ax.set_xticklabels(1 + np.arange(0, Eff.shape[1], int(Eff.shape[1]/10)), fontsize=9)

ax.set_yticks(np.round(np.arange(0, 1.2, 0.2), 1))
ax.set_yticklabels(ax.get_yticks(), fontsize=12)

fig.savefig("_figs/"+infection_model+'-'+'fates-by-lin-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
plt.errorbar(ts, np.mean(Eff, axis = 1), yerr = np.std(Eff, axis = 1), errorevery = 100)
plt.semilogy()
# Out:
# []

# %%
plt.hist(T_pEcytM, bins = 'auto', histtype='step');
plt.xlabel("Time in effector state")
plt.ylabel("Counts")
# Out:
# Text(0, 0.5, 'Counts')

# %%
plt.hist(memory_lifespan(T_pEcytM[memory_lifespan(T_pEcytM) > t_E_die])/365.25, bins = 'auto', histtype='step');
plt.xlabel("Memory lifespan")
plt.ylabel("Counts")
print(sim_summary[9], sim_summary[11])
# Out:
# 0.0 0.29190751445086704

# %%
# Compute max values in the data
r = np.arange(6)
width = 0.5
plt.bar(r, np.amax(np.array([I, Na, E, M, HI, HE]).T, axis = 0), width = width)

plt.xlabel("response")
plt.ylabel("value")

plt.xticks(r, ["Infected","Naive","Effector","Memory", "Inflammation", "Anti-inflammation"], fontsize = 7)

plt.semilogy()
plt.suptitle(r'Peak response response: $N_0=$ '+str(N_0) +r', $d_I=$'+str(d_I))
# Out:
# Text(0.5, 0.98, 'Peak response response: $N_0=$ 100, $d_I=$0.2')

# %%
bias_1 = f_XtoY(I, HI, 
       -2.0, -2.0, 0.0, L_0 = 4*np.log(2), 
       K_I = K_I, K_H = K_H)
bias_2 = f_XtoY(I, HI, 
       -2.0, 2.0, 0.0, L_0 = -0*np.log(2), 
       K_I = K_I, K_H = K_H)

plt.plot(ts, bias_1, 'r')
plt.plot(ts, bias_2, 'k--')
plt.plot(ts, Na/np.amax(Na))
plt.plot(ts, A/(Na + A))
plt.plot(ts, H**l_H/(K_H**l_H + H**l_H))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 bias_1 = f_XtoY(I, HI,
#       2        -2.0, -2.0, 0.0, L_0 = 4*np.log(2),
#       3        K_I = K_I, K_H = K_H)
#       4 bias_2 = f_XtoY(I, HI,
#       5        -2.0, 2.0, 0.0, L_0 = -0*np.log(2),
#       6        K_I = K_I, K_H = K_H)
#       8 plt.plot(ts, bias_1, 'r')
#
# NameError: name 'f_XtoY' is not defined

# %%
d="/gscratch/scrubbed/oukogu/infoimmune/sim_output/no_cell_var/raw/"
comment = "sparse-reg"
infection_model = "acute" # "cancer", "acute"
runs = 5

run(batch = [196.0], outdir=d, comment=comment, infection_model = infection_model, runs = runs, num_cpu = 136, run_time = 4.0)

# %%
d_file = '/gscratch/scrubbed/oukogu/infoimmune/sim_output/no_cell_var/raw/sim_batch_0.0-'+str(runs)+'-'+infection_model+'-'+comment+'.pkl'
with open(d_file, 'rb') as f:   
    out = pickle.load(f)
