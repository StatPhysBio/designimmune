# %% [markdown]
# # Run infection dynamics with monoclonal killer T cell response

# %%
import numpy as np
from matplotlib.cm import get_cmap
import matplotlib.pyplot as plt
import matplotlib as mpl

import multiprocessing as mp
from tqdm import tqdm
from joblib import Parallel, delayed
from scipy import stats
import os
import seaborn as sns
from stoch_sim_model import *
from optimize_nets import *

plt.style.use('custom.mplstyle')
# %config InlineBackend.figure_format = 'retina'
# %load_ext line_profiler

# %%
avg_sim_time = 2.5/(60*60) # 1.6/(60*60)

print('full-reg:',(len(psi_4d)**4)*len(infection_sample_select),
      np.ceil((len(psi_4d)**4*len(infection_sample_select))/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('auto-sparse-reg:',len(psi_sparse)*len(auto_sample), 
      np.ceil((len(psi_sparse)*len(auto_sample))/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('cancer-sparse-reg:',len(psi_sparse)*len(cancer_sample), 
      np.ceil((len(psi_sparse)*len(cancer_sample))/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('sparse-reg:', len(psi_sparse)*len(infection_sample_select),
      np.ceil(len(psi_sparse)*len(infection_sample_select)/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')
# Out:
# full-reg: 185302018885184100 1801547405829.0 1028 jobs per cpu per hour
# auto-sparse-reg: 7971615 78.0 1028 jobs per cpu per hour
# cancer-sparse-reg: 4782969 47.0 1028 jobs per cpu per hour
# sparse-reg: 53144100 517.0 1028 jobs per cpu per hour

# %% [markdown]
# ### (1) Plot population averaged trajectories

# %%
# Set simulation parameters
N_0 = 1000
K_I = 0.01*S_0
d_I = 25*d_S #50*d_S # d_S
b_I = 1.0*(10**(-7)) # 1.50*(10**(-7)) # b_C
I_0 = I_min #0.05*S_0 # I_0

infection_model = 'acute_all' #'acute', 'autoimmune', 'cancer'
Na_regulation = [2.0, 2.0, -0.0, -0.5*L0_max]
NE_regulation = [2, 2, -0, 0.5*L0_max]
EM_regulation = [-0, -0, 0, -L0_max**2]
Edie_regulation = [-2, -2, 0.0, 0.5*L0_max]

# %%
# %lprun -T lprof0 -f lin_stoch_sim lin_stoch_sim(N_0 = 1000, b_I = b_I, K_I = K_I, d_I = d_I, K_H = K_H, \
                                                NE_regulation = NE_regulation, \
                                                EM_regulation = EM_regulation, \
                                                activation_regulation = Na_regulation, \
                                                contraction_regulation = Edie_regulation, \
                                                memory_death = False)
# Out:
# *** Profile printout saved to text file 'lprof0'.
# Timer unit: 1e-09 s
#
# Total time: 1.65642 s
# File: /mmfs1/home/oukogu/infoimmune/stoch_sim_model.py
# Function: lin_stoch_sim at line 182
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    182                                           def lin_stoch_sim(S_0 = S_0, I_0 = I_min, b_I = b_I, d_S = d_S, d_I = d_I, d_IE = d_IE, K_I = K_I, K_S = K_S,
#    183                                                             b_H = b_H, d_H = d_H, K_H = K_H,
#    184                                                             N_0 = N_0, max_Na = max_Na, b_myc = b_myc, d_myc = d_myc, myc_thresh = myc_thresh, max_expand = max_expand,
#    185                                                             char_times = [t_bind, t_unbind, t_Na_div, t_E_div, t_M_div, t_E_die, t_cycle],
#    186                                                             NE_regulation = NE_psis,
#    187                                                             EM_regulation = EM_psis,
#    188                                                             activation_regulation = act_psis,
#    189                                                             contraction_regulation = contract_psis,
#    190                                                             infection_model = "acute",
#    191                                                             duration = sim_duration,
#    192                                                             steps = sim_steps,
#    193                                                             reg_model = "mwc_like",
#    194                                                             out_data = "small",
#    195                                                             memory_death = False,
#    196                                                             seed = None):
#    197         1     400892.0 400892.0      0.0      rng = np.random.default_rng(seed)
#    198
#    199         1        391.0    391.0      0.0      if reg_model == 'mwc_like':
#    200         1        561.0    561.0      0.0          f_XtoY = f_XtoY_mwc_like
#    201                                               else:
#    202                                                   f_XtoY = f_XtoY_ret0
#    203
#    204                                               # VARIABLE DEFINITIONS:
#    205                                               # S_0 := S_0, I_0 := I_0, b_S := b_S, b_I := b_I, d_S := d_S, d_I := d_I, d_IE := d_IE, K_I := K_I,
#    206                                               # b_H := b_H, d_H := d_H, K_H := K_H,
#    207                                               # N_0 := N_0, max_Na := max_Na, b_myc := b_myc, d_myc := d_myc, myc_thresh := myc_thresh,
#    208                                               # char_times := [t_bind, t_unbind, t_Na_div, t_E_div, t_M_div, t_EM_diff, t_E_die, t_Na],
#    209
#    210                                               #################################
#    211                                               ### SET META-VARIABLES FOR SIMULATION ###
#    212                                               #################################
#    213         1       1362.0   1362.0      0.0      dt =  duration/steps
#    214         1        471.0    471.0      0.0      N_0_var = int(N_0)
#    215         1        952.0    952.0      0.0      b_S = S_0*d_S
#    216
#    217                                               # draw population of reponding cells for agent-based simulations
#    218         1       1522.0   1522.0      0.0      psi_myc_I, psi_myc_HI, psi_myc_HE, L0_Na = activation_regulation[0], activation_regulation[1], activation_regulation[2], activation_regulation[3]
#    219         1        391.0    391.0      0.0      psi_NE_I, psi_NE_HI, psi_NE_HE, L0_NE = NE_regulation[0], NE_regulation[1], NE_regulation[2], NE_regulation[3]
#    220         1        480.0    480.0      0.0      psi_EM_I, psi_EM_HI, psi_EM_HE, L0_EM = EM_regulation[0], EM_regulation[1], EM_regulation[2], EM_regulation[3]
#    221         1       1132.0   1132.0      0.0      psi_Edie_I, psi_Edie_HI, psi_Edie_HE, L0_Edie = contraction_regulation[0], contraction_regulation[1], contraction_regulation[2], contraction_regulation[3]
#    222
#    223         1      36755.0  36755.0      0.0      p_tcr = np.array(int(0.1*N_0_var)*[K_I] + int(0.9*N_0_var)*[10*K_I])
#    224         1        150.0    150.0      0.0      p_cyt = 1.0 #np.ones(N_0_var)
#    225
#    226         1        330.0    330.0      0.0      int_steps = int(steps)
#    227
#    228                                               # define variables for storage
#    229         1       2904.0   2904.0      0.0      I = np.zeros(int_steps+1)
#    230         1       1993.0   1993.0      0.0      S = np.zeros(int_steps+1)
#    231         1       2114.0   2114.0      0.0      HI = np.zeros(int_steps+1)
#    232         1       2164.0   2164.0      0.0      HE = np.zeros(int_steps+1)
#    233         1       2614.0   2614.0      0.0      I_d_I = np.zeros(int_steps+1)
#    234         1       1863.0   1863.0      0.0      I_d_IE = np.zeros(int_steps+1)
#    235         1       2464.0   2464.0      0.0      S_d_SE = np.zeros(int_steps+1)
#    236
#    237         1      28552.0  28552.0      0.0      N_m = np.zeros((int_steps+1, N_0_var), dtype = np.int32)
#    238         1      32229.0  32229.0      0.0      N_m[0,:] += 1
#    239         1     206770.0 206770.0      0.0      T_Ecyt = [[] for i in np.arange(0, N_0_var)]
#    240         1      94322.0  94322.0      0.0      survive_M = [[] for i in np.arange(0, N_0_var)]
#    241
#    242         1        911.0    911.0      0.0      div_count = np.zeros(N_0_var)
#    243         1      36584.0  36584.0      0.0      div_E_count = np.log2(max_Na)*np.ones(N_0_var)
#    244         1       7341.0   7341.0      0.0      div_M_count = np.log2(max_Na)*np.ones(N_0_var)
#    245         1       2835.0   2835.0      0.0      diff_EpM_count = np.zeros(N_0_var, dtype = np.int32)
#    246         1        621.0    621.0      0.0      die_M = np.zeros(N_0_var, dtype = np.int32)
#    247
#    248         1       8523.0   8523.0      0.0      Na_m = np.zeros((int_steps+1, N_0_var), dtype = np.int32)
#    249         1       4186.0   4186.0      0.0      Ma_m = np.zeros((int_steps+1, N_0_var), dtype = np.int32)
#    250         1       9164.0   9164.0      0.0      E_m = np.zeros((int_steps+1, N_0_var), dtype = np.int32) # effector in periphary
#    251         1       1131.0   1131.0      0.0      T_E = np.zeros(N_0_var)
#    252
#    253         1        581.0    581.0      0.0      if out_data == "full":
#    254                                                   mycN_m = np.zeros((int_steps+1, N_0_var))
#    255                                                   mycMa_m = np.zeros((int_steps+1, N_0_var))
#    256                                                   mycE_m = np.zeros((int_steps+1, N_0_var))
#    257
#    258         1       5438.0   5438.0      0.0      bias_t = np.zeros((int_steps+1, 4))
#    259
#    260                                               # Define event timer variables
#    261         1        641.0    641.0      0.0      bound_N = np.zeros(N_0_var, dtype =np.int32)
#    262         1        861.0    861.0      0.0      bound_N_time = np.zeros(N_0_var)
#    263         1       3696.0   3696.0      0.0      Na_div_flag = np.ones(N_0_var, dtype =np.int32)
#    264         1       2975.0   2975.0      0.0      Na_flag = np.ones(N_0_var, dtype =np.int32)
#    265
#    266         1       1042.0   1042.0      0.0      mycN = np.zeros(N_0_var)
#    267         1       2724.0   2724.0      0.0      mycE = np.zeros(N_0_var)
#    268         1       1232.0   1232.0      0.0      mycMa = np.zeros(N_0_var)
#    269
#    270         1       6549.0   6549.0      0.0      r_NaE = np.zeros((int_steps+1, N_0_var))
#    271         1       4567.0   4567.0      0.0      r_EM = np.zeros((int_steps+1, N_0_var))
#    272         1       4326.0   4326.0      0.0      r_Na = np.zeros((int_steps+1, N_0_var))
#    273         1       4436.0   4436.0      0.0      r_Edie = np.zeros((int_steps+1, N_0_var))
#    274         1       1141.0   1141.0      0.0      cum_r_NaE = np.zeros(N_0_var)
#    275
#    276         1        972.0    972.0      0.0      r_unbind_t = np.zeros(N_0_var)
#    277         1        911.0    911.0      0.0      r_N_bind = np.zeros(N_0_var)
#    278         1      10506.0  10506.0      0.0      r_Na_div = np.ones(N_0_var)/char_times[2]
#    279         1        501.0    501.0      0.0      r_myc_t = np.zeros(N_0_var)
#    280         1       5077.0   5077.0      0.0      r_E_div = np.ones(N_0_var)/char_times[3]
#    281         1       5188.0   5188.0      0.0      r_Ma_div = np.ones(N_0_var)/char_times[4]
#    282
#    283                                               #################################
#    284                                               ### RUN POPULATION SIMULATION ###
#    285                                               #################################
#    286         1        170.0    170.0      0.0      t = 0.0
#    287         1        470.0    470.0      0.0      S[0] = S_0
#    288         1        221.0    221.0      0.0      I[0] = I_0
#    289         1        351.0    351.0      0.0      HI[0] = 0.0
#    290         1        230.0    230.0      0.0      HE[0] = 0.0
#    291
#    292         1        130.0    130.0      0.0      sum_e_m = 0
#    293
#    294      4001     752885.0    188.2      0.0      for i in np.arange(1, int_steps + 1):
#    295                                                   # select virulence model:
#    296      4000    1381861.0    345.5      0.1          if (b_I > 0 and I_0 <= 0.001*S_0) or infection_model == 'acute': # "acute"
#    297      4000     572924.0    143.2      0.0              b_I_t = b_I
#    298      4000     538660.0    134.7      0.0              d_Sauto = 0.0
#    299      4000     661444.0    165.4      0.0              infection_model = 'acute'
#    300
#    301                                                   elif (b_I > 0 and I_0 >= 0.01*S_0) or 'cancer' in infection_model: # "cancer"
#    302                                                       b_I_t = b_I/S_0
#    303                                                       d_Sauto = 0.0
#    304                                                       infection_model = 'cancer'
#    305
#    306                                                   elif b_I == 0 or 'autoimmune' in infection_model: # "autoimmune"
#    307                                                       b_I_t = 0.0
#    308                                                       d_Sauto = d_I
#    309                                                       K_S = K_I
#    310                                                       I_0 = 0.0
#    311                                                       infection_model = 'autoimmune'
#    312
#    313                                                   else:
#    314                                                       b_I_t = b_I
#    315                                                       d_Sauto = 0
#    316
#    317                                                   # Compute total population of cell types
#    318                                                   # Use sum computed in previous iteration.
#    319      4000     561204.0    140.3      0.0          E_pop = sum_e_m
#    320
#    321                                                   #### Run infection dynamics: replication and effector clearance ####
#    322
#    323                                                   # Update state of susceptible, infected and inflammation
#    324                                                   # (a) Record new cell infections and cell killing events
#    325      4000    4917703.0   1229.4      0.3          S_to_I = dt * S[i - 1] * b_I_t * I[i - 1] * (S[i - 1] >= 1.0) * (I[i - 1] >= I_min)
#    326      4000    5343055.0   1335.8      0.3          I_d_IE[i] += I_d_IE[i - 1] + dt * I[i - 1] * d_IE * E_pop / (K_I + I[i - 1] + E_pop) # infected/cancer cells killed by immune response
#    327      4000    3959760.0    989.9      0.2          I_d_I[i] += I_d_I[i - 1] + dt * I[i - 1]*d_I*(infection_model == "acute") + S_to_I * (infection_model == "cancer") # cells killed by infection or cancer
#    328      4000    5070358.0   1267.6      0.3          S_d_SE[i] += S_d_SE[i - 1] + dt * S[i - 1] * (d_IE * E_pop / (K_S + S[i - 1] + E_pop)) # susceptible cells killed by immune response
#    329
#    330                                                   # (b) Evolve susceptible and infected populations
#    331     12000    3873356.0    322.8      0.2          S[i] += S[i - 1] - S_to_I + dt * (
#    332      8000    7346684.0    918.3      0.4              b_S - (d_S + (d_Sauto / t_Hauto) * np.exp(-(t / t_Hauto)**2 / 2)) * S[i - 1]
#    333      4000    1831111.0    457.8      0.1              - (S_d_SE[i] - S_d_SE[i - 1])/dt
#    334      4000    1177873.0    294.5      0.1          ) * (S[i - 1] >= 1.0)
#    335
#    336      4000    5047275.0   1261.8      0.3          I[i] += I[i - 1] + S_to_I - (I_d_IE[i] + I_d_I[i] - I_d_IE[i - 1] - I_d_I[i - 1]) + S_to_I * (infection_model == "cancer")
#    337
#    338                                                   # (C) Evolve inflammatory responses
#    339      4000    6254069.0   1563.5      0.4          harm_detected = (I_d_I[i] - I_d_I[i - 1]) + dt * S[i - 1] * (d_Sauto / t_Hauto) * np.exp(-(t / t_Hauto)**2 / 2)
#    340      4000    2759643.0    689.9      0.2          immunopathology = (S_d_SE[i] - S_d_SE[i - 1]) + (I_d_IE[i] - I_d_IE[i - 1])
#    341      4000    1036674.0    259.2      0.1          cells_sensed = I[i - 1] # + (S[i - 1] * K_I / K_S)
#    342
#    343      4000    4416193.0   1104.0      0.3          HI[i] += HI[i - 1] + b_H * harm_detected - dt * d_H * HI[i - 1] * (HI[i - 1] >= 0.0)
#    344
#    345      4000    4090562.0   1022.6      0.2          HE[i] += HE[i - 1] + b_H * immunopathology - dt * d_H * HE[i - 1] * (HE[i - 1] >= 0.0)
#    346
#    347                                                   ## I. Recruitment/Priming
#    348
#    349                                                   # (a) Phase 1: Naive cells encounter and bind APCs
#    350      4000     745573.0    186.4      0.0          if cells_sensed >= 1:
#    351       373   19455496.0  52159.5      1.2              bound_N += rng.binomial(N_m[i - 1], r_N_bind * dt) - rng.binomial(N_m[i - 1], r_unbind_t * dt)
#    352                                                   else:
#    353      3627     459824.0    126.8      0.0              bound_N = 0
#    354
#    355      4000   20855604.0   5213.9      1.3          bound_N_time += dt * bound_N - (1 - bound_N) * bound_N_time * N_m[i - 1] # only reset to zero if the cell is not activated
#    356
#    357                                                   # (b) Phase 2: Activated naive cells are bound to APCs and receive stimulation.
#    358      4000   21574166.0   5393.5      1.3          act_N = (1 - bound_N) * (mycN >= myc_thresh) * (N_m[i - 1] > 0)
#    359
#    360                                                   ## II. Early differentiation
#    361
#    362                                                   # (a) Unbound activated naive cells divide and then differentiate
#    363      4000   72913210.0  18228.3      4.4          div_Na = rng.binomial(Na_m[i - 1] * Na_div_flag, dt * r_Na_div)
#    364
#    365      8000   54111918.0   6764.0      3.3          diff_NaE = rng.binomial(
#    366      4000   12416291.0   3104.1      0.7              Na_m[i - 1] * (1 - Na_div_flag),
#    367      4000   22400321.0   5600.1      1.4              1 - np.exp(-cum_r_NaE * dt) if np.sum(Na_m[i - 1]) > 0 else 0
#    368                                                   )
#    369
#    370                                                   ## III. Expansion and contraction
#    371
#    372                                                   # (a) New central memory cells divide
#    373      4000   65964471.0  16491.1      4.0          div_Ma = rng.binomial(Ma_m[i - 1] - diff_EpM_count, dt * r_Ma_div)
#    374
#    375                                                   # (b) Effector cells divide, differentiate, die
#    376      4000   74717609.0  18679.4      4.5          die_E = rng.binomial(E_m[i - 1], dt * r_Edie[i - 1])
#    377      4000   71961037.0  17990.3      4.3          diff_EM = rng.binomial(E_m[i - 1] - die_E, dt * r_EM[i - 1])
#    378      4000   75704753.0  18926.2      4.6          div_E = rng.binomial(E_m[i - 1] - die_E - diff_EM, dt * r_E_div)
#    379      4000   14430495.0   3607.6      0.9          diff_EpM_count += diff_EM - die_M
#    380
#    381                                                   #### Update population dynamics: ####
#    382      4000   26582640.0   6645.7      1.6          N_m[i] += N_m[i - 1] - act_N
#    383      4000   40550914.0  10137.7      2.4          Na_m[i] += Na_m[i - 1] + div_Na + act_N - (1 - Na_div_flag) * Na_m[i - 1]
#    384
#    385      4000   46899847.0  11725.0      2.8          Ma_m[i] += Ma_m[i - 1] + div_Ma + (1 - Na_div_flag)*(Na_m[i - 1] - diff_NaE) + diff_EM - die_M
#    386      4000   39448435.0   9862.1      2.4          E_m[i] += E_m[i - 1] + div_E + (1 - Na_div_flag) * diff_NaE - (die_E + diff_EM)
#    387
#    388                                                   # Evaluate sums and create masks
#    389      4000   20243447.0   5060.9      1.2          sum_e_m = np.sum(E_m[i])
#    390      4000    7255864.0   1814.0      0.4          e_m_nonzero_mask = E_m[i] > 0
#    391      4000    5701986.0   1425.5      0.3          n_m_nonzero_mask = N_m[i] > 0
#    392      4000    5637154.0   1409.3      0.3          na_m_nonzero_mask = Na_m[i] > 0
#    393      4000    6286157.0   1571.5      0.4          bound_na_sum_nonzero_mask = Na_m[i] > 0 | bound_N
#    394      4000    9226307.0   2306.6      0.6          ma_m_nonzero_mask = Ma_m[i] + Ma_m[i-1] > 0
#    395      4000    2795515.0    698.9      0.2          n_na_sum_nonzero_mask = n_m_nonzero_mask | na_m_nonzero_mask
#    396
#    397                                                   # store time cells spend in effector effector
#    398      4000    6132640.0   1533.2      0.4          T_E += dt * e_m_nonzero_mask if sum_e_m > 0 else 0.0
#    399      4000    5963959.0   1491.0      0.4          die_M = 0*die_M
#    400
#    401                                                   # store time an effector spends in cytotoxic state
#    402      4000   34368852.0   8592.2      2.1          for_where = ((1 - Na_div_flag)*(Na_m[i-1] - diff_NaE) + div_Ma + diff_EM + ma_m_nonzero_mask*memory_death > 0)
#    403      4000    7568298.0   1892.1      0.5          where_output = np.where(for_where)[0]
#    404      4761    5252841.0   1103.3      0.3          for l in where_output:
#    405
#    406       761     115143.0    151.3      0.0              if memory_death:
#    407                                                           if Ma_m[i,l] > 0:
#    408                                                               T_Ecyt[l] = list(itertools.compress(T_Ecyt[l], survive_M[l])) + ((1 - Na_div_flag[l])*(Na_m[i-1,l] - diff_NaE[l]) + div_Ma[l]) * [0.0] + diff_EM[l] * [T_E[l].item()]
#    409                                                               arr = np.array(T_Ecyt[l])
#    410                                                               survive_M[l] = (rng.random(size = Ma_m[i,l]) > (arr > 0)*dt/memory_lifespan(arr, min_time = dt))
#    411                                                               die_M[l] = Ma_m[i,l] - np.sum(survive_M[l])
#    412                                                           else:
#    413                                                               T_Ecyt[l].extend(((1 - Na_div_flag[l])*(Na_m[i-1,l] - diff_NaE[l]) + div_Ma[l]) * [0.0] + diff_EM[l] * [T_E[l].item()])
#    414                                                               arr = np.array([])
#    415                                                               survive_M[l] = []
#    416                                                               die_M[l] = 0
#    417                                                       else:
#    418       761    3039983.0   3994.7      0.2                  T_Ecyt[l].extend(((1 - Na_div_flag[l])*(Na_m[i-1,l] - diff_NaE[l]) + div_Ma[l]) * [0.0] + diff_EM[l] * [T_E[l].item()])
#    419
#    420                                                   # Update division flag to allow division to proceed
#    421      4000   11403655.0   2850.9      0.7          div_count += div_Na + div_E + div_Ma
#    422      4000    5527350.0   1381.8      0.3          div_E_count += div_E
#    423      4000    5386384.0   1346.6      0.3          div_M_count += div_Ma
#    424      4000    8241209.0   2060.3      0.5          Na_div_flag = (Na_m[i] < max_Na)*(na_m_nonzero_mask)
#    425
#    426                                                   #### New binding events ####
#    427      4746    8898987.0   1875.0      0.5          r_N_bind = (n_m_nonzero_mask) * (1 - bound_N) * f_XtoY(
#    428       373     677852.0   1817.3      0.0              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    429       373     571866.0   1533.2      0.0              psi_1 = 0.0, psi_2 = 1/np.log(2), psi_3 = 0.0, L_0 = -1, K_1 = S_0, K_2 = K_H, K_3 = K_HE # The rate of non-specific binding is important
#    430      4373    1037430.0    237.2      0.1          ) / (char_times[0]) if cells_sensed >= 1 else 0.0
#    431
#    432      4372    1736584.0    397.2      0.1          r_unbind_t = bound_N * np.fmin(
#    433       744    1306179.0   1755.6      0.1              2 * bound_N_time / (
#    434      1860    7154685.0   3846.6      0.4                  f_XtoY(
#    435       372     579015.0   1556.5      0.0                      sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    436       372     471011.0   1266.2      0.0                      psi_1 = L0_max/np.log(2), psi_2 = 0.0, psi_3 = 0.0, L_0 = -L0_max,
#    437       372     135986.0    365.6      0.0                      K_1 = (K_I*(infection_model != "autoimmune") + K_S*(infection_model == "autoimmune")),
#    438       372      52484.0    141.1      0.0                      K_2 = K_H, K_3 = K_HE
#    439      1116     474049.0    424.8      0.0                  ) * char_times[1] * 2 / np.sqrt(np.pi)
#    440       744     122253.0    164.3      0.0              )**2, 1 / dt
#    441      4000   22848069.0   5712.0      1.4          ) if np.sum(bound_N) >= 1 else 0.0
#    442
#    443      8000   67067268.0   8383.4      4.0          r_myc_t = b_myc * f_XtoY(
#    444      4000    6758114.0   1689.5      0.4              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    445      4000     543132.0    135.8      0.0              psi_1 = psi_myc_I, psi_2 = psi_myc_HI, psi_3 = psi_myc_HE, L_0 = L0_Na,
#    446      4000    1227340.0    306.8      0.1              K_1 = (K_I*(infection_model != "autoimmune") + K_S*(infection_model == "autoimmune")),
#    447      4000     627072.0    156.8      0.0              K_2 = K_H, K_3 = K_HE
#    448                                                   )
#    449
#    450                                                   #### MYC Dynamics ####
#    451      4000   39935521.0   9983.9      2.4          mycN = (mycN + dt * ((bound_N + na_m_nonzero_mask)*r_myc_t - d_myc * mycN * (mycN > 0)) ) * n_na_sum_nonzero_mask
#    452
#    453      4000   35266552.0   8816.6      2.1          mycE = (mycE + dt * (r_myc_t - d_myc * mycE * (mycE > 0)) ) * e_m_nonzero_mask + mycN * (na_m_nonzero_mask)
#    454
#    455     20000   87565483.0   4378.3      5.3          mycMa = 0*(mycMa + dt * (b_myc * f_XtoY(
#    456      4000    5975331.0   1493.8      0.4              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    457      4000     637630.0    159.4      0.0              psi_1 = psi_myc_I, psi_2 = 0.0, psi_3 = 0.0, L_0 = L0_Na,
#    458      4000     988405.0    247.1      0.1              K_1 = (K_I*(infection_model != "autoimmune") + K_S*(infection_model == "autoimmune")),
#    459      4000     570239.0    142.6      0.0              K_2 = K_H, K_3 = K_HE
#    460     12000   19584539.0   1632.0      1.2          ) - d_myc * mycMa * (mycMa > 0)) ) * ma_m_nonzero_mask + mycN * na_m_nonzero_mask # Unclear division dynamics for central memory
#    461
#    462                                                   #### Time-dependent rates modulated by antigen and cytokine signals ####
#    463      4000    1127118.0    281.8      0.1          r_Na_div = 1 / char_times[2]
#    464      4000   17712045.0   4428.0      1.1          r_E_div = (mycE >= myc_thresh) * (div_count < max_expand) / char_times[3]
#    465      4000   16567552.0   4141.9      1.0          r_Ma_div = (mycMa >= myc_thresh) * (div_count < max_expand) / char_times[4]
#    466
#    467                                                   #### Transition rates modulated by antigen and cytokine signals ####
#    468      4000   23638596.0   5909.6      1.4          r_Na[i] += r_E_div
#    469
#    470     20000   97857321.0   4892.9      5.9          r_NaE[i] += f_XtoY(
#    471      4000    6066957.0   1516.7      0.4              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    472      4000     619040.0    154.8      0.0              psi_1 = psi_NE_I, psi_2 = psi_NE_HI, psi_3 = psi_NE_HE,L_0 = L0_NE,
#    473      4000    1056664.0    264.2      0.1              K_1 = (K_I*(infection_model != "autoimmune") + K_S*(infection_model == "autoimmune")),
#    474     16000    6099933.0    381.2      0.4              K_2 = K_H, K_3 = K_HE)/char_times[6] * (mycN >= myc_thresh) * bound_na_sum_nonzero_mask
#    475
#    476     16000   91416297.0   5713.5      5.5          r_EM[i] += f_XtoY(
#    477      4000    5967291.0   1491.8      0.4              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    478      4000     572484.0    143.1      0.0              psi_1 = psi_EM_I, psi_2 = psi_EM_HI, psi_3 = psi_EM_HE, L_0 = L0_EM,
#    479      4000     999653.0    249.9      0.1              K_1 = (K_I*(infection_model != "autoimmune") + K_S*(infection_model == "autoimmune")),
#    480     12000    1761471.0    146.8      0.1              K_2 = K_H, K_3 = K_HE)/char_times[6] * e_m_nonzero_mask
#    481
#    482     16000   90089933.0   5630.6      5.4          r_Edie[i] += f_XtoY(
#    483      4000    5903761.0   1475.9      0.4              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*HI[i], sig_3 = p_cyt*HE[i],
#    484      4000     545699.0    136.4      0.0              psi_1 = psi_Edie_I, psi_2 = psi_Edie_HI, psi_3 = psi_Edie_HE, L_0 = L0_Edie,
#    485      4000    1038672.0    259.7      0.1              K_1 = (K_I*(infection_model != "autoimmune") + K_S*(infection_model == "autoimmune")),
#    486     12000    1707882.0    142.3      0.1              K_2 = K_H, K_3 = K_HE)/char_times[6] * e_m_nonzero_mask
#    487
#    488      4000    3587376.0    896.8      0.2          cum_r_NaE += r_NaE[i]
#    489
#    490                                                   #### Store myc levels ####
#    491      4000     860916.0    215.2      0.1          if out_data == "full":
#    492                                                       mycN_m[i] += mycN
#    493                                                       mycMa_m[i] += mycMa
#    494                                                       mycE_m[i] += mycE
#    495
#    496                                                   #### Store differentiation biases
#    497      4000    2288229.0    572.1      0.1          to_add_to_bias = np.zeros(4)
#    498      4000   26228548.0   6557.1      1.6          if np.sum(bound_na_sum_nonzero_mask) > 0.:
#    499       571    6661628.0  11666.6      0.4              to_add_to_bias[1] = np.mean(r_NaE[i][bound_na_sum_nonzero_mask])
#    500
#    501      4000    4554083.0   1138.5      0.3          if sum_e_m > 0.:
#    502       805    7754347.0   9632.7      0.5              to_add_to_bias[0] = np.mean(r_Na[i][e_m_nonzero_mask])
#    503       805    6500510.0   8075.2      0.4              to_add_to_bias[2] = np.mean(r_EM[i][e_m_nonzero_mask])
#    504       805    6298147.0   7823.8      0.4              to_add_to_bias[3] = np.mean(r_Edie[i][e_m_nonzero_mask])
#    505
#    506      4000    3821258.0    955.3      0.2          bias_t[i] += to_add_to_bias
#    507
#    508                                                   # Increment time
#    509      4000     871491.0    217.9      0.1          t += dt
#    510
#    511                                               # Collect population dynamics
#    512         1    6943815.0    7e+06      0.4      N, Na, Ma, E = np.sum(N_m, axis = 1), np.sum(Na_m, axis = 1), np.sum(Ma_m, axis = 1), np.sum(E_m, axis = 1)
#    513
#    514         1     441363.0 441363.0      0.0      T_pEcytM = np.concatenate(T_Ecyt) if N_0 > 0 else np.array([0.0]) # time that memory spends in effector
#    515         1      13610.0  13610.0      0.0      count_cM = np.sum(T_pEcytM == 0
#    516         1      56675.0  56675.0      0.0                       ) if len(T_pEcytM[T_pEcytM == 0]) > 0 and N_0 > 0.0 else 0.0
#    517         1       7932.0   7932.0      0.0      count_eM = np.sum(T_pEcytM > 0
#    518         1       6279.0   6279.0      0.0                       ) if len(T_pEcytM[T_pEcytM == 0]) > 0 and N_0 > 0.0 else 0.0
#    519
#    520                                               # Project out surviving primary memory
#    521         1    1176026.0    1e+06      0.1      mean_frac_cM = count_cM/np.sum(np.amax(Na_m, axis = 0)) if np.sum(np.amax(Na_m, axis = 0)) > 0.0 else 0.0
#    522         1      64046.0  64046.0      0.0      mean_T_pEcyteM = np.mean(T_pEcytM[T_pEcytM > 0]) if len(T_pEcytM[T_pEcytM > 0]) > 0 and N_0 > 0.0 else 0.0
#    523
#    524         1       2594.0   2594.0      0.0      zeros_n_0_var = np.zeros(N_0_var)
#    525
#    526         1      18699.0  18699.0      0.0      selection_ratio = np.sum(div_E_count[0:int(0.1*N_0_var)])/np.sum(div_E_count)/(1/10) if np.sum(div_E_count) > 0.0 else 0.0
#    527
#    528         2      61442.0  30721.0      0.0      lineage_comp = np.vstack([
#    529         1     391988.0 391988.0      0.0          np.amax(Na_m, axis = 0), div_M_count, div_E_count,
#    530         1       5999.0   5999.0      0.0          p_tcr + zeros_n_0_var, p_cyt + zeros_n_0_var
#    531                                               ])
#    532
#    533         1      31217.0  31217.0      0.0      dyn_data = np.array([S, I, N, Na, E, Ma, HI, I_d_I + I_d_IE, S_d_SE, HE]).T # add I_d_IE as a separate variable
#    534         1        240.0    240.0      0.0      prim_bias = bias_t
#    535
#    536         1      75603.0  75603.0      0.0      ts = np.linspace(0, duration, int_steps + 1)
#    537
#    538                                               # Compute summary statistics from simulations
#    539                                               ## extract primary/secondary infection dynamics
#    540         1       3125.0   3125.0      0.0      pS, pI, N, Na, pE, pM, pHI, pI_d_I, pI_d_SE, pHE = dyn_data[:,0], dyn_data[:,1], dyn_data[:,2], dyn_data[:,3], dyn_data[:,4], dyn_data[:,5], dyn_data[:,6], dyn_data[:,7], dyn_data[:,8], dyn_data[:,9]
#    541
#    542         1       1091.0   1091.0      0.0      dt = ts[1] - ts[0]
#    543
#    544         3      10866.0   3622.0      0.0      parameters = np.concatenate((np.array([S_0, I_0, b_I, d_S, d_I, d_IE, K_I,
#    545         1        250.0    250.0      0.0                b_H, d_H, K_H,
#    546         1        120.0    120.0      0.0                N_0, max_Na, b_myc, d_myc, myc_thresh]),
#    547         1        331.0    331.0      0.0                char_times,
#    548         1        211.0    211.0      0.0                activation_regulation, NE_regulation, EM_regulation, contraction_regulation))
#    549
#    550         2      17818.0   8909.0      0.0      sim_summary = np.array([np.amax(pI) + np.amax(pS)*(infection_model == "autoimmune"),
#    551         1      20891.0  20891.0      0.0                         np.argmax(pI)*dt,
#    552         1       8413.0   8413.0      0.0                         np.argmax(pI < I_min)*dt,
#    553         1       5549.0   5549.0      0.0                         np.amax(pI_d_I) + I[-1],
#    554         1       4467.0   4467.0      0.0                         np.amax(pI_d_SE),
#    555         1       5398.0   5398.0      0.0                         np.sum(div_E_count),
#    556         1      12539.0  12539.0      0.0                         np.argmax(pE)*dt*(np.max(pE + pM) >= max_Na) if N_0 > 0 else duration,
#    557         1      18498.0  18498.0      0.0                         (np.argmax((pE + pM) >= max_Na, axis = 0)*dt + duration*(np.amax(pE + pM) < max_Na)) if N_0 > 0 else duration,
#    558         1        310.0    310.0      0.0                         count_eM,
#    559         1        450.0    450.0      0.0                         mean_T_pEcyteM,
#    560         1      12829.0  12829.0      0.0                         (duration - (np.argmax(pE[::-1] >= N_0 , axis = 0)*dt))*(np.max(pE) >= N_0) if N_0 > 0 else 0.0,
#    561         1        421.0    421.0      0.0                         mean_frac_cM,
#    562         1       4337.0   4337.0      0.0                         np.amax(pHE),
#    563         1       4567.0   4567.0      0.0                         np.amax(pHI),
#    564         1        111.0    111.0      0.0                         selection_ratio])
#    565
#    566                                               # down-size timeseries
#    567         1        591.0    591.0      0.0      pnts = int(0.1*steps)
#    568         1      60962.0  60962.0      0.0      keep = [i*10 for i in np.arange(0,pnts)]
#    569
#    570         1        781.0    781.0      0.0      if out_data == "full":
#    571                                                   out_dict = {"reg_coeffs": np.concatenate((activation_regulation, NE_regulation, EM_regulation, contraction_regulation)),
#    572                                                               "cell_time_series": dyn_data,
#    573                                                               "time": ts,
#    574                                                               "lineage_diff": lineage_comp,
#    575                                                               "prim_diff_bias": prim_bias,
#    576                                                               "eff_by_lin": (E_m),
#    577                                                               "N_myc_by_lin": mycN_m,
#    578                                                               "Ma_myc_by_lin": mycMa_m,
#    579                                                               "E_myc_by_lin": mycE_m,
#    580                                                               "parameters": parameters,
#    581                                                               "summary_stats": sim_summary,
#    582                                                               "pmemory_formed": T_pEcytM if N_0 > 0 else []}
#    583         1        310.0    310.0      0.0      elif out_data == "small":
#    584         2      24286.0  12143.0      0.0          out_dict = {"cell_time_series": dyn_data[keep],
#    585         1      20191.0  20191.0      0.0                      "prim_diff_bias": prim_bias[keep],
#    586         1         90.0     90.0      0.0                      "parameters": parameters,
#    587         1        101.0    101.0      0.0                      "summary_stats": sim_summary}
#    588
#    589         1         90.0     90.0      0.0      return out_dict

# %%
# Run single simulation
# %timeit -n 2 -r 2
data_dict = lin_stoch_sim(N_0 = N_0,
                          I_0 = I_0,
                          b_I = b_I, 
                          K_I = K_I,
                          d_I = d_I,
                          K_H = K_H,
                          NE_regulation = NE_regulation,
                          EM_regulation = EM_regulation,
                          activation_regulation = Na_regulation,
                          contraction_regulation = Edie_regulation,
                          infection_model = infection_model,
                          reg_model = 'mwc_like',
                          out_data = "full",
                          memory_death = False)

# %%
regs = data_dict["reg_coeffs"]
dyn = data_dict["cell_time_series"]
ts = data_dict["time"]
lin_comp = data_dict["lineage_diff"]
p_diff = data_dict["prim_diff_bias"]
parameters = data_dict["parameters"]
sim_summary = data_dict["summary_stats"]
mycN = data_dict["N_myc_by_lin"]
mycMa = data_dict["Ma_myc_by_lin"]
mycE = data_dict["E_myc_by_lin"]
Eff = data_dict["eff_by_lin"]
T_pEcytM = data_dict["pmemory_formed"]

S, I, N, Na, E, M, HI, I_d_I, I_d_S, HE = dyn[:,0], dyn[:,1], dyn[:,2], dyn[:, 3], dyn[:,4], dyn[:,5], dyn[:,6], dyn[:,7], dyn[:,8], dyn[:,9]

reg_string = '-'.join(np.array(Na_regulation + NE_regulation + EM_regulation + Edie_regulation).astype('U4'))

# %%
# Plot simulated immune dynamics
fig, (ax1, ax2, ax3) = plt.subplots(3, dpi = 150, constrained_layout=True, sharex = True, figsize=(5,5))

ax1.plot(ts, S, 'k', label = r'susceptible, $S$')
ax1.plot(ts, I, 'b', label = r'infected, $I$')

ax1.plot(ts, I_d_S, 'r', linestyle = '--', label = r'susceptible killed')
ax1.plot(ts, I_d_I, 'g', linestyle = '--', label = r'infected killed')
ax1.set(ylabel='Cell count')
ax1.set_ylim(1, S_0*2)
ax1.semilogy()
ax1.minorticks_off()
ax1.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

ax2.plot(ts, Na, 'b', linewidth = 1.5, label = r'Activated, $N^*$')
ax2.plot(ts, E, 'orange', linewidth = 1.5, label = r'Effector, $E$')
ax2.plot(ts, M, 'g', linewidth = 1.5, label = r'Memory, $M$')
ax2.plot(ts, S, 'grey', linewidth = 1.5, label = r'Susceptible, $S$')
ax2.plot(ts, I, 'r', linewidth = 1.5, label = r'infected, $I$')
ax2.set(ylabel='Cell count')
ax2.semilogy()
ax2.minorticks_off()
ax2.set_ylim(1, S_0*2)
ax2.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

ax3.plot(ts, f_XtoY_mwc_like(sig_1 = I, sig_2 = HI, sig_3 = HE, 
                             psi_1 = EM_regulation[0], psi_2 = EM_regulation[1], psi_3 = EM_regulation[2], L_0 = EM_regulation[3], 
                             K_1 = K_I, K_2 = K_H, K_3 = K_H),
         'k-', label = r'Regulation, $f(I,H)$')
ax3.set(xlabel=r'Time [days]', ylabel='Regulation')
ax3.minorticks_off()
ax3.set_ylim(0,1.05)

fig.savefig("_figs/"+infection_model+'-'+'virus-effector dynamics.png', dpi=300, bbox_inches="tight")

# %%
S[0]/S[-1]
# Out:
# 1.4301259372772586

# %%
plt.plot(ts, N)
plt.ylim(0, 1.05*N_0)
np.mean(np.argmax(Eff >0 , axis = 0)*(ts[1]-ts[0])*(np.amax(Eff, axis = 0) > 0 ))
# Out:
# 2.58485

# %%
plt.plot(ts, np.log((1 + I/K_I)), 'r', label = "Ag.")
plt.plot(ts, np.log((1 + HE/K_H)), 'b--', label = "Anti-inflam.")
plt.plot(ts, np.log((1 + HI/K_H)), 'k--', label = "Pro-inflam.")
plt.legend()

# %%
plt.plot(ts,d_IE*E/(K_I + I + E), 'r')
plt.plot(ts, d_IE*E/(K_I + E), 'k--')

# %%
print(f'Memory fraction = {(sim_summary[8])/(sim_summary[5] + sim_summary[8])}')
print(f'Number of memory cells = {np.max(M)}')
print(f'1st infection harm = {sim_summary[3]/S_0}')
print(f'1st response toxicity = {sim_summary[4]/S_0}')
print(f'Minimum susceptible = {np.min(S)/S_0}')

# %%
# Plot simulated infection dynamics: pretty plots
pnts = 50
keep = [i*int(len(E)/pnts) for i in np.arange(0,pnts)]
sus = S[keep]
naive = Na[keep]
eff = E[keep]
mem = M[keep]
p_load = np.log(1 + I[keep]/K_I)/np.log(1 + np.max(I[keep])/K_I) if np.max(I[keep]) > 0 else I[keep]
inflam = np.log((1 + HI[keep]/K_H))/np.log((1 + np.max(HI[keep])/K_H))
anti_inflam = np.log((1 + HE[keep]/K_H))/np.log((1 + np.max(HE[keep])/K_H)) if np.max(HE[keep]) > 0 else HE[keep]
inf_harm = I_d_I[keep]
toxicity = I_d_S[keep]
time = ts[keep]

fig, ax = plt.subplots(figsize=(7.5,5))

ax.plot(ts, I, 'r', label = r'Infected, $I$', linewidth=2.5)
# ax.plot(ts, S, 'grey', label = r'Susceptible, $S$', linewidth=2.5)

ax.plot(ts, E + M, 'orange', zorder = 1, linewidth=2.5, label = r'T cells, $E + M$')
im = ax.scatter(time, eff+mem, marker ='o', c = p_load, cmap='coolwarm') #, norm=mpl.colors.LogNorm())

ax.plot(ts, I_d_I, 'black', zorder = 1, linewidth=2.5, label = r'Infection harm')
ax.plot(ts, I_d_S, 'green', zorder = 1, linewidth=2.5, label = r'Toxicity harm')
# ax.plot(time, mem, 'k--')
# ax.scatter(time, mem, marker ='s', c = p_load, cmap='coolwarm',
#             label = r'Mem., $M$') #, norm=mpl.colors.LogNorm())

# ax.plot(time, inf_harm, 'r', linewidth = 2.0, label = r'Harm, $\mathcal{H}_I$')

# ax.plot(time, toxicity, 'y', linewidth = 2.0,label = r'Toxicity, $\mathcal{H}_S$')

ax.set_box_aspect(1)
cb = fig.colorbar(im, ax=ax, orientation='vertical', shrink = 0.75, pad = 0.05)
cb.set_label('Ag. stimulation', fontsize = 14)
cb.ax.tick_params(labelsize=8)
ax.set_ylabel('Cell count', fontsize = 18)
ax.set_xlabel(r"Time [days]", fontsize = 18)
ax.semilogy()
ax.minorticks_off()
ax.set_ylim(1,)
# locmaj = mpl.ticker.LogLocator(numticks=4)
# ax.yaxis.set_major_locator(locmaj)

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        ax.axvline(x=time[i], linestyle='-', linewidth=6.5, color='pink', alpha=inflam[i], label =r"Harm. stim.", zorder = 0)
        ax.axvline(x=time[i], linestyle='-', linewidth=6.5, color='grey', alpha=anti_inflam[i]/2, label =r"Tox. stim.", zorder = 0)
    else:
        ax.axvline(x=time[i], linestyle='-', linewidth=6.5, color='pink', alpha=inflam[i], zorder = 0)
        ax.axvline(x=time[i], linestyle='-', linewidth=6.5, color='grey', alpha=anti_inflam[i]/2, zorder = 0)

ax.legend(loc='lower right', fontsize = 10)

plt.savefig('_figs/'+infection_model+'-timeline-of-infection-dynamics-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
# Plot simulated infection dynamics: pretty plots of harm
pnts = 50
keep = [i*int(len(E)/pnts) for i in np.arange(0,pnts)]

eff = E[keep]
p_load = I[keep]/S_0
sus = S[keep]/S_0
inf_harm = I_d_I[keep]/S_0
inflam_harm = I_d_S[keep]/S_0
inflam = np.log((1 + HI[keep]/K_H))/np.log((1 + S_0/K_H))
time = ts[keep]

plt.scatter(time, p_load, marker ='s', c =eff/K_I, cmap='coolwarm', 
            label = r'Infected cells, $I$') #, norm=mpl.colors.LogNorm())
plt.plot(time, p_load, 'k--')

# plt.scatter(time, sus, marker ='>', c =eff/K_I, cmap='coolwarm', 
#             label = r'Susceptible cells, $S$') #, norm=mpl.colors.LogNorm())
# plt.plot(time, sus, 'k--')

plt.scatter(time, inf_harm, marker ='o', c =eff/K_I, cmap='coolwarm', 
            label = 'Infected cells killed')
plt.plot(time, inf_harm, 'k--')

plt.scatter(time, inflam_harm, marker ='*', c =eff/K_I, cmap='coolwarm',
            label = 'Susceptible cells killed')
plt.plot(time, inflam_harm, 'k--')

plt.colorbar(label = "Primary effector response")
plt.ylabel('Fraction of susceptible cells', fontsize = 14)
plt.xlabel(r"Time, $t$ [days]", fontsize = 14)

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        plt.axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], label =r"Inflammation, $H$", zorder = 0)
    else:
        plt.axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        
plt.legend(loc='center right', bbox_to_anchor=(1.85, 0.8), fontsize = 10)
plt.savefig('_figs/'+infection_model+'-infection-harm-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
# Plot simulated infection dynamics: pretty plots
pnts = 150
keep = [1 + i*int(len(E)/pnts) for i in np.arange(0,pnts)]
bias_diff = p_diff[keep]
sus = S[keep]
p_load = np.log(1 + I[keep]/K_I)/np.log(1 + np.max(I[keep])/K_I) if np.max(I[keep]) > 0 else I[keep]
inflam = np.log((1 + HI[keep]/K_H))/np.log((1 + np.max(HI[keep])/K_H))
anti_inflam = np.log((1 + HE[keep]/K_H))/np.log((1 + np.max(HE[keep])/K_H)) if np.max(HE[keep]) > 0 else HE[keep]
time = ts[keep]

fig, axs = plt.subplots(2,2, figsize=(7,7))

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0, label =r"Inflammation, $H$")
        
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0, label =r"Anti-inflammation, $P$")
    else:
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0, label =r"Inflammation, $H$")
        
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0, label =r"Anti-inflammation, $P$")


im1 = axs[0,0].scatter(time, bias_diff[:,0], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$E \longrightarrow 2E$')
axs[0,0].plot(time, bias_diff[:,0],'k--')
axs[0,0].title.set_text(r'$E \longrightarrow 2E$')
axs[0,0].set_box_aspect(1)

im2 = axs[0,1].scatter(time, bias_diff[:,1], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$N^* \longrightarrow E$')
axs[0,1].plot(time, bias_diff[:,1],'k--')
axs[0,1].title.set_text(r'$N^* \longrightarrow E$')
axs[0,1].set_box_aspect(1)

im3 = axs[1,0].scatter(time, bias_diff[:,2], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$E \longrightarrow M$')
axs[1,0].plot(time, bias_diff[:,2],'k--')
axs[1,0].title.set_text(r'$E \longrightarrow M$')
axs[1,0].set_box_aspect(1)

im4 = axs[1,1].scatter(time, bias_diff[:,3], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$E \longrightarrow \emptyset$')
axs[1,1].plot(time, bias_diff[:,3],'k--')
axs[1,1].title.set_text(r'$E \longrightarrow \emptyset$')
axs[1,1].set_box_aspect(1)

axs[0,0].set_ylabel('Rate [day$^{-1}$]', fontsize = 14)
axs[1,0].set_ylabel('Rate [day$^{-1}$]', fontsize = 14)
axs[1,0].set_xlabel("Time [days]", fontsize = 14)
axs[1,1].set_xlabel("Time [days]", fontsize = 14)

fig.subplots_adjust(wspace=.3, hspace = 0.1)
cb = fig.colorbar(im1, ax=axs, shrink = 0.5, pad = 0.05, orientation='vertical')
cb.set_label('Ag. stimulation')

#cb.set_clim(-0.4,0.4)
    
# plt.colorbar(label =r"pathogen load, $I(t)$")
# plt.ylabel('transition weight', fontsize = 16)
# plt.xlabel("time (days)", fontsize = 16)
# plt.legend() #bbox_to_anchor=(1.05, 1.0), loc='upper left')

plt.savefig('_figs/'+infection_model+'-diff-bias-over-time-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %% [markdown]
# ### (2) Plot lineage-based trajectories

# %%
keys = np.array(['Memory', 'Effector'])
all_counts = lin_comp[1:3].T
effector_ranking = np.argsort(all_counts[:, 1])[::-1]
all_counts = all_counts[effector_ranking]
total_counts = all_counts.sum(axis=1)
norm_counts = all_counts / total_counts[:, None]
norm_counts[~np.isfinite(norm_counts)] = 0
comp_argsort = np.argsort(np.max(all_counts, axis=0))
bar_dict = {k: v for k, v in zip(keys[comp_argsort], norm_counts.T[comp_argsort])}
lineage_idxs = np.arange(all_counts.shape[0])

fig, ax = plt.subplots()
bottom = np.zeros(len(lineage_idxs))
cmap_colors = sns.color_palette('Set2', 10)
cmap_colors = [cmap_colors[i]
               for i in [0, 1, 5]]#[7, 2, 0, 1, 5]]
# cmap_colors = [cmap_colors[i]
#                for i in [6, 1, 2, 5, 0]]
width = 1

for i, (celltype, fraction) in enumerate(bar_dict.items()):
    ax.bar(lineage_idxs, fraction, width,
           edgecolor='k', linewidth=0.01,
           label=celltype, bottom=bottom, color=cmap_colors[i])
    bottom += fraction
    
ax.legend(loc='center right', bbox_to_anchor=(1.4, 0.5), fontsize = 12)
ax.set_xlim(-0.5, len(all_counts) - 0.5)
ax.set_xlabel('sub-clone lineages \n (ranked by effector response)', fontsize = 15)
ax.set_ylabel('fractional cell-fate \ncomposition', fontsize = 15)
#ax.set_yscale('log')

ax.set_xticks(np.arange(0, Eff.shape[1], int(Eff.shape[1]/10)))
ax.set_xticklabels(1 + np.arange(0, Eff.shape[1], int(Eff.shape[1]/10)), fontsize=9)

ax.set_yticks(np.round(np.arange(0, 1.2, 0.2), 1))
ax.set_yticklabels(ax.get_yticks(), fontsize=12)

fig.savefig("_figs/"+infection_model+'-'+'fates-by-lin-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
plt.errorbar(ts, np.mean(Eff, axis = 1), yerr = np.std(Eff, axis = 1), errorevery = 100)
plt.semilogy()

# %%
plt.plot(ts, mycN, 'r--')
plt.errorbar(ts, np.mean(mycN, axis = 1), yerr = np.std(mycN, axis = 1), errorevery = 100)
#plt.plot(ts, mycMa, 'k-')
plt.axhline(y = myc_thresh, color = 'k', linestyle = '--')
print(np.sum(np.max(mycN, axis=0) > myc_thresh)/N_0)

# %%
plt.hist(T_pEcytM, bins = 'auto', histtype='step');
plt.xlabel("Time in effector state")
plt.ylabel("Counts")

# %%
plt.hist(memory_lifespan(T_pEcytM[memory_lifespan(T_pEcytM) > t_E_die])/365.25, bins = 'auto', histtype='step');
plt.xlabel("Memory lifespan")
plt.ylabel("Counts")
print(sim_summary[9], sim_summary[11])

# %%
# Compute max values in the data
r = np.arange(6)
width = 0.5
plt.bar(r, np.amax(np.array([I, Na, E, M, HI, HE]).T, axis = 0), width = width)

plt.xlabel("response")
plt.ylabel("value")

plt.xticks(r, ["Infected","Naive","Effector","Memory", "Inflammation", "Anti-inflammation"], fontsize = 7)

plt.semilogy()
plt.suptitle(r'Peak response response: $N_0=$ '+str(N_0) +r', $d_I=$'+str(d_I))

# %%
bias_1 = f_XtoY(I, HI, 
       -2.0, -2.0, 0.0, L_0 = 4*np.log(2), 
       K_I = K_I, K_H = K_H)
bias_2 = f_XtoY(I, HI, 
       -2.0, 2.0, 0.0, L_0 = -0*np.log(2), 
       K_I = K_I, K_H = K_H)

plt.plot(ts, bias_1, 'r')
plt.plot(ts, bias_2, 'k--')
plt.plot(ts, Na/np.amax(Na))
plt.plot(ts, A/(Na + A))
plt.plot(ts, H**l_H/(K_H**l_H + H**l_H))

# %%
d="/gscratch/scrubbed/oukogu/infoimmune/sim_output/no_cell_var/raw/"
comment = "sparse-reg"
infection_model = "acute" # "cancer", "acute"
runs = 5

run(batch = [196.0], outdir=d, comment=comment, infection_model = infection_model, runs = runs, num_cpu = 136, run_time = 4.0)

# %%
d_file = '/gscratch/scrubbed/oukogu/infoimmune/sim_output/no_cell_var/raw/sim_batch_0.0-'+str(runs)+'-'+infection_model+'-'+comment+'.pkl'
with open(d_file, 'rb') as f:   
    out = pickle.load(f)
