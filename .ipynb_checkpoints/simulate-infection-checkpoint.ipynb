# %% [markdown]
# # Run infection dynamics with monoclonal killer T cell response

# %%
import numpy as np
from matplotlib.cm import get_cmap
import matplotlib.pyplot as plt
import matplotlib as mpl

import multiprocessing as mp
from tqdm import tqdm
from joblib import Parallel, delayed
from scipy import stats
import os
import seaborn as sns
from stoch_sim_model import *
from optimize_nets import *

plt.style.use('custom.mplstyle')
# %config InlineBackend.figure_format = 'retina'
# %load_ext line_profiler

# %%
avg_sim_time = 2.5/(60*60) # 1.6/(60*60)

print('full-reg:',(len(psi_2d_nobias)**4)*len(infection_sample_select),
      np.ceil((len(psi_2d_nobias)**4*len(infection_sample_select))/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('prim-Nact-Ediv:',len(psi_2d)*len(psi_2d)*len(infection_sample_select), 
      np.ceil((len(psi_2d)*len(psi_2d)*len(infection_sample_select))/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('auto-sparse-reg:',len(psi_2d_sparse)*len(auto_sample), 
      np.ceil((len(psi_2d_sparse)*len(auto_sample))/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('cancer-sparse-reg:',len(psi_2d_sparse)*len(cancer_sample), 
      np.ceil((len(psi_2d_sparse)*len(cancer_sample))/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('sparse-reg:', len(psi_2d_sparse)*len(infection_sample_select),
      np.ceil(len(psi_2d_sparse)*len(infection_sample_select)/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')
# Out:
# full-reg: 6581250 55.0 1200 jobs per cpu per hour
# prim-Nact-Ediv: 731250 7.0 1200 jobs per cpu per hour
# auto-sparse-reg: 1562500 14.0 1200 jobs per cpu per hour
# cancer-sparse-reg: 7812500 66.0 1200 jobs per cpu per hour
# sparse-reg: 40625000 339.0 1200 jobs per cpu per hour

# %% [markdown]
# ### (1) Plot population averaged trajectories

# %%
# Set simulation parameters
N_0 = 300
K_IE = (1)*(10**5)
d_I = 50*d_S # d_S #
b_I = 1.5*(10**(-7)) # 1.50*(10**(-7)) # b_C
I_0 = 1*I_0  # 0.1*S_0 # I_0

infection_model = 'acute' #'acute', 'autoimmune', 'cancer'
Na_regulation = [psi_max, psi_max, -psi_max, -0.5*F0_max]
NE_regulation = [psi_max, psi_max, -psi_max, 1.0*F0_max]
EM_regulation = [-psi_max, -psi_max, 0*psi_max, -1.0*F0_max]
EE_regulation = [psi_max, psi_max, -psi_max, 1.0*F0_max]

# %%
# %lprun -T lprof0 -f lin_stoch_sim lin_stoch_sim(N_0 = 3000, b_I = b_I, K_IE = K_IE, d_I = d_I, K_EH = K_EH, \
                                                NE_regulation = NE_regulation, \
                                                EM_regulation = EM_regulation, \
                                                activation_regulation = Na_regulation, \
                                                expansion_regulation = EE_regulation, \
                                                memory_death = False)
# Out:
# *** Profile printout saved to text file 'lprof0'.
# Timer unit: 1e-09 s
#
# Total time: 2.75467 s
# File: /mmfs1/home/oukogu/infoimmune/stoch_sim_model.py
# Function: lin_stoch_sim at line 192
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    192                                           def lin_stoch_sim(S_0 = S_0, I_0 = I_0, b_I = b_I, d_S = d_S, d_I = d_I, d_IE = d_IE, K_IE = K_IE, K_SE = K_SE,
#    193                                                             b_H = b_H, d_H = d_H, K_EH = K_EH,
#    194                                                             N_0 = N_0, max_Na = max_Na, b_myc = b_myc, d_myc = d_myc, myc_thresh = myc_thresh, max_expand = max_expand,
#    195                                                             char_times = [t_bind, t_unbind, t_Na_div, t_E_div, t_M_div, t_E_die, t_act],
#    196                                                             NE_regulation = NE_psis,
#    197                                                             EM_regulation = EM_psis,
#    198                                                             activation_regulation = act_psis,
#    199                                                             expansion_regulation = exp_psis,
#    200                                                             infection_model = "acute",
#    201                                                             duration = sim_duration,
#    202                                                             steps = sim_steps,
#    203                                                             reg_model = "mwc_like",
#    204                                                             out_data = "small",
#    205                                                             memory_death = False,
#    206                                                             seed = None):
#    207         1     150571.0 150571.0      0.0      rng = np.random.default_rng(seed)
#    208
#    209         1        281.0    281.0      0.0      if reg_model == 'mwc_like':
#    210         1        451.0    451.0      0.0          f_XtoY = f_XtoY_mwc_like
#    211                                               elif reg_model == 'competition_model':
#    212                                                   f_XtoY = f_XtoY_competition
#    213                                               else:
#    214                                                   f_XtoY = f_XtoY_ret0
#    215                                               # VARIABLE DEFINITIONS:
#    216                                               # S_0 := S_0, I_0 := I_0, b_S := b_S, b_I := b_I, d_S := d_S, d_I := d_I, d_IE := d_IE, K_IE := K_IE,
#    217                                               # b_H := b_H, d_H := d_H, K_EH := K_EH,
#    218                                               # N_0 := N_0, max_Na := max_Na, b_myc := b_myc, d_myc := d_myc, myc_thresh := myc_thresh,
#    219                                               # char_times := [t_bind, t_unbind, t_Na_div, t_E_div, t_M_div, t_EM_diff, t_E_die, t_Na],
#    220
#    221                                               #################################
#    222                                               ### SET META-VARIABLES FOR SIMULATION ###
#    223                                               #################################
#    224         1        351.0    351.0      0.0      dt =  duration/steps
#    225         1        551.0    551.0      0.0      N_0_var = int(N_0)
#    226         1        311.0    311.0      0.0      b_S = S_0*d_S
#    227
#    228                                               # draw population of reponding cells for agent-based simulations
#    229         1       1172.0   1172.0      0.0      psi_Na_I, psi_Na_H, psi_Na_P, F0_Na = activation_regulation[0], activation_regulation[1], activation_regulation[2], activation_regulation[3]
#    230         1       1182.0   1182.0      0.0      psi_NE_I, psi_NE_H, psi_NE_P, F0_NE = NE_regulation[0], NE_regulation[1], NE_regulation[2], NE_regulation[3]
#    231         1       1222.0   1222.0      0.0      psi_EM_I, psi_EM_H, psi_EM_P, F0_EM = EM_regulation[0], EM_regulation[1], EM_regulation[2], EM_regulation[3]
#    232         1        691.0    691.0      0.0      psi_EE_I, psi_EE_H, psi_EE_P, F0_EE = expansion_regulation[0], expansion_regulation[1], expansion_regulation[2], expansion_regulation[3]
#    233
#    234         1        131.0    131.0      0.0      p_tcr = 1.0 #np.ones(N_0_var)
#    235         1        130.0    130.0      0.0      p_cyt = 1.0 #np.ones(N_0_var)
#    236
#    237         1        270.0    270.0      0.0      int_steps = int(steps)
#    238
#    239                                               # define variables for storage
#    240         1       1943.0   1943.0      0.0      I = np.zeros(int_steps+1)
#    241         1       1612.0   1612.0      0.0      S = np.zeros(int_steps+1)
#    242         1       1662.0   1662.0      0.0      H = np.zeros(int_steps+1)
#    243         1       1673.0   1673.0      0.0      P = np.zeros(int_steps+1)
#    244         1       1372.0   1372.0      0.0      I_d_I = np.zeros(int_steps+1)
#    245         1       1552.0   1552.0      0.0      I_d_IE = np.zeros(int_steps+1)
#    246         1       1492.0   1492.0      0.0      S_d_SE = np.zeros(int_steps+1)
#    247
#    248         1      77258.0  77258.0      0.0      N_m = np.zeros((int_steps+1, N_0_var), dtype = np.int32)
#    249         1      14042.0  14042.0      0.0      N_m[0,:] +=1
#    250         1     490393.0 490393.0      0.0      T_Ecyt = [[] for i in np.arange(0, N_0_var)]
#    251         1     587902.0 587902.0      0.0      survive_M = [[] for i in np.arange(0, N_0_var)]
#    252                                               # T_Ecyt = np.zeros(int_steps+1, dtype = np.int32)
#    253
#    254         1       1372.0   1372.0      0.0      div_count = np.zeros(N_0_var)
#    255         1      39841.0  39841.0      0.0      div_E_count = np.log2(max_Na)*np.ones(N_0_var)
#    256         1       9374.0   9374.0      0.0      div_M_count = np.log2(max_Na)*np.ones(N_0_var)
#    257         1       1172.0   1172.0      0.0      diff_EpM_count = np.zeros(N_0_var, dtype = np.int32)
#    258         1        761.0    761.0      0.0      die_M = np.zeros(N_0_var, dtype = np.int32)
#    259
#    260         1      70748.0  70748.0      0.0      Na_m = np.zeros((int_steps+1, N_0_var), dtype = np.int32)
#    261         1      67624.0  67624.0      0.0      Ma_m = np.zeros((int_steps+1, N_0_var), dtype = np.int32)
#    262         1      62646.0  62646.0      0.0      E_m = np.zeros((int_steps+1, N_0_var), dtype = np.int32) # effector in periphary
#    263         1       2213.0   2213.0      0.0      T_E = np.zeros(N_0_var)
#    264
#    265         1        501.0    501.0      0.0      if out_data == "full":
#    266                                                   mycN_m = np.zeros((int_steps+1, N_0_var))
#    267                                                   mycMa_m = np.zeros((int_steps+1, N_0_var))
#    268                                                   mycE_m = np.zeros((int_steps+1, N_0_var))
#    269
#    270         1       3666.0   3666.0      0.0      bias_t = np.zeros((int_steps+1, 4))
#    271
#    272                                               # Define event timer variables
#    273         1       1493.0   1493.0      0.0      bound_N = np.zeros(N_0_var, dtype =np.int32)
#    274         1       1713.0   1713.0      0.0      bound_N_time = np.zeros(N_0_var)
#    275         1       5378.0   5378.0      0.0      Na_div_flag = np.ones(N_0_var, dtype =np.int32)
#    276         1       3906.0   3906.0      0.0      Na_flag = np.ones(N_0_var, dtype =np.int32)
#    277
#    278         1       1552.0   1552.0      0.0      mycN = np.zeros(N_0_var)
#    279         1       1682.0   1682.0      0.0      mycE = np.zeros(N_0_var)
#    280         1       1753.0   1753.0      0.0      mycMa = np.zeros(N_0_var)
#    281
#    282         1      17006.0  17006.0      0.0      r_NaE = np.zeros((int_steps+1, N_0_var))
#    283         1       5419.0   5419.0      0.0      r_EM = np.zeros((int_steps+1, N_0_var))
#    284         1       5529.0   5529.0      0.0      r_Na = np.zeros((int_steps+1, N_0_var))
#    285         1       5158.0   5158.0      0.0      r_EE = np.zeros((int_steps+1, N_0_var))
#    286         1       1773.0   1773.0      0.0      cum_r_NaE = np.zeros(N_0_var)
#    287
#    288         1       1262.0   1262.0      0.0      b_unbind_t = np.zeros(N_0_var)
#    289         1       1322.0   1322.0      0.0      b_N_bind = np.zeros(N_0_var)
#    290         1      11308.0  11308.0      0.0      b_Na_div = np.ones(N_0_var)/char_times[2]
#    291         1        721.0    721.0      0.0      b_myc_t = np.zeros(N_0_var)
#    292         1       7001.0   7001.0      0.0      b_E_div = np.ones(N_0_var)/char_times[3]
#    293         1       6300.0   6300.0      0.0      b_Ma_div = np.ones(N_0_var)/char_times[4]
#    294         1       5889.0   5889.0      0.0      d_E_die = np.ones(N_0_var)/char_times[5]
#    295
#    296                                               #################################
#    297                                               ### RUN POPULATION SIMULATION ###
#    298                                               #################################
#    299         1        171.0    171.0      0.0      t = 0.0
#    300         1        721.0    721.0      0.0      S[0] = S_0
#    301         1        241.0    241.0      0.0      I[0] = I_0
#    302         1        230.0    230.0      0.0      H[0] = 0.0
#    303         1        310.0    310.0      0.0      P[0] = 0.0
#    304
#    305         1        110.0    110.0      0.0      sum_e_m = 0
#    306
#    307      2501     737072.0    294.7      0.0      for i in np.arange(1, int_steps + 1):
#    308                                                   # select virulence model:
#    309      2500    1604834.0    641.9      0.1          if (b_I > 0 and I_0 <= S_0/1000) or infection_model == 'acute': # "acute"
#    310      2500     393822.0    157.5      0.0              b_I_t = b_I
#    311      2500     428563.0    171.4      0.0              d_Sauto = 0.0
#    312      2500     488057.0    195.2      0.0              infection_model = 'acute'
#    313                                                   elif (b_I > 0 and I_0 > S_0/1000) or infection_model == 'cancer': # "cancer"
#    314                                                       b_I_t = b_I/S_0
#    315                                                       d_Sauto = 0.0
#    316                                                       infection_model = 'cancer'
#    317                                                   elif b_I == 0 or infection_model == 'autoimmune': # "autoimmune"
#    318                                                       b_I_t = 0.0
#    319                                                       d_Sauto = d_I
#    320                                                       K_SE = K_IE
#    321                                                       I_0 = 0.0
#    322                                                       infection_model = 'autoimmune'
#    323                                                   else:
#    324                                                       b_I_t = b_I
#    325                                                       d_Sauto = 0
#    326
#    327                                                   # Compute total population of cell types
#    328                                                   # Use sum computed in previous iteration.
#    329      2500     423148.0    169.3      0.0          E_pop = sum_e_m
#    330
#    331                                                   #### Run infection dynamics: replication and effector clearance ####
#    332
#    333                                                   # Update state of susceptible, infected and inflammation
#    334                                                   # (a) event variables
#    335      2500    4041563.0   1616.6      0.1          S_to_I = dt * S[i - 1] * (I[i - 1] >= I_0) * b_I_t * I[i - 1] * (S[i - 1] >= 1.0)
#    336      2500    4118403.0   1647.4      0.1          I_d_IE[i] += I_d_IE[i - 1] + dt * I[i - 1] * d_IE * E_pop / (K_IE + I[i - 1] + E_pop) # infected/cancer cells killed by immune response
#    337      2500    2711989.0   1084.8      0.1          I_d_I[i] += I_d_I[i - 1] + dt * I[i - 1]*d_I*(infection_model == "acute") # cells killed by infection
#    338      2500    3725204.0   1490.1      0.1          S_d_SE[i] += S_d_SE[i - 1] + dt * S[i - 1] * (d_IE * E_pop / (K_SE + S[i - 1] + E_pop)) # susceptible cells killed by immune response
#    339
#    340                                                   # (b) state variables
#    341      7500    2959225.0    394.6      0.1          S[i] += S[i - 1] - S_to_I + dt * (
#    342      5000    5541045.0   1108.2      0.2              b_S - (d_S + (d_Sauto / t_Hauto) * np.exp(-(t / t_Hauto)**2 / 2)) * S[i - 1]
#    343      2500    1121160.0    448.5      0.0              - (S_d_SE[i] - S_d_SE[i - 1])
#    344      2500     862072.0    344.8      0.0          ) * (S[i - 1] >= 1.0)
#    345
#    346      2500    3286902.0   1314.8      0.1          I[i] += I[i - 1] + S_to_I - (I_d_IE[i] + I_d_I[i] - I_d_IE[i - 1] - I_d_I[i - 1])
#    347
#    348      2500    5393206.0   2157.3      0.2          harm_detected = (I_d_I[i] - I_d_I[i - 1]) + dt * S[i - 1] * (d_Sauto / t_Hauto) * np.exp(-(t / t_Hauto)**2 / 2) + S_to_I * (infection_model == "cancer")
#    349      2500    2055255.0    822.1      0.1          immunopathology = (S_d_SE[i] - S_d_SE[i - 1]) + (I_d_IE[i] - I_d_IE[i - 1])
#    350      2500    1904059.0    761.6      0.1          cells_sensed = I[i - 1] + (S[i - 1] * K_IE / K_SE)
#    351
#    352      2500    3520752.0   1408.3      0.1          H[i] += H[i - 1] + b_H * harm_detected - dt * d_H * H[i - 1] * (H[i - 1] >= 0.0)
#    353
#    354      2500    2992256.0   1196.9      0.1          P[i] += P[i - 1] + b_H * immunopathology - dt * d_H * P[i - 1] * (P[i - 1] >= 0.0)
#    355
#    356                                                   ## I. Recruitment/Priming
#    357
#    358                                                   # (a) Phase 1: Naive cells encounter and bind APCs
#    359      2500     502243.0    200.9      0.0          if cells_sensed >= 1:
#    360      2500  264835017.0 105934.0      9.6              bound_N += rng.binomial(N_m[i - 1], b_N_bind * dt) - rng.binomial(N_m[i - 1], b_unbind_t * dt)
#    361                                                   else:
#    362                                                       bound_N = 0
#    363
#    364      2500   32084493.0  12833.8      1.2          bound_N_time += dt * (bound_N - (1 - bound_N) * bound_N_time * N_m[i - 1]) # only reset to zero if the cell is not activated
#    365
#    366                                                   # (b) Phase 2: Activated naive cells are bound to APCs and receive stimulation.
#    367      2500   22756962.0   9102.8      0.8          act_N = (1 - bound_N) * (mycN >= myc_thresh) * (N_m[i - 1] > 0)
#    368
#    369                                                   # (c) Phase 3: Unbound activated naive cells divide and then differentiate
#    370      2500   80468065.0  32187.2      2.9          div_Na = rng.binomial(Na_m[i - 1] * Na_div_flag, dt * b_Na_div)
#    371
#    372      5000   68145965.0  13629.2      2.5          diff_NaE = rng.binomial(
#    373      2500   13829560.0   5531.8      0.5              Na_m[i - 1] * (1 - Na_div_flag),
#    374      2500   22782171.0   9112.9      0.8              1 - np.exp(-cum_r_NaE*dt) if np.sum(Na_m[i - 1]) > 0 else 0
#    375                                                   )
#    376
#    377                                                   ## II. Expansion
#    378
#    379                                                   # (a) New central memory cells divide
#    380      2500   98751245.0  39500.5      3.6          div_Ma = rng.binomial(Ma_m[i - 1] - diff_EpM_count, dt * b_Ma_div)
#    381
#    382                                                   # (b) Effector cells divide, differentiate, die
#    383      2500  197084489.0  78833.8      7.2          die_E = rng.binomial(E_m[i - 1], d_E_die * dt)
#    384      2500  165637380.0  66255.0      6.0          diff_EM = rng.binomial(E_m[i - 1] - die_E, dt * r_EM[i - 1])
#    385      2500  129277943.0  51711.2      4.7          div_E = rng.binomial(E_m[i - 1] - die_E - diff_EM, dt * b_E_div)
#    386      2500   16325459.0   6530.2      0.6          diff_EpM_count += diff_EM - die_M
#    387
#    388                                                   #### Update population dynamics: ####
#    389      2500   25261313.0  10104.5      0.9          N_m[i] += N_m[i - 1] - act_N
#    390      2500   52323685.0  20929.5      1.9          Na_m[i] += Na_m[i - 1] + div_Na + act_N - (1 - Na_div_flag) * Na_m[i - 1]
#    391
#    392      2500   55819804.0  22327.9      2.0          Ma_m[i] += Ma_m[i - 1] + div_Ma + (1 - Na_div_flag)*(Na_m[i - 1] - diff_NaE) + diff_EM - die_M
#    393      2500   46933123.0  18773.2      1.7          E_m[i] += E_m[i - 1] + div_E + (1 - Na_div_flag) * diff_NaE - (die_E + diff_EM)
#    394
#    395                                                   # Evaluate sums and create masks
#    396      2500   18395804.0   7358.3      0.7          sum_n_m = np.sum(N_m[i])
#    397      2500   14292682.0   5717.1      0.5          sum_e_m = np.sum(E_m[i])
#    398      2500    6311344.0   2524.5      0.2          e_m_nonzero_mask = E_m[i] > 0
#    399      2500    4829988.0   1932.0      0.2          n_m_nonzero_mask = N_m[i] > 0
#    400      2500    4502081.0   1800.8      0.2          na_m_nonzero_mask = Na_m[i] > 0
#    401      2500    8493132.0   3397.3      0.3          ma_m_nonzero_mask = Ma_m[i] + Ma_m[i-1]> 0
#    402      2500    3080179.0   1232.1      0.1          n_na_sum_nonzero_mask = n_m_nonzero_mask | na_m_nonzero_mask
#    403
#    404                                                   # store time cells spend in effector effector
#    405      2500    9707423.0   3883.0      0.4          T_E += dt * e_m_nonzero_mask if sum_e_m > 0 else 0.0
#    406      2500   20832083.0   8332.8      0.8          d_E_die = 0.5 * np.sqrt(np.pi) * e_m_nonzero_mask * T_E / char_times[5]**2
#    407      2500    5533430.0   2213.4      0.2          die_M = 0*die_M
#    408
#    409                                                   # store time an effector spends in cytotoxic state
#    410      2500   41699123.0  16679.6      1.5          for_where = ((1 - Na_div_flag)*(Na_m[i-1] - diff_NaE) + div_Ma + diff_EM + ma_m_nonzero_mask*memory_death > 0)
#    411      2500    9708176.0   3883.3      0.4          where_output = np.where(for_where)[0]
#    412    149773   28677806.0    191.5      1.0          for l in where_output:
#    413
#    414    147273   19106660.0    129.7      0.7              if memory_death:
#    415                                                           if Ma_m[i,l] > 0:
#    416                                                               T_Ecyt[l] = list(itertools.compress(T_Ecyt[l], survive_M[l])) + ((1 - Na_div_flag[l])*(Na_m[i-1,l] - diff_NaE[l]) + div_Ma[l]) * [0.0] + diff_EM[l] * [T_E[l].item()]
#    417                                                               arr = np.array(T_Ecyt[l])
#    418                                                               survive_M[l] = (rng.random(size = Ma_m[i,l]) > (arr > 0)*dt/memory_lifespan(arr, min_time = dt))
#    419                                                               die_M[l] = Ma_m[i,l] - np.sum(survive_M[l])
#    420                                                           else:
#    421                                                               T_Ecyt[l] += ((1 - Na_div_flag[l])*(Na_m[i-1,l] - diff_NaE[l]) + div_Ma[l]) * [0.0] + diff_EM[l] * [T_E[l].item()]
#    422                                                               arr = np.array([])
#    423                                                               survive_M[l] = []
#    424                                                               die_M[l] = 0
#    425                                                       else:
#    426    147273  437428026.0   2970.2     15.9                  T_Ecyt[l] += ((1 - Na_div_flag[l])*(Na_m[i-1,l] - diff_NaE[l]) + div_Ma[l]) * [0.0] + diff_EM[l] * [T_E[l].item()]
#    427
#    428                                                   # Update division flag to allow division to proceed
#    429      2500   14658941.0   5863.6      0.5          div_count += div_Na + div_E + div_Ma
#    430      2500    6684513.0   2673.8      0.2          div_E_count += div_E
#    431      2500    6683309.0   2673.3      0.2          div_M_count += div_Ma
#    432      2500    8020519.0   3208.2      0.3          Na_div_flag = (Na_m[i] < max_Na)*(na_m_nonzero_mask)
#    433
#    434                                                   #### New binding events ####
#    435      7500   36162630.0   4821.7      1.3          b_N_bind = (n_m_nonzero_mask) * (1 - bound_N) * f_XtoY(
#    436      2500    1875853.0    750.3      0.1              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i],
#    437      2500    4804856.0   1921.9      0.2              psi_1 = 0.0, psi_2 = psi_max, psi_3 = 0.0, F_0 = -psi_max*np.log(2), K_1 = S_0, K_2 = K_EH, K_3 = K_EH
#    438      5000    1487620.0    297.5      0.1          ) / (char_times[0] if infection_model != "autoimmune" else t_bind_eM) if cells_sensed >= 1 else 0.0
#    439
#    440      4999   14280590.0   2856.7      0.5          b_unbind_t = bound_N * np.fmin(
#    441      4998   12468520.0   2494.7      0.5              2 * bound_N_time / (
#    442     12495   12994011.0   1039.9      0.5                  f_XtoY(
#    443      2499    1571859.0    629.0      0.1                      sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i],
#    444      2499    3657309.0   1463.5      0.1                      psi_1 = psi_max, psi_2 = 0.0,psi_3 = 0.0, F_0 = -psi_max*np.log(2),
#    445      2499     945775.0    378.5      0.0                      K_1 = (K_IE*(infection_model != "autoimmune") + K_SE*(infection_model == "autoimmune")),
#    446      2499     330411.0    132.2      0.0                      K_2 = K_EH, K_3 = K_EH
#    447      7497    3353358.0    447.3      0.1                  ) * char_times[1] * 2 / np.sqrt(np.pi)
#    448      4998     971922.0    194.5      0.0              )**2, 1 / dt
#    449      2500   19930158.0   7972.1      0.7          ) if np.sum(bound_N) >= 1 else 0.0
#    450
#    451      7500   17998725.0   2399.8      0.7          b_myc_t = b_myc * f_XtoY(
#    452      2500    1433013.0    573.2      0.1              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i],
#    453      2500     481429.0    192.6      0.0              psi_1 = psi_Na_I, psi_2 = psi_Na_H, psi_3 = psi_Na_P, F_0 = F0_Na,
#    454      2500     667567.0    267.0      0.0              K_1 = (K_IE*(infection_model != "autoimmune") + K_SE*(infection_model == "autoimmune")),
#    455      2500     286987.0    114.8      0.0              K_2 = K_EH, K_3 = K_EH
#    456      2500     271228.0    108.5      0.0          ) * bound_N
#    457
#    458                                                   #### MYC Dynamics ####
#    459     15000   55678579.0   3711.9      2.0          mycN = (mycN + dt * (b_myc_t - (1 - bound_N) * f_XtoY(
#    460      2500    1371535.0    548.6      0.0              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i],
#    461      2500     603095.0    241.2      0.0              psi_1 = -psi_EE_I, psi_2 = -psi_EE_H, psi_3 = -psi_EE_P, F_0 = -F0_EE,
#    462      2500     634537.0    253.8      0.0              K_1 = (K_IE*(infection_model != "autoimmune") + K_SE*(infection_model == "autoimmune")),
#    463      2500     307411.0    123.0      0.0              K_2 = K_EH, K_3 = K_EH
#    464     10000    6114799.0    611.5      0.2          ) * mycN * d_myc * (mycN > 0))) * n_na_sum_nonzero_mask # (1 - bound_N)*
#    465
#    466     15000   38454987.0   2563.7      1.4          mycE = (mycE - dt * (f_XtoY(
#    467      2500    1378428.0    551.4      0.1              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i],
#    468      2500     582673.0    233.1      0.0              psi_1 = -psi_EE_I, psi_2 = -psi_EE_H, psi_3 = -psi_EE_P, F_0 = -F0_EE,
#    469      2500     608316.0    243.3      0.0              K_1 = (K_IE*(infection_model != "autoimmune") + K_SE*(infection_model == "autoimmune")),
#    470      7500     931889.0    124.3      0.0              K_2 = K_EH, K_3 = K_EH)*mycE*d_myc)
#    471      5000   11580321.0   2316.1      0.4          ) * (E_m[i] >= 1) + mycN * (na_m_nonzero_mask)
#    472
#    473      2500   31666603.0  12666.6      1.1          mycMa = (mycMa - dt * mycMa * d_myc) * (Ma_m[i] > 0) + mycN * na_m_nonzero_mask # higher decay rate of myc
#    474
#    475                                                   #### Time-dependent rates modulated by antigen and cytokine signals ####
#    476      2500     752589.0    301.0      0.0          b_Na_div = 1 / char_times[2]
#    477      2500   19114797.0   7645.9      0.7          b_E_div = (mycE >= myc_thresh) * (div_count < max_expand) / char_times[3]
#    478      2500   16746693.0   6698.7      0.6          b_Ma_div = (mycMa >= myc_thresh) * (div_count < max_expand) / char_times[4]
#    479
#    480                                                   #### Transition probabilities modulated by antigen and cytokine signals ####
#    481      2500   40563839.0  16225.5      1.5          r_Na[i] += b_myc_t / myc_thresh
#    482
#    483     10000   80142758.0   8014.3      2.9          r_NaE[i] += (r_NaE[i - 1] + 2 * (mycN >= myc_thresh) * dt * f_XtoY(
#    484      2500    1426541.0    570.6      0.1              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i],
#    485      2500     429739.0    171.9      0.0              psi_1 = psi_NE_I, psi_2 = psi_NE_H, psi_3 = psi_NE_P,F_0 = F0_NE,
#    486      2500     805781.0    322.3      0.0              K_1 = (K_IE*(infection_model != "autoimmune") + K_SE*(infection_model == "autoimmune")),
#    487      2500     335025.0    134.0      0.0              K_2 = K_EH, K_3 = K_EH
#    488      5000    4035974.0    807.2      0.1          ) / (2 / np.sqrt(np.pi) * (char_times[1] - char_times[6]))**2) * n_na_sum_nonzero_mask
#    489
#    490     10000   54275965.0   5427.6      2.0          r_EM[i] += (r_EM[i - 1] + 2 * dt * f_XtoY(
#    491      2500    1280817.0    512.3      0.0              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i],
#    492      2500     416372.0    166.5      0.0              psi_1 = psi_EM_I, psi_2 = psi_EM_H, psi_3 = psi_EM_P, F_0 = F0_EM,
#    493      2500     681821.0    272.7      0.0              K_1 = (K_IE*(infection_model != "autoimmune") + K_SE*(infection_model == "autoimmune")),
#    494      2500     320809.0    128.3      0.0              K_2 = K_EH, K_3 = K_EH
#    495      5000    3655265.0    731.1      0.1          ) / (2 / np.sqrt(np.pi) * (char_times[1] + char_times[6]))**2) * e_m_nonzero_mask # char_times[6] + char_times[6] to reverse priming and differentiation
#    496
#    497      2500   29400796.0  11760.3      1.1          r_EE[i] += b_E_div
#    498
#    499      2500    3842934.0   1537.2      0.1          cum_r_NaE += r_NaE[i]
#    500
#    501                                                   #### Store myc levels ####
#    502      2500     635094.0    254.0      0.0          if out_data == "full":
#    503                                                       mycN_m[i] += mycN
#    504                                                       mycMa_m[i] += mycMa
#    505                                                       mycE_m[i] += mycE
#    506
#    507                                                   #### Store differentiation biases
#    508      2500    2203825.0    881.5      0.1          to_add_to_bias = np.zeros(4)
#    509      2500    4563580.0   1825.4      0.2          if sum_n_m > 0.:
#    510      2500   52778845.0  21111.5      1.9              to_add_to_bias[0] = np.mean(r_Na[i][n_m_nonzero_mask])
#    511      2500   37350907.0  14940.4      1.4              to_add_to_bias[1] = np.mean(r_NaE[i][n_m_nonzero_mask])
#    512      2500    3592647.0   1437.1      0.1          if sum_e_m > 0.:
#    513      1943   29745376.0  15309.0      1.1              to_add_to_bias[2] = np.mean(r_EM[i][e_m_nonzero_mask])
#    514      1943   27900575.0  14359.5      1.0              to_add_to_bias[3] = np.mean(r_EE[i][e_m_nonzero_mask])
#    515      2500    3247028.0   1298.8      0.1          bias_t[i] += to_add_to_bias
#    516
#    517                                                   # Increment time
#    518      2500     728576.0    291.4      0.0          t += dt
#    519
#    520                                               # Collect population dynamics
#    521         1   15626313.0    2e+07      0.6      N, Na, Ma, E = np.sum(N_m, axis = 1), np.sum(Na_m, axis = 1), np.sum(Ma_m, axis = 1), np.sum(E_m, axis = 1)
#    522
#    523         1   15059434.0    2e+07      0.5      T_pEcytM = np.concatenate(T_Ecyt) if N_0 > 0 else np.array([0.0]) # time that memory spends in effector
#    524         1     111180.0 111180.0      0.0      count_cM = np.sum(T_pEcytM == 0
#    525         1     120565.0 120565.0      0.0                       ) if len(T_pEcytM[T_pEcytM == 0]) > 0 and N_0 > 0.0 else 0.0
#    526         1     429358.0 429358.0      0.0      count_eM = np.sum(memory_lifespan(T_pEcytM) > char_times[5]
#    527         1    1300416.0    1e+06      0.0                       ) if len(T_pEcytM[memory_lifespan(T_pEcytM) > char_times[5]]) > 0 and N_0 > 0.0 else 0.0
#    528
#    529                                               # Project out surviving primary memory
#    530         2     115377.0  57688.5      0.0      cM_duration = np.mean(memory_lifespan(T_pEcytM[T_pEcytM == 0])
#    531         2      78941.0  39470.5      0.0                           )/365.25 if len(T_pEcytM[T_pEcytM == 0]) > 0 and N_0 > 0.0 else 0.0
#    532         2    1256359.0 628179.5      0.0      eM_duration = np.mean(memory_lifespan(T_pEcytM[memory_lifespan(T_pEcytM) > char_times[5]])
#    533         2     509121.0 254560.5      0.0                           )/365.25 if len(T_pEcytM[memory_lifespan(T_pEcytM) > char_times[5]]) > 0 and N_0 > 0.0 else 0.0
#    534
#    535         1       1833.0   1833.0      0.0      zeros_n_0_var = np.zeros(N_0_var)
#    536
#    537         2      86202.0  43101.0      0.0      lineage_comp = np.vstack([
#    538         1    1234104.0    1e+06      0.0          np.amax(Na_m, axis = 0), div_M_count, div_E_count,
#    539         1       8112.0   8112.0      0.0          p_tcr + zeros_n_0_var, p_cyt + zeros_n_0_var
#    540                                               ])
#    541
#    542         1      54553.0  54553.0      0.0      dyn_data = np.array([S, I, N, Na, E, Ma, H, I_d_I + I_d_IE, S_d_SE, P]).T # add I_d_IE as a separate variable
#    543         1        250.0    250.0      0.0      prim_bias = bias_t
#    544
#    545         1      92583.0  92583.0      0.0      ts = np.linspace(0, duration, int_steps + 1)
#    546
#    547                                               # Compute summary statistics from simulations
#    548                                               ## extract primary/secondary infection dynamics
#    549         1       4146.0   4146.0      0.0      pS, pI, N, Na, pE, pM, pH, pI_d_I, pI_d_SE, pP = dyn_data[:,0], dyn_data[:,1], dyn_data[:,2], dyn_data[:, 3], dyn_data[:,4], dyn_data[:,5], dyn_data[:,6], dyn_data[:,7], dyn_data[:,8], dyn_data[:,9]
#    550
#    551         1        821.0    821.0      0.0      dt = ts[1]-ts[0]
#    552
#    553         3      19359.0   6453.0      0.0      parameters = np.concatenate((np.array([S_0, I_0, b_I, d_S, d_I, d_IE, K_IE,
#    554         1        250.0    250.0      0.0                b_H, d_H, K_EH,
#    555         1        310.0    310.0      0.0                N_0, max_Na, b_myc, d_myc, myc_thresh]),
#    556         1        220.0    220.0      0.0                char_times,
#    557         1        391.0    391.0      0.0                activation_regulation, NE_regulation, EM_regulation, expansion_regulation))
#    558
#    559         2      25749.0  12874.5      0.0      sim_summary = np.array([np.sum(pI*dt) + np.sum(pS*dt)*(infection_model == "autoimmune"),
#    560         1      22534.0  22534.0      0.0                         np.argmax(pI)*dt,
#    561         1       8673.0   8673.0      0.0                         np.argmax(pI < I_0)*dt,
#    562         1      10416.0  10416.0      0.0                         np.amax(pI_d_I) + I[-1],
#    563         1       4827.0   4827.0      0.0                         np.amax(pI_d_SE),
#    564         1       5409.0   5409.0      0.0                         np.sum(div_E_count),
#    565         1      12269.0  12269.0      0.0                         np.argmax(pE)*dt + sim_duration*(np.max(pE) < 1.0),
#    566         1      14162.0  14162.0      0.0                         (np.argmax(pE >= N_0 , axis = 0)*dt + sim_duration*(np.max(pE) < N_0)) if N_0 > 0 else sim_duration,
#    567         1        150.0    150.0      0.0                         count_eM,
#    568         1        310.0    310.0      0.0                         eM_duration,
#    569         1        511.0    511.0      0.0                         count_cM,
#    570         1        100.0    100.0      0.0                         cM_duration,
#    571         1       7471.0   7471.0      0.0                         np.sum(pP*dt),
#    572         1       6830.0   6830.0      0.0                         np.sum(pH*dt),
#    573         1      10757.0  10757.0      0.0                         np.amin(pS)])
#    574
#    575                                               # down-size timeseries
#    576         1       2203.0   2203.0      0.0      pnts = int(0.1*steps)
#    577         1      50778.0  50778.0      0.0      keep = [i*10 for i in np.arange(0,pnts)]
#    578
#    579         1        821.0    821.0      0.0      if out_data == "full":
#    580                                                   out_dict = {"reg_coeffs": np.concatenate((activation_regulation, NE_regulation, EM_regulation, expansion_regulation)), "cell_time_series": dyn_data, "time": ts, "lineage_diff": lineage_comp, "prim_diff_bias": prim_bias, "eff_by_lin": (E_m), "N_myc_by_lin": mycN_m, "Ma_myc_by_lin": mycMa_m, "E_myc_by_lin": mycE_m, "parameters": parameters, "summary_stats": sim_summary, "pmemory_formed": T_pEcytM if N_0 > 0 else []}
#    581         1        190.0    190.0      0.0      elif out_data == "small":
#    582         1      57228.0  57228.0      0.0          out_dict = {"cell_time_series": dyn_data[keep], "prim_diff_bias": prim_bias[keep],"parameters": parameters, "summary_stats": sim_summary}
#    583
#    584         1        150.0    150.0      0.0      return out_dict

# %%
# Run single simulation
# %timeit -n 2 -r 2
data_dict = lin_stoch_sim(N_0 = N_0,
                          I_0 = I_0,
                          b_I = b_I, 
                          K_IE = K_IE,
                          d_I = d_I,
                          K_EH = K_EH,
                          NE_regulation = NE_regulation,
                          EM_regulation = EM_regulation,
                          activation_regulation = Na_regulation,
                          expansion_regulation = EE_regulation,
                          infection_model = infection_model,
                          reg_model = 'mwc_like',
                          out_data = "full",
                          memory_death = False)

# %%
regs = data_dict["reg_coeffs"]
dyn = data_dict["cell_time_series"]
ts = data_dict["time"]
lin_comp = data_dict["lineage_diff"]
p_diff = data_dict["prim_diff_bias"]
parameters = data_dict["parameters"]
sim_summary = data_dict["summary_stats"]
mycN = data_dict["N_myc_by_lin"]
mycMa = data_dict["Ma_myc_by_lin"]
mycE = data_dict["E_myc_by_lin"]
Eff = data_dict["eff_by_lin"]
T_pEcytM = data_dict["pmemory_formed"]

S, I, N, Na, E, M, H, I_d_I, I_d_S, P = dyn[:,0], dyn[:,1], dyn[:,2], dyn[:, 3], dyn[:,4], dyn[:,5], dyn[:,6], dyn[:,7], dyn[:,8], dyn[:,9]

reg_string = '-'.join(np.array(Na_regulation + NE_regulation + EM_regulation + EE_regulation).astype('U4'))

# %%
# Plot simulated immune dynamics
fig, (ax1, ax2, ax3) = plt.subplots(3, dpi = 150, constrained_layout=True, sharex = False, figsize=(5,5))

ax1.plot(ts, S, 'k', label = r'susceptible, $S$')
ax1.plot(ts, I, 'b', label = r'infected, $I$')

ax1.plot(ts, I_d_S, 'r', linestyle = '--', label = r'susceptible killed')
ax1.plot(ts, I_d_I, 'g', linestyle = '--', label = r'infected killed')
ax1.set(ylabel='Cell count')
ax1.set_ylim(1, S_0*2)
ax1.semilogy()
ax1.minorticks_off()
ax1.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

ax2.plot(ts, Na, 'b', label = r'Activated, $N^*$')
ax2.plot(ts, E, 'orange', label = r'Effector, $E$')
ax2.plot(ts, M, 'g', label = r'Memory, $M$')
ax2.plot(ts, S, 'grey', label = r'Susceptible, $S$')
ax2.plot(ts, I, 'r', label = r'infected, $I$')
ax2.set(ylabel='Cell count')
ax2.semilogy()
ax2.minorticks_off()
ax2.set_ylim(1, S_0*2)
ax2.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

ax3.plot(ts, f_XtoY_mwc_like(sig_1 = I, sig_2 = H, sig_3 = P, 
                             psi_1 = EM_regulation[0], psi_2 = EM_regulation[1], psi_3 = EM_regulation[2], F_0 = EM_regulation[3], 
                             K_1 = K_IE, K_2 = K_EH, K_3 = K_EH),
         'k-', label = r'Regulation, $f(I,H)$')
ax3.set(xlabel=r'Time (days)', ylabel='Regulation')
ax3.minorticks_off()
ax3.set_ylim(0,1.05)

fig.savefig("_figs/"+infection_model+'-'+'virus-effector dynamics-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
plt.plot(ts, N)
plt.ylim(0, 1.05*N_0)
np.mean(np.argmax(Eff >0 , axis = 0)*(ts[1]-ts[0])*(np.amax(Eff, axis = 0) > 0 ))
# Out:
# 6.684959999999999

# %%
plt.plot(ts, np.log((1 + I/K_IE)), 'r', label = "Ag.")
plt.plot(ts, np.log((1 + P/K_EH)), 'b--', label = "Anti-inflam.")
plt.plot(ts, np.log((1 + H/K_EH)), 'k--', label = "Pro-inflam.")
plt.legend()

# %%
plt.plot(ts,d_IE*E/(K_IE + I + E), 'r')
plt.plot(ts, d_IE*E/(K_IE + E), 'k--')

# %%
print(f'Memory fraction = {(sim_summary[8]+sim_summary[10])/sim_summary[5]}')
print(f'Number of memory cells = {np.max(M)}')
print(f'1st infection harm = {sim_summary[3]/(d_S*S_0)}')
print(f'1st response toxicity = {sim_summary[4]/(d_S*S_0)}')
print(f'Minimum susceptible = {np.min(S)/S_0}')
# Out:
# Memory fraction = 0.02669609046179652
# Number of memory cells = 28820.0
# 1st infection harm = 36.58734578421554
# 1st response toxicity = 19.039946954876864
# Minimum susceptible = 0.6411628965726318

# %%
# Plot simulated infection dynamics: pretty plots
pnts = 50
keep = [i*int(len(E)/pnts) for i in np.arange(0,pnts)]
sus = S[keep]
naive = Na[keep]
eff = E[keep]
mem = M[keep]
p_load = np.log(1 + I[keep]/K_IE)/np.log(1 + np.max(I[keep])/K_IE) if np.max(I[keep]) > 0 else I[keep]
inflam = np.log((1 + H[keep]/K_EH))/np.log((1 + np.max(H[keep])/K_EH))
anti_inflam = np.log((1 + P[keep]/K_EH))/np.log((1 + np.max(P[keep])/K_EH)) if np.max(P[keep]) > 0 else P[keep]
inf_harm = I_d_I[keep]
toxicity = I_d_S[keep]
time = ts[keep]

fig, ax = plt.subplots(figsize=(7.5,5))

ax.plot(ts, I, 'r', label = r'Infected, $I$', linewidth=2.5)
# ax.plot(ts, S, 'grey', label = r'Susceptible, $S$', linewidth=2.5)

ax.plot(ts, E + M, 'orange', zorder = 1, linewidth=2.5, label = r'T cells, $E + M$')
im = ax.scatter(time, eff+mem, marker ='o', c = p_load, cmap='coolwarm') #, norm=mpl.colors.LogNorm())

ax.plot(ts, I_d_I, 'black', zorder = 1, linewidth=2.5, label = r'Infection harm')
ax.plot(ts, I_d_S, 'green', zorder = 1, linewidth=2.5, label = r'Toxicity harm')
# ax.plot(time, mem, 'k--')
# ax.scatter(time, mem, marker ='s', c = p_load, cmap='coolwarm',
#             label = r'Mem., $M$') #, norm=mpl.colors.LogNorm())

# ax.plot(time, inf_harm, 'r', linewidth = 2.0, label = r'Harm, $\mathcal{H}_I$')

# ax.plot(time, toxicity, 'y', linewidth = 2.0,label = r'Toxicity, $\mathcal{H}_S$')

ax.set_box_aspect(1)
cb = fig.colorbar(im, ax=ax, orientation='vertical', shrink = 0.75, pad = 0.05)
cb.set_label('Ag. stimulation', fontsize = 14)
cb.ax.tick_params(labelsize=8)
ax.set_ylabel('Cell count', fontsize = 18)
ax.set_xlabel(r"Time (days)", fontsize = 18)
ax.semilogy()
ax.minorticks_off()
ax.set_ylim(1,)
# locmaj = mpl.ticker.LogLocator(numticks=4)
# ax.yaxis.set_major_locator(locmaj)

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        ax.axvline(x=time[i], linestyle='-', linewidth=6.5, color='pink', alpha=inflam[i], label =r"Harm. stim.", zorder = 0)
        ax.axvline(x=time[i], linestyle='-', linewidth=6.5, color='grey', alpha=anti_inflam[i]/2, label =r"Tox. stim.", zorder = 0)
    else:
        ax.axvline(x=time[i], linestyle='-', linewidth=6.5, color='pink', alpha=inflam[i], zorder = 0)
        ax.axvline(x=time[i], linestyle='-', linewidth=6.5, color='grey', alpha=anti_inflam[i]/2, zorder = 0)

ax.legend(loc='lower right', fontsize = 10)

plt.savefig('_figs/'+infection_model+'-timeline-of-infection-dynamics-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
# Plot simulated infection dynamics: pretty plots of harm
pnts = 50
keep = [i*int(len(E)/pnts) for i in np.arange(0,pnts)]

eff = E[keep]
p_load = I[keep]/S_0
sus = S[keep]/S_0
inf_harm = I_d_I[keep]/S_0
inflam_harm = I_d_S[keep]/S_0
inflam = np.log((1 + H[keep]/K_EH))/np.log((1 + S_0/K_EH))
time = ts[keep]

plt.scatter(time, p_load, marker ='s', c =eff/K_IE, cmap='coolwarm', 
            label = r'Infected cells, $I$') #, norm=mpl.colors.LogNorm())
plt.plot(time, p_load, 'k--')

# plt.scatter(time, sus, marker ='>', c =eff/K_IE, cmap='coolwarm', 
#             label = r'Susceptible cells, $S$') #, norm=mpl.colors.LogNorm())
# plt.plot(time, sus, 'k--')

plt.scatter(time, inf_harm, marker ='o', c =eff/K_IE, cmap='coolwarm', 
            label = 'Infected cells killed')
plt.plot(time, inf_harm, 'k--')

plt.scatter(time, inflam_harm, marker ='*', c =eff/K_IE, cmap='coolwarm',
            label = 'Susceptible cells killed')
plt.plot(time, inflam_harm, 'k--')

plt.colorbar(label = "Primary effector response")
plt.ylabel('Fraction of susceptible cells', fontsize = 14)
plt.xlabel(r"Time, $t$ (days)", fontsize = 14)

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        plt.axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], label =r"Inflammation, $H$", zorder = 0)
    else:
        plt.axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        
plt.legend(loc='center right', bbox_to_anchor=(1.85, 0.8), fontsize = 10)
plt.savefig('_figs/'+infection_model+'-infection-harm-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
# Plot simulated infection dynamics: pretty plots
pnts = 150
keep = [1 + i*int(len(E)/pnts) for i in np.arange(0,pnts)]
bias_diff = p_diff[keep]
sus = S[keep]
p_load = np.log(1 + I[keep]/K_IE)/np.log(1 + np.max(I[keep])/K_IE) if np.max(I[keep]) > 0 else I[keep]
inflam = np.log((1 + H[keep]/K_EH))/np.log((1 + np.max(H[keep])/K_EH))
anti_inflam = np.log((1 + P[keep]/K_EH))/np.log((1 + np.max(P[keep])/K_EH)) if np.max(P[keep]) > 0 else P[keep]
time = ts[keep]

fig, axs = plt.subplots(2,2, figsize=(7,7))

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0, label =r"Inflammation, $H$")
        
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0, label =r"Anti-inflammation, $P$")
    else:
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0, label =r"Inflammation, $H$")
        
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0, label =r"Anti-inflammation, $P$")


im1 = axs[0,0].scatter(time, bias_diff[:,0], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$N \longrightarrow N^*$')
axs[0,0].plot(time, bias_diff[:,0],'k--')
axs[0,0].title.set_text(r'$N \longrightarrow N^*$')
axs[0,0].set_box_aspect(1)

im2 = axs[0,1].scatter(time, bias_diff[:,1], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$N^* \longrightarrow E$')
axs[0,1].plot(time, bias_diff[:,1],'k--')
axs[0,1].title.set_text(r'$N^* \longrightarrow E$')
axs[0,1].set_box_aspect(1)

im3 = axs[1,0].scatter(time, bias_diff[:,2], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$E \longrightarrow M$')
axs[1,0].plot(time, bias_diff[:,2],'k--')
axs[1,0].title.set_text(r'$E \longrightarrow M$')
axs[1,0].set_box_aspect(1)

im4 = axs[1,1].scatter(time, bias_diff[:,3], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$E \longrightarrow M$')
axs[1,1].plot(time, bias_diff[:,3],'k--')
axs[1,1].title.set_text(r'$E \longrightarrow E + E$')
axs[1,1].set_box_aspect(1)

axs[0,0].set_ylabel('Rate [day$^{-1}$]', fontsize = 14)
axs[1,0].set_ylabel('Rate [day$^{-1}$]', fontsize = 14)
axs[1,0].set_xlabel("Time (days)", fontsize = 14)
axs[1,1].set_xlabel("Time (days)", fontsize = 14)

fig.subplots_adjust(wspace=.3, hspace = 0.1)
cb = fig.colorbar(im1, ax=axs, shrink = 0.5, pad = 0.05, orientation='vertical')
cb.set_label('Ag. stimulation')

#cb.set_clim(-0.4,0.4)
    
# plt.colorbar(label =r"pathogen load, $I(t)$")
# plt.ylabel('transition weight', fontsize = 16)
# plt.xlabel("time (days)", fontsize = 16)
# plt.legend() #bbox_to_anchor=(1.05, 1.0), loc='upper left')

plt.savefig('_figs/'+infection_model+'-diff-bias-over-time-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %% [markdown]
# ### (2) Plot lineage-based trajectories

# %%
keys = np.array(['Memory', 'Effector'])
all_counts = lin_comp[1:3].T
effector_ranking = np.argsort(all_counts[:, 1])[::-1]
all_counts = all_counts[effector_ranking]
total_counts = all_counts.sum(axis=1)
norm_counts = all_counts / total_counts[:, None]
norm_counts[~np.isfinite(norm_counts)] = 0
comp_argsort = np.argsort(np.max(all_counts, axis=0))
bar_dict = {k: v for k, v in zip(keys[comp_argsort], norm_counts.T[comp_argsort])}
lineage_idxs = np.arange(all_counts.shape[0])

fig, ax = plt.subplots()
bottom = np.zeros(len(lineage_idxs))
cmap_colors = sns.color_palette('Set2', 10)
cmap_colors = [cmap_colors[i]
               for i in [0, 1, 5]]#[7, 2, 0, 1, 5]]
# cmap_colors = [cmap_colors[i]
#                for i in [6, 1, 2, 5, 0]]
width = 1

for i, (celltype, fraction) in enumerate(bar_dict.items()):
    ax.bar(lineage_idxs, fraction, width,
           edgecolor='k', linewidth=0.01,
           label=celltype, bottom=bottom, color=cmap_colors[i])
    bottom += fraction
    
ax.legend(loc='center right', bbox_to_anchor=(1.4, 0.5), fontsize = 12)
ax.set_xlim(-0.5, len(all_counts) - 0.5)
ax.set_xlabel('sub-clone lineages \n (ranked by effector response)', fontsize = 15)
ax.set_ylabel('fractional cell-fate \ncomposition', fontsize = 15)
#ax.set_yscale('log')

ax.set_xticks(np.arange(0, Eff.shape[1], int(Eff.shape[1]/10)))
ax.set_xticklabels(1 + np.arange(0, Eff.shape[1], int(Eff.shape[1]/10)), fontsize=9)

ax.set_yticks(np.round(np.arange(0, 1.2, 0.2), 1))
ax.set_yticklabels(ax.get_yticks(), fontsize=12)

fig.savefig("_figs/"+infection_model+'-'+'fates-by-lin-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
plt.errorbar(ts, np.mean(Eff, axis = 1), yerr = np.std(Eff, axis = 1), errorevery = 100)
plt.semilogy()
# Out:
# []

# %%
plt.plot(ts, mycE, 'r--')
plt.errorbar(ts, np.mean(mycE, axis = 1), yerr = np.std(mycE, axis = 1), errorevery = 100)
#plt.plot(ts, mycMa, 'k-')
plt.axhline(y = myc_thresh, color = 'k', linestyle = '--')
print(np.sum(np.max(mycE, axis=0) > myc_thresh)/N_0)
# Out:
# 0.9266666666666666

# %%
plt.hist(T_pEcytM, bins = 'auto', histtype='step');
plt.xlabel("Time in effector state")
plt.ylabel("Counts")
# Out:
# Text(0, 0.5, 'Counts')

# %%
plt.hist(memory_lifespan(T_pEcytM[memory_lifespan(T_pEcytM) > t_E_die])/365.25, bins = 'auto', histtype='step');
plt.xlabel("Memory lifespan")
plt.ylabel("Counts")
print(sim_summary[9], sim_summary[11])
# Out:
# 0.3165064905908365 5.0

# %%
# Compute max values in the data
r = np.arange(5)
width = 0.5
plt.bar(r, np.amax(np.array([I, Na, E, M, H]).T, axis = 0), width = width)

plt.xlabel("response")
plt.ylabel("value")

plt.xticks(r, ["Infected","Naive","Effector","Memory", "Inflammation"], fontsize = 7)

plt.semilogy()
plt.suptitle(r'Peak response response: $N_0=$ '+str(N_0) +r', $d_I=$'+str(d_I))
# Out:
# Text(0.5, 0.98, 'Peak response response: $N_0=$ 300, $d_I=$0.5')

# %%
bias_1 = f_XtoY(I, H, 
       -2.0, -2.0, 0.0, F_0 = 4*np.log(2), 
       K_I = K_IE, K_H = K_EH)
bias_2 = f_XtoY(I, H, 
       -2.0, 2.0, 0.0, F_0 = -0*np.log(2), 
       K_I = K_IE, K_H = K_EH)

plt.plot(ts, bias_1, 'r')
plt.plot(ts, bias_2, 'k--')
plt.plot(ts, Na/np.amax(Na))
plt.plot(ts, A/(Na + A))
plt.plot(ts, H**l_H/(K_EH**l_H + H**l_H))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 bias_1 = f_XtoY(I, H,
#       2        -2.0, -2.0, 0.0, F_0 = 4*np.log(2),
#       3        K_I = K_IE, K_H = K_EH)
#       4 bias_2 = f_XtoY(I, H,
#       5        -2.0, 2.0, 0.0, F_0 = -0*np.log(2),
#       6        K_I = K_IE, K_H = K_EH)
#       8 plt.plot(ts, bias_1, 'r')
#
# NameError: name 'f_XtoY' is not defined

# %%
d="/gscratch/scrubbed/oukogu/infoimmune/sim_output/no_cell_var/raw/"
comment = "sparse-reg"
infection_model = "acute" # "cancer", "acute"
runs = 5

run(batch = [196.0], outdir=d, comment=comment, infection_model = infection_model, runs = runs, num_cpu = 136, run_time = 4.0)

# %%
d_file = '/gscratch/scrubbed/oukogu/infoimmune/sim_output/no_cell_var/raw/sim_batch_0.0-'+str(runs)+'-'+infection_model+'-'+comment+'.pkl'
with open(d_file, 'rb') as f:   
    out = pickle.load(f)
