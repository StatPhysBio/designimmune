# %% [markdown]
# # Run infection dynamics with monoclonal killer T cell response

# %%
import numpy as np
from matplotlib.cm import get_cmap
import matplotlib.pyplot as plt
import matplotlib as mpl

import multiprocessing as mp
from tqdm import tqdm
from joblib import Parallel, delayed
from scipy import stats
import os
from stoch_sim_model import *
from optimize_nets import *
import seaborn as sns

plt.style.use('custom.mplstyle')
# %config InlineBackend.figure_format = 'retina'
# %load_ext line_profiler

# %%
num_pnts = 4
vir_prop = np.array(np.meshgrid(d_S*np.linspace(10, 100, num_pnts), # vary d_I
                                   K_IE*np.logspace(0.0, 2, num_pnts), # vary K_IE
                                   b_I*np.linspace(0.75, 2.0, num_pnts) # vary b_I
                                           )).T.reshape(-1,3)

vir_prop_select = vir_prop[vir_prop[:,2]*S_0 > vir_prop[:,0]]
print(len(vir_prop), len(vir_prop_select))
# Out:
# 64 60

# %%
avg_sim_time = 1.80/(60*60)

print('full-reg:',(len(psi_2d_nobias)**4)*len(vir_prop_select),
      np.ceil((len(psi_2d_nobias)**4*len(vir_prop_select))/(num_cpu*run_time/avg_sim_time)), int(num_cpu*run_time/avg_sim_time))

print('prim-Nact-Ediv:',len(psi_2d)*len(psi_2d)*len(vir_prop_select), 
      np.ceil((len(psi_2d)*len(psi_2d)*len(vir_prop_select))/(num_cpu*run_time/avg_sim_time)), int(num_cpu*run_time/avg_sim_time))

print('prim-Nact-Ediv-EM:',len(psi_2d)**3*len(vir_prop_select), 
      np.ceil((len(psi_2d)**3*len(vir_prop_select))/(num_cpu*run_time/avg_sim_time)), int(num_cpu*run_time/avg_sim_time))

print('comp_model-Nact-Ediv:',len(psi_2d_comp)*len(psi_2d_comp)*len(vir_prop_select), 
      np.ceil((len(psi_2d_comp)*len(psi_2d_comp)*len(vir_prop_select))/(num_cpu*run_time/avg_sim_time)), int(num_cpu*run_time/avg_sim_time))

print('auto-Nact-Ediv:',len(psi_2d)*len(psi_2d)*2, 
      np.ceil((len(psi_2d)*len(psi_2d)*2)/(num_cpu*run_time/avg_sim_time)), int(num_cpu*run_time/avg_sim_time))
# Out:
# full-reg: 473428860 1480.0 320000
# prim-Nact-Ediv: 4213500 14.0 320000
# prim-Nact-Ediv-EM: 1116577500 3490.0 320000
# comp_model-Nact-Ediv: 937500 3.0 320000
# auto-Nact-Ediv: 140450 1.0 320000

# %% [markdown]
# ### (1) Plot population averaged trajectories

# %%
# Set simulation parameters
N_0 = 200
K_IE = (1)*(10**4)
d_I = 10*d_S
b_I = 2.0*(10**(-7))

infection_type = "prim" #"prim", "sec"
vir_model = 'indep_harm' #'indep_harm
mem_reg = psi_max*np.array([-0.0*psi_max/2, -0.0*psi_max/2, -0.0*psi_max/1, -0.0*psi_max/2, -0.0*psi_max/2, -0.0*psi_max/2, -1.0*psi_max/2, -0.0*psi_max/2]) # np.array([-0.5, -0.5, -0.0, -0.5, -0.5, -0.0])

# %%
# %lprun -T lprof0 -f lin_stoch_sim lin_stoch_sim(N_0 = 200, b_I = b_I, K_IE = K_IE, d_I = d_I, K_IH = K_IH, NM_regulation = mem_reg[0:4], EM_regulation = mem_reg[4:], activation_regulation = [psi_max/2, psi_max/2, 0, 0], expansion_regulation = [psi_max/2, psi_max/2, 0, 0])
# Out:
# *** Profile printout saved to text file 'lprof0'.
# Timer unit: 1e-09 s
#
# Total time: 1.21663 s
# File: /mmfs1/home/oukogu/infoimmune/stoch_sim_model.py
# Function: lin_stoch_sim at line 109
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    109                                           def lin_stoch_sim(S_0 = S_0, I_0 = I_0, b_I = b_I, d_S = d_S, d_I = d_I, d_IE = d_IE, d_IH = d_IH, K_IE = K_IE, K_IH = K_IH, K_SE = K_SE,
#    110                                                               b_H = b_H, d_H = d_H, K_EI = K_EI, K_EH = K_EH, kappa = kappa,
#    111                                                               N_0 = N_0, max_Na = max_Na, b_myc = b_myc, d_myc = d_myc, myc_thresh = myc_thresh, max_expand = max_expand,
#    112                                                               char_times = [t_bind, t_unbind, t_Na_div, t_E_div, t_M_div, t_E_die, t_act],
#    113                                                               NM_regulation = NM_psis,
#    114                                                               EM_regulation = EM_psis,
#    115                                                               activation_regulation = act_psis,
#    116                                                               expansion_regulation = exp_psis,
#    117                                                               alpha = alpha,
#    118                                                               infection = "prim",
#    119                                                               vir_model = "indep_harm",
#    120                                                               duration = sim_duration,
#    121                                                               steps = sim_steps,
#    122                                                               reg_model = "mwc_like",
#    123                                                               out_data = "small"):
#    124
#    125                                               # VARIABLE DEFINITIONS:
#    126                                               # S_0 := S_0, I_0 := I_0, b_S := b_S, b_I := b_I, d_S := d_S, d_I := d_I, d_IE := d_IE, d_IH := d_IH, K_IE := K_IE, K_IH := K_IH,
#    127                                               # b_H := b_H, d_H := d_H, K_EI := K_EI, K_EH := K_EH,
#    128                                               # N_0 := N_0, max_Na := max_Na, b_myc := b_myc, d_myc := d_myc, myc_thresh := myc_thresh,
#    129                                               # char_times := [t_bind, t_unbind, t_Na_div, t_E_div, t_M_div, t_EM_diff, t_E_die, t_Nact],
#    130
#    131                                               #################################
#    132                                               ### SET META-VARIABLES FOR SIMULATION ###
#    133                                               #################################
#    134         1       1102.0   1102.0      0.0      dt =  duration/steps
#    135         1        842.0    842.0      0.0      N_0_var = int(N_0)
#    136         1        731.0    731.0      0.0      b_S = S_0*d_S
#    137
#    138                                               # draw population of reponding cells for agent-based simulations
#    139         1        961.0    961.0      0.0      psi_Nact_I, psi_Nact_H, psi_Nact_IH, F0_Nact = activation_regulation[0], activation_regulation[1], activation_regulation[2], activation_regulation[3]
#    140         1       2744.0   2744.0      0.0      psi_NM_I, psi_NM_H, psi_NM_IH, F0_NM = NM_regulation[0], NM_regulation[1], NM_regulation[2], NM_regulation[3]
#    141         1        370.0    370.0      0.0      psi_EM_I, psi_EM_H, psi_EM_IH, F0_EM = EM_regulation[0], EM_regulation[1], EM_regulation[2], EM_regulation[3]
#    142         1        410.0    410.0      0.0      psi_Ediv_I, psi_Ediv_H, psi_Ediv_IH, F0_Ediv = expansion_regulation[0], expansion_regulation[1], expansion_regulation[2], expansion_regulation[3]
#    143
#    144         1        230.0    230.0      0.0      p_tcr = 1.0 #np.ones(N_0_var)
#    145         1        110.0    110.0      0.0      p_cyt = 1.0 #np.ones(N_0_var)
#    146
#    147                                               # define variables for storage
#    148         1       7582.0   7582.0      0.0      I = np.zeros(int(steps)+1)
#    149         1       1272.0   1272.0      0.0      S = np.zeros(int(steps)+1)
#    150         1      10045.0  10045.0      0.0      V = np.zeros(int(steps)+1)
#    151         1       9174.0   9174.0      0.0      H = np.zeros(int(steps)+1)
#    152         1      13130.0  13130.0      0.0      I_d_I = np.zeros(int(steps)+1)
#    153         1       6260.0   6260.0      0.0      I_d_IE = np.zeros(int(steps)+1)
#    154         1       5238.0   5238.0      0.0      I_d_S = np.zeros(int(steps)+1)
#    155
#    156         1     535325.0 535325.0      0.0      N_m = np.zeros((int(steps)+1, N_0_var), dtype = np.int32)
#    157         1      30386.0  30386.0      0.0      N_m[0,:] +=1
#    158         1      35132.0  35132.0      0.0      T_Ecyt = [[] for i in np.arange(0, N_0_var)]
#    159
#    160         1        821.0    821.0      0.0      div_E_count = np.zeros(N_0_var)
#    161         1       3535.0   3535.0      0.0      diff_EpM_count = np.zeros(N_0_var, dtype = np.int32)
#    162
#    163         1     160912.0 160912.0      0.0      Na_m = np.zeros((int(steps)+1, N_0_var), dtype = np.int32)
#    164         1      18888.0  18888.0      0.0      Ma_m = np.zeros((int(steps)+1, N_0_var), dtype = np.int32)
#    165         1     402395.0 402395.0      0.0      E_m = np.zeros((int(steps)+1, N_0_var), dtype = np.int32) # effector in periphary
#    166         1       2884.0   2884.0      0.0      T_E = np.zeros(N_0_var)
#    167
#    168         1        691.0    691.0      0.0      if out_data == "full":
#    169                                                   mycN_m = np.zeros((int(steps)+1, N_0_var))
#    170                                                   mycMa_m = np.zeros((int(steps)+1, N_0_var))
#    171                                                   mycE_m = np.zeros((int(steps)+1, N_0_var))
#    172
#    173         1      22544.0  22544.0      0.0      bias_t = np.zeros((int(steps)+1, 4))
#    174
#    175                                               # Define event timer variables
#    176         1        941.0    941.0      0.0      bound_N = np.zeros(N_0_var, dtype =np.int32)
#    177         1      17687.0  17687.0      0.0      Na_div_flag = np.ones(N_0_var, dtype =np.int32)
#    178         1       3735.0   3735.0      0.0      Na_flag = np.ones(N_0_var, dtype =np.int32)
#    179
#    180         1       2644.0   2644.0      0.0      mycN = np.zeros(N_0_var)
#    181         1        451.0    451.0      0.0      mycE = np.zeros(N_0_var)
#    182         1        651.0    651.0      0.0      mycMa = np.zeros(N_0_var)
#    183
#    184         1     698460.0 698460.0      0.1      r_NaM = np.zeros((int(steps)+1, N_0_var))
#    185         1      52609.0  52609.0      0.0      r_EM = np.zeros((int(steps)+1, N_0_var))
#    186         1      50856.0  50856.0      0.0      r_Nact = np.zeros((int(steps)+1, N_0_var))
#    187         1      56936.0  56936.0      0.0      r_Ediv = np.zeros((int(steps)+1, N_0_var))
#    188
#    189         1       1923.0   1923.0      0.0      b_unbind_t = np.zeros(N_0_var)
#    190         1       2745.0   2745.0      0.0      b_N_bind = np.zeros(N_0_var)
#    191         1      13871.0  13871.0      0.0      b_Na_div = np.ones(N_0_var)/char_times[2]
#    192         1        581.0    581.0      0.0      b_myc_t = np.zeros(N_0_var)
#    193         1       8884.0   8884.0      0.0      b_E_div = np.ones(N_0_var)*(alpha*p_tcr + (1-alpha)*p_cyt)/char_times[3]
#    194         1       6891.0   6891.0      0.0      b_Ma_div = np.ones(N_0_var)*(alpha*p_tcr + (1-alpha)*p_cyt)/char_times[4]
#    195         1       3275.0   3275.0      0.0      d_E_die = np.ones(N_0_var)/char_times[5]
#    196
#    197                                               #################################
#    198                                               ### RUN POPULATION SIMULATION ###
#    199                                               #################################
#    200         1        161.0    161.0      0.0      t = 0.0
#    201         1        751.0    751.0      0.0      S[0] = S_0
#    202         1        631.0    631.0      0.0      I[0] = I_0 if vir_model != 'autoimmune' else 0.0
#    203         1        301.0    301.0      0.0      V[0] = 0
#    204         1        220.0    220.0      0.0      H[0] = 0.0
#    205
#    206      2001     452070.0    225.9      0.0      for i in np.arange(1, int(steps) + 1):
#    207                                                   # select virulence model:
#    208      2000     334491.0    167.2      0.0          if vir_model == "dep_harm": # makes  average virus produced roughly the same independent of infected death rate
#    209                                                       b_I_t = b_I + d_I/S_0
#    210                                                       d_Sauto = 0
#    211                                                       t_Hauto = 0.25
#    212      2000     324970.0    162.5      0.0          elif vir_model == "autoimmune":
#    213                                                       b_I_t = 0.0
#    214                                                       d_Sauto = d_I
#    215                                                       K_SE = K_IE
#    216                                                       I_0 = 0.0
#    217                                                       t_Hauto = 0.25 # duration of autoimmune inflammation
#    218                                                   else:
#    219      2000     227988.0    114.0      0.0              b_I_t = b_I
#    220      2000     237606.0    118.8      0.0              d_Sauto = 0
#    221      2000     219245.0    109.6      0.0              t_Hauto = 0.25
#    222
#    223                                                   # Compute total population of cell types
#    224      2000    8816016.0   4408.0      0.7          E_pop = np.sum(E_m[i-1])
#    225
#    226
#    227                                                   #### Run infection dynamics: replication and effector clearance ####
#    228
#    229                                                   # Update state of susceptible, infected and inflammation
#    230                                                   # (a) event variables
#    231                                                   # S_to_I, I_die = np.random.binomial(S[i-1], (I[i-1] >= I_0)*b_I_t*I[i-1]*dt), np.random.binomial(I[i-1], dt*(d_IE*(E_pop)/(K_IE + I[i-1] + E_pop) + d_I))
#    232                                                   # I_d_IE[i] += I_d_IE[i-1] + np.random.binomial(I_die, d_IE*(E_pop)/(K_IE + I[i-1] + E_pop)/( d_IE*(E_pop)/(K_IE + I[i-1] + E_pop) + d_I)) # cells killed by immune response
#    233                                                   # I_d_I[i] += I_d_I[i-1] + (I_die - (I_d_IE[i] - I_d_IE[i-1])) + (I[i] if i == int(steps) else 0) # cells killed by infection
#    234
#    235      2000    4175585.0   2087.8      0.3          S_to_I, I_die = dt*S[i-1]*(I[i-1] >= I_0)*b_I_t*I[i-1], dt*I[i-1]*(d_IE*(E_pop)/(K_IE + I[i-1] + E_pop) + d_I)
#    236      2000    2682810.0   1341.4      0.2          I_d_IE[i] += I_d_IE[i-1] + dt*I[i-1]*d_IE*(E_pop)/(K_IE + I[i-1] + E_pop) # cells killed by immune response
#    237      2000    2082599.0   1041.3      0.2          I_d_I[i] += I_d_I[i-1] + dt*I[i-1]*d_I + (I[i] if i == int(steps) else 0) # cells killed by infection
#    238      2000    5180909.0   2590.5      0.4          I_d_S[i] += I_d_S[i-1] + dt*S[i-1]*( d_IE*(E_pop)/(K_SE + S[i-1] + E_pop) + d_Sauto*np.exp(-((t-2.0)/t_Hauto)**2) )
#    239
#    240                                                   # (b) state variables
#    241      2000    6107474.0   3053.7      0.5          S[i] += S[i-1] - S_to_I + dt*(b_S - (d_S + d_Sauto*np.exp(-((t-2.0)/t_Hauto)**2))*S[i-1] - S[i-1]*d_IE*(E_pop)/(K_SE + S[i-1] + E_pop))*(S[i-1] >= 1.0)
#    242
#    243      2000    1134074.0    567.0      0.1          I[i] += I[i-1] + S_to_I - I_die
#    244
#    245      2000    2864267.0   1432.1      0.2          harm_detected = I_die + dt*S[i-1]*d_Sauto*np.exp(-((t-2.0)/t_Hauto)**2)
#    246
#    247      2000    2200928.0   1100.5      0.2          cell_lysed = harm_detected + dt*S[i-1]*d_IE*(E_pop)/(K_SE + S[i-1] + E_pop)*(vir_model == "autoimmune")
#    248
#    249      2000     926138.0    463.1      0.1          cells_sensed = (I[i] + S[i]*(vir_model == "autoimmune"))
#    250
#    251      2000    2499777.0   1249.9      0.2          H[i] += H[i-1] + b_H*(harm_detected) - dt*d_H*H[i-1]*(H[i-1] >= 0.0)
#    252
#    253                                                   ## I. Recruitment/Priming
#    254
#    255                                                   # (a) Phase 1: Naive cells encounter and bind APCs
#    256      2000   31369328.0  15684.7      2.6          bound_N += np.random.binomial(N_m[i-1], b_N_bind*dt) - np.random.binomial(N_m[i-1], b_unbind_t*dt) if cells_sensed >= 1 else 0
#    257
#    258                                                   # (b) Phase 2: Activated naive cells are bound to APCs and receive stimulation.
#    259      2000   10379918.0   5190.0      0.9          act_N = (1 - bound_N)*(mycN >= myc_thresh)*(N_m[i-1] > 0)
#    260
#    261                                                   # (c) Phase 3: Unbound activated naive cells divide and then differentiate
#    262      2000   27602014.0  13801.0      2.3          div_Na = np.random.binomial(Na_m[i-1]*Na_div_flag, dt*b_Na_div)
#    263
#    264      2000   59450978.0  29725.5      4.9          diff_NaM = np.random.binomial(Na_m[i-1]*(1 - Na_div_flag), 1 - np.exp(-np.sum(r_NaM[0:i-1], axis = 0)*dt) if np.sum(Na_m[i-1]) > 0 else 0)
#    265
#    266                                                   ## II. Expansion
#    267
#    268                                                   # (a) New central memory cells divide
#    269      2000   25898077.0  12949.0      2.1          div_Ma = np.random.binomial(Ma_m[i-1] - diff_EpM_count, dt*b_Ma_div)
#    270
#    271                                                   # (b) Effector cells divide, differentiate, die
#    272      2000   32272717.0  16136.4      2.7          die_E = np.random.binomial(E_m[i-1], d_E_die*dt)
#    273      2000   29985543.0  14992.8      2.5          div_E = np.random.binomial(E_m[i-1] - die_E, dt*(b_E_div))
#    274      2000   30743393.0  15371.7      2.5          diff_EM = np.random.binomial(E_m[i-1] - die_E, dt*r_EM[i-1])
#    275
#    276                                                   #### Update population dynamics: ####
#    277      2000    4061966.0   2031.0      0.3          N_m[i] += N_m[i-1] - act_N
#    278      2000   14237384.0   7118.7      1.2          Na_m[i] += Na_m[i-1] + div_Na + act_N - (1 - Na_div_flag)*Na_m[i-1]
#    279
#    280      2000   10922025.0   5461.0      0.9          Ma_m[i] += Ma_m[i-1] + div_Ma + (1 - Na_div_flag)*(diff_NaM) + diff_EM
#    281      2000   14013464.0   7006.7      1.2          E_m[i] += E_m[i-1] + div_E + (1 - Na_div_flag)*(Na_m[i-1] - diff_NaM) - (die_E + diff_EM)
#    282
#    283                                                   # Update division flag to allow division to proceed
#    284      2000    6329438.0   3164.7      0.5          Na_div_flag = (Na_m[i] < max_Na)*(Na_m[i] > 0)
#    285      2000    4005514.0   2002.8      0.3          div_E_count += div_Na + div_E + div_Ma
#    286      2000    3097845.0   1548.9      0.3          diff_EpM_count += diff_EM
#    287
#    288                                                   #### New binding events ####
#    289
#    290      2000   11180471.0   5590.2      0.9          b_N_bind = (N_m[i] > 0)*(1 - bound_N)*f_XtoY(sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], psi_1 = psi_max/4, psi_2 = psi_max/2, psi_1_2 = 0.0, F_0 = -2.0, K_1 = S_0, K_2 = K_EH, reg_model = reg_model)/char_times[0] if cells_sensed >= 1 else 0.0
#    291
#    292      2000   67635058.0  33817.5      5.6          b_unbind_t = bound_N*np.fmin(2*(i - np.argmin(N_m[0:i], axis = 0))*dt/(f_XtoY(sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], psi_1 = psi_max/2, psi_2 = psi_max/4, psi_1_2 = 0.0, F_0 = -2.0, K_1 = (K_EI*(vir_model != "autoimmune") + K_SE*(vir_model == "autoimmune")), K_2 = K_EH, reg_model = reg_model)*char_times[1]*2/np.sqrt(np.pi))**2, 1/dt) if np.sum(bound_N) >= 1 else 0.0
#    293
#    294      2000   17178704.0   8589.4      1.4          b_myc_t = b_myc*f_XtoY(sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], psi_1 = psi_Nact_I, psi_2 = psi_Nact_H, psi_1_2 = psi_Nact_IH, F_0 = F0_Nact, K_1 = (K_EI*(vir_model != "autoimmune") + K_SE*(vir_model == "autoimmune")), K_2 = K_EH, reg_model = reg_model)*bound_N
#    295
#    296                                                   #### MYC Dynamics ####
#    297      2000   20158822.0  10079.4      1.7          mycN = (mycN + dt*(b_myc_t - (1 - bound_N)*mycN*d_myc*(mycN > 0)))*(N_m[i] + Na_m[i] > 0)
#    298
#    299      2000   29659405.0  14829.7      2.4          mycE = (mycE - dt*(f_XtoY(sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], psi_1 = -psi_Ediv_I, psi_2 = -psi_Ediv_H, psi_1_2 = -psi_Ediv_IH, F_0 = -F0_Ediv, K_1 = (K_EI*(vir_model != "autoimmune") + K_SE*(vir_model == "autoimmune")), K_2 = K_EH, reg_model = reg_model)*mycE*d_myc))*(E_m[i] >= 1) + mycN*(Na_m[i] > 0)
#    300
#    301      2000   27652618.0  13826.3      2.3          mycMa = (mycMa - dt*f_XtoY(sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], psi_1 = -psi_Ediv_I, psi_2 = -psi_Ediv_H, psi_1_2 = -psi_Ediv_IH, F_0 = -F0_Ediv, K_1 = (K_EI*(vir_model != "autoimmune") + K_SE*(vir_model == "autoimmune")), K_2 = K_EH, reg_model = reg_model)*(mycMa*d_myc))*(Ma_m[i] > 0) + mycN*(Na_m[i] >= 1) # higher decay rate of myc
#    302
#    303                                                   #### Time-dependent rates modulated by antigen and cytokine signals ####
#    304      2000     583480.0    291.7      0.0          b_Na_div = 1/char_times[2]
#    305      2000    9913013.0   4956.5      0.8          b_E_div = (mycE >= myc_thresh)*(div_E_count < max_expand)*(alpha*p_tcr + (1-alpha)*p_cyt)/char_times[3]
#    306      2000    8897935.0   4449.0      0.7          b_Ma_div = (mycMa >= myc_thresh)*(div_E_count < max_expand)*(alpha*p_tcr + (1-alpha)*p_cyt)/char_times[4]
#    307
#    308                                                   #### Transition probabilities modulated by antigen and cytokine signals ####
#    309      2000    6747806.0   3373.9      0.6          r_Nact[i] += b_myc_t/myc_thresh
#    310
#    311      2000   30168470.0  15084.2      2.5          r_NaM[i] += (r_NaM[i-1] + 2*dt*f_XtoY(sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], psi_1 = psi_NM_I, psi_2 = psi_NM_H, psi_1_2 = psi_NM_IH, F_0 = F0_NM, K_1 = (K_EI*(vir_model != "autoimmune") + K_SE*(vir_model == "autoimmune")), K_2 = K_EH, reg_model = reg_model)/(2/np.sqrt(np.pi)*(char_times[1] - char_times[6]))**2)*(N_m[i]*bound_N > 0)*(mycN >= myc_thresh)
#    312
#    313      2000   25871171.0  12935.6      2.1          r_EM[i] += (r_EM[i-1] + 2*dt*f_XtoY(sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], psi_1 = psi_EM_I, psi_2 = psi_EM_H, psi_1_2 = psi_EM_IH, F_0 = F0_EM, K_1 = (K_EI*(vir_model != "autoimmune") + K_SE*(vir_model == "autoimmune")), K_2 = K_EH, reg_model = reg_model)/(2/np.sqrt(np.pi)*char_times[5]**2))*(E_m[i] > 0)
#    314
#    315      2000    4402130.0   2201.1      0.4          r_Ediv[i] += b_E_div
#    316
#    317                                                   # store time cells become effector
#    318      2000   15219215.0   7609.6      1.3          T_E += dt*(E_m[i] > 0) if np.sum(E_m[i]) > 0 else 0.0
#    319      2000   10904969.0   5452.5      0.9          d_E_die = 2*(E_m[i] > 0)*T_E/(2/np.sqrt(np.pi)*char_times[5])**2
#    320
#    321                                                   # store time an effector spends in cytotoxic state
#    322    270516   45573319.0    168.5      3.7          for l in np.where(N_m[i] == 0)[0]:
#    323    268516  326207104.0   1214.9     26.8              T_Ecyt[l] += diff_NaM[l]*[0.0] + diff_EM[l]*[T_E[l].item()] + div_Ma[l]*[0.0]
#    324
#    325                                                   #### Store myc levels ####
#    326      2000     428544.0    214.3      0.0          if out_data == "full":
#    327                                                       mycN_m[i] += mycN
#    328                                                       mycMa_m[i] += mycMa
#    329                                                       mycE_m[i] += mycE
#    330
#    331                                                   #### Store differentiation biases
#    332      4000   21497352.0   5374.3      1.8          bias_t[i] += np.array([np.mean((r_Nact[i])),
#    333      2000   20166743.0  10083.4      1.7                                 np.mean((r_NaM[i])[N_m[i]*bound_N > 0]) if np.sum(N_m[i]*bound_N) > 0.0 else 0.0,
#    334      2000   22710049.0  11355.0      1.9                                 np.mean((r_EM[i])[E_m[i] > 0]) if np.sum(E_m[i]) > 0.0 else 0.0,
#    335      2000   21777722.0  10888.9      1.8                                 np.mean(r_Ediv[i][E_m[i] > 0]) if np.sum(E_m[i]) > 0.0 else 0.0])
#    336
#    337                                                   # Increment time
#    338      2000     415907.0    208.0      0.0          t += dt
#    339
#    340                                               # Collect population dynamics
#    341         1     655575.0 655575.0      0.1      N, Na, Ma, E = np.sum(N_m, axis = 1), np.sum(Na_m, axis = 1), np.sum(Ma_m, axis = 1), np.sum(E_m, axis = 1)
#    342
#    343         1   16601943.0    2e+07      1.4      T_pEcytM = np.concatenate(T_Ecyt) # time that memory spends in effector
#    344                                               # Project out surviving primary memory
#    345         1  106352714.0    1e+08      8.7      M_duration = fsolve(memory_duration, t_long_M, args = (T_pEcytM, char_times[5], N_0)).item()/365.25 if N_0 > 0 else 0.0
#    346
#    347         2     144057.0  72028.5      0.0      lineage_comp = np.vstack([np.amax(N_m, axis = 0) ,
#    348         1      72649.0  72649.0      0.0                                np.amax(Ma_m, axis = 0),
#    349         1      92599.0  92599.0      0.0                                np.amax(E_m, axis = 0),
#    350         1      28903.0  28903.0      0.0                                p_tcr*np.ones(N_0_var),
#    351         1       4346.0   4346.0      0.0                                p_cyt*np.ones(N_0_var)])
#    352
#    353         1      28783.0  28783.0      0.0      dyn_data = np.array([S, I, N, Na, E, Ma, H, I_d_I + I_d_IE, I_d_S]).T
#    354         1        321.0    321.0      0.0      prim_bias = bias_t #[r_NaM, r_EM]
#    355
#    356         1      79249.0  79249.0      0.0      ts = np.linspace(0, duration, int(steps) + 1)
#    357
#    358                                               # Compute summary statistics from simulations
#    359                                               ## extract primary/secondary infection dynamics
#    360         1       3245.0   3245.0      0.0      pS, pI, N, Na, pE, pM, pH, pI_d_I, pI_d_S = dyn_data[:,0], dyn_data[:,1], dyn_data[:,2], dyn_data[:, 3], dyn_data[:,4], dyn_data[:,5], dyn_data[:,6], dyn_data[:,7], dyn_data[:,8]
#    361
#    362         1        891.0    891.0      0.0      dt = ts[1]-ts[0]
#    363
#    364         3      12899.0   4299.7      0.0      parameters = np.concatenate((np.array([S_0, I_0, b_I, d_S, d_I, d_IE, d_IH, K_IE, K_IH,
#    365         1        310.0    310.0      0.0                b_H, d_H, K_EI, K_EH,
#    366         1        540.0    540.0      0.0                N_0, max_Na, b_myc, d_myc, myc_thresh]),
#    367         1        280.0    280.0      0.0                char_times,
#    368         1       1862.0   1862.0      0.0                activation_regulation, NM_regulation, EM_regulation, expansion_regulation))
#    369
#    370         2      12729.0   6364.5      0.0      sim_summary = np.array([np.sum(pI*dt),
#    371         1      17877.0  17877.0      0.0                         np.argmax(pI)*dt,
#    372         1       9704.0   9704.0      0.0                         np.argmax(pI < I_0)*dt,
#    373         1       7040.0   7040.0      0.0                         np.amax(pI_d_I),
#    374         1       4066.0   4066.0      0.0                         np.amax(pI_d_S),
#    375         1       4367.0   4367.0      0.0                         np.max(pE),
#    376         1       3154.0   3154.0      0.0                         np.argmax(pE)*dt,
#    377         1     385339.0 385339.0      0.0                         np.mean(np.argmax(E_m > 0 , axis = 0)*dt*(np.amax(E_m, axis = 0) > 0 )) + sim_duration*(np.max(pE) < 1.0),
#    378         1        391.0    391.0      0.0                         pM[-1],
#    379         1        221.0    221.0      0.0                         M_duration if N_0 > 0 else 0.0,
#    380         1       7201.0   7201.0      0.0                         np.sum(pE*dt),
#    381         1       5729.0   5729.0      0.0                         np.sum(pH*dt),
#    382         1      11757.0  11757.0      0.0                         np.amin(pS)])
#    383
#    384                                               # down-size timeseries
#    385         1        550.0    550.0      0.0      pnts = int(0.1*steps)
#    386         1      53079.0  53079.0      0.0      keep = [i*10 for i in np.arange(0,pnts)]
#    387
#    388         1        661.0    661.0      0.0      if out_data == "full":
#    389                                                   out_dict = {"reg_coeffs": np.concatenate((activation_regulation, NM_regulation, EM_regulation, expansion_regulation)), "cell_time_series": dyn_data, "time": ts, "lineage_diff": lineage_comp, "prim_diff_bias": prim_bias, "eff_by_lin": (E_m), "N_myc_by_lin": mycN_m, "Ma_myc_by_lin": mycMa_m, "E_myc_by_lin": mycE_m, "parameters": parameters, "summary_stats": sim_summary, "pmemory_formed": T_pEcytM if N_0 > 0 else []}
#    390         1        171.0    171.0      0.0      elif out_data == "small":
#    391         1      34391.0  34391.0      0.0          out_dict = {"cell_time_series": dyn_data[keep], "prim_diff_bias": prim_bias[keep],"parameters": parameters, "summary_stats": sim_summary}
#    392
#    393         1        100.0    100.0      0.0      return out_dict

# %%
# Run single simulation
# %timeit -n 2 -r 2
data_dict = lin_stoch_sim(N_0 = N_0, b_I = b_I, 
                          K_IE = K_IE,
                          d_I = d_I,
                          K_IH = K_IH,
                          NM_regulation = mem_reg[0:4],
                          EM_regulation = mem_reg[4:],
                          activation_regulation = [0.0*psi_max/2, 0.0*psi_max/2, 1.0*psi_max/2, 0.0*psi_max/2],
                          expansion_regulation = [psi_max/2, psi_max/2, 0*psi_max/4, 0.0*psi_max/4],
                          infection = infection_type,
                          vir_model = vir_model,
                          reg_model = 'mwc_like',
                          out_data = "full")

# %%
regs = data_dict["reg_coeffs"]
dyn = data_dict["cell_time_series"]
ts = data_dict["time"]
lin_comp = data_dict["lineage_diff"]
p_diff = data_dict["prim_diff_bias"]
parameters = data_dict["parameters"]
sim_summary = data_dict["summary_stats"]
mycN = data_dict["N_myc_by_lin"]
mycMa = data_dict["Ma_myc_by_lin"]
mycE = data_dict["E_myc_by_lin"]
Eff = data_dict["eff_by_lin"]
T_pEcytM = data_dict["pmemory_formed"]

S, I, N, Na, E, M, H, I_d_I, I_d_S = dyn[:,-9], dyn[:,-8], dyn[:,-7], dyn[:,-6], dyn[:,-5], dyn[:,-4], dyn[:,-3], dyn[:,-2], dyn[:,-1]

reg_string = '-'.join((mem_reg * 1).astype('U4'))

# %%
# Plot simulated immune dynamics
fig, (ax1, ax2, ax3) = plt.subplots(3, dpi = 150, constrained_layout=True, sharex = False, figsize=(5,5))

ax1.plot(ts, S, 'k', label = r'susceptible, $S$')
ax1.plot(ts, I, 'b', label = r'infected, $I$')

ax1.plot(ts, I_d_S, 'r', linestyle = '--', label = r'susceptible killed')
ax1.plot(ts, I_d_I, 'g', linestyle = '--', label = r'infected killed')
ax1.axhline(y = K_EH, color = 'k', linestyle = '--')
ax1.set(ylabel='cell count')
ax1.set_ylim(1,)
ax1.semilogy()
ax1.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

ax2.plot(ts, Na, 'b', label = r'activated, $N^*$')
ax2.plot(ts, E, 'orange', label = r'effector, $E$')
ax2.plot(ts, M, 'g', label = r'memory, $M$')
#ax2.plot(ts, N, 'm', label = r'naive, $N$')
ax2.plot(ts, S, 'grey', label = r'susceptible, $S$')
ax2.plot(ts, I, 'r', label = r'infected, $I$')
ax2.set(ylabel='cell count')
ax2.semilogy()
ax2.set_ylim(1,)
ax2.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

ax3.plot(ts, f_XtoY(sig_1 = I, sig_2 = H, psi_1 = psi_max/2, psi_2 = psi_max/2, psi_1_2 = 0, F_0 = 0.0, K_1 = K_EI, K_2 = K_EH),
         'k-', label = r'Regulation, $f(I,H)$')
ax3.set(xlabel=r'time, $t$ (days)', ylabel='Regulation')
ax3.set_ylim(0,1.05)

fig.savefig("_figs/"+infection_type+'-'+'virus-effector dynamics-'+reg_string+'.png', dpi=300, bbox_inches="tight")

# %%
plt.plot(ts, N)
plt.ylim(0, 1.1*N_0)
np.mean(np.argmax(Eff >0 , axis = 0)*(ts[1]-ts[0])*(np.amax(Eff, axis = 0) > 0 ))
# Out:
# 5.3711175

# %%
plt.plot(ts, np.log((1 + I/K_IE)), 'r')
plt.plot(ts, np.log((1 + H/K_IH)), 'k--')

# %%
plt.plot(ts,d_IE*E/(K_IE + I + E), 'r')
plt.plot(ts, d_IE*E/(K_IE + E), 'k--')

# %%
print(f'Memory fraction = {(np.max(M))/np.max(E)}')
print(f'Number of memory cells = {np.max(M)}')
print(f'1st infection harm = {sim_summary[3]/(d_S*S_0)}')
print(f'1st response toxicity = {sim_summary[4]/(d_S*S_0)}')
print(f'Minimum susceptible = {np.min(S)/S_0}')
# Out:
# Memory fraction = 0.4530052528992955
# Number of memory cells = 412999.0
# 1st infection harm = 99.8552934836274
# 1st response toxicity = 1.7907783459984719
# Minimum susceptible = 0.026994202900149127

# %%
# Plot simulated infection dynamics: pretty plots
pnts = 150
keep = [i*int(len(E)/pnts) for i in np.arange(0,pnts)]
sus = S[keep]
naive = Na[keep]
eff = E[keep]
mem = M[keep]
p_load = np.log(1 + I[keep]/K_IE)
inflam = np.log((1 + H[keep]/K_EH))/np.log((1 + S_0/K_EH))
time = ts[keep]

plt.scatter(time, naive, marker ='*', c = p_load, cmap='coolwarm', 
            label = r'Act. naive, $N^*$') #, norm=mpl.colors.LogNorm())
plt.plot(time, naive, 'b--')
plt.scatter(time, eff, marker ='o', c = p_load, cmap='coolwarm', 
            label = r'Effector, $E$') #, norm=mpl.colors.LogNorm())
plt.plot(time, eff, 'y--')
plt.scatter(time, mem, marker ='s', c = p_load, cmap='coolwarm',
            label = r'Memory, $cM+eM$') #, norm=mpl.colors.LogNorm())
plt.plot(time, mem, 'g--')

plt.colorbar(label ='Antigenic stimulation,'+ r'$\log(1 + \frac{I}{K_{I,E}})$')
plt.ylabel('cellular response', fontsize = 14)
plt.xlabel(r"time, $t$ (days)", fontsize = 14)
plt.semilogy()

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        plt.axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], label =r"Inflammation, $\log(1 + \frac{H}{K_{H,E}})$")
    else:
        plt.axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i])

plt.legend(loc='center right', bbox_to_anchor=(2.1, 0.8), fontsize = 10)

plt.savefig('_figs/'+infection_type+'-timeline-of-infection-dynamics-'+reg_string+'.png', dpi=300, bbox_inches="tight")

# %%
# Plot simulated infection dynamics: pretty plots of harm
pnts = 150
keep = [i*int(len(E)/pnts) for i in np.arange(0,pnts)]

eff = E[keep]
p_load = I[keep]/S_0
sus = S[keep]/S_0
inf_harm = I_d_I[keep]/S_0
inflam_harm = I_d_S[keep]/S_0
inflam = np.log((1 + H[keep]/K_EH))/np.log((1 + S_0/K_EH))
time = ts[keep]

plt.scatter(time, p_load, marker ='s', c =eff/K_IE, cmap='coolwarm', 
            label = r'Infected cells, $I$') #, norm=mpl.colors.LogNorm())
plt.plot(time, p_load, 'k--')

plt.scatter(time, sus, marker ='>', c =eff/K_IE, cmap='coolwarm', 
            label = r'Susceptible cells, $S$') #, norm=mpl.colors.LogNorm())
plt.plot(time, sus, 'k--')

plt.scatter(time, inf_harm, marker ='o', c =eff/K_IE, cmap='coolwarm', 
            label = 'Infected cells killed')
plt.plot(time, inf_harm, 'k--')

plt.scatter(time, inflam_harm, marker ='*', c =eff/K_IE, cmap='coolwarm',
            label = 'Susceptible cells killed')
plt.plot(time, inflam_harm, 'k--')

plt.colorbar(label = "Primary effector response")
plt.ylabel('Cell count \n (fraction of initial susceptible cells)', fontsize = 14)
plt.xlabel(r"Time, $t$ (days)", fontsize = 14)

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        plt.axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], label =r"Inflammation, $H$", zorder = 0)
    else:
        plt.axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        
plt.legend(loc='center right', bbox_to_anchor=(1.85, 0.8), fontsize = 10)
plt.savefig('_figs/'+infection_type+'-infection-harm-'+reg_string+'.png', dpi=300, bbox_inches="tight")

# %%
# Plot simulated infection dynamics: pretty plots
pnts = 150
keep = [1 + i*int(len(E)/pnts) for i in np.arange(0,pnts)]
bias_diff = p_diff[keep] if infection_type == "prim" else s_diff[keep]
p_load = I[keep]/S_0
sus = S[keep]
inflam =  np.log((1 + H[keep]/K_EH))/np.log((1 + S_0/K_EH))
time = ts[keep]

fig, axs = plt.subplots(1,4, figsize=(15,2.5))

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        axs[0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[2].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[3].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0, label =r"Inflammation, $H$")
    else:
        axs[0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[2].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[3].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0, label =r"Inflammation, $H$")

im1 = axs[0].scatter(time, bias_diff[:,0], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$N \longrightarrow N^*$')
axs[0].plot(time, bias_diff[:,0],'k--')
axs[0].title.set_text(r'$N \longrightarrow N^*$')

im2 = axs[1].scatter(time, bias_diff[:,1], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$N^* \longrightarrow M$')
axs[1].plot(time, bias_diff[:,1],'k--')
axs[1].title.set_text(r'$N^* \longrightarrow M$')

im3 = axs[2].scatter(time, bias_diff[:,2], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$E \longrightarrow M$')
axs[2].plot(time, bias_diff[:,2],'k--')
axs[2].title.set_text(r'$E \longrightarrow M$')

im4 = axs[3].scatter(time, bias_diff[:,3], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$E \longrightarrow M$')
axs[3].plot(time, bias_diff[:,3],'k--')
axs[3].title.set_text(r'$E \longrightarrow E + E$')

axs[0].set(ylabel='Instantaneous \n rate', 
           xlabel="Time (days)")

fig.subplots_adjust(wspace=.4)
cb = fig.colorbar(im1, ax=axs, orientation='vertical')
cb.set_label('Infected over \n susceptible,'+ r'$\frac{I}{S_0}$')

#cb.set_clim(-0.4,0.4)
    
# plt.colorbar(label =r"pathogen load, $I(t)$")
# plt.ylabel('transition weight', fontsize = 16)
# plt.xlabel("time (days)", fontsize = 16)
# plt.legend() #bbox_to_anchor=(1.05, 1.0), loc='upper left')

plt.savefig('_figs/'+infection_type+'-diff-bias-over-time-'+reg_string+'.png', dpi=300, bbox_inches="tight")

# %% [markdown]
# ### (2) Plot lineage-based trajectories

# %%
keys = np.array(['Memory', 'Effector'])
all_counts = lin_comp[1:3].T
effector_ranking = np.argsort(all_counts[:, 1])[::-1]
all_counts = all_counts[effector_ranking]
total_counts = all_counts.sum(axis=1)
norm_counts = all_counts / total_counts[:, None]
norm_counts[~np.isfinite(norm_counts)] = 0
comp_argsort = np.argsort(np.max(all_counts, axis=0))
bar_dict = {k: v for k, v in zip(keys[comp_argsort], norm_counts.T[comp_argsort])}
lineage_idxs = np.arange(all_counts.shape[0])

fig, ax = plt.subplots()
bottom = np.zeros(len(lineage_idxs))
cmap_colors = sns.color_palette('Set2', 10)
cmap_colors = [cmap_colors[i]
               for i in [0, 1, 5]]#[7, 2, 0, 1, 5]]
# cmap_colors = [cmap_colors[i]
#                for i in [6, 1, 2, 5, 0]]
width = 1

for i, (celltype, fraction) in enumerate(bar_dict.items()):
    ax.bar(lineage_idxs, fraction, width,
           edgecolor='k', linewidth=0.01,
           label=celltype, bottom=bottom, color=cmap_colors[i])
    bottom += fraction
    
ax.legend(loc='center right', bbox_to_anchor=(1.4, 0.5), fontsize = 12)
ax.set_xlim(-0.5, len(all_counts) - 0.5)
ax.set_xlabel('sub-clone lineages \n (ranked by effector response)', fontsize = 15)
ax.set_ylabel('fractional cell-fate \ncomposition', fontsize = 15)
#ax.set_yscale('log')

ax.set_xticks(np.arange(0, Eff.shape[1], int(Eff.shape[1]/10)))
ax.set_xticklabels(1 + np.arange(0, Eff.shape[1], int(Eff.shape[1]/10)), fontsize=9)

ax.set_yticks(np.round(np.arange(0, 1.2, 0.2), 1))
ax.set_yticklabels(ax.get_yticks(), fontsize=12)

fig.savefig("_figs/"+infection_type+'-'+'fates-by-lin-'+reg_string+'.png', dpi=300, bbox_inches="tight")
# Out:
# /tmp/ipykernel_74239/4250528192.py:6: RuntimeWarning: invalid value encountered in divide
#   norm_counts = all_counts / total_counts[:, None]

# %%
plt.errorbar(ts, np.mean(Eff, axis = 1), yerr = np.std(Eff, axis = 1), errorevery = 100)
plt.semilogy()
# Out:
# []

# %%
plt.plot(ts, mycE, 'r--')
plt.errorbar(ts, np.mean(mycE, axis = 1), yerr = np.std(mycE, axis = 1), errorevery = 100)
#plt.plot(ts, mycMa, 'k-')
plt.axhline(y = myc_thresh, color = 'k', linestyle = '--')
print(np.sum(np.max(mycE, axis=0) < myc_thresh)/N_0)
# Out:
# 0.115

# %%
#plt.hist(np.argmax(mycNa > 0, axis = 0)*sim_duration/sim_steps, bins='auto')
plt.hist(T_pEcytM, bins='auto', histtype='step');
# plt.hist(T_sEcytM, bins='auto', histtype='step');
# Out:
# 24.15921163377378

# %%
# Compute max values in the data
r = np.arange(5)
width = 0.5
plt.bar(r, np.amax(np.array([I, Na, E, M, H]).T, axis = 0), width = width)

plt.xlabel("response")
plt.ylabel("value")

plt.xticks(r, ["Infected","Naive","Effector","Memory", "Inflammation"], fontsize = 7)

plt.semilogy()
plt.suptitle(r'Peak response response: $N_0=$ '+str(N_0) +r', $d_I=$'+str(d_I))
# Out:
# Text(0.5, 0.98, 'Peak response response: $N_0=$ 200, $d_I=$0.1')

# %%
bias_1 = f_XtoY(I, H, 
       -2.0, -2.0, 0.0, F_0 = 4*np.log(2), 
       K_I = K_IE, K_H = K_EH)
bias_2 = f_XtoY(I, H, 
       -2.0, 2.0, 0.0, F_0 = -0*np.log(2), 
       K_I = K_IE, K_H = K_EH)

plt.plot(ts, bias_1, 'r')
plt.plot(ts, bias_2, 'k--')
plt.plot(ts, Na/np.amax(Na))
plt.plot(ts, A/(Na + A))
plt.plot(ts, H**l_H/(K_EH**l_H + H**l_H))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 bias_1 = f_XtoY(I, H,
#       2        -2.0, -2.0, 0.0, F_0 = 4*np.log(2),
#       3        K_I = K_IE, K_H = K_EH)
#       4 bias_2 = f_XtoY(I, H,
#       5        -2.0, 2.0, 0.0, F_0 = -0*np.log(2),
#       6        K_I = K_IE, K_H = K_EH)
#       8 plt.plot(ts, bias_1, 'r')
#
# TypeError: f_XtoY() got an unexpected keyword argument 'K_I'

# %%
d="/gscratch/scrubbed/oukogu/infoimmune/sim_output/no_cell_var/"
comment = "auto-Nact-Ediv-vir"
runs = 1

run(batch = [0], outdir=d, comment=comment, runs = runs, num_cpu = 20)

# %%
d_file = '/gscratch/scrubbed/oukogu/infoimmune/sim_output/no_cell_var/raw/sim_batch_0-'+str(runs)+'-prim-'+comment+'.pkl'
with open(d_file, 'rb') as f:   
    out = pickle.load(f)
