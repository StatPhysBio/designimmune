# %% [markdown]
# # Run infection dynamics with monoclonal killer T cell response

# %%
import numpy as np
from matplotlib.cm import get_cmap
import matplotlib.pyplot as plt
import matplotlib as mpl

import multiprocessing as mp
from tqdm import tqdm
from joblib import Parallel, delayed
from scipy import stats
import os
from stoch_sim_model import *
from optimize_nets import *
import seaborn as sns

plt.style.use('custom.mplstyle')
# %config InlineBackend.figure_format = 'retina'
# %load_ext line_profiler

# %%
avg_sim_time = 1.5/(60*60)

print('full-reg:',(len(psi_2d_nobias)**4)*len(vir_prop_select),
      np.ceil((len(psi_2d_nobias)**4*len(vir_prop_select))/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('prim-Nact-Ediv:',len(psi_2d)*len(psi_2d)*len(vir_prop_select), 
      np.ceil((len(psi_2d)*len(psi_2d)*len(vir_prop_select))/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('auto-Nact-Ediv:',len(psi_2d_sparse)*4, 
      np.ceil((len(psi_2d_sparse)*4)/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('sparse-reg:', len(psi_2d_sparse)*len(vir_prop_select),
      np.ceil(len(psi_2d_sparse)*len(vir_prop_select)/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')
# Out:
# full-reg: 2367144300 9864.0 2400 jobs per cpu per hour
# prim-Nact-Ediv: 21067500 88.0 2400 jobs per cpu per hour
# auto-Nact-Ediv: 1250000 6.0 2400 jobs per cpu per hour
# sparse-reg: 93750000 391.0 2400 jobs per cpu per hour

# %% [markdown]
# ### (1) Plot population averaged trajectories

# %%
# Set simulation parameters
N_0 = 300
K_IE = (1)*(10**4)
d_I = 125*d_S
b_I = 2.0*(10**(-7))

infection_type = "prim" #"prim", "sec"
vir_model = 'indep_harm' #'indep_harm
mem_reg = psi_max*np.array([-1.0*psi_max/2, -1.0*psi_max/2, -0.0*psi_max/2, -0.0*psi_max, -1.0*psi_max/2, -1.0*psi_max/2, 0.0*psi_max/2, -0.0*psi_max]) # np.array([-0.5, -0.5, -0.0, -0.5, -0.5, -0.0])

# %%
# %lprun -T lprof0 -f lin_stoch_sim lin_stoch_sim(N_0 = 300, b_I = b_I, K_IE = 100*K_IE, d_I = d_I, K_EH = 10*K_EH, NM_regulation = mem_reg[0:4], EM_regulation = mem_reg[4:], activation_regulation = [psi_max/2, psi_max/2, 0, 0], expansion_regulation = [psi_max/2, psi_max/2, 0, 0])
# Out:
# *** Profile printout saved to text file 'lprof0'.
# Timer unit: 1e-09 s
#
# Total time: 0.927036 s
# File: /mmfs1/home/oukogu/infoimmune/stoch_sim_model.py
# Function: lin_stoch_sim at line 136
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    136                                           def lin_stoch_sim(S_0 = S_0, I_0 = I_0, b_I = b_I, d_S = d_S, d_I = d_I, d_IE = d_IE, K_IE = K_IE, K_SE = K_SE,
#    137                                                               b_H = b_H, d_H = d_H, K_EH = K_EH,
#    138                                                               N_0 = N_0, max_Na = max_Na, b_myc = b_myc, d_myc = d_myc, myc_thresh = myc_thresh, max_expand = max_expand,
#    139                                                               char_times = [t_bind, t_unbind, t_Na_div, t_E_div, t_M_div, t_E_die, t_act],
#    140                                                               NM_regulation = NM_psis,
#    141                                                               EM_regulation = EM_psis,
#    142                                                               activation_regulation = act_psis,
#    143                                                               expansion_regulation = exp_psis,
#    144                                                               infection = "prim",
#    145                                                               vir_model = "indep_harm",
#    146                                                               duration = sim_duration,
#    147                                                               steps = sim_steps,
#    148                                                               reg_model = "mwc_like",
#    149                                                               out_data = "small"):
#    150
#    151                                               # VARIABLE DEFINITIONS:
#    152                                               # S_0 := S_0, I_0 := I_0, b_S := b_S, b_I := b_I, d_S := d_S, d_I := d_I, d_IE := d_IE, K_IE := K_IE,
#    153                                               # b_H := b_H, d_H := d_H, K_EH := K_EH,
#    154                                               # N_0 := N_0, max_Na := max_Na, b_myc := b_myc, d_myc := d_myc, myc_thresh := myc_thresh,
#    155                                               # char_times := [t_bind, t_unbind, t_Na_div, t_E_div, t_M_div, t_EM_diff, t_E_die, t_Nact],
#    156
#    157                                               #################################
#    158                                               ### SET META-VARIABLES FOR SIMULATION ###
#    159                                               #################################
#    160         1        871.0    871.0      0.0      dt =  duration/steps
#    161         1        591.0    591.0      0.0      N_0_var = int(N_0)
#    162         1        291.0    291.0      0.0      b_S = S_0*d_S
#    163
#    164                                               # draw population of reponding cells for agent-based simulations
#    165         1        761.0    761.0      0.0      psi_Nact_I, psi_Nact_H, psi_Nact_P, F0_Nact = activation_regulation[0], activation_regulation[1], activation_regulation[2], activation_regulation[3]
#    166         1       3345.0   3345.0      0.0      psi_NM_I, psi_NM_H, psi_NM_P, F0_NM = NM_regulation[0], NM_regulation[1], NM_regulation[2], NM_regulation[3]
#    167         1        451.0    451.0      0.0      psi_EM_I, psi_EM_H, psi_EM_P, F0_EM = EM_regulation[0], EM_regulation[1], EM_regulation[2], EM_regulation[3]
#    168         1        381.0    381.0      0.0      psi_Ediv_I, psi_Ediv_H, psi_Ediv_P, F0_Ediv = expansion_regulation[0], expansion_regulation[1], expansion_regulation[2], expansion_regulation[3]
#    169
#    170         1        120.0    120.0      0.0      p_tcr = 1.0 #np.ones(N_0_var)
#    171         1        100.0    100.0      0.0      p_cyt = 1.0 #np.ones(N_0_var)
#    172
#    173                                               # define variables for storage
#    174         1       8503.0   8503.0      0.0      I = np.zeros(int(steps)+1)
#    175         1      76836.0  76836.0      0.0      S = np.zeros(int(steps)+1)
#    176         1       2735.0   2735.0      0.0      V = np.zeros(int(steps)+1)
#    177         1       1172.0   1172.0      0.0      H = np.zeros(int(steps)+1)
#    178         1       1112.0   1112.0      0.0      P = np.zeros(int(steps)+1)
#    179         1      34021.0  34021.0      0.0      I_d_I = np.zeros(int(steps)+1)
#    180         1       3455.0   3455.0      0.0      I_d_S = np.zeros(int(steps)+1)
#    181         1       1061.0   1061.0      0.0      I_d_IE = np.zeros(int(steps)+1)
#    182         1       9394.0   9394.0      0.0      I_d_SE = np.zeros(int(steps)+1)
#    183
#    184         1      60501.0  60501.0      0.0      N_m = np.zeros((int(steps)+1, N_0_var), dtype = np.int32)
#    185         1      25419.0  25419.0      0.0      N_m[0,:] +=1
#    186         1      64898.0  64898.0      0.0      T_Ecyt = [[] for i in np.arange(0, N_0_var)]
#    187
#    188         1      14983.0  14983.0      0.0      div_E_count = np.ones(N_0_var)
#    189         1       3185.0   3185.0      0.0      diff_EpM_count = np.zeros(N_0_var, dtype = np.int32)
#    190
#    191         1      66580.0  66580.0      0.0      Na_m = np.zeros((int(steps)+1, N_0_var), dtype = np.int32)
#    192         1     255675.0 255675.0      0.0      Ma_m = np.zeros((int(steps)+1, N_0_var), dtype = np.int32)
#    193         1      56004.0  56004.0      0.0      E_m = np.zeros((int(steps)+1, N_0_var), dtype = np.int32) # effector in periphary
#    194         1       3856.0   3856.0      0.0      T_E = np.zeros(N_0_var)
#    195
#    196         1        391.0    391.0      0.0      if out_data == "full":
#    197                                                   mycN_m = np.zeros((int(steps)+1, N_0_var))
#    198                                                   mycMa_m = np.zeros((int(steps)+1, N_0_var))
#    199                                                   mycE_m = np.zeros((int(steps)+1, N_0_var))
#    200
#    201         1      18167.0  18167.0      0.0      bias_t = np.zeros((int(steps)+1, 4))
#    202
#    203                                               # Define event timer variables
#    204         1        961.0    961.0      0.0      bound_N = np.zeros(N_0_var, dtype =np.int32)
#    205         1       1893.0   1893.0      0.0      bound_N_time = np.zeros(N_0_var)
#    206         1       7541.0   7541.0      0.0      Na_div_flag = np.ones(N_0_var, dtype =np.int32)
#    207         1       2824.0   2824.0      0.0      Na_flag = np.ones(N_0_var, dtype =np.int32)
#    208
#    209         1       1963.0   1963.0      0.0      mycN = np.zeros(N_0_var)
#    210         1       1562.0   1562.0      0.0      mycE = np.zeros(N_0_var)
#    211         1        681.0    681.0      0.0      mycMa = np.zeros(N_0_var)
#    212
#    213         1    1006303.0    1e+06      0.1      r_NaM = np.zeros((int(steps)+1, N_0_var))
#    214         1    1005321.0    1e+06      0.1      r_EM = np.zeros((int(steps)+1, N_0_var))
#    215         1     384638.0 384638.0      0.0      r_Nact = np.zeros((int(steps)+1, N_0_var))
#    216         1     113260.0 113260.0      0.0      r_Ediv = np.zeros((int(steps)+1, N_0_var))
#    217         1       2003.0   2003.0      0.0      cum_r_NaM = np.zeros(N_0_var)
#    218
#    219         1       2945.0   2945.0      0.0      b_unbind_t = np.zeros(N_0_var)
#    220         1        561.0    561.0      0.0      b_N_bind = np.zeros(N_0_var)
#    221         1      18157.0  18157.0      0.0      b_Na_div = np.ones(N_0_var)/char_times[2]
#    222         1        701.0    701.0      0.0      b_myc_t = np.zeros(N_0_var)
#    223         1       4857.0   4857.0      0.0      b_E_div = np.ones(N_0_var)/char_times[3]
#    224         1       3856.0   3856.0      0.0      b_Ma_div = np.ones(N_0_var)/char_times[4]
#    225         1       3565.0   3565.0      0.0      d_E_die = np.ones(N_0_var)/char_times[5]
#    226
#    227                                               #################################
#    228                                               ### RUN POPULATION SIMULATION ###
#    229                                               #################################
#    230         1        220.0    220.0      0.0      t = 0.0
#    231         1        932.0    932.0      0.0      S[0] = S_0
#    232         1        611.0    611.0      0.0      I[0] = I_0 if vir_model != 'autoimmune' else 0.0
#    233         1        311.0    311.0      0.0      V[0] = 0
#    234         1        260.0    260.0      0.0      H[0] = 0.0
#    235         1        190.0    190.0      0.0      P[0] = 0.0
#    236
#    237      2001     394897.0    197.3      0.0      for i in np.arange(1, int(steps) + 1):
#    238                                                   # select virulence model:
#    239      2000     330621.0    165.3      0.0          if vir_model == "dep_harm": # makes  average virus produced roughly the same independent of infected death rate
#    240                                                       b_I_t = b_I + d_I/S_0
#    241                                                       d_Sauto = 0
#    242                                                       t_Hauto = 1.0
#    243      2000     312308.0    156.2      0.0          elif vir_model == "autoimmune":
#    244                                                       b_I_t = 0.0
#    245                                                       d_Sauto = d_I
#    246                                                       K_SE = K_IE
#    247                                                       I_0 = 0.0
#    248                                                       t_Hauto = 1.0 # duration of autoimmune inflammation
#    249                                                   else:
#    250      2000     218176.0    109.1      0.0              b_I_t = b_I
#    251      2000     225961.0    113.0      0.0              d_Sauto = 0
#    252      2000     213228.0    106.6      0.0              t_Hauto = 1.0
#    253
#    254                                                   # Compute total population of cell types
#    255      2000    9068492.0   4534.2      1.0          E_pop = np.sum(E_m[i-1])
#    256
#    257
#    258                                                   #### Run infection dynamics: replication and effector clearance ####
#    259
#    260                                                   # Update state of susceptible, infected and inflammation
#    261                                                   # (a) event variables
#    262
#    263      2000    4038561.0   2019.3      0.4          S_to_I, I_die = dt*S[i-1]*(I[i-1] >= I_0)*b_I_t*I[i-1], dt*I[i-1]*(d_IE*(E_pop)/(K_IE + I[i-1] + E_pop) + d_I)
#    264      2000    2669443.0   1334.7      0.3          I_d_IE[i] += I_d_IE[i-1] + dt*I[i-1]*d_IE*(E_pop)/(K_IE + I[i-1] + E_pop) # cells killed by immune response
#    265      2000    2054230.0   1027.1      0.2          I_d_I[i] += I_d_I[i-1] + dt*I[i-1]*d_I + (I[i] if i == int(steps) else 0) # cells killed by infection
#    266      2000    2458006.0   1229.0      0.3          I_d_SE[i] += I_d_SE[i-1] + dt*S[i-1]*( d_IE*(E_pop)/(K_SE + S[i-1] + E_pop) )
#    267      2000    1490938.0    745.5      0.2          I_d_S[i] += I_d_S[i-1] + dt*S[i-1]*d_S
#    268
#    269                                                   # (b) state variables
#    270      2000    6155925.0   3078.0      0.7          S[i] += S[i-1] - S_to_I + dt*(b_S - (d_S + d_Sauto*np.exp(-(t/t_Hauto)**2))*S[i-1] - S[i-1]*d_IE*(E_pop)/(K_SE + S[i-1] + E_pop))*(S[i-1] >= 1.0)
#    271
#    272      2000    1123838.0    561.9      0.1          I[i] += I[i-1] + S_to_I - I_die
#    273
#    274      2000    2675916.0   1338.0      0.3          harm_detected = I_die + dt*S[i-1]*d_Sauto*np.exp(-(t/t_Hauto)**2)
#    275      2000     782901.0    391.5      0.1          immunopathology = I_d_SE[i] + I_d_IE[i]
#    276      2000    1025323.0    512.7      0.1          cells_sensed = (I[i] + S[i]*K_IE/K_SE)
#    277
#    278      2000    2444026.0   1222.0      0.3          H[i] += H[i-1] + b_H*(harm_detected) - dt*d_H*H[i-1]*(H[i-1] >= 0.0)
#    279      2000    2138260.0   1069.1      0.2          P[i] += P[i-1] + b_H*(immunopathology) - dt*d_H*P[i-1]*(P[i-1] >= 0.0)
#    280
#    281                                                   ## I. Recruitment/Priming
#    282
#    283                                                   # (a) Phase 1: Naive cells encounter and bind APCs
#    284      2000     335607.0    167.8      0.0          if cells_sensed >= 1:
#    285      2000   66537465.0  33268.7      7.2              bound_N += np.random.binomial(N_m[i-1], b_N_bind*dt) - np.random.binomial(N_m[i-1], b_unbind_t*dt)
#    286                                                   else:
#    287                                                       bound_N = 0*bound_N
#    288
#    289      2000   15195361.0   7597.7      1.6          bound_N_time += bound_N*bound_N*dt - (1-bound_N)*bound_N_time*dt*N_m[i-1] # only reset to zero if the cell is not activated
#    290
#    291                                                   # (b) Phase 2: Activated naive cells are bound to APCs and receive stimulation.
#    292      2000   11146077.0   5573.0      1.2          act_N = (1 - bound_N)*(mycN >= myc_thresh)*(N_m[i-1] > 0)
#    293
#    294                                                   # (c) Phase 3: Unbound activated naive cells divide and then differentiate
#    295      2000   27854540.0  13927.3      3.0          div_Na = np.random.binomial(Na_m[i-1]*Na_div_flag, dt*b_Na_div)
#    296
#    297      2000   42549738.0  21274.9      4.6          diff_NaM = np.random.binomial(Na_m[i-1]*(1 - Na_div_flag), 1 - np.exp(-cum_r_NaM*dt) if np.sum(Na_m[i-1]) > 0 else 0)
#    298
#    299                                                   ## II. Expansion
#    300
#    301                                                   # (a) New central memory cells divide
#    302      2000   27969129.0  13984.6      3.0          div_Ma = np.random.binomial(Ma_m[i-1] - diff_EpM_count, dt*b_Ma_div)
#    303
#    304                                                   # (b) Effector cells divide, differentiate, die
#    305      2000   30866523.0  15433.3      3.3          die_E = np.random.binomial(E_m[i-1], d_E_die*dt)
#    306      2000   30781693.0  15390.8      3.3          div_E = np.random.binomial(E_m[i-1] - die_E, dt*(b_E_div))
#    307      2000   30804207.0  15402.1      3.3          diff_EM = np.random.binomial(E_m[i-1] - die_E, dt*r_EM[i-1])
#    308
#    309                                                   #### Update population dynamics: ####
#    310      2000    3937318.0   1968.7      0.4          N_m[i] += N_m[i-1] - act_N
#    311      2000   13970087.0   6985.0      1.5          Na_m[i] += Na_m[i-1] + div_Na + act_N - (1 - Na_div_flag)*Na_m[i-1]
#    312
#    313      2000   11351251.0   5675.6      1.2          Ma_m[i] += Ma_m[i-1] + div_Ma + (1 - Na_div_flag)*(diff_NaM) + diff_EM
#    314      2000   14126275.0   7063.1      1.5          E_m[i] += E_m[i-1] + div_E + (1 - Na_div_flag)*(Na_m[i-1] - diff_NaM) - (die_E + diff_EM)
#    315
#    316                                                   # Update division flag to allow division to proceed
#    317      2000    6257448.0   3128.7      0.7          Na_div_flag = (Na_m[i] < max_Na)*(Na_m[i] > 0)
#    318      2000    4235101.0   2117.6      0.5          div_E_count += div_Na + div_E + div_Ma
#    319      2000    3108290.0   1554.1      0.3          diff_EpM_count += diff_EM
#    320
#    321                                                   #### New binding events ####
#    322
#    323      2000   27152752.0  13576.4      2.9          b_N_bind = (N_m[i] > 0)*(1 - bound_N)*f_XtoY(sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i], psi_1 = psi_max/4, psi_2 = psi_max/2, psi_1_2 = 0.0, F_0 = -1.0, K_1 = S_0, K_2 = K_EH, K_3 = K_EH, reg_model = reg_model)/char_times[0] if cells_sensed >= 1 else 0.0
#    324
#    325      2000   33111118.0  16555.6      3.6          b_unbind_t = bound_N*np.fmin(2*(bound_N_time)/(f_XtoY(sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i], psi_1 = psi_max/2, psi_2 = 0.0, psi_1_2 = 0.0, F_0 = -2.0, K_1 = (K_IE*(vir_model != "autoimmune") + K_SE*(vir_model == "autoimmune")), K_2 = K_EH, K_3 = K_EH, reg_model = reg_model)*char_times[1]*2/np.sqrt(np.pi))**2, 1/dt) if np.sum(bound_N) >= 1 else 0.0
#    326
#    327      2000   16646438.0   8323.2      1.8          b_myc_t = b_myc*f_XtoY(sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i], psi_1 = psi_Nact_I, psi_2 = psi_Nact_H, psi_3 = psi_Nact_P, F_0 = F0_Nact, K_1 = (K_IE*(vir_model != "autoimmune") + K_SE*(vir_model == "autoimmune")), K_2 = K_EH, K_3 = K_EH, reg_model = reg_model)*bound_N # Maybe: multiply by np.sqrt(np.pi)/2. Can see argument for leaving as a linear rate
#    328
#    329                                                   #### MYC Dynamics ####
#    330      2000   36292794.0  18146.4      3.9          mycN = (mycN + dt*(b_myc_t - (1 - bound_N)*f_XtoY(sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i], psi_1 = -psi_Ediv_I, psi_2 = -psi_Ediv_H, psi_3 = -psi_Ediv_P, F_0 = -F0_Ediv, K_1 = (K_IE*(vir_model != "autoimmune") + K_SE*(vir_model == "autoimmune")), K_2 = K_EH, K_3 = K_EH, reg_model = reg_model)*mycN*d_myc*(mycN > 0)))*(N_m[i] + Na_m[i] > 0)
#    331
#    332      2000   30377079.0  15188.5      3.3          mycE = (mycE - dt*(f_XtoY(sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i], psi_1 = -psi_Ediv_I, psi_2 = -psi_Ediv_H, psi_3 = -psi_Ediv_P, F_0 = -F0_Ediv, K_1 = (K_IE*(vir_model != "autoimmune") + K_SE*(vir_model == "autoimmune")), K_2 = K_EH, K_3 = K_EH, reg_model = reg_model)*mycE*d_myc))*(E_m[i] >= 1) + mycN*(Na_m[i] > 0)
#    333
#    334      2000   28337107.0  14168.6      3.1          mycMa = (mycMa - dt*f_XtoY(sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i], psi_1 = -psi_Ediv_I, psi_2 = -psi_Ediv_H, psi_3 = -psi_Ediv_P, F_0 = -F0_Ediv, K_1 = (K_IE*(vir_model != "autoimmune") + K_SE*(vir_model == "autoimmune")), K_2 = K_EH, K_3 = K_EH, reg_model = reg_model)*(mycMa*d_myc))*(Ma_m[i] > 0) + mycN*(Na_m[i] >= 1) # higher decay rate of myc
#    335
#    336                                                   #### Time-dependent rates modulated by antigen and cytokine signals ####
#    337      2000     457104.0    228.6      0.0          b_Na_div = 1/char_times[2]
#    338      2000    7620626.0   3810.3      0.8          b_E_div = (mycE >= myc_thresh)*(div_E_count < max_expand)/char_times[3]
#    339      2000    7121985.0   3561.0      0.8          b_Ma_div = (mycMa >= myc_thresh)*(div_E_count < max_expand)/char_times[4]
#    340
#    341                                                   #### Transition probabilities modulated by antigen and cytokine signals ####
#    342      2000    4257590.0   2128.8      0.5          r_Nact[i] += b_myc_t/myc_thresh
#    343
#    344      2000   29331000.0  14665.5      3.2          r_NaM[i] += (r_NaM[i-1] + 2*dt*f_XtoY(sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i], psi_1 = psi_NM_I, psi_2 = psi_NM_H, psi_3 = psi_NM_P,F_0 = F0_NM, K_1 = (K_IE*(vir_model != "autoimmune") + K_SE*(vir_model == "autoimmune")), K_2 = K_EH, K_3 = K_EH, reg_model = reg_model)/(2/np.sqrt(np.pi)*(char_times[1]))**2)*(N_m[i]*bound_N > 0)*(mycN >= myc_thresh)
#    345
#    346      2000   24066630.0  12033.3      2.6          r_EM[i] += (r_EM[i-1] + 2*dt*f_XtoY(sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i], psi_1 = psi_EM_I, psi_2 = psi_EM_H, psi_3 = psi_EM_P, F_0 = F0_EM, K_1 = (K_IE*(vir_model != "autoimmune") + K_SE*(vir_model == "autoimmune")), K_2 = K_EH, K_3 = K_EH, reg_model = reg_model)/(2/np.sqrt(np.pi)*char_times[1]**2))*(E_m[i] > 0) # Urgent: need to square entire denominator
#    347
#    348      2000    2081826.0   1040.9      0.2          r_Ediv[i] += b_E_div
#    349
#    350      2000    1475586.0    737.8      0.2          cum_r_NaM += r_NaM[i]
#    351
#    352                                                   # store time cells become effector
#    353      2000   13709317.0   6854.7      1.5          T_E += dt*(E_m[i] > 0) if np.sum(E_m[i]) > 0 else 0.0
#    354      2000   11179013.0   5589.5      1.2          d_E_die = 2*(E_m[i] > 0)*T_E/(2/np.sqrt(np.pi)*char_times[5])**2
#    355
#    356                                                   # store time an effector spends in cytotoxic state
#    357    133209   30947589.0    232.3      3.3          for l in np.where((N_m[i] == 0)*(E_m[i] + b_Ma_div > 0))[0]:
#    358    131209  145878590.0   1111.8     15.7              T_Ecyt[l] += (diff_NaM[l] + div_Ma[l])*[0.0] + diff_EM[l]*[T_E[l].item()]
#    359
#    360                                                   # T_Ecyt += np.sum(diff_NaM)*[0.0] + diff_EM*T_E.tolist() + np.sum(div_Ma)*[0.0]
#    361
#    362                                                   #### Store myc levels ####
#    363      2000     332180.0    166.1      0.0          if out_data == "full":
#    364                                                       mycN_m[i] += mycN
#    365                                                       mycMa_m[i] += mycMa
#    366                                                       mycE_m[i] += mycE
#    367
#    368                                                   #### Store differentiation biases
#    369      4000   19895129.0   4973.8      2.1          bias_t[i] += np.array([np.mean((r_Nact[i])),
#    370      2000   29849787.0  14924.9      3.2                                 np.mean((r_NaM[i])[N_m[i]*bound_N > 0]) if np.sum(N_m[i]*bound_N) > 0.0 else 0.0,
#    371      2000   20101765.0  10050.9      2.2                                 np.mean((r_EM[i])[E_m[i] > 0]) if np.sum(E_m[i]) > 0.0 else 0.0,
#    372      2000   19629024.0   9814.5      2.1                                 np.mean(r_Ediv[i][E_m[i] > 0]) if np.sum(E_m[i]) > 0.0 else 0.0])
#    373
#    374                                                   # Increment time
#    375      2000     461849.0    230.9      0.0          t += dt
#    376
#    377                                               # Collect population dynamics
#    378         1    1082877.0    1e+06      0.1      N, Na, Ma, E = np.sum(N_m, axis = 1), np.sum(Na_m, axis = 1), np.sum(Ma_m, axis = 1), np.sum(E_m, axis = 1)
#    379
#    380         1     157367.0 157367.0      0.0      T_pEcytM = np.concatenate(T_Ecyt) if N_0 > 0 else np.array([0.0]) # time that memory spends in effector
#    381                                               # Project out surviving primary memory
#    382         1     208303.0 208303.0      0.0      M_duration = fsolve(memory_duration, 1.0, args = (T_pEcytM, char_times[5], N_0), xtol = 0.001).item() if len(T_pEcytM) > N_0 and N_0 > 0.0 else 0.0
#    383
#    384         2     109084.0  54542.0      0.0      lineage_comp = np.vstack([np.amax(N_m, axis = 0) ,
#    385         1      83085.0  83085.0      0.0                                np.amax(Ma_m, axis = 0),
#    386         1      84196.0  84196.0      0.0                                np.amax(E_m, axis = 0),
#    387         1      12249.0  12249.0      0.0                                p_tcr*np.ones(N_0_var),
#    388         1       3956.0   3956.0      0.0                                p_cyt*np.ones(N_0_var)])
#    389
#    390         1      16475.0  16475.0      0.0      dyn_data = np.array([S, I, N, Na, E, Ma, H, I_d_I + I_d_IE, I_d_SE]).T
#    391         1        130.0    130.0      0.0      prim_bias = bias_t #[r_NaM, r_EM]
#    392
#    393         1      36214.0  36214.0      0.0      ts = np.linspace(0, duration, int(steps) + 1)
#    394
#    395                                               # Compute summary statistics from simulations
#    396                                               ## extract primary/secondary infection dynamics
#    397         1       2614.0   2614.0      0.0      pS, pI, N, Na, pE, pM, pH, pI_d_I, pI_d_SE = dyn_data[:,0], dyn_data[:,1], dyn_data[:,2], dyn_data[:, 3], dyn_data[:,4], dyn_data[:,5], dyn_data[:,6], dyn_data[:,7], dyn_data[:,8]
#    398
#    399         1        581.0    581.0      0.0      dt = ts[1]-ts[0]
#    400
#    401         3       7642.0   2547.3      0.0      parameters = np.concatenate((np.array([S_0, I_0, b_I, d_S, d_I, d_IE, K_IE,
#    402         1        200.0    200.0      0.0                b_H, d_H, K_EH,
#    403         1        250.0    250.0      0.0                N_0, max_Na, b_myc, d_myc, myc_thresh]),
#    404         1        110.0    110.0      0.0                char_times,
#    405         1        110.0    110.0      0.0                activation_regulation, NM_regulation, EM_regulation, expansion_regulation))
#    406
#    407         2      12448.0   6224.0      0.0      sim_summary = np.array([np.sum(pI*dt),
#    408         1       9865.0   9865.0      0.0                         np.argmax(pI)*dt,
#    409         1       6780.0   6780.0      0.0                         np.argmax(pI < I_0)*dt,
#    410         1       6019.0   6019.0      0.0                         np.amax(pI_d_I),
#    411         1       4487.0   4487.0      0.0                         np.amax(pI_d_SE),
#    412         1       4848.0   4848.0      0.0                         np.sum(div_E_count),
#    413         1       3245.0   3245.0      0.0                         np.argmax(pE)*dt,
#    414         1     653232.0 653232.0      0.1                         np.mean(np.argmax(E_m > 0 , axis = 0)*dt*(np.amax(E_m, axis = 0) > 0 )) + sim_duration*(np.max(pE) < 1.0),
#    415         1        411.0    411.0      0.0                         pM[-1],
#    416         1        260.0    260.0      0.0                         M_duration if N_0 > 0 else 0.0,
#    417         1       7200.0   7200.0      0.0                         np.sum(pE*dt),
#    418         1       5819.0   5819.0      0.0                         np.sum(pH*dt),
#    419         1       7862.0   7862.0      0.0                         np.amin(pS)])
#    420
#    421                                               # down-size timeseries
#    422         1        651.0    651.0      0.0      pnts = int(0.1*steps)
#    423         1      38147.0  38147.0      0.0      keep = [i*10 for i in np.arange(0,pnts)]
#    424
#    425         1        290.0    290.0      0.0      if out_data == "full":
#    426                                                   out_dict = {"reg_coeffs": np.concatenate((activation_regulation, NM_regulation, EM_regulation, expansion_regulation)), "cell_time_series": dyn_data, "time": ts, "lineage_diff": lineage_comp, "prim_diff_bias": prim_bias, "eff_by_lin": (E_m), "N_myc_by_lin": mycN_m, "Ma_myc_by_lin": mycMa_m, "E_myc_by_lin": mycE_m, "parameters": parameters, "summary_stats": sim_summary, "pmemory_formed": T_pEcytM if N_0 > 0 else []}
#    427         1        150.0    150.0      0.0      elif out_data == "small":
#    428         1      26330.0  26330.0      0.0          out_dict = {"cell_time_series": dyn_data[keep], "prim_diff_bias": prim_bias[keep],"parameters": parameters, "summary_stats": sim_summary}
#    429
#    430         1        100.0    100.0      0.0      return out_dict

# %%
# Run single simulation
# %timeit -n 2 -r 2
data_dict = lin_stoch_sim(N_0 = N_0, b_I = b_I, 
                          K_IE = K_IE,
                          d_I = d_I,
                          K_EH = K_EH,
                          NM_regulation = mem_reg[0:4],
                          EM_regulation = mem_reg[4:],
                          activation_regulation = [0.5*psi_max/2, 1.0*psi_max/2, 0.0*psi_max/2, -1.0*psi_max/2],
                          expansion_regulation = [psi_max/2, psi_max/2, -0.0*psi_max/2, -1.0*psi_max/2],
                          infection = infection_type,
                          vir_model = vir_model,
                          reg_model = 'mwc_like',
                          out_data = "full")

# %%
regs = data_dict["reg_coeffs"]
dyn = data_dict["cell_time_series"]
ts = data_dict["time"]
lin_comp = data_dict["lineage_diff"]
p_diff = data_dict["prim_diff_bias"]
parameters = data_dict["parameters"]
sim_summary = data_dict["summary_stats"]
mycN = data_dict["N_myc_by_lin"]
mycMa = data_dict["Ma_myc_by_lin"]
mycE = data_dict["E_myc_by_lin"]
Eff = data_dict["eff_by_lin"]
T_pEcytM = data_dict["pmemory_formed"]

S, I, N, Na, E, M, H, I_d_I, I_d_S = dyn[:,-9], dyn[:,-8], dyn[:,-7], dyn[:,-6], dyn[:,-5], dyn[:,-4], dyn[:,-3], dyn[:,-2], dyn[:,-1]

reg_string = '-'.join((mem_reg * 1).astype('U4'))

# %%
# Plot simulated immune dynamics
fig, (ax1, ax2, ax3) = plt.subplots(3, dpi = 150, constrained_layout=True, sharex = False, figsize=(5,5))

ax1.plot(ts, S, 'k', label = r'susceptible, $S$')
ax1.plot(ts, I, 'b', label = r'infected, $I$')

ax1.plot(ts, I_d_S, 'r', linestyle = '--', label = r'susceptible killed')
ax1.plot(ts, I_d_I, 'g', linestyle = '--', label = r'infected killed')
ax1.axhline(y = K_EH, color = 'k', linestyle = '--')
ax1.set(ylabel='Cell count')
ax1.set_ylim(1, S_0*2)
ax1.semilogy()
ax1.minorticks_off()
ax1.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

ax2.plot(ts, Na, 'b', label = r'Activated, $N^*$')
ax2.plot(ts, E, 'orange', label = r'Effector, $E$')
ax2.plot(ts, M, 'g', label = r'Memory, $M$')
ax2.plot(ts, S, 'grey', label = r'Susceptible, $S$')
ax2.plot(ts, I, 'r', label = r'infected, $I$')
ax2.set(ylabel='Cell count')
ax2.semilogy()
ax2.minorticks_off()
ax2.set_ylim(1, S_0*2)
ax2.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

ax3.plot(ts, f_XtoY(sig_1 = I, sig_2 = H, psi_1 = psi_max/2, psi_2 = psi_max/2, psi_1_2 = 0, F_0 = 0.0, K_1 = K_IE, K_2 = K_EH),
         'k-', label = r'Regulation, $f(I,H)$')
ax3.set(xlabel=r'Time (days)', ylabel='Regulation')
ax3.minorticks_off()
ax3.set_ylim(0,1.05)

fig.savefig("_figs/"+infection_type+'-'+'virus-effector dynamics-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
plt.plot(ts, N)
plt.ylim(0, 1.1*N_0)
np.mean(np.argmax(Eff >0 , axis = 0)*(ts[1]-ts[0])*(np.amax(Eff, axis = 0) > 0 ))
# Out:
# 5.717833333333334

# %%
plt.plot(ts, np.log((1 + I/K_IE)), 'r')
plt.plot(ts, np.log((1 + H/K_EH)), 'k--')

# %%
plt.plot(ts,d_IE*E/(K_IE + I + E), 'r')
plt.plot(ts, d_IE*E/(K_IE + E), 'k--')

# %%
print(f'Memory fraction = {(np.max(M))/np.max(E)}')
print(f'Number of memory cells = {np.max(M)}')
print(f'1st infection harm = {sim_summary[3]/(d_S*S_0)}')
print(f'1st response toxicity = {sim_summary[4]/(d_S*S_0)}')
print(f'Minimum susceptible = {np.min(S)/S_0}')
# Out:
# Memory fraction = 0.22360810665684785
# Number of memory cells = 14575.0
# 1st infection harm = 4.905558203687736
# 1st response toxicity = 1.625987399408296
# Minimum susceptible = 0.9375230315873135

# %%
# Plot simulated infection dynamics: pretty plots
pnts = 50
keep = [i*int(len(E)/pnts) for i in np.arange(0,pnts)]
sus = S[keep]
naive = Na[keep]
eff = E[keep]
mem = M[keep]
p_load = np.log(1 + I[keep]/K_IE)
inflam = np.log((1 + H[keep]/K_EH))/np.log((1 + S_0/K_EH))
inf_harm = I_d_I[keep]
toxicity = I_d_S[keep]
time = ts[keep]

fig, ax = plt.subplots(figsize=(10.0,5))

ax.plot(time, naive, 'k--')
im = ax.scatter(time, naive, marker ='*', c = p_load, cmap='coolwarm', 
            label = r'Act., $N^*$') #, norm=mpl.colors.LogNorm())

ax.plot(time, eff, 'k--')
ax.scatter(time, eff, marker ='o', c = p_load, cmap='coolwarm', 
            label = r'Eff., $E$') #, norm=mpl.colors.LogNorm())

ax.plot(time, mem, 'k--')
ax.scatter(time, mem, marker ='s', c = p_load, cmap='coolwarm',
            label = r'Mem., $M$') #, norm=mpl.colors.LogNorm())

ax.plot(time, inf_harm, 'r', linewidth = 2.0, label = r'Harm, $\mathcal{H}_I$')

ax.plot(time, toxicity, 'y', linewidth = 2.0,label = r'Toxicity, $\mathcal{H}_S$')

ax.set_box_aspect(1)
cb = fig.colorbar(im, ax=ax, orientation='vertical', shrink = 0.75, pad = 0.05)
cb.set_label('Ag. stimulation', fontsize = 14)
cb.ax.tick_params(labelsize=8)
ax.set_ylabel('Cell count', fontsize = 18)
ax.set_xlabel(r"Time (days)", fontsize = 18)
ax.semilogy()
ax.minorticks_off()
ax.set_ylim(1,)
locmaj = mpl.ticker.LogLocator(numticks=4)
ax.yaxis.set_major_locator(locmaj)

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        ax.axvline(x=time[i], linestyle='-', linewidth=5.5, color='pink', alpha=inflam[i], label =r"Infam. stim.", zorder = 0)
    else:
        ax.axvline(x=time[i], linestyle='-', linewidth=5.5, color='pink', alpha=inflam[i], zorder = 0)

ax.legend(loc='center right', bbox_to_anchor=(1.8, 0.7), fontsize = 12)

plt.savefig('_figs/'+infection_type+'-timeline-of-infection-dynamics-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
# Plot simulated infection dynamics: pretty plots of harm
pnts = 150
keep = [i*int(len(E)/pnts) for i in np.arange(0,pnts)]

eff = E[keep]
p_load = I[keep]/S_0
sus = S[keep]/S_0
inf_harm = I_d_I[keep]/S_0
inflam_harm = I_d_S[keep]/S_0
inflam = np.log((1 + H[keep]/K_EH))/np.log((1 + S_0/K_EH))
time = ts[keep]

plt.scatter(time, p_load, marker ='s', c =eff/K_IE, cmap='coolwarm', 
            label = r'Infected cells, $I$') #, norm=mpl.colors.LogNorm())
plt.plot(time, p_load, 'k--')

plt.scatter(time, sus, marker ='>', c =eff/K_IE, cmap='coolwarm', 
            label = r'Susceptible cells, $S$') #, norm=mpl.colors.LogNorm())
plt.plot(time, sus, 'k--')

plt.scatter(time, inf_harm, marker ='o', c =eff/K_IE, cmap='coolwarm', 
            label = 'Infected cells killed')
plt.plot(time, inf_harm, 'k--')

plt.scatter(time, inflam_harm, marker ='*', c =eff/K_IE, cmap='coolwarm',
            label = 'Susceptible cells killed')
plt.plot(time, inflam_harm, 'k--')

plt.colorbar(label = "Primary effector response")
plt.ylabel('Cell count \n (fraction of initial susceptible cells)', fontsize = 14)
plt.xlabel(r"Time, $t$ (days)", fontsize = 14)

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        plt.axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], label =r"Inflammation, $H$", zorder = 0)
    else:
        plt.axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        
plt.legend(loc='center right', bbox_to_anchor=(1.85, 0.8), fontsize = 10)
plt.savefig('_figs/'+infection_type+'-infection-harm-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
# Plot simulated infection dynamics: pretty plots
pnts = 150
keep = [1 + i*int(len(E)/pnts) for i in np.arange(0,pnts)]
bias_diff = p_diff[keep] if infection_type == "prim" else s_diff[keep]
p_load = I[keep]/S_0
sus = S[keep]
inflam =  np.log((1 + H[keep]/K_EH))/np.log((1 + S_0/K_EH))
time = ts[keep]

fig, axs = plt.subplots(2,2, figsize=(7,7))

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0, label =r"Inflammation, $H$")
    else:
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0, label =r"Inflammation, $H$")

im1 = axs[0,0].scatter(time, bias_diff[:,0], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$N \longrightarrow N^*$')
axs[0,0].plot(time, bias_diff[:,0],'k--')
axs[0,0].title.set_text(r'$N \longrightarrow N^*$')
axs[0,0].set_box_aspect(1)

im2 = axs[0,1].scatter(time, bias_diff[:,1], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$N^* \longrightarrow M$')
axs[0,1].plot(time, bias_diff[:,1],'k--')
axs[0,1].title.set_text(r'$N^* \longrightarrow M$')
axs[0,1].set_box_aspect(1)

im3 = axs[1,0].scatter(time, bias_diff[:,2], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$E \longrightarrow M$')
axs[1,0].plot(time, bias_diff[:,2],'k--')
axs[1,0].title.set_text(r'$E \longrightarrow M$')
axs[1,0].set_box_aspect(1)

im4 = axs[1,1].scatter(time, bias_diff[:,3], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$E \longrightarrow M$')
axs[1,1].plot(time, bias_diff[:,3],'k--')
axs[1,1].title.set_text(r'$E \longrightarrow E + E$')
axs[1,1].set_box_aspect(1)

axs[0,0].set_ylabel('Rate [day$^{-1}$]', fontsize = 14)
axs[1,0].set_ylabel('Rate [day$^{-1}$]', fontsize = 14)
axs[1,0].set_xlabel("Time (days)", fontsize = 14)
axs[1,1].set_xlabel("Time (days)", fontsize = 14)

fig.subplots_adjust(wspace=.4, hspace = 0.1)
cb = fig.colorbar(im1, ax=axs, shrink = 0.5, pad = 0.05, orientation='vertical')
cb.set_label('Fraction infected,'+ r'$\frac{I}{S_0}$')

#cb.set_clim(-0.4,0.4)
    
# plt.colorbar(label =r"pathogen load, $I(t)$")
# plt.ylabel('transition weight', fontsize = 16)
# plt.xlabel("time (days)", fontsize = 16)
# plt.legend() #bbox_to_anchor=(1.05, 1.0), loc='upper left')

plt.savefig('_figs/'+infection_type+'-diff-bias-over-time-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %% [markdown]
# ### (2) Plot lineage-based trajectories

# %%
keys = np.array(['Memory', 'Effector'])
all_counts = lin_comp[1:3].T
effector_ranking = np.argsort(all_counts[:, 1])[::-1]
all_counts = all_counts[effector_ranking]
total_counts = all_counts.sum(axis=1)
norm_counts = all_counts / total_counts[:, None]
norm_counts[~np.isfinite(norm_counts)] = 0
comp_argsort = np.argsort(np.max(all_counts, axis=0))
bar_dict = {k: v for k, v in zip(keys[comp_argsort], norm_counts.T[comp_argsort])}
lineage_idxs = np.arange(all_counts.shape[0])

fig, ax = plt.subplots()
bottom = np.zeros(len(lineage_idxs))
cmap_colors = sns.color_palette('Set2', 10)
cmap_colors = [cmap_colors[i]
               for i in [0, 1, 5]]#[7, 2, 0, 1, 5]]
# cmap_colors = [cmap_colors[i]
#                for i in [6, 1, 2, 5, 0]]
width = 1

for i, (celltype, fraction) in enumerate(bar_dict.items()):
    ax.bar(lineage_idxs, fraction, width,
           edgecolor='k', linewidth=0.01,
           label=celltype, bottom=bottom, color=cmap_colors[i])
    bottom += fraction
    
ax.legend(loc='center right', bbox_to_anchor=(1.4, 0.5), fontsize = 12)
ax.set_xlim(-0.5, len(all_counts) - 0.5)
ax.set_xlabel('sub-clone lineages \n (ranked by effector response)', fontsize = 15)
ax.set_ylabel('fractional cell-fate \ncomposition', fontsize = 15)
#ax.set_yscale('log')

ax.set_xticks(np.arange(0, Eff.shape[1], int(Eff.shape[1]/10)))
ax.set_xticklabels(1 + np.arange(0, Eff.shape[1], int(Eff.shape[1]/10)), fontsize=9)

ax.set_yticks(np.round(np.arange(0, 1.2, 0.2), 1))
ax.set_yticklabels(ax.get_yticks(), fontsize=12)

fig.savefig("_figs/"+infection_type+'-'+'fates-by-lin-'+reg_string+'.png', dpi=150, bbox_inches="tight")
# Out:
# /tmp/ipykernel_20274/3021603312.py:6: RuntimeWarning: invalid value encountered in divide
#   norm_counts = all_counts / total_counts[:, None]

# %%
plt.errorbar(ts, np.mean(Eff, axis = 1), yerr = np.std(Eff, axis = 1), errorevery = 100)
plt.semilogy()
# Out:
# []

# %%
plt.plot(ts, mycN, 'r--')
plt.errorbar(ts, np.mean(mycN, axis = 1), yerr = np.std(mycN, axis = 1), errorevery = 100)
#plt.plot(ts, mycMa, 'k-')
plt.axhline(y = myc_thresh, color = 'k', linestyle = '--')
print(np.sum(np.max(mycE, axis=0) < myc_thresh)/N_0)
# Out:
# 0.15

# %%
#plt.hist(np.argmax(mycNa > 0, axis = 0)*sim_duration/sim_steps, bins='auto')
plt.hist(T_pEcytM, bins='auto', histtype='step');
# plt.hist(T_sEcytM, bins='auto', histtype='step');

# %%
# Compute max values in the data
r = np.arange(5)
width = 0.5
plt.bar(r, np.amax(np.array([I, Na, E, M, H]).T, axis = 0), width = width)

plt.xlabel("response")
plt.ylabel("value")

plt.xticks(r, ["Infected","Naive","Effector","Memory", "Inflammation"], fontsize = 7)

plt.semilogy()
plt.suptitle(r'Peak response response: $N_0=$ '+str(N_0) +r', $d_I=$'+str(d_I))
# Out:
# Text(0.5, 0.98, 'Peak response response: $N_0=$ 300, $d_I=$1.25')

# %%
bias_1 = f_XtoY(I, H, 
       -2.0, -2.0, 0.0, F_0 = 4*np.log(2), 
       K_I = K_IE, K_H = K_EH)
bias_2 = f_XtoY(I, H, 
       -2.0, 2.0, 0.0, F_0 = -0*np.log(2), 
       K_I = K_IE, K_H = K_EH)

plt.plot(ts, bias_1, 'r')
plt.plot(ts, bias_2, 'k--')
plt.plot(ts, Na/np.amax(Na))
plt.plot(ts, A/(Na + A))
plt.plot(ts, H**l_H/(K_EH**l_H + H**l_H))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 bias_1 = f_XtoY(I, H,
#       2        -2.0, -2.0, 0.0, F_0 = 4*np.log(2),
#       3        K_I = K_IE, K_H = K_EH)
#       4 bias_2 = f_XtoY(I, H,
#       5        -2.0, 2.0, 0.0, F_0 = -0*np.log(2),
#       6        K_I = K_IE, K_H = K_EH)
#       8 plt.plot(ts, bias_1, 'r')
#
# TypeError: f_XtoY() got an unexpected keyword argument 'K_I'

# %%
d="/gscratch/scrubbed/oukogu/infoimmune/sim_output/no_cell_var/raw/"
comment = "auto-sparse-reg"
runs = 1

run(batch = [0.0], outdir=d, comment=comment, runs = runs, num_cpu = 160, run_time = 10.0)

# %%
d_file = '/gscratch/scrubbed/oukogu/infoimmune/sim_output/no_cell_var/raw/sim_batch_0.0-'+str(runs)+'-prim-'+comment+'.pkl'
with open(d_file, 'rb') as f:   
    out = pickle.load(f)
