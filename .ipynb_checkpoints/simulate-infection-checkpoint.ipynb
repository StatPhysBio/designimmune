# %% [markdown]
# # Run infection dynamics with monoclonal killer T cell response

# %%
import numpy as np
from matplotlib.cm import get_cmap
import matplotlib.pyplot as plt
import matplotlib as mpl

import multiprocessing as mp
from tqdm import tqdm
from joblib import Parallel, delayed
from scipy import stats
import os
import seaborn as sns
from stoch_sim_model import *
from optimize_nets import *

plt.style.use('custom.mplstyle')
# %config InlineBackend.figure_format = 'retina'
# %load_ext line_profiler

# %%
avg_sim_time = 2.0/(60*60) # 1.6/(60*60)

print('full-reg:',(len(psi_2d_nobias)**4)*len(infection_sample_select),
      np.ceil((len(psi_2d_nobias)**4*len(infection_sample_select))/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('prim-Nact-Ediv:',len(psi_2d)*len(psi_2d)*len(infection_sample_select), 
      np.ceil((len(psi_2d)*len(psi_2d)*len(infection_sample_select))/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('auto-sparse-reg:',len(psi_2d_sparse)*len(auto_sample), 
      np.ceil((len(psi_2d_sparse)*len(auto_sample))/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('cancer-sparse-reg:',len(psi_2d_sparse)*len(cancer_sample), 
      np.ceil((len(psi_2d_sparse)*len(cancer_sample))/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')

print('sparse-reg:', len(psi_2d_sparse)*len(infection_sample_select),
      np.ceil(len(psi_2d_sparse)*len(infection_sample_select)/(num_cpu*run_time/avg_sim_time)), 
      str(int(1.0/avg_sim_time)) + ' jobs per cpu per hour')
# Out:
# full-reg: 6581250 37.0 1800 jobs per cpu per hour
# prim-Nact-Ediv: 731250 5.0 1800 jobs per cpu per hour
# auto-sparse-reg: 1562500 9.0 1800 jobs per cpu per hour
# cancer-sparse-reg: 7812500 44.0 1800 jobs per cpu per hour
# sparse-reg: 40625000 226.0 1800 jobs per cpu per hour

# %% [markdown]
# ### (1) Plot population averaged trajectories

# %%
# Set simulation parameters
N_0 = 300
K_IE = (1)*(10**5)
d_I = 50*d_S # d_S #
b_I = 1.5*(10**(-7)) # 1.50*(10**(-7)) # b_C
I_0 = 1*I_0  # 0.1*S_0 # I_0

infection_model = 'acute' #'acute', 'autoimmune', 'cancer'
Na_regulation = [psi_max, psi_max, -psi_max, -0.5*F0_max]
NE_regulation = [psi_max, psi_max, -psi_max, 1.0*F0_max]
EM_regulation = [-psi_max, -psi_max, 1*psi_max, -1.0*F0_max]
EE_regulation = [psi_max, psi_max, -psi_max, -0.0*F0_max]

# %%
# %lprun -T lprof0 -f lin_stoch_sim lin_stoch_sim(N_0 = 300, b_I = b_I, K_IE = K_IE, d_I = d_I, K_EH = K_EH, \
                                                NE_regulation = NE_regulation, \
                                                EM_regulation = EM_regulation, \
                                                activation_regulation = Na_regulation, \
                                                expansion_regulation = EE_regulation)
# Out:
# *** Profile printout saved to text file 'lprof0'.
# Timer unit: 1e-09 s
#
# Total time: 22.0684 s
# File: /mmfs1/home/oukogu/infoimmune/stoch_sim_model.py
# Function: lin_stoch_sim at line 191
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    191                                           def lin_stoch_sim(S_0 = S_0, I_0 = I_0, b_I = b_I, d_S = d_S, d_I = d_I, d_IE = d_IE, K_IE = K_IE, K_SE = K_SE,
#    192                                                             b_H = b_H, d_H = d_H, K_EH = K_EH,
#    193                                                             N_0 = N_0, max_Na = max_Na, b_myc = b_myc, d_myc = d_myc, myc_thresh = myc_thresh, max_expand = max_expand,
#    194                                                             char_times = [t_bind, t_unbind, t_Na_div, t_E_div, t_M_div, t_E_die, t_act],
#    195                                                             NE_regulation = NE_psis,
#    196                                                             EM_regulation = EM_psis,
#    197                                                             activation_regulation = act_psis,
#    198                                                             expansion_regulation = exp_psis,
#    199                                                             infection_model = "acute",
#    200                                                             duration = sim_duration,
#    201                                                             steps = sim_steps,
#    202                                                             reg_model = "mwc_like",
#    203                                                             out_data = "small",
#    204                                                             seed = None):
#    205         1     223264.0 223264.0      0.0      rng = np.random.default_rng(seed)
#    206
#    207         1        250.0    250.0      0.0      if reg_model == 'mwc_like':
#    208         1       1252.0   1252.0      0.0          f_XtoY = f_XtoY_mwc_like
#    209                                               elif reg_model == 'competition_model':
#    210                                                   f_XtoY = f_XtoY_competition
#    211                                               else:
#    212                                                   f_XtoY = f_XtoY_ret0
#    213                                               # VARIABLE DEFINITIONS:
#    214                                               # S_0 := S_0, I_0 := I_0, b_S := b_S, b_I := b_I, d_S := d_S, d_I := d_I, d_IE := d_IE, K_IE := K_IE,
#    215                                               # b_H := b_H, d_H := d_H, K_EH := K_EH,
#    216                                               # N_0 := N_0, max_Na := max_Na, b_myc := b_myc, d_myc := d_myc, myc_thresh := myc_thresh,
#    217                                               # char_times := [t_bind, t_unbind, t_Na_div, t_E_div, t_M_div, t_EM_diff, t_E_die, t_Na],
#    218
#    219                                               #################################
#    220                                               ### SET META-VARIABLES FOR SIMULATION ###
#    221                                               #################################
#    222         1        601.0    601.0      0.0      dt =  duration/steps
#    223         1        411.0    411.0      0.0      N_0_var = int(N_0)
#    224         1        831.0    831.0      0.0      b_S = S_0*d_S
#    225
#    226                                               # draw population of reponding cells for agent-based simulations
#    227         1       1061.0   1061.0      0.0      psi_Na_I, psi_Na_H, psi_Na_P, F0_Na = activation_regulation[0], activation_regulation[1], activation_regulation[2], activation_regulation[3]
#    228         1        811.0    811.0      0.0      psi_NE_I, psi_NE_H, psi_NE_P, F0_NE = NE_regulation[0], NE_regulation[1], NE_regulation[2], NE_regulation[3]
#    229         1        991.0    991.0      0.0      psi_EM_I, psi_EM_H, psi_EM_P, F0_EM = EM_regulation[0], EM_regulation[1], EM_regulation[2], EM_regulation[3]
#    230         1        701.0    701.0      0.0      psi_EE_I, psi_EE_H, psi_EE_P, F0_EE = expansion_regulation[0], expansion_regulation[1], expansion_regulation[2], expansion_regulation[3]
#    231
#    232         1        320.0    320.0      0.0      p_tcr = 1.0 #np.ones(N_0_var)
#    233         1        290.0    290.0      0.0      p_cyt = 1.0 #np.ones(N_0_var)
#    234
#    235         1        461.0    461.0      0.0      int_steps = int(steps)
#    236
#    237                                               # define variables for storage
#    238         1       5768.0   5768.0      0.0      I = np.zeros(int_steps+1)
#    239         1       1853.0   1853.0      0.0      S = np.zeros(int_steps+1)
#    240         1      14762.0  14762.0      0.0      H = np.zeros(int_steps+1)
#    241         1       2553.0   2553.0      0.0      P = np.zeros(int_steps+1)
#    242         1       1823.0   1823.0      0.0      I_d_I = np.zeros(int_steps+1)
#    243         1       2164.0   2164.0      0.0      I_d_IE = np.zeros(int_steps+1)
#    244         1       1662.0   1662.0      0.0      S_d_SE = np.zeros(int_steps+1)
#    245
#    246         1     164176.0 164176.0      0.0      N_m = np.zeros((int_steps+1, N_0_var), dtype = np.int32)
#    247         1      34151.0  34151.0      0.0      N_m[0,:] +=1
#    248         1      46680.0  46680.0      0.0      T_Ecyt = [[] for i in np.arange(0, N_0_var)]
#    249         1     118227.0 118227.0      0.0      survive_M = [[] for i in np.arange(0, N_0_var)]
#    250                                               # T_Ecyt = np.zeros(int_steps+1, dtype = np.int32)
#    251
#    252         1      16514.0  16514.0      0.0      div_count = np.ones(N_0_var)
#    253         1       1422.0   1422.0      0.0      div_E_count = np.zeros(N_0_var)
#    254         1       1092.0   1092.0      0.0      div_M_count = np.zeros(N_0_var)
#    255         1       1062.0   1062.0      0.0      diff_EpM_count = np.zeros(N_0_var, dtype = np.int32)
#    256         1       2964.0   2964.0      0.0      die_M = np.zeros(N_0_var, dtype = np.int32)
#    257
#    258         1     296644.0 296644.0      0.0      Na_m = np.zeros((int_steps+1, N_0_var), dtype = np.int32)
#    259         1     929871.0 929871.0      0.0      Ma_m = np.zeros((int_steps+1, N_0_var), dtype = np.int32)
#    260         1      54051.0  54051.0      0.0      E_m = np.zeros((int_steps+1, N_0_var), dtype = np.int32) # effector in periphary
#    261         1       1242.0   1242.0      0.0      T_E = np.zeros(N_0_var)
#    262
#    263         1        601.0    601.0      0.0      if out_data == "full":
#    264                                                   mycN_m = np.zeros((int_steps+1, N_0_var))
#    265                                                   mycMa_m = np.zeros((int_steps+1, N_0_var))
#    266                                                   mycE_m = np.zeros((int_steps+1, N_0_var))
#    267
#    268         1       5558.0   5558.0      0.0      bias_t = np.zeros((int_steps+1, 4))
#    269
#    270                                               # Define event timer variables
#    271         1        811.0    811.0      0.0      bound_N = np.zeros(N_0_var, dtype =np.int32)
#    272         1        591.0    591.0      0.0      bound_N_time = np.zeros(N_0_var)
#    273         1       7502.0   7502.0      0.0      Na_div_flag = np.ones(N_0_var, dtype =np.int32)
#    274         1       2904.0   2904.0      0.0      Na_flag = np.ones(N_0_var, dtype =np.int32)
#    275
#    276         1        901.0    901.0      0.0      mycN = np.zeros(N_0_var)
#    277         1       1071.0   1071.0      0.0      mycE = np.zeros(N_0_var)
#    278         1       3435.0   3435.0      0.0      mycMa = np.zeros(N_0_var)
#    279
#    280         1      51988.0  51988.0      0.0      r_NaE = np.zeros((int_steps+1, N_0_var))
#    281         1      51787.0  51787.0      0.0      r_EM = np.zeros((int_steps+1, N_0_var))
#    282         1      50556.0  50556.0      0.0      r_Na = np.zeros((int_steps+1, N_0_var))
#    283         1      51958.0  51958.0      0.0      r_EE = np.zeros((int_steps+1, N_0_var))
#    284         1       1001.0   1001.0      0.0      cum_r_NaE = np.zeros(N_0_var)
#    285
#    286         1        791.0    791.0      0.0      b_unbind_t = np.zeros(N_0_var)
#    287         1        721.0    721.0      0.0      b_N_bind = np.zeros(N_0_var)
#    288         1      13731.0  13731.0      0.0      b_Na_div = np.ones(N_0_var)/char_times[2]
#    289         1        601.0    601.0      0.0      b_myc_t = np.zeros(N_0_var)
#    290         1       5268.0   5268.0      0.0      b_E_div = np.ones(N_0_var)/char_times[3]
#    291         1       3786.0   3786.0      0.0      b_Ma_div = np.ones(N_0_var)/char_times[4]
#    292         1       5608.0   5608.0      0.0      d_E_die = np.ones(N_0_var)/char_times[5]
#    293
#    294                                               #################################
#    295                                               ### RUN POPULATION SIMULATION ###
#    296                                               #################################
#    297         1        340.0    340.0      0.0      t = 0.0
#    298         1       1472.0   1472.0      0.0      S[0] = S_0
#    299         1        210.0    210.0      0.0      I[0] = I_0
#    300         1        441.0    441.0      0.0      H[0] = 0.0
#    301         1        191.0    191.0      0.0      P[0] = 0.0
#    302
#    303         1        141.0    141.0      0.0      sum_e_m = 0
#    304
#    305      2501     626482.0    250.5      0.0      for i in np.arange(1, int_steps + 1):
#    306                                                   # select virulence model:
#    307      2500    1327142.0    530.9      0.0          if (b_I > 0 and I_0 <= S_0/1000) or infection_model == 'acute': # "acute"
#    308      2500     410859.0    164.3      0.0              b_I_t = b_I
#    309      2500     384485.0    153.8      0.0              d_Sauto = 0.0
#    310      2500     370619.0    148.2      0.0              infection_model = 'acute'
#    311                                                   elif (b_I > 0 and I_0 > S_0/1000) or infection_model == 'cancer': # "cancer"
#    312                                                       b_I_t = b_I/S_0
#    313                                                       d_Sauto = 0.0
#    314                                                       infection_model = 'cancer'
#    315                                                   elif b_I == 0 or infection_model == 'autoimmune': # "autoimmune"
#    316                                                       b_I_t = 0.0
#    317                                                       d_Sauto = d_I
#    318                                                       K_SE = K_IE
#    319                                                       I_0 = 0.0
#    320                                                       infection_model = 'autoimmune'
#    321                                                   else:
#    322                                                       b_I_t = b_I
#    323                                                       d_Sauto = 0
#    324
#    325                                                   # Compute total population of cell types
#    326                                                   # Use sum computed in previous iteration.
#    327      2500     471911.0    188.8      0.0          E_pop = sum_e_m
#    328
#    329                                                   #### Run infection dynamics: replication and effector clearance ####
#    330
#    331                                                   # Update state of susceptible, infected and inflammation
#    332                                                   # (a) event variables
#    333      2500    4078904.0   1631.6      0.0          S_to_I = dt * S[i - 1] * (I[i - 1] >= I_0) * b_I_t * I[i - 1] * (S[i - 1] >= 1.0)
#    334      2500    4153393.0   1661.4      0.0          I_d_IE[i] += I_d_IE[i - 1] + dt * I[i - 1] * d_IE * E_pop / (K_IE + I[i - 1] + E_pop) # infected/cancer cells killed by immune response
#    335      2500    2549543.0   1019.8      0.0          I_d_I[i] += I_d_I[i - 1] + dt * I[i - 1]*d_I*(infection_model == "acute") # cells killed by infection
#    336      2500    3930134.0   1572.1      0.0          S_d_SE[i] += S_d_SE[i - 1] + dt * S[i - 1] * (d_IE * E_pop / (K_SE + S[i - 1] + E_pop)) # susceptible cells killed by immune response
#    337
#    338                                                   # (b) state variables
#    339      7500    3042606.0    405.7      0.0          S[i] += S[i - 1] - S_to_I + dt * (
#    340      5000    5384127.0   1076.8      0.0              b_S - (d_S + (d_Sauto / t_Hauto) * np.exp(-(t / t_Hauto)**2 / 2)) * S[i - 1]
#    341      2500    1034230.0    413.7      0.0              - (S_d_SE[i] - S_d_SE[i - 1])
#    342      2500     814296.0    325.7      0.0          ) * (S[i - 1] >= 1.0)
#    343
#    344      2500    3116182.0   1246.5      0.0          I[i] += I[i - 1] + S_to_I - (I_d_IE[i] + I_d_I[i] - I_d_IE[i - 1] - I_d_I[i - 1])
#    345
#    346      2500    4837744.0   1935.1      0.0          harm_detected = (I_d_I[i] - I_d_I[i - 1]) + dt * S[i - 1] * (d_Sauto / t_Hauto) * np.exp(-(t / t_Hauto)**2 / 2) + S_to_I * (infection_model == "cancer")
#    347      2500    1895143.0    758.1      0.0          immunopathology = (S_d_SE[i] - S_d_SE[i - 1]) + (I_d_IE[i] - I_d_IE[i - 1])
#    348      2500    1735667.0    694.3      0.0          cells_sensed = I[i - 1] + (S[i - 1] * K_IE / K_SE)
#    349
#    350      2500    3287228.0   1314.9      0.0          H[i] += H[i - 1] + b_H * harm_detected - dt * d_H * H[i - 1] * (H[i - 1] >= 0.0)
#    351
#    352      2500    2745451.0   1098.2      0.0          P[i] += P[i - 1] + b_H * immunopathology - dt * d_H * P[i - 1] * (P[i - 1] >= 0.0)
#    353
#    354                                                   ## I. Recruitment/Priming
#    355
#    356                                                   # (a) Phase 1: Naive cells encounter and bind APCs
#    357      2500     498895.0    199.6      0.0          if cells_sensed >= 1:
#    358      2500   95712869.0  38285.1      0.4              bound_N += rng.binomial(N_m[i - 1], b_N_bind * dt) - rng.binomial(N_m[i - 1], b_unbind_t * dt)
#    359                                                   else:
#    360                                                       bound_N = 0
#    361
#    362      2500   16645018.0   6658.0      0.1          bound_N_time += dt * (bound_N - (1 - bound_N) * bound_N_time * N_m[i - 1]) # only reset to zero if the cell is not activated
#    363
#    364                                                   # (b) Phase 2: Activated naive cells are bound to APCs and receive stimulation.
#    365      2500   14791414.0   5916.6      0.1          act_N = (1 - bound_N) * (mycN >= myc_thresh) * (N_m[i - 1] > 0)
#    366
#    367                                                   # (c) Phase 3: Unbound activated naive cells divide and then differentiate
#    368      2500   30814743.0  12325.9      0.1          div_Na = rng.binomial(Na_m[i - 1] * Na_div_flag, dt * b_Na_div)
#    369
#    370      5000   25953147.0   5190.6      0.1          diff_NaE = rng.binomial(
#    371      2500    7369234.0   2947.7      0.0              Na_m[i - 1] * (1 - Na_div_flag),
#    372      2500   16346564.0   6538.6      0.1              1 - np.exp(-cum_r_NaE*dt) if np.sum(Na_m[i - 1]) > 0 else 0
#    373                                                   )
#    374
#    375                                                   ## II. Expansion
#    376
#    377                                                   # (a) New central memory cells divide
#    378      2500   35446244.0  14178.5      0.2          div_Ma = rng.binomial(Ma_m[i - 1] - diff_EpM_count, dt * b_Ma_div)
#    379
#    380                                                   # (b) Effector cells divide, differentiate, die
#    381      2500   39404068.0  15761.6      0.2          die_E = rng.binomial(E_m[i - 1], d_E_die * dt)
#    382      2500   41185210.0  16474.1      0.2          diff_EM = rng.binomial(E_m[i - 1] - die_E, dt * r_EM[i - 1])
#    383      2500   37648313.0  15059.3      0.2          div_E = rng.binomial(E_m[i - 1] - die_E - diff_EM, dt * b_E_div)
#    384      2500    7839902.0   3136.0      0.0          diff_EpM_count += diff_EM - die_M
#    385
#    386                                                   #### Update population dynamics: ####
#    387      2500    5316677.0   2126.7      0.0          N_m[i] += N_m[i - 1] - act_N
#    388      2500   18226478.0   7290.6      0.1          Na_m[i] += Na_m[i - 1] + div_Na + act_N - (1 - Na_div_flag) * Na_m[i - 1]
#    389
#    390      2500   20906959.0   8362.8      0.1          Ma_m[i] += Ma_m[i - 1] + div_Ma + (1 - Na_div_flag)*(Na_m[i - 1] - diff_NaE) + diff_EM - die_M
#    391      2500   17253217.0   6901.3      0.1          E_m[i] += E_m[i - 1] + div_E + (1 - Na_div_flag) * diff_NaE - (die_E + diff_EM)
#    392
#    393                                                   # Evaluate sums and create masks
#    394      2500   12565144.0   5026.1      0.1          sum_n_m = np.sum(N_m[i])
#    395      2500   11407901.0   4563.2      0.1          sum_e_m = np.sum(E_m[i])
#    396      2500    4185700.0   1674.3      0.0          e_m_nonzero_mask = E_m[i] > 0
#    397      2500    3428820.0   1371.5      0.0          n_m_nonzero_mask = N_m[i] > 0
#    398      2500    3282235.0   1312.9      0.0          na_m_nonzero_mask = Na_m[i] > 0
#    399      2500    5669034.0   2267.6      0.0          ma_m_nonzero_mask = Ma_m[i] + Ma_m[i-1]> 0
#    400      2500    2264220.0    905.7      0.0          n_na_sum_nonzero_mask = n_m_nonzero_mask | na_m_nonzero_mask
#    401
#    402                                                   # store time cells spend in effector effector
#    403      2500    4673951.0   1869.6      0.0          T_E += dt * e_m_nonzero_mask if sum_e_m > 0 else 0.0
#    404      2500   11640940.0   4656.4      0.1          d_E_die = 0.5 * np.sqrt(np.pi) * e_m_nonzero_mask * T_E / char_times[5]**2
#    405      2500    4190750.0   1676.3      0.0          die_M = 0*die_M
#    406
#    407                                                   # store time an effector spends in cytotoxic state
#    408      2500   15017304.0   6006.9      0.1          for_where = ((1 - Na_div_flag)*(Na_m[i-1] - diff_NaE) + div_Ma + diff_EM + ma_m_nonzero_mask > 0)
#    409      2500    6740400.0   2696.2      0.0          where_output = np.where(for_where)[0]
#    410    398952   72143200.0    180.8      0.3          for l in where_output:
#    411
#    412    396452  559547125.0   1411.4      2.5              if Ma_m[i-1,l] > 0:
#    413    396063 4622840746.0  11672.0     20.9                  T_Ecyt[l] = list(itertools.compress(T_Ecyt[l], survive_M[l]))
#    414
#    415    396452 1171272266.0   2954.4      5.3              T_Ecyt[l] += ((1 - Na_div_flag[l])*(Na_m[i-1,l] - diff_NaE[l]) + div_Ma[l]) * [0.0] + diff_EM[l] * [T_E[l].item()]
#    416
#    417                                                       # if Ma_m[i,l] != len(T_Ecyt[l]) or Ma_m[i,l] < 0 or Ma_m[i-1,l] != len(survive_M[l]):
#    418                                                       #     print(Ma_m[i,l], Ma_m[i-1,l], div_Ma[l], (1 - Na_div_flag[l])*(Na_m[i-1,l] - diff_NaE[l]), diff_EM[l], die_M[l], survive_M[l], T_Ecyt[l])
#    419
#    420    396452 7074460663.0  17844.4     32.1              arr = np.array(T_Ecyt[l])
#    421    396452 5002688391.0  12618.6     22.7              survive_M[l] = (rng.random(size = Ma_m[i,l]) > (arr > 0)*dt/memory_lifespan(arr, min_time = dt)) if Ma_m[i,l] > 0 else []
#    422    396452 2566632775.0   6474.0     11.6              die_M[l] = Ma_m[i,l] - np.sum(survive_M[l]) if Ma_m[i,l] > 0 else 0
#    423
#    424                                                   # Update division flag to allow division to proceed
#    425      2500    7180409.0   2872.2      0.0          Na_div_flag = (Na_m[i] < max_Na)*(na_m_nonzero_mask)
#    426      2500    7965359.0   3186.1      0.0          div_count += div_Na + div_E + div_Ma
#    427      2500    3111559.0   1244.6      0.0          div_E_count += div_E
#    428      2500    2943703.0   1177.5      0.0          div_M_count += div_Ma
#    429
#    430                                                   #### New binding events ####
#    431      7500   30402604.0   4053.7      0.1          b_N_bind = (n_m_nonzero_mask) * (1 - bound_N) * f_XtoY(
#    432      2500    2152868.0    861.1      0.0              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i],
#    433      2500    4791517.0   1916.6      0.0              psi_1 = 0.0, psi_2 = psi_max, psi_3 = 0.0, F_0 = -psi_max*np.log(2), K_1 = S_0, K_2 = K_EH, K_3 = K_EH
#    434      5000    1842980.0    368.6      0.0          ) / (char_times[0] if infection_model != "autoimmune" else t_bind_eM) if cells_sensed >= 1 else 0.0
#    435
#    436      3908    4339548.0   1110.4      0.0          b_unbind_t = bound_N * np.fmin(
#    437      2816    4163509.0   1478.5      0.0              2 * bound_N_time / (
#    438      7040    6595138.0    936.8      0.0                  f_XtoY(
#    439      1408     766655.0    544.5      0.0                      sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i],
#    440      1408    1719396.0   1221.2      0.0                      psi_1 = psi_max, psi_2 = 0.0,psi_3 = 0.0, F_0 = -psi_max*np.log(2),
#    441      1408     466022.0    331.0      0.0                      K_1 = (K_IE*(infection_model != "autoimmune") + K_SE*(infection_model == "autoimmune")),
#    442      1408     153787.0    109.2      0.0                      K_2 = K_EH, K_3 = K_EH
#    443      4224    1722318.0    407.7      0.0                  ) * char_times[1] * 2 / np.sqrt(np.pi)
#    444      2816     441699.0    156.9      0.0              )**2, 1 / dt
#    445      2500   12794760.0   5117.9      0.1          ) if np.sum(bound_N) >= 1 else 0.0
#    446
#    447      7500   15540076.0   2072.0      0.1          b_myc_t = b_myc * f_XtoY(
#    448      2500    1492901.0    597.2      0.0              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i],
#    449      2500     380114.0    152.0      0.0              psi_1 = psi_Na_I, psi_2 = psi_Na_H, psi_3 = psi_Na_P, F_0 = F0_Na,
#    450      2500     877211.0    350.9      0.0              K_1 = (K_IE*(infection_model != "autoimmune") + K_SE*(infection_model == "autoimmune")),
#    451      2500     261949.0    104.8      0.0              K_2 = K_EH, K_3 = K_EH
#    452      2500     267497.0    107.0      0.0          ) * bound_N
#    453
#    454                                                   #### MYC Dynamics ####
#    455     15000   34128475.0   2275.2      0.2          mycN = (mycN + dt * (b_myc_t - (1 - bound_N) * f_XtoY(
#    456      2500    1302251.0    520.9      0.0              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i],
#    457      2500     538572.0    215.4      0.0              psi_1 = -psi_EE_I, psi_2 = -psi_EE_H, psi_3 = -psi_EE_P, F_0 = -F0_EE,
#    458      2500     701777.0    280.7      0.0              K_1 = (K_IE*(infection_model != "autoimmune") + K_SE*(infection_model == "autoimmune")),
#    459      2500     272149.0    108.9      0.0              K_2 = K_EH, K_3 = K_EH
#    460     10000    4213617.0    421.4      0.0          ) * mycN * d_myc * (mycN > 0))) * n_na_sum_nonzero_mask # (1 - bound_N)*
#    461
#    462     15000   24887738.0   1659.2      0.1          mycE = (mycE - dt * (f_XtoY(
#    463      2500    1498993.0    599.6      0.0              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i],
#    464      2500     627518.0    251.0      0.0              psi_1 = -psi_EE_I, psi_2 = -psi_EE_H, psi_3 = -psi_EE_P, F_0 = -F0_EE,
#    465      2500     807847.0    323.1      0.0              K_1 = (K_IE*(infection_model != "autoimmune") + K_SE*(infection_model == "autoimmune")),
#    466      7500     893621.0    119.1      0.0              K_2 = K_EH, K_3 = K_EH)*mycE*d_myc)
#    467      5000    7320881.0   1464.2      0.0          ) * (E_m[i] >= 1) + mycN * (na_m_nonzero_mask)
#    468
#    469      2500   16382988.0   6553.2      0.1          mycMa = (mycMa - dt * mycMa * d_myc) * (Ma_m[i] > 0) + mycN * na_m_nonzero_mask # higher decay rate of myc
#    470
#    471                                                   #### Time-dependent rates modulated by antigen and cytokine signals ####
#    472      2500     786011.0    314.4      0.0          b_Na_div = 1 / char_times[2]
#    473      2500   11477468.0   4591.0      0.1          b_E_div = (mycE >= myc_thresh) * (div_count < max_expand) / char_times[3]
#    474      2500    9105947.0   3642.4      0.0          b_Ma_div = (mycMa >= myc_thresh) * (div_count < max_expand) / char_times[4]
#    475
#    476                                                   #### Transition probabilities modulated by antigen and cytokine signals ####
#    477      2500   13571466.0   5428.6      0.1          r_Na[i] += b_myc_t / myc_thresh
#    478
#    479     10000   38754028.0   3875.4      0.2          r_NaE[i] += (r_NaE[i - 1] + 2 * (mycN >= myc_thresh) * dt * f_XtoY(
#    480      2500    1483684.0    593.5      0.0              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i],
#    481      2500     440965.0    176.4      0.0              psi_1 = psi_NE_I, psi_2 = psi_NE_H, psi_3 = psi_NE_P,F_0 = F0_NE,
#    482      2500     700576.0    280.2      0.0              K_1 = (K_IE*(infection_model != "autoimmune") + K_SE*(infection_model == "autoimmune")),
#    483      2500     308005.0    123.2      0.0              K_2 = K_EH, K_3 = K_EH
#    484      5000    4802241.0    960.4      0.0          ) / (2 / np.sqrt(np.pi) * (char_times[1] - char_times[6]))**2) * n_na_sum_nonzero_mask
#    485
#    486     10000   25302848.0   2530.3      0.1          r_EM[i] += (r_EM[i - 1] + 2 * dt * f_XtoY(
#    487      2500    1323767.0    529.5      0.0              sig_1 = p_tcr*cells_sensed, sig_2 = p_cyt*H[i], sig_3 = p_cyt*P[i],
#    488      2500     403394.0    161.4      0.0              psi_1 = psi_EM_I, psi_2 = psi_EM_H, psi_3 = psi_EM_P, F_0 = F0_EM,
#    489      2500     707367.0    282.9      0.0              K_1 = (K_IE*(infection_model != "autoimmune") + K_SE*(infection_model == "autoimmune")),
#    490      2500     280582.0    112.2      0.0              K_2 = K_EH, K_3 = K_EH
#    491      5000    3284198.0    656.8      0.0          ) / (2 / np.sqrt(np.pi) * (char_times[1] + char_times[6]))**2) * e_m_nonzero_mask # char_times[6] + char_times[6] to reverse priming and differentiation
#    492
#    493      2500    6468242.0   2587.3      0.0          r_EE[i] += b_E_div
#    494
#    495      2500    2192695.0    877.1      0.0          cum_r_NaE += r_NaE[i]
#    496
#    497                                                   #### Store myc levels ####
#    498      2500     618329.0    247.3      0.0          if out_data == "full":
#    499                                                       mycN_m[i] += mycN
#    500                                                       mycMa_m[i] += mycMa
#    501                                                       mycE_m[i] += mycE
#    502
#    503                                                   #### Store differentiation biases
#    504      2500    2103141.0    841.3      0.0          to_add_to_bias = np.zeros(4)
#    505      2500    3841224.0   1536.5      0.0          if sum_n_m > 0.:
#    506      2500   40194208.0  16077.7      0.2              to_add_to_bias[0] = np.mean(r_Na[i][n_m_nonzero_mask])
#    507      2500   20898116.0   8359.2      0.1              to_add_to_bias[1] = np.mean(r_NaE[i][n_m_nonzero_mask])
#    508      2500    3448675.0   1379.5      0.0          if sum_e_m > 0.:
#    509      1234   10002721.0   8105.9      0.0              to_add_to_bias[2] = np.mean(r_EM[i][e_m_nonzero_mask])
#    510      1234    9098216.0   7372.9      0.0              to_add_to_bias[3] = np.mean(r_EE[i][e_m_nonzero_mask])
#    511      2500    2850307.0   1140.1      0.0          bias_t[i] += to_add_to_bias
#    512
#    513                                                   # Increment time
#    514      2500     970935.0    388.4      0.0          t += dt
#    515
#    516                                               # Collect population dynamics
#    517         1    2062586.0    2e+06      0.0      N, Na, Ma, E = np.sum(N_m, axis = 1), np.sum(Na_m, axis = 1), np.sum(Ma_m, axis = 1), np.sum(E_m, axis = 1)
#    518
#    519         1    6105986.0    6e+06      0.0      T_pEcytM = np.concatenate(T_Ecyt) if N_0 > 0 else np.array([0.0]) # time that memory spends in effector
#    520         1      82243.0  82243.0      0.0      count_cM = np.sum(T_pEcytM == 0
#    521         1      58938.0  58938.0      0.0                       ) if len(T_pEcytM[T_pEcytM == 0]) > 0 and N_0 > 0.0 else 0.0
#    522         1     276714.0 276714.0      0.0      count_eM = np.sum(memory_lifespan(T_pEcytM) > char_times[5]
#    523         1    1830259.0    2e+06      0.0                       ) if len(T_pEcytM[memory_lifespan(T_pEcytM) > char_times[5]]) > 0 and N_0 > 0.0 else 0.0
#    524
#    525                                               # Project out surviving primary memory
#    526         2      73200.0  36600.0      0.0      cM_duration = np.mean(memory_lifespan(T_pEcytM[T_pEcytM == 0])
#    527         2      44778.0  22389.0      0.0                           )/365.25 if len(T_pEcytM[T_pEcytM == 0]) > 0 and N_0 > 0.0 else 0.0
#    528         2    1023312.0 511656.0      0.0      eM_duration = np.mean(memory_lifespan(T_pEcytM[memory_lifespan(T_pEcytM) > char_times[5]])
#    529         2     305348.0 152674.0      0.0                           )/365.25 if len(T_pEcytM[memory_lifespan(T_pEcytM) > char_times[5]]) > 0 and N_0 > 0.0 else 0.0
#    530
#    531         1       1752.0   1752.0      0.0      zeros_n_0_var = np.zeros(N_0_var)
#    532
#    533         2     108873.0  54436.5      0.0      lineage_comp = np.vstack([
#    534         1     140560.0 140560.0      0.0          np.amax(Na_m, axis = 0), div_M_count, div_E_count,
#    535         1       4266.0   4266.0      0.0          p_tcr + zeros_n_0_var, p_cyt + zeros_n_0_var
#    536                                               ])
#    537
#    538         1      74221.0  74221.0      0.0      dyn_data = np.array([S, I, N, Na, E, Ma, H, I_d_I + I_d_IE, S_d_SE, P]).T # add I_d_IE as a separate variable
#    539         1       8753.0   8753.0      0.0      prim_bias = bias_t
#    540
#    541         1     126089.0 126089.0      0.0      ts = np.linspace(0, duration, int_steps + 1)
#    542
#    543                                               # Compute summary statistics from simulations
#    544                                               ## extract primary/secondary infection dynamics
#    545         1       3576.0   3576.0      0.0      pS, pI, N, Na, pE, pM, pH, pI_d_I, pI_d_SE, pP = dyn_data[:,0], dyn_data[:,1], dyn_data[:,2], dyn_data[:, 3], dyn_data[:,4], dyn_data[:,5], dyn_data[:,6], dyn_data[:,7], dyn_data[:,8], dyn_data[:,9]
#    546
#    547         1        621.0    621.0      0.0      dt = ts[1]-ts[0]
#    548
#    549         3      10726.0   3575.3      0.0      parameters = np.concatenate((np.array([S_0, I_0, b_I, d_S, d_I, d_IE, K_IE,
#    550         1        431.0    431.0      0.0                b_H, d_H, K_EH,
#    551         1        151.0    151.0      0.0                N_0, max_Na, b_myc, d_myc, myc_thresh]),
#    552         1         80.0     80.0      0.0                char_times,
#    553         1        241.0    241.0      0.0                activation_regulation, NE_regulation, EM_regulation, expansion_regulation))
#    554
#    555         2      21893.0  10946.5      0.0      sim_summary = np.array([np.sum(pI*dt) + np.sum(pS*dt)*(infection_model == "autoimmune"),
#    556         1      33430.0  33430.0      0.0                         np.argmax(pI)*dt,
#    557         1      11548.0  11548.0      0.0                         np.argmax(pI < I_0)*dt,
#    558         1       7211.0   7211.0      0.0                         np.amax(pI_d_I) + I[-1],
#    559         1       4787.0   4787.0      0.0                         np.amax(pI_d_SE),
#    560         1       4557.0   4557.0      0.0                         np.sum(div_E_count),
#    561         1      11337.0  11337.0      0.0                         np.argmax(pE)*dt + sim_duration*(np.max(pE) < 1.0),
#    562         1      11788.0  11788.0      0.0                         (np.argmax(pE >= N_0 , axis = 0)*dt + sim_duration*(np.max(pE) < N_0)) if N_0 > 0 else sim_duration,
#    563         1        120.0    120.0      0.0                         count_eM,
#    564         1         80.0     80.0      0.0                         eM_duration,
#    565         1        130.0    130.0      0.0                         count_cM,
#    566         1         81.0     81.0      0.0                         cM_duration,
#    567         1       6660.0   6660.0      0.0                         np.sum(pP*dt),
#    568         1       6250.0   6250.0      0.0                         np.sum(pH*dt),
#    569         1      11567.0  11567.0      0.0                         np.amin(pS)])
#    570
#    571                                               # down-size timeseries
#    572         1       2835.0   2835.0      0.0      pnts = int(0.1*steps)
#    573         1      47541.0  47541.0      0.0      keep = [i*10 for i in np.arange(0,pnts)]
#    574
#    575         1        350.0    350.0      0.0      if out_data == "full":
#    576                                                   out_dict = {"reg_coeffs": np.concatenate((activation_regulation, NE_regulation, EM_regulation, expansion_regulation)), "cell_time_series": dyn_data, "time": ts, "lineage_diff": lineage_comp, "prim_diff_bias": prim_bias, "eff_by_lin": (E_m), "N_myc_by_lin": mycN_m, "Ma_myc_by_lin": mycMa_m, "E_myc_by_lin": mycE_m, "parameters": parameters, "summary_stats": sim_summary, "pmemory_formed": T_pEcytM if N_0 > 0 else []}
#    577         1        150.0    150.0      0.0      elif out_data == "small":
#    578         1      83685.0  83685.0      0.0          out_dict = {"cell_time_series": dyn_data[keep], "prim_diff_bias": prim_bias[keep],"parameters": parameters, "summary_stats": sim_summary}
#    579
#    580         1        100.0    100.0      0.0      return out_dict

# %%
# Run single simulation
# %timeit -n 2 -r 2
data_dict = lin_stoch_sim(N_0 = N_0,
                          I_0 = I_0,
                          b_I = b_I, 
                          K_IE = K_IE,
                          d_I = d_I,
                          K_EH = K_EH,
                          NE_regulation = NE_regulation,
                          EM_regulation = EM_regulation,
                          activation_regulation = Na_regulation,
                          expansion_regulation = EE_regulation,
                          infection_model = infection_model,
                          reg_model = 'mwc_like',
                          out_data = "full")

# %%
regs = data_dict["reg_coeffs"]
dyn = data_dict["cell_time_series"]
ts = data_dict["time"]
lin_comp = data_dict["lineage_diff"]
p_diff = data_dict["prim_diff_bias"]
parameters = data_dict["parameters"]
sim_summary = data_dict["summary_stats"]
mycN = data_dict["N_myc_by_lin"]
mycMa = data_dict["Ma_myc_by_lin"]
mycE = data_dict["E_myc_by_lin"]
Eff = data_dict["eff_by_lin"]
T_pEcytM = data_dict["pmemory_formed"]

S, I, N, Na, E, M, H, I_d_I, I_d_S, P = dyn[:,0], dyn[:,1], dyn[:,2], dyn[:, 3], dyn[:,4], dyn[:,5], dyn[:,6], dyn[:,7], dyn[:,8], dyn[:,9]

reg_string = '-'.join(np.array(Na_regulation + NE_regulation + EM_regulation + EE_regulation).astype('U4'))

# %%
# Plot simulated immune dynamics
fig, (ax1, ax2, ax3) = plt.subplots(3, dpi = 150, constrained_layout=True, sharex = False, figsize=(5,5))

ax1.plot(ts, S, 'k', label = r'susceptible, $S$')
ax1.plot(ts, I, 'b', label = r'infected, $I$')

ax1.plot(ts, I_d_S, 'r', linestyle = '--', label = r'susceptible killed')
ax1.plot(ts, I_d_I, 'g', linestyle = '--', label = r'infected killed')
ax1.set(ylabel='Cell count')
ax1.set_ylim(1, S_0*2)
ax1.semilogy()
ax1.minorticks_off()
ax1.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

ax2.plot(ts, Na, 'b', label = r'Activated, $N^*$')
ax2.plot(ts, E, 'orange', label = r'Effector, $E$')
ax2.plot(ts, M, 'g', label = r'Memory, $M$')
ax2.plot(ts, S, 'grey', label = r'Susceptible, $S$')
ax2.plot(ts, I, 'r', label = r'infected, $I$')
ax2.set(ylabel='Cell count')
ax2.semilogy()
ax2.minorticks_off()
ax2.set_ylim(1, S_0*2)
ax2.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')

ax3.plot(ts, f_XtoY_mwc_like(sig_1 = I, sig_2 = H, sig_3 = P, 
                             psi_1 = EM_regulation[0], psi_2 = EM_regulation[1], psi_3 = EM_regulation[2], F_0 = EM_regulation[3], 
                             K_1 = K_IE, K_2 = K_EH, K_3 = K_EH),
         'k-', label = r'Regulation, $f(I,H)$')
ax3.set(xlabel=r'Time (days)', ylabel='Regulation')
ax3.minorticks_off()
ax3.set_ylim(0,1.05)

fig.savefig("_figs/"+infection_model+'-'+'virus-effector dynamics-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
plt.plot(ts, N)
plt.ylim(0, 1.05*N_0)
np.mean(np.argmax(Eff >0 , axis = 0)*(ts[1]-ts[0])*(np.amax(Eff, axis = 0) > 0 ))
# Out:
# 9.104000000000001

# %%
plt.plot(ts, np.log((1 + I/K_IE)), 'r', label = "Ag.")
plt.plot(ts, np.log((1 + P/K_EH)), 'b--', label = "Anti-inflam.")
plt.plot(ts, np.log((1 + H/K_EH)), 'k--', label = "Pro-inflam.")
plt.legend()

# %%
plt.plot(ts,d_IE*E/(K_IE + I + E), 'r')
plt.plot(ts, d_IE*E/(K_IE + E), 'k--')

# %%
print(f'Memory fraction = {(sim_summary[8]+sim_summary[10])/sim_summary[5]}')
print(f'Number of memory cells = {np.max(M)}')
print(f'1st infection harm = {sim_summary[3]/(d_S*S_0)}')
print(f'1st response toxicity = {sim_summary[4]/(d_S*S_0)}')
print(f'Minimum susceptible = {np.min(S)/S_0}')
# Out:
# Memory fraction = 0.0
# Number of memory cells = 0.0
# 1st infection harm = 97.13081896475461
# 1st response toxicity = 0.06409319382217113
# Minimum susceptible = 0.1095476083666889

# %%
# Plot simulated infection dynamics: pretty plots
pnts = 50
keep = [i*int(len(E)/pnts) for i in np.arange(0,pnts)]
sus = S[keep]
naive = Na[keep]
eff = E[keep]
mem = M[keep]
p_load = np.log(1 + I[keep]/K_IE)/np.log(1 + np.max(I[keep])/K_IE) if np.max(I[keep]) > 0 else I[keep]
inflam = np.log((1 + H[keep]/K_EH))/np.log((1 + np.max(H[keep])/K_EH))
anti_inflam = np.log((1 + P[keep]/K_EH))/np.log((1 + np.max(P[keep])/K_EH)) if np.max(P[keep]) > 0 else P[keep]
inf_harm = I_d_I[keep]
toxicity = I_d_S[keep]
time = ts[keep]

fig, ax = plt.subplots(figsize=(7.5,5))

ax.plot(ts, I, 'r', label = r'Infected, $I$', linewidth=2.5)
ax.plot(ts, S, 'grey', label = r'Susceptible, $S$', linewidth=2.5)

ax.plot(ts, E + M, 'orange', zorder = 1, linewidth=2.5)
im = ax.scatter(time, eff+mem, marker ='o', c = p_load, cmap='coolwarm', 
            label = r'T cells, $E + M$', zorder = 2) #, norm=mpl.colors.LogNorm())

# ax.plot(time, mem, 'k--')
# ax.scatter(time, mem, marker ='s', c = p_load, cmap='coolwarm',
#             label = r'Mem., $M$') #, norm=mpl.colors.LogNorm())

# ax.plot(time, inf_harm, 'r', linewidth = 2.0, label = r'Harm, $\mathcal{H}_I$')

# ax.plot(time, toxicity, 'y', linewidth = 2.0,label = r'Toxicity, $\mathcal{H}_S$')

# ax.set_box_aspect(1)
cb = fig.colorbar(im, ax=ax, orientation='vertical', shrink = 0.75, pad = 0.05)
cb.set_label('Ag. stimulation', fontsize = 14)
cb.ax.tick_params(labelsize=8)
ax.set_ylabel('Cell count', fontsize = 18)
ax.set_xlabel(r"Time (days)", fontsize = 18)
ax.semilogy()
ax.minorticks_off()
ax.set_ylim(1,)
# locmaj = mpl.ticker.LogLocator(numticks=4)
# ax.yaxis.set_major_locator(locmaj)

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        ax.axvline(x=time[i], linestyle='-', linewidth=6.5, color='pink', alpha=inflam[i], label =r"Inflam. stim.", zorder = 0)
        ax.axvline(x=time[i], linestyle='-', linewidth=6.5, color='grey', alpha=anti_inflam[i]/2, label =r"Anti-inflam. stim.", zorder = 0)
    else:
        ax.axvline(x=time[i], linestyle='-', linewidth=6.5, color='pink', alpha=inflam[i], zorder = 0)
        ax.axvline(x=time[i], linestyle='-', linewidth=6.5, color='grey', alpha=anti_inflam[i]/2, zorder = 0)

ax.legend(loc='lower right', fontsize = 12)

plt.savefig('_figs/'+infection_model+'-timeline-of-infection-dynamics-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
# Plot simulated infection dynamics: pretty plots of harm
pnts = 50
keep = [i*int(len(E)/pnts) for i in np.arange(0,pnts)]

eff = E[keep]
p_load = I[keep]/S_0
sus = S[keep]/S_0
inf_harm = I_d_I[keep]/S_0
inflam_harm = I_d_S[keep]/S_0
inflam = np.log((1 + H[keep]/K_EH))/np.log((1 + S_0/K_EH))
time = ts[keep]

plt.scatter(time, p_load, marker ='s', c =eff/K_IE, cmap='coolwarm', 
            label = r'Infected cells, $I$') #, norm=mpl.colors.LogNorm())
plt.plot(time, p_load, 'k--')

# plt.scatter(time, sus, marker ='>', c =eff/K_IE, cmap='coolwarm', 
#             label = r'Susceptible cells, $S$') #, norm=mpl.colors.LogNorm())
# plt.plot(time, sus, 'k--')

plt.scatter(time, inf_harm, marker ='o', c =eff/K_IE, cmap='coolwarm', 
            label = 'Infected cells killed')
plt.plot(time, inf_harm, 'k--')

plt.scatter(time, inflam_harm, marker ='*', c =eff/K_IE, cmap='coolwarm',
            label = 'Susceptible cells killed')
plt.plot(time, inflam_harm, 'k--')

plt.colorbar(label = "Primary effector response")
plt.ylabel('Fraction of susceptible cells', fontsize = 14)
plt.xlabel(r"Time, $t$ (days)", fontsize = 14)

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        plt.axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], label =r"Inflammation, $H$", zorder = 0)
    else:
        plt.axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        
plt.legend(loc='center right', bbox_to_anchor=(1.85, 0.8), fontsize = 10)
plt.savefig('_figs/'+infection_model+'-infection-harm-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %%
# Plot simulated infection dynamics: pretty plots
pnts = 150
keep = [1 + i*int(len(E)/pnts) for i in np.arange(0,pnts)]
bias_diff = p_diff[keep]
sus = S[keep]
p_load = np.log(1 + I[keep]/K_IE)/np.log(1 + np.max(I[keep])/K_IE) if np.max(I[keep]) > 0 else I[keep]
inflam = np.log((1 + H[keep]/K_EH))/np.log((1 + np.max(H[keep])/K_EH))
anti_inflam = np.log((1 + P[keep]/K_EH))/np.log((1 + np.max(P[keep])/K_EH)) if np.max(P[keep]) > 0 else P[keep]
time = ts[keep]

fig, axs = plt.subplots(2,2, figsize=(7,7))

for i in np.arange(0, len(inflam), 1):
    if i == np.argmax(inflam):
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0, label =r"Inflammation, $H$")
        
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0, label =r"Anti-inflammation, $P$")
    else:
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='pink', alpha=inflam[i], zorder = 0, label =r"Inflammation, $H$")
        
        axs[0,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[0,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[1,0].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0)
        axs[1,1].axvline(x=time[i], linestyle='-', linewidth=2.0, color='grey', alpha=anti_inflam[i]/2, zorder = 0, label =r"Anti-inflammation, $P$")


im1 = axs[0,0].scatter(time, bias_diff[:,0], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$N \longrightarrow N^*$')
axs[0,0].plot(time, bias_diff[:,0],'k--')
axs[0,0].title.set_text(r'$N \longrightarrow N^*$')
axs[0,0].set_box_aspect(1)

im2 = axs[0,1].scatter(time, bias_diff[:,1], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$N^* \longrightarrow E$')
axs[0,1].plot(time, bias_diff[:,1],'k--')
axs[0,1].title.set_text(r'$N^* \longrightarrow E$')
axs[0,1].set_box_aspect(1)

im3 = axs[1,0].scatter(time, bias_diff[:,2], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$E \longrightarrow M$')
axs[1,0].plot(time, bias_diff[:,2],'k--')
axs[1,0].title.set_text(r'$E \longrightarrow M$')
axs[1,0].set_box_aspect(1)

im4 = axs[1,1].scatter(time, bias_diff[:,3], marker = 's', c =p_load, cmap='coolwarm', 
            label = r'$E \longrightarrow M$')
axs[1,1].plot(time, bias_diff[:,3],'k--')
axs[1,1].title.set_text(r'$E \longrightarrow E + E$')
axs[1,1].set_box_aspect(1)

axs[0,0].set_ylabel('Rate [day$^{-1}$]', fontsize = 14)
axs[1,0].set_ylabel('Rate [day$^{-1}$]', fontsize = 14)
axs[1,0].set_xlabel("Time (days)", fontsize = 14)
axs[1,1].set_xlabel("Time (days)", fontsize = 14)

fig.subplots_adjust(wspace=.3, hspace = 0.1)
cb = fig.colorbar(im1, ax=axs, shrink = 0.5, pad = 0.05, orientation='vertical')
cb.set_label('Infection severity,'+ r'$\frac{I}{S_0}$')

#cb.set_clim(-0.4,0.4)
    
# plt.colorbar(label =r"pathogen load, $I(t)$")
# plt.ylabel('transition weight', fontsize = 16)
# plt.xlabel("time (days)", fontsize = 16)
# plt.legend() #bbox_to_anchor=(1.05, 1.0), loc='upper left')

plt.savefig('_figs/'+infection_model+'-diff-bias-over-time-'+reg_string+'.png', dpi=150, bbox_inches="tight")

# %% [markdown]
# ### (2) Plot lineage-based trajectories

# %%
keys = np.array(['Memory', 'Effector'])
all_counts = lin_comp[1:3].T
effector_ranking = np.argsort(all_counts[:, 1])[::-1]
all_counts = all_counts[effector_ranking]
total_counts = all_counts.sum(axis=1)
norm_counts = all_counts / total_counts[:, None]
norm_counts[~np.isfinite(norm_counts)] = 0
comp_argsort = np.argsort(np.max(all_counts, axis=0))
bar_dict = {k: v for k, v in zip(keys[comp_argsort], norm_counts.T[comp_argsort])}
lineage_idxs = np.arange(all_counts.shape[0])

fig, ax = plt.subplots()
bottom = np.zeros(len(lineage_idxs))
cmap_colors = sns.color_palette('Set2', 10)
cmap_colors = [cmap_colors[i]
               for i in [0, 1, 5]]#[7, 2, 0, 1, 5]]
# cmap_colors = [cmap_colors[i]
#                for i in [6, 1, 2, 5, 0]]
width = 1

for i, (celltype, fraction) in enumerate(bar_dict.items()):
    ax.bar(lineage_idxs, fraction, width,
           edgecolor='k', linewidth=0.01,
           label=celltype, bottom=bottom, color=cmap_colors[i])
    bottom += fraction
    
ax.legend(loc='center right', bbox_to_anchor=(1.4, 0.5), fontsize = 12)
ax.set_xlim(-0.5, len(all_counts) - 0.5)
ax.set_xlabel('sub-clone lineages \n (ranked by effector response)', fontsize = 15)
ax.set_ylabel('fractional cell-fate \ncomposition', fontsize = 15)
#ax.set_yscale('log')

ax.set_xticks(np.arange(0, Eff.shape[1], int(Eff.shape[1]/10)))
ax.set_xticklabels(1 + np.arange(0, Eff.shape[1], int(Eff.shape[1]/10)), fontsize=9)

ax.set_yticks(np.round(np.arange(0, 1.2, 0.2), 1))
ax.set_yticklabels(ax.get_yticks(), fontsize=12)

fig.savefig("_figs/"+infection_model+'-'+'fates-by-lin-'+reg_string+'.png', dpi=150, bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[15], line 33
#      30 ax.set_ylabel('fractional cell-fate \ncomposition', fontsize = 15)
#      31 #ax.set_yscale('log')
# ---> 33 ax.set_xticks(np.arange(0, Eff.shape[1], int(Eff.shape[1]/10)))
#      34 ax.set_xticklabels(1 + np.arange(0, Eff.shape[1], int(Eff.shape[1]/10)), fontsize=9)
#      36 ax.set_yticks(np.round(np.arange(0, 1.2, 0.2), 1))
#
# ZeroDivisionError: division by zero

# %%
plt.errorbar(ts, np.mean(Eff, axis = 1), yerr = np.std(Eff, axis = 1), errorevery = 100)
plt.semilogy()

# %%
plt.plot(ts, mycE, 'r--')
plt.errorbar(ts, np.mean(mycE, axis = 1), yerr = np.std(mycE, axis = 1), errorevery = 100)
#plt.plot(ts, mycMa, 'k-')
plt.axhline(y = myc_thresh, color = 'k', linestyle = '--')
print(np.sum(np.max(mycE, axis=0) > myc_thresh)/N_0)

# %%
plt.hist(T_pEcytM, bins = 'auto', histtype='step');
plt.xlabel("Time in effector state")
plt.ylabel("Counts")

# %%
plt.hist(memory_lifespan(T_pEcytM[memory_lifespan(T_pEcytM) > t_E_die])/365.25, bins = 'auto', histtype='step');
plt.xlabel("Memory lifespan")
plt.ylabel("Counts")
print(sim_summary[9], sim_summary[11])

# %%
# Compute max values in the data
r = np.arange(5)
width = 0.5
plt.bar(r, np.amax(np.array([I, Na, E, M, H]).T, axis = 0), width = width)

plt.xlabel("response")
plt.ylabel("value")

plt.xticks(r, ["Infected","Naive","Effector","Memory", "Inflammation"], fontsize = 7)

plt.semilogy()
plt.suptitle(r'Peak response response: $N_0=$ '+str(N_0) +r', $d_I=$'+str(d_I))

# %%
bias_1 = f_XtoY(I, H, 
       -2.0, -2.0, 0.0, F_0 = 4*np.log(2), 
       K_I = K_IE, K_H = K_EH)
bias_2 = f_XtoY(I, H, 
       -2.0, 2.0, 0.0, F_0 = -0*np.log(2), 
       K_I = K_IE, K_H = K_EH)

plt.plot(ts, bias_1, 'r')
plt.plot(ts, bias_2, 'k--')
plt.plot(ts, Na/np.amax(Na))
plt.plot(ts, A/(Na + A))
plt.plot(ts, H**l_H/(K_EH**l_H + H**l_H))

# %%
d="/gscratch/scrubbed/oukogu/infoimmune/sim_output/no_cell_var/raw/"
comment = "sparse-reg"
infection_model = "acute" # "cancer", "acute"
runs = 5

run(batch = [196.0], outdir=d, comment=comment, infection_model = infection_model, runs = runs, num_cpu = 136, run_time = 4.0)

# %%
d_file = '/gscratch/scrubbed/oukogu/infoimmune/sim_output/no_cell_var/raw/sim_batch_0.0-'+str(runs)+'-'+infection_model+'-'+comment+'.pkl'
with open(d_file, 'rb') as f:   
    out = pickle.load(f)
