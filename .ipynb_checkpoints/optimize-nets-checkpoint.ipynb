# %%
import numpy as np

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

from scipy.integrate import solve_ivp
from scipy.interpolate import interp1d

import multiprocessing as mp
from tqdm import tqdm
from joblib import Parallel, delayed
import os
from scipy.spatial import ConvexHull, convex_hull_plot_2d
from sklearn.feature_selection import mutual_info_classif
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from scipy.stats import qmc
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import itertools

from stoch_sim_model import *

plt.style.use('/Users/ObinnaUkogu/Desktop/custom.mplstyle')
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ### (1) Define function to run simulations and compute MI

# %%
# Make grid
b_I = 8
t1 = 10
cv_b_I, cv_t1 = 0.2, 0.5

d_IE = 3.8*10**(-4)
T_I = 2

infection_type = 'prim' #'prim' or 'sec'
sim_kind = "pop_ode"

runs = 1000

def comp_MI(psi_N_I = 0.5, psi_N_c = 0.5, psi_cM_I = 0.5, psi_cM_c = 0.5, psi_E_I = 0.5, psi_E_c = 0.5):
    
    Is = np.random.lognormal(mean = np.log(np.array([b_I, t1])/np.sqrt(1 + np.array([cv_b_I, cv_t1])**2)), 
                            sigma = np.sqrt(np.log(1 + np.array([cv_b_I, cv_t1])**2)), size = (runs,2))

    # choose which parameter to vary
    run_data = np.array(Parallel(n_jobs=os.cpu_count(), batch_size = max(int(len(Is)/8),1))(delayed(sum_sim)(b_I = param[0], t1 = param[1],
                                                                                                        regulation_coeffs = [psi_N_I, psi_N_c, psi_cM_I, psi_cM_c, psi_E_I, psi_E_c],
                                                                                                        infection = infection_type,
                                                                                                        sim_kind = sim_kind)
                                                    for param in Is))
        
    MI_args = np.arange(10,len(stat_names))
        
    MI_data = np.zeros(2*len(MI_args))
    for i in np.arange(len(MI_args)):
        MI_data[i] = calc_MI(run_data[:,8], run_data[:,MI_args[i]]) # 6 = a1_0, 7 = b_I
        MI_data[i + len(MI_args)] = calc_MI(run_data[:,7], run_data[:,MI_args[i]])
        
    return  np.array(np.append(MI_data, np.mean(run_data[:,10])))


# function to slice data by parameters
extract_stats = np.vectorize(lambda x,stat: x[stat])

v_comp_MI = np.vectorize(comp_MI)

# functions for generating sobol sequence grids
def sample_grid(d,m, type = 'discrete'):
    
    if type == 'discrete':
        sample = np.array(list(itertools.product(np.arange(0,3)/2, repeat=d)))
    else:
        sampler = qmc.Sobol(d=d, scramble=False)
        vertices = np.array(list(itertools.product(np.arange(0,3)/2, repeat=d)))
        sample = np.vstack((sampler.random_base2(m=m), vertices))
    
    return sample

# %% [markdown]
# ### (2) Maximize MI over $\psi_N^{(I)}$ and $\psi_N^{(c)}$

# %%
# Create grid of regulation coeffs
m = 7
regs_N = sample_grid(d=2,m=m, type = 'cts')

# %%
# Run simulations
MI_N_grid = np.array(Parallel(n_jobs=os.cpu_count(), 
                              batch_size=max(int(len(regs_N)/8),1))(delayed(comp_MI)(psi_N_I = reg[0], 
                                                                                 psi_N_c = reg[1], 
                                                                                 psi_cM_I = 0.5, 
                                                                                 psi_cM_c = 0.5, 
                                                                                 psi_E_I = 0.5, 
                                                                                 psi_E_c = 0.5)
                                              for reg in regs_N))
# Out:
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 436, in _process_worker
#     r = call_item()
#   File "/opt/anaconda3/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py", line 288, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 595, in __call__
#     return self.func(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
# ...

# %% [markdown]
# #### (2a) Plot information transmission as a function of network structure

# %%
# plot surface plots
fig_b_I = plt.figure(figsize=(12,12),dpi = 150)

i = 0

for val in stat_names[i+10:]:
    z = MI_N_grid[:,i]

    ax = fig_b_I.add_subplot(4, 2, i+1, projection='3d')
    cs = ax.plot_trisurf(regs_N[:,0], regs_N[:,1], z, cmap = plt.cm.cividis)

    #ax.set_title(val)
    # set the limits of the plot to the limits of the data
    ax.axis([0.0, 1.0, 0.0, 1.0])
    ax.set(xlabel=r'$\psi_N^{(I)}$', ylabel=r'$\psi_N^{(c)}$')
    fig_b_I.colorbar(cs,  shrink=0.5, aspect=8, label =r"I("+val+r";$t_1)$")

    i += 1
    
fig_b_I.suptitle(r'MI as a function of $\psi_N^{(I)}$ and $\psi_N^{(c)}$'+' for '+infection_type+". infection")
fig_b_I.savefig(infection_type+'-'+'surf-MI-t1-vs-N-reg.pdf', dpi=300, bbox_inches="tight")
plt.tight_layout()

plt.show()

# %% [markdown]
# #### (2b) Network optimization as a multi-objective optimization (MOO) problem

# %%
# plot pareto front for appropriateness and effectiveness of the immune response
fig_t1 = plt.figure(figsize=(12,12),dpi = 150)

i = 0

for val in stat_names[i+10:]:

    xy = np.array([np.nan_to_num(MI_N_grid[:,i], copy = False) ,
                   np.nan_to_num(MI_N_grid[:,-1], copy = False)]).T
    
    # remove biologically infeasible network architectures
    keep_row = np.ones(xy.shape[0], dtype = bool)
    for k in np.arange(xy.shape[0]):
        if xy[k,-1] == 0.0:
            keep_row[k] = False
            
    xy = (xy[keep_row,...])
    
    # hull = ConvexHull(np.array([x_, y_]).T)
    
    ax = fig_t1.add_subplot(4, 2, i+1)
    cs = ax.plot(xy[:,0], xy[:,1], 'ko')
    
    # find pareto front
    keep_row = np.ones(xy.shape[0], dtype = bool)
    
    for j in np.arange(len(xy[:,0])):
        for k in np.arange(len(xy[:,0])):
            if xy[j,0] < xy[k,0] and xy[j,1] > xy[k,1]:
                keep_row[j] = False
    
    x_front = (xy[:,0])[keep_row,...]
    y_front = (xy[:,1])[keep_row,...]
    ax.plot(x_front, y_front, 'ro')
    ax.plot(x_front[-9:], y_front[-9:], 'k^')
    ax.axis([0.0, np.max(xy[:,0])*1.15, 0.95*np.min(xy[:,1]), np.max(xy[:,1])*1.15])
    # for k in np.arange(0,len(x_front)):
    #     ax.text(x_front[k],y_front[k], k, ha="center", va="center")
    
    # inset plot: these are in unitless percentages of the figure size. (0,0 is bottom left)
    axins = inset_axes(ax, width="25%", height="25%", loc=1, borderpad = 1)
    axins.plot(regs_N[keep_row,0], regs_N[keep_row,1], 'ro')
    axins.plot(regs_N[np.argmin(xy[:,1]),0], regs_N[np.argmin(xy[:,1]),1], 'bo')
    axins.set(xlabel=r'$\psi_N^{(I)}$', ylabel=r'$\psi_N^{(c)}$')
    axins.axis([0.0, 1.0, 0.0, 1.0])

    # set the limits of the plot to the limits of the data
    ax.set(xlabel=r"$I($"+val+r";$t_1)$", ylabel=r"$\mathbb{E}_{\sim t_1}[$"+stat_names[10]+r"$]$")

    i += 1
    
fig_t1.suptitle(r'Pareto front varying $\psi_N^{(I)}$ and $\psi_N^{(c)}$'+' for '+infection_type+". infection")
fig_t1.savefig(infection_type+'-pareto-N-reg-antigenicity.pdf', dpi=300, bbox_inches="tight")
plt.tight_layout()

plt.show()

# %%
# plot pareto front for appropriateness and effectiveness of the immune response
fig_b_I = plt.figure(figsize=(12,12),dpi = 150)

i = 0

for val in stat_names[i+10:]:

    xy = np.array([np.nan_to_num(MI_N_grid[:,i+8], copy = False) ,
                   np.nan_to_num(MI_N_grid[:,-1], copy = False)]).T
    
    # remove biologically infeasible network architectures
    keep_row = np.ones(xy.shape[0], dtype = bool)
    for k in np.arange(xy.shape[0]):
        if xy[k,-1] == 0.0:
            keep_row[k] = False
            
    xy = (xy[keep_row,...])
    
    # hull = ConvexHull(np.array([x_, y_]).T)
    
    ax = fig_b_I.add_subplot(4, 2, i+1)
    cs = ax.plot(xy[:,0], xy[:,1], 'ko')
    
    # find pareto front
    keep_row = np.ones(xy.shape[0], dtype = bool)
    
    for j in np.arange(len(xy[:,0])):
        for k in np.arange(len(xy[:,0])):
            if xy[j,0] < xy[k,0] and xy[j,1] > xy[k,1]:
                keep_row[j] = False
    
    x_front = (xy[:,0])[keep_row,...]
    y_front = (xy[:,1])[keep_row,...]
    ax.plot(x_front, y_front, 'ro')
    ax.plot(x_front[-9:], y_front[-9:], 'k^')
    ax.axis([0.0, np.max(xy[:,0])*1.15, 0.95*np.min(xy[:,1]), np.max(xy[:,1])*1.15])
    # for k in np.arange(0,len(x_front)):
    #     ax.text(x_front[k],y_front[k], k, ha="center", va="center")
    
    # inset plot: these are in unitless percentages of the figure size. (0,0 is bottom left)
    axins = inset_axes(ax, width="25%", height="25%", loc=1, borderpad = 1)
    axins.plot(regs_N[keep_row,0], regs_N[keep_row,1], 'ro')
    axins.plot(regs_N[np.argmin(xy[:,1]),0], regs_N[np.argmin(xy[:,1]),1], 'bo')
    axins.set(xlabel=r'$\psi_N^{(I)}$', ylabel=r'$\psi_N^{(c)}$')
    axins.axis([0.0, 1.0, 0.0, 1.0])

    # set the limits of the plot to the limits of the data
    ax.set(xlabel=r"$I($"+val+r";$b_I)$", ylabel=r"$\mathbb{E}_{\sim t_1}[$"+stat_names[10]+r"$]$")

    i += 1
    
fig_b_I.suptitle(r'Pareto front varying $\psi_N^{(I)}$ and $\psi_N^{(c)}$'+' for '+infection_type+". infection")
fig_b_I.savefig(infection_type+'-pareto-N-reg-virulence.pdf', dpi=300, bbox_inches="tight")
plt.tight_layout()

plt.show()

# %% [markdown]
# ### (3)  Maximize MI over $\psi_{cM}^{(I)}$ and $\psi_{cM}^{(c)}$

# %%
# Create grid of regulation coeffs
m = 7
regs_cM = sample_grid(d=2,m=m, type = 'cts')

# %%
# Run simulations
MI_cM_grid = np.array(Parallel(n_jobs=os.cpu_count(), 
                              batch_size=max(int(len(regs_cM)/8),1))(delayed(comp_MI)(psi_N_I = 0.5, 
                                                                                 psi_N_c = 0.5, 
                                                                                 psi_cM_I = reg[0], 
                                                                                 psi_cM_c = reg[1], 
                                                                                 psi_E_I = 0.5, 
                                                                                 psi_E_c = 0.5)
                                              for reg in regs_cM))

# %% [markdown]
# #### (3a) Plot information transmission as a function of network structure

# %%
# plot surface plots
fig_t1 = plt.figure(figsize=(12,12),dpi = 150)

i = 0

for val in stat_names[i+10:]:
    z = MI_cM_grid[:,i]

    ax = fig_t1.add_subplot(4, 2, i+1, projection='3d')
    cs = ax.plot_trisurf(regs_cM[:,0], regs_cM[:,1], z, cmap = plt.cm.cividis)

    #ax.set_title(val)
    # set the limits of the plot to the limits of the data
    ax.axis([0.0, 1.0, 0.0, 1.0])
    ax.set(xlabel=r'$\psi_{cM}^{(I)}$', ylabel=r'$\psi_{cM}^{(c)}$')
    fig_t1.colorbar(cs,  shrink=0.5, aspect=8, label =r"I("+val+r";$t_1)$")

    i += 1
    
fig_t1.suptitle(r'MI as a function of $\psi_{cM}^{(I)}$ and $\psi_{cM}^{(c)}$'+' for '+infection_type+". infection")
fig_t1.savefig(infection_type+'-'+'surf-MI-t1-vs-cM-reg.pdf', dpi=300, bbox_inches="tight")
plt.tight_layout()

plt.show()

# %% [markdown]
# #### (3b) Network optimization as a multi-objective optimization (MOO) problem

# %%
# plot pareto front for appropriateness and effectiveness of the immune response
fig_t1 = plt.figure(figsize=(12,12),dpi = 150)

i = 0

for val in stat_names[i+10:]:

    xy = np.array([np.nan_to_num(MI_cM_grid[:, i], copy = False) ,
                   np.nan_to_num(MI_cM_grid[:, -1], copy = False)]).T
    
    # remove biologically infeasible network architectures
    keep_row = np.ones(xy.shape[0], dtype = bool)
    for k in np.arange(xy.shape[0]):
        if xy[k,-1] == 0.0:
            keep_row[k] = False
            
    xy = (xy[keep_row,...])
    
    # hull = ConvexHull(np.array([x_, y_]).T)
    
    ax = fig_t1.add_subplot(4, 2, i+1)
    cs = ax.plot(xy[:,0], xy[:,1], 'ko')
    
    # find pareto front
    keep_row = np.ones(xy.shape[0], dtype = bool)
    
    for j in np.arange(len(xy[:,0])):
        for k in np.arange(len(xy[:,0])):
            if xy[j,0] < xy[k,0] and xy[j,1] > xy[k,1]:
                keep_row[j] = False
    
    x_front = (xy[:,0])[keep_row,...]
    y_front = (xy[:,1])[keep_row,...]
    ax.plot(x_front, y_front, 'ro')
    ax.plot(x_front[-9:], y_front[-9:], 'k^')
    ax.axis([0.0, np.max(xy[:,0])*1.15, 0.95*np.min(xy[:,1]), np.max(xy[:,1])*1.15])
    # for k in np.arange(0,len(x_front)):
    #     ax.text(x_front[k],y_front[k], k, ha="center", va="center")
    
    # inset plot: these are in unitless percentages of the figure size. (0,0 is bottom left)
    axins = inset_axes(ax, width="25%", height="25%", loc=1, borderpad = 1)
    axins.plot(regs_cM[keep_row,0], regs_cM[keep_row,1], 'ro')
    axins.plot(regs_cM[np.argmin(xy[:,1]),0], regs_cM[np.argmin(xy[:,1]),1], 'bo')
    axins.set(xlabel=r'$\psi_{cM}^{(I)}$', ylabel=r'$\psi_{cM}^{(c)}$')
    axins.axis([0.0, 1.0, 0.0, 1.0])

    # set the limits of the plot to the limits of the data
    ax.set(xlabel=r"$I($"+val+r";$t_1)$", ylabel=r"$\mathbb{E}_{\sim (t_1,b_I)}[$"+stat_names[10]+r"$]$")

    i += 1
    
fig_t1.suptitle(r'Pareto front varying $\psi_{cM}^{(I)}$ and $\psi_{cM}^{(c)}$'+' for '+infection_type+". infection")
fig_t1.savefig(infection_type+'-pareto-cM-reg-antigenicity.pdf', dpi=300, bbox_inches="tight")
plt.tight_layout()

plt.show()

# %%
# plot pareto front for appropriateness and effectiveness of the immune response
fig_b_I = plt.figure(figsize=(12,12),dpi = 150)

i = 0

for val in stat_names[i+10:]:

    xy = np.array([np.nan_to_num(MI_cM_grid[:, i+8], copy = False) ,
                   np.nan_to_num(MI_cM_grid[:, -1], copy = False)]).T
    
    # remove biologically infeasible network architectures
    keep_row = np.ones(xy.shape[0], dtype = bool)
    for k in np.arange(xy.shape[0]):
        if xy[k,-1] == 0.0:
            keep_row[k] = False
            
    xy = (xy[keep_row,...])
    
    # hull = ConvexHull(np.array([x_, y_]).T)
    
    ax = fig_b_I.add_subplot(4, 2, i+1)
    cs = ax.plot(xy[:,0], xy[:,1], 'ko')
    
    # find pareto front
    keep_row = np.ones(xy.shape[0], dtype = bool)
    
    for j in np.arange(len(xy[:,0])):
        for k in np.arange(len(xy[:,0])):
            if xy[j,0] < xy[k,0] and xy[j,1] > xy[k,1]:
                keep_row[j] = False
    
    x_front = (xy[:,0])[keep_row,...]
    y_front = (xy[:,1])[keep_row,...]
    ax.plot(x_front, y_front, 'ro')
    ax.plot(x_front[-9:], y_front[-9:], 'k^')
    ax.axis([0.0, np.max(xy[:,0])*1.15, 0.95*np.min(xy[:,1]), np.max(xy[:,1])*1.15])
    # for k in np.arange(0,len(x_front)):
    #     ax.text(x_front[k],y_front[k], k, ha="center", va="center")
    
    # inset plot: these are in unitless percentages of the figure size. (0,0 is bottom left)
    axins = inset_axes(ax, width="25%", height="25%", loc=1, borderpad = 1)
    axins.plot(regs_cM[keep_row,0], regs_cM[keep_row,1], 'ro')
    axins.plot(regs_cM[np.argmin(xy[:,1]),0], regs_cM[np.argmin(xy[:,1]),1], 'bo')
    axins.set(xlabel=r'$\psi_{cM}^{(I)}$', ylabel=r'$\psi_{cM}^{(c)}$')
    axins.axis([0.0, 1.0, 0.0, 1.0])

    # set the limits of the plot to the limits of the data
    ax.set(xlabel=r"$I($"+val+r";$b_I)$", ylabel=r"$\mathbb{E}_{\sim (t_1,b_I)}[$"+stat_names[10]+r"$]$")

    i += 1
    
fig_b_I.suptitle(r'Pareto front varying $\psi_{cM}^{(I)}$ and $\psi_{cM}^{(c)}$'+' for '+infection_type+". infection")
fig_b_I.savefig(infection_type+'-pareto-cM-reg-virulence.pdf', dpi=300, bbox_inches="tight")
plt.tight_layout()

plt.show()

# %% [markdown]
# ### (4) Maximize MI over $\psi_{E}^{(I)}$ and $\psi_{E}^{(c)}$

# %%
# Create grid of regulation coeffs
m = 7
regs_E = sample_grid(d=2,m=m, type = 'cts')

# %%
# Run simulations
MI_E_grid = np.array(Parallel(n_jobs=os.cpu_count(), 
                              batch_size=max(int(len(regs_cM)/8),1))(delayed(comp_MI)(psi_N_I = 0.5, 
                                                                                 psi_N_c = 0.5, 
                                                                                 psi_cM_I = 0.5, 
                                                                                 psi_cM_c = 0.5, 
                                                                                 psi_E_I = reg[0], 
                                                                                 psi_E_c = reg[1])
                                              for reg in regs_E))

# %% [markdown]
# #### (4a) Plot information transmission as a function of network structure

# %%
# plot surface plots
fig_b_I = plt.figure(figsize=(12,12),dpi = 150)

i = 0

for val in stat_names[i+10:]:
    z = MI_E_grid[:,i]

    ax = fig_b_I.add_subplot(4, 2, i+1, projection='3d')
    cs = ax.plot_trisurf(regs_E[:,0], regs_E[:,1], z, cmap = plt.cm.cividis)

    #ax.set_title(val)
    # set the limits of the plot to the limits of the data
    ax.axis([0.0, 1.0, 0.0, 1.0])
    ax.set(xlabel=r'$\psi_{E}^{(I)}$', ylabel=r'$\psi_{E}^{(c)}$')
    fig_b_I.colorbar(cs,  shrink=0.5, aspect=8, label =r"I("+val+r";$t_1)$")

    i += 1
    
fig_b_I.suptitle(r'MI as a function of $\psi_{E}^{(I)}$ and $\psi_{E}^{(c)}$'+' for '+infection_type+". infection")
fig_b_I.savefig(infection_type+'-'+'surf-MI-t1-vs-E-reg.pdf', dpi=300, bbox_inches="tight")
plt.tight_layout()

plt.show()

# %% [markdown]
# #### (4b) Network optimization as a multi-objective optimization (MOO) problem

# %%
# plot pareto front for appropriateness and effectiveness of the immune response
fig_t1 = plt.figure(figsize=(12,12),dpi = 150)

i = 0

for val in stat_names[i+10:]:

    xy = np.array([np.nan_to_num(MI_E_grid[:, i], copy = False) ,
                   np.nan_to_num(MI_E_grid[:, -1], copy = False)]).T
    
    # remove biologically infeasible network architectures
    keep_row = np.ones(xy.shape[0], dtype = bool)
    for k in np.arange(xy.shape[0]):
        if xy[k,-1] == 0.0:
            keep_row[k] = False
            
    xy = (xy[keep_row,...])
    
    # hull = ConvexHull(np.array([x_, y_]).T)
    
    ax = fig_t1.add_subplot(4, 2, i+1)
    cs = ax.plot(xy[:,0], xy[:,1], 'ko')
    
    # find pareto front
    keep_row = np.ones(xy.shape[0], dtype = bool)
    
    for j in np.arange(len(xy[:,0])):
        for k in np.arange(len(xy[:,0])):
            if xy[j,0] < xy[k,0] and xy[j,1] > xy[k,1]:
                keep_row[j] = False
    
    x_front = (xy[:,0])[keep_row,...]
    y_front = (xy[:,1])[keep_row,...]
    ax.plot(x_front, y_front, 'ro')
    ax.plot(x_front[-9:], y_front[-9:], 'k^')
    ax.axis([0.0, np.max(xy[:,0])*1.15, 0.95*np.min(xy[:,1]), np.max(xy[:,1])*1.15])
    # for k in np.arange(0,len(x_front)):
    #     ax.text(x_front[k],y_front[k], k, ha="center", va="center")
    
    # inset plot: these are in unitless percentages of the figure size. (0,0 is bottom left)
    axins = inset_axes(ax, width="25%", height="25%", loc=1, borderpad = 1)
    axins.plot(regs_E[keep_row,0], regs_E[keep_row,1], 'ro')
    axins.plot(regs_E[np.argmin(xy[:,1]),0], regs_E[np.argmin(xy[:,1]),1], 'bo')
    axins.set(xlabel=r'$\psi_{E}^{(I)}$', ylabel=r'$\psi_{E}^{(c)}$')
    axins.axis([0.0, 1.0, 0.0, 1.0])

    # set the limits of the plot to the limits of the data
    ax.set(xlabel=r"$I($"+val+r";$t_1)$", ylabel=r"$\mathbb{E}_{\sim (t_1, b_I)}[$"+stat_names[10]+r"$]$")

    i += 1
    
fig_t1.suptitle(r'Pareto front varying $\psi_{E}^{(I)}$ and $\psi_{E}^{(c)}$'+' for '+infection_type+". infection")
fig_t1.savefig(infection_type+'-pareto-E-reg-antigenicity.pdf', dpi=300, bbox_inches="tight")
plt.tight_layout()

plt.show()

# %%
# plot pareto front for appropriateness and effectiveness of the immune response
fig_b_I = plt.figure(figsize=(12,12),dpi = 150)

i = 0

for val in stat_names[i+10:]:

    xy = np.array([np.nan_to_num(MI_E_grid[:, i+8], copy = False) ,
                   np.nan_to_num(MI_E_grid[:, -1], copy = False)]).T
    
    # remove biologically infeasible network architectures
    keep_row = np.ones(xy.shape[0], dtype = bool)
    for k in np.arange(xy.shape[0]):
        if xy[k,-1] == 0.0:
            keep_row[k] = False
            
    xy = (xy[keep_row,...])
    
    # hull = ConvexHull(np.array([x_, y_]).T)
    
    ax = fig_b_I.add_subplot(4, 2, i+1)
    cs = ax.plot(xy[:,0], xy[:,1], 'ko')
    
    # find pareto front
    keep_row = np.ones(xy.shape[0], dtype = bool)
    
    for j in np.arange(len(xy[:,0])):
        for k in np.arange(len(xy[:,0])):
            if xy[j,0] < xy[k,0] and xy[j,1] > xy[k,1]:
                keep_row[j] = False
    
    x_front = (xy[:,0])[keep_row,...]
    y_front = (xy[:,1])[keep_row,...]
    ax.plot(x_front, y_front, 'ro')
    ax.plot(x_front[-9:], y_front[-9:], 'k^')
    ax.axis([0.0, np.max(xy[:,0])*1.15, 0.95*np.min(xy[:,1]), np.max(xy[:,1])*1.15])
    # for k in np.arange(0,len(x_front)):
    #     ax.text(x_front[k],y_front[k], k, ha="center", va="center")
    
    # inset plot: these are in unitless percentages of the figure size. (0,0 is bottom left)
    axins = inset_axes(ax, width="25%", height="25%", loc=1, borderpad = 1)
    axins.plot(regs_E[keep_row,0], regs_E[keep_row,1], 'ro')
    axins.plot(regs_E[np.argmin(xy[:,1]),0], regs_E[np.argmin(xy[:,1]),1], 'bo')
    axins.set(xlabel=r'$\psi_{E}^{(I)}$', ylabel=r'$\psi_{E}^{(c)}$')
    axins.axis([0.0, 1.0, 0.0, 1.0])

    # set the limits of the plot to the limits of the data
    ax.set(xlabel=r"$I($"+val+r";$b_I)$", ylabel=r"$\mathbb{E}_{\sim (t_1, b_I)}[$"+stat_names[10]+r"$]$")

    i += 1
    
fig_b_I.suptitle(r'Pareto front varying $\psi_{E}^{(I)}$ and $\psi_{E}^{(c)}$'+' for '+infection_type+". infection")
fig_b_I.savefig(infection_type+'-pareto-E-reg-virulence.pdf', dpi=300, bbox_inches="tight")
plt.tight_layout()

plt.show()

# %% [markdown]
# ### (5) Compute MI over all networks

# %%
# Create grid of regulation coeffs
m = 11
regs_all = sample_grid(d=6,m=m)

# %%
# Run simulations
MI_reg_grid = np.array(Parallel(n_jobs=os.cpu_count(), 
                              batch_size=max(int(len(regs_cM)/8),1))(delayed(comp_MI)(psi_N_I = reg[0], 
                                                                                 psi_N_c = reg[1], 
                                                                                 psi_cM_I = reg[2], 
                                                                                 psi_cM_c = reg[3], 
                                                                                 psi_E_I = reg[4], 
                                                                                 psi_E_c = reg[5])
                                              for reg in regs_all))

# %%
# Match networks with MI outputs
MI_data = np.zeros((len(MI_reg_grid),len(MI_reg_grid[0])))

for i in np.arange(len(MI_reg_grid)):
    MI_data[i,:] = MI_reg_grid[i].astype(float)

# %%
#np.save(infection_type+'-optimize-nets.npy',MI_data)

raw_network_MI = np.append(regs_all, MI_reg_grid, axis = 1)

# remove biologically infeasible network architectures
keep_row = np.ones(raw_network_MI.shape[0], dtype = bool)
for i in np.arange(raw_network_MI.shape[0]):
    if raw_network_MI[i,-1] == 0.0 or raw_network_MI[i,-1] == 0.0:
        keep_row[i] = False
    
network_MI = (raw_network_MI[keep_row,...])
MI_data_no_zero = (MI_reg_grid[keep_row,...])

# %%
# Plot MI of networks
from matplotlib.offsetbox import AnchoredText
fig_networks, axs = plt.subplots(4,2, dpi = 150, constrained_layout = True, figsize = (6,8))
i = 0

for ax, val in zip(axs.flat,stat_names[10:]):
    
    rank_net = network_MI[(-network_MI[:, i]).argsort()]
    anchored_text = AnchoredText("Top 3: \n"+str(np.round_(rank_net[:3,0:6],2))+"\n\n Bottom 3: \n"+str(np.round_(rank_net[-4:-1,0:6],2)), 
                                 prop=dict(size=5), loc = "upper right")
    
    r = np.arange(6)
    width = 0.5
    ax.bar(r, np.append(rank_net[0:3,i], rank_net[-4:-1,i], axis = 0), width = width, label = r'vary $b_I$')

    ax.set(ylabel = r"$I($"+val+r"$;,b_I)$")
    ax.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
    ax.add_artist(anchored_text)
    
    #ax.set_title(plot_title, fontsize = 5)
    i += 1

    #ax.semilogy()
    #plt.legend()
fig_networks.suptitle(r'Optimal networks for information processing $(\psi_{N}^{(I)},\psi_{N}^{(c)},\psi_{cM}^{(I)},\psi_{cM}^{(c)}, \psi_{E}^{(I)}, \psi_{E}^{(c)})$'+' for '+infection_type+". infection")
fig_networks.savefig(infection_type+'-'+'rank-optimal-nets-for-info'+str(t1)+'.pdf', dpi=150)

# %%
# plot pareto front for appropriateness and effectiveness of the immune response
fig_b_I = plt.figure(figsize=(12,12),dpi = 150)

i = 0

for val in stat_names[i+10:]:

    xy = np.array([np.nan_to_num(MI_data_no_zero[:,i], copy = False) ,np.nan_to_num(MI_data_no_zero[:,-1], copy = False)]).T
    
    # hull = ConvexHull(np.array([x_, y_]).T)
    
    ax = fig_b_I.add_subplot(4, 2, i+1)
    cs = ax.plot(xy[:,0], xy[:,1], 'ko')
    
    # find pareto front
    remove_row = np.ones(xy.shape[0], dtype = bool)
    
    for j in np.arange(len(xy[:,0])):
        for k in np.arange(len(xy[:,0])):
            if xy[j,0] < xy[k,0] and xy[j,1] > xy[k,1]:
                remove_row[j] = False
                
    
    x_front = (xy[:,0])[remove_row,...]
    y_front = (xy[:,1])[remove_row,...]
    ax.plot(x_front, y_front, 'ro')
    
    ax.axis([0.0, np.max(xy[:,0])*1.15, 0.95*np.min(xy[:,1]), np.max(xy[:,1])*1.15])
    # for k in np.arange(0,len(x_front)):
    #     ax.text(x_front[k],y_front[k], k, ha="center", va="center")
    
    # inset plot: these are in unitless percentages of the figure size. (0,0 is bottom left)
    axins = inset_axes(ax, width="25%", height="25%", loc=1, borderpad = 1)
    axins.plot(regs_all[remove_row,4], regs_all[remove_row,5], 'ro')
    axins.plot(regs_all[np.argmin(xy[:,1]),0], regs_all[np.argmin(xy[:,1]),1], 'bo')
    axins.plot(regs_all[np.argmax(xy[:,0]),0], regs_all[np.argmax(xy[:,0]),1], 'ko')
    axins.set(xlabel=r'$\psi_E^{(I)}$', ylabel=r'$\psi_E^{(c)}$')
    axins.axis([-0.05, 1.05, -0.05, 1.05])

    # set the limits of the plot to the limits of the data
    ax.set(xlabel=r"$I($"+val+r";$t_1)$", ylabel=r"$\mathbb{E}_{\sim t_1, b_I}[$"+stat_names[10]+r"$]$")

    i += 1
    
fig_b_I.suptitle(r'Pareto front over $(\psi_{N}^{(I)},\psi_{N}^{(c)},\psi_{cM}^{(I)},\psi_{cM}^{(c)}, \psi_{E}^{(I)}, \psi_{E}^{(c)})$'+' for '+infection_type+". infection")
fig_b_I.savefig(infection_type+'-pareto-over-all-antigenicity.pdf', dpi=300, bbox_inches="tight")
plt.tight_layout()

plt.show()

# %%
# plot pareto front for appropriateness and effectiveness of the immune response
fig_b_I = plt.figure(figsize=(12,12),dpi = 150)

i = 0

for val in stat_names[i+10:]:

    xy = np.array([np.nan_to_num(MI_data_no_zero[:,i+8], copy = False) ,np.nan_to_num(MI_data_no_zero[:,-1], copy = False)]).T
    
    # hull = ConvexHull(np.array([x_, y_]).T)
    
    ax = fig_b_I.add_subplot(4, 2, i+1)
    cs = ax.plot(xy[:,0], xy[:,1], 'ko')
    
    # find pareto front
    remove_row = np.ones(xy.shape[0], dtype = bool)
    
    for j in np.arange(len(xy[:,0])):
        for k in np.arange(len(xy[:,0])):
            if xy[j,0] < xy[k,0] and xy[j,1] > xy[k,1]:
                remove_row[j] = False
                
    
    x_front = (xy[:,0])[remove_row,...]
    y_front = (xy[:,1])[remove_row,...]
    ax.plot(x_front, y_front, 'ro')
    ax.axis([0.0, np.max(xy[:,0])*1.15, 0.95*np.min(xy[:,1]), np.max(xy[:,1])*1.15])
    # for k in np.arange(0,len(x_front)):
    #     ax.text(x_front[k],y_front[k], k, ha="center", va="center")
    
    # inset plot: these are in unitless percentages of the figure size. (0,0 is bottom left)
    axins = inset_axes(ax, width="25%", height="25%", loc=1, borderpad = 1)
    axins.plot(regs_all[remove_row,4], regs_all[remove_row,5], 'ro')
    axins.plot(regs_all[np.argmin(xy[:,1]),0], regs_all[np.argmin(xy[:,1]),1], 'bo')
    axins.plot(regs_all[np.argmax(xy[:,0]),0], regs_all[np.argmax(xy[:,0]),1], 'ko')
    axins.set(xlabel=r'$\psi_E^{(I)}$', ylabel=r'$\psi_E^{(c)}$')
    axins.axis([-0.05, 1.05, -0.05, 1.05])

    # set the limits of the plot to the limits of the data
    ax.set(xlabel=r"$I($"+val+r";$b_I)$", ylabel=r"$\mathbb{E}_{\sim t_1, b_I}[$"+stat_names[10]+r"$]$")

    i += 1
    
fig_b_I.suptitle(r'Pareto front over $(\psi_{N}^{(I)},\psi_{N}^{(c)},\psi_{cM}^{(I)},\psi_{cM}^{(c)}, \psi_{E}^{(I)}, \psi_{E}^{(c)})$'+' for '+infection_type+". infection")
fig_b_I.savefig(infection_type+'-pareto-over-all-virulence.pdf', dpi=300, bbox_inches="tight")
plt.tight_layout()

plt.show()

# %% [markdown]
# ### (6) Data visualization: Run PCA

# %%
from sklearn.decomposition import PCA
import seaborn as sns

pca = PCA(n_components = 3)
pca_result = pca.fit_transform(network_MI[:,:4])
print(pca.explained_variance_ratio_)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

img = ax.scatter(pca_result[:,0], pca_result[:,1], pca_result[:,2], c=network_MI[:,-1], cmap=plt.hot())
fig.colorbar(img)
plt.show()

# %%
import itertools

out = list(itertools.product(np.arange(0,3), repeat=2))

np.array(out)
