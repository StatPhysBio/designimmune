# %%
import numpy as np
import pandas as pd
import os

from tqdm import tqdm

# %%
d = '/mmfs1/home/oukogu/github/infoimmune/opt_nets/'

data = []

for f in tqdm(os.listdir(d)):
    filepath = os.path.join(d, f)
    data.append(np.load(filepath))
    
data = np.vstack(data)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 644/644 [00:00<00:00, 5618.45it/s]

# %%
data
# Out:
# array([[1.00000000e+00, 5.00000000e-01, 5.00000000e-01, ...,
#         9.89072296e+04, 4.54300334e+01, 1.31300147e+02],
#        [1.00000000e+00, 0.00000000e+00, 5.00000000e-01, ...,
#         9.14210363e+04, 4.46496571e+01, 1.34304751e+02],
#        [5.00000000e-01, 5.00000000e-01, 5.00000000e-01, ...,
#         9.78430873e+04, 4.51455214e+01, 1.36564129e+02],
#        ...,
#        [1.00000000e+00, 5.00000000e-01, 5.00000000e-01, ...,
#         9.50702614e+04, 4.56154267e+01, 1.30966877e+02],
#        [5.00000000e-01, 5.00000000e-01, 0.00000000e+00, ...,
#         9.47285944e+04, 4.45837649e+01, 1.30776406e+02],
#        [1.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         9.84416237e+04, 4.59824079e+01, 1.33800070e+02]])

# %%
data.shape
# Out:
# (644, 33)
