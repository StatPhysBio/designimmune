# %%
import numpy as np
from matplotlib.cm import get_cmap
import matplotlib.pyplot as plt
import matplotlib as mpl

import multiprocessing as mp
from tqdm import tqdm
from joblib import Parallel, delayed
from scipy import stats
import os
from stoch_sim_model import *
from optimize_nets import *
import seaborn as sns

# %%
# Set simulation parameters
N_0 = 100
K_IE = 1*(10**4)
d_I = 1*d_S
infection_type = "sec" #"prim", "sec"
sim_type = "agent" #"pop_ode", "agent"
reg = psi_opts[0]
np.random.seed(0)

# %%
import tracemalloc
tracemalloc.start()
lin_stoch_sim(N_0 = N_0, b_I = 0.25*b_I, 
                          K_IE = K_IE,
                          d_I = d_I,
                          K_IH = K_IH,
                          regulation_coeffs = reg,
                          infection = infection_type,
                          vir_model = "dep_harm",
                          out_data = "small") # Your function here.
current, peak_usage = tracemalloc.get_traced_memory()
tracemalloc.stop()
print(current / 1024**3, peak_usage / 1024**3)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 import tracemalloc
#       2 tracemalloc.start()
# ----> 3 lin_stoch_sim(N_0 = N_0, b_I = 0.25*b_I,
#       4                           K_IE = K_IE,
#       5                           d_I = d_I,
#       6                           K_IH = K_IH,
#       7                           regulation_coeffs = reg,
#       8                           infection = infection_type,
#       9                           vir_model = "dep_harm",
#      10                           out_data = "small") # Your function here.
#      11 current, peak_usage = tracemalloc.get_traced_memory()
#      12 tracemalloc.stop()
#
# File ~/infoimmune/stoch_sim_model.py:305, in lin_stoch_sim(S_0, I_0, b_I, d_S, d_I, d_IE, d_IH, K_IE, K_IH, K_SE, Aout_0, b_Ain, b_H, d_H, K_EI, K_EH, kappa, N_0, max_Na, b_myc, d_myc, myc_thresh, max_expand, char_times, regulation_coeffs, regulation_bias, alpha, infection, vir_model, duration, steps, out_data)
#     303 # (b) Effector cells divide, differentiate, die
#     304 die_E = np.random.binomial(E_m[i-1], d_E_die*dt)
# --> 305 div_E = np.random.binomial(E_m[i-1] - die_E, dt*(b_E_div))
#     306 diff_EM = np.random.binomial(E_m[i-1] - die_E + div_E, p_EM[i-1])
#     308 #### Update population dynamics: ####
#
# KeyboardInterrupt:
